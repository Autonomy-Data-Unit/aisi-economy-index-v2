# %% [markdown]
# # dev_utils
#
# Development utilities for working with pipeline node notebooks.

# %%
#|default_exp __init__

# %%
#|export
from dev_utils.utils import set_node_func_args, show_node_vars
