# %% [markdown]
# # Helpers

# %%
import json
import re
import random
import statistics
from pathlib import Path
from collections import Counter, defaultdict
from datetime import datetime

import numpy as np

# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------
_RUN_RE = re.compile(
    r"llama_drop_only_(?P<month>adzuna_month\d{2})_(?P<start>\d+)_(?P<stop>\d+)_job(?P<jobid>\d+)_task(?P<taskid>\d+)_\d{8}_\d{6}\.jsonl$"
)

IT_PATTERNS = [
    r"\bsoftware\b", r"\bdeveloper\b", r"\bengineer\b", r"\bdata\b", r"\bml\b", r"\bai\b",
    r"\bcloud\b", r"\bcyber\b", r"\bsecurity\b", r"\bnetwork\b", r"\bsystems?\b",
    r"\bdatabase\b", r"\bit\b", r"\bdevops\b"
]
_IT_RE = re.compile("|".join(IT_PATTERNS), flags=re.I)

def _is_it_role(title: str) -> bool:
    if not title:
        return False
    return bool(_IT_RE.search(title))


def _infer_npz_from_jsonl(jsonl_path: Path) -> Path:
    """
    NEW layout:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>/llama_drop_only_....jsonl
    NPZ sits at:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>.npz
    """
    m = _RUN_RE.search(jsonl_path.name)
    if not m:
        raise ValueError(f"JSONL filename doesn't match expected pattern: {jsonl_path.name}")

    month = m.group("month")
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    return embed_root / f"{month}.npz"


def _get_job_ids(z) -> np.ndarray:
    """
    Supports both schemas:
      new: job_ids
      old: job_id
    Returns np.ndarray[str]
    """
    if "job_ids" in z.files:
        return z["job_ids"].astype(str)
    if "job_id" in z.files:
        return z["job_id"].astype(str)
    raise KeyError(f"NPZ missing job id key. Need job_ids or job_id. Have={sorted(z.files)}")


def _load_npz_lookup(npz_path: Path):
    """
    Expects stage3-prep NPZ keys (canonical):
      job_ids (or job_id), job_ad_title, job_desc, job_tasks, domain, job_sector_category, job_description
    """
    with np.load(npz_path, allow_pickle=True) as z:
        job_ids = _get_job_ids(z)

        # canonical (your stage3-prep)
        job_ad_title = z["job_ad_title"]
        job_desc = z["job_desc"]
        job_tasks = z["job_tasks"]

        domain = z["domain"] if "domain" in z.files else None
        job_sector_category = z["job_sector_category"] if "job_sector_category" in z.files else None
        job_description = z["job_description"] if "job_description" in z.files else None

    lookup = {}
    for i, jid in enumerate(job_ids):
        lookup[jid] = {
            "job_ad_title": None if job_ad_title[i] is None else str(job_ad_title[i]),
            "job_desc": None if job_desc[i] is None else str(job_desc[i]),
            "job_tasks": None if job_tasks[i] is None else str(job_tasks[i]),
            "job_description": None if job_description is None or job_description[i] is None else str(job_description[i]),
            "domain": None if domain is None or domain[i] is None else str(domain[i]),
            "job_sector_category": None if job_sector_category is None or job_sector_category[i] is None else str(job_sector_category[i]),
        }
    return lookup


# ---------------------------------------------------------------------
# Main: report generator
# ---------------------------------------------------------------------
def gen_report(jsonl_path: str, *, npz_path: str | None = None, sample_n: int = 30, seed: int = 0):
    """
    jsonl_path: path to llama_drop_only_*.jsonl
    npz_path  : optional explicit context NPZ. If None, inferred from jsonl name/dir.
    """
    random.seed(seed)

    jsonl_path = Path(jsonl_path)
    if not jsonl_path.exists():
        raise FileNotFoundError(f"Missing JSONL: {jsonl_path}")

    inferred_npz = _infer_npz_from_jsonl(jsonl_path)
    npz_path = Path(npz_path) if npz_path else inferred_npz
    if not npz_path.exists():
        raise FileNotFoundError(f"Missing NPZ: {npz_path}")

    # report folder: put it under .../llm_negative_selection/<EMBED>/evaluation_reports/
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    report_dir = embed_root / "evaluation_reports"
    report_dir.mkdir(parents=True, exist_ok=True)

    print("JSONL:", jsonl_path)
    print("NPZ :", npz_path)
    print("OUT :", report_dir)

    lookup = _load_npz_lookup(npz_path)

    before_counts = []
    after_counts = []
    kept_titles = Counter()
    domain_kept = defaultdict(list)

    it_leak = 0
    total_kept = 0
    empty_outputs = 0

    samples = []
    seen_sample_ids = set()

    with jsonl_path.open("r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            try:
                r = json.loads(line)
            except Exception:
                continue

            jid = str(r.get("job_id", "")).strip()
            if not jid:
                continue

            ctx = lookup.get(jid, {})

            cand = r.get("candidates") or []
            final = r.get("final") or []

            before_counts.append(len(cand))
            after_counts.append(len(final))

            if len(final) == 0:
                empty_outputs += 1

            for t in final:
                kept_titles[t] += 1
                total_kept += 1
                if _is_it_role(t):
                    it_leak += 1

            dom = ctx.get("domain") or "UNKNOWN"
            domain_kept[dom].append(len(final))

            # sample gate
            if len(samples) < sample_n and jid not in seen_sample_ids and random.random() < 0.05:
                seen_sample_ids.add(jid)
                samples.append({
                    "job_id": jid,
                    "job_ad_title": ctx.get("job_ad_title"),
                    "domain": ctx.get("domain"),
                    "sector": ctx.get("job_sector_category"),
                    "job_desc": ctx.get("job_desc"),
                    "kept": final,
                    "dropped": r.get("drop") or [],
                })

    if not before_counts:
        raise RuntimeError("No valid rows parsed from JSONL.")

    before_avg = statistics.mean(before_counts)
    after_avg = statistics.mean(after_counts)
    drop_rate = 1.0 - (after_avg / before_avg if before_avg else 0.0)
    it_share = it_leak / max(total_kept, 1)

    metrics = {
        "jobs": len(before_counts),
        "avg_candidates_before": round(before_avg, 3),
        "avg_candidates_after": round(after_avg, 3),
        "drop_rate": round(drop_rate, 4),
        "empty_outputs_percent": round(100.0 * empty_outputs / len(before_counts), 3),
        "it_leakage_share": round(it_share, 4),
        "min_kept": int(min(after_counts)),
        "max_kept": int(max(after_counts)),
    }

    domain_summary = {d: round(statistics.mean(v), 3) for d, v in domain_kept.items()}

    report = {
        "run": {
            "jsonl": str(jsonl_path),
            "npz": str(npz_path),
            "generated_at": datetime.now().isoformat(timespec="seconds"),
        },
        "global_metrics": metrics,
        "top_kept_roles": kept_titles.most_common(25),
        "domain_summary_avg_kept": dict(sorted(domain_summary.items(), key=lambda x: (-x[1], x[0]))),
        "sample_cases": samples,
    }

    base = jsonl_path.stem
    report_json = report_dir / f"{base}_report.json"
    report_txt = report_dir / f"{base}_report.txt"

    with report_json.open("w", encoding="utf-8") as f:
        json.dump(report, f, indent=2, ensure_ascii=False)

    with report_txt.open("w", encoding="utf-8") as f:
        f.write("=== GLOBAL METRICS ===\n")
        for k, v in metrics.items():
            f.write(f"{k}: {v}\n")

        f.write("\n=== TOP KEPT OCCUPATIONS ===\n")
        for title, cnt in kept_titles.most_common(25):
            f.write(f"{cnt}  {title}\n")

        f.write("\n=== DOMAIN AVG KEPT ===\n")
        for d, v in sorted(domain_summary.items(), key=lambda x: (-x[1], x[0])):
            f.write(f"{d}: {v}\n")

        f.write("\n=== SAMPLE CASES (truncated) ===\n")
        for s in samples[:10]:
            f.write(f"\njob_id: {s['job_id']}\n")
            f.write(f"title:  {s.get('job_ad_title')}\n")
            f.write(f"domain: {s.get('domain')} | sector: {s.get('sector')}\n")
            f.write(f"kept:   {s.get('kept')}\n")
            f.write(f"drop:   {s.get('dropped')}\n")

    print("\nSaved:")
    print(" ", report_json)
    print(" ", report_txt)

    return report_json, report_txt

# %% [markdown]
# # Prompt 1 - RUTHLESS- Embeddings weight 0.6 tasks e 0.4 roles;

# %%
# ===== Prompt printer: EXACT wiring check (single row) =====

import numpy as np
from pathlib import Path

# ---- CONFIG ----
NPZ_PATH = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz")
ROW_IDX = 35  # Change this to inspect different samples

# ---- LOAD ----
data = np.load(NPZ_PATH, allow_pickle=True)

# Map keys
job_ad_titles = data["job_ad_title"]
job_tasks_arr = data["job_tasks"]
domains = data["domain"]
job_descs = data["job_desc"]
job_sector_categories = data["job_sector_category"]
job_full_ads = data["job_description"]
candidates_matrix = data["titles"]  # 2D array [N, K]

# ---- EXTRACT ROW ----
title = job_ad_titles[ROW_IDX]
domain = domains[ROW_IDX]
tasks = job_tasks_arr[ROW_IDX]
desc = job_descs[ROW_IDX]
category = job_sector_categories[ROW_IDX]
full_excerpt = job_full_ads[ROW_IDX]
row_candidates = candidates_matrix[ROW_IDX]

# Clean up tasks
if isinstance(tasks, (list, np.ndarray)):
    tasks_str = ", ".join([str(t) for t in tasks if t])
else:
    tasks_str = str(tasks)

# Format candidates as a 1-based numbered list
numbered_candidates = "\n".join([f"{i+1}) {cand}" for i, cand in enumerate(row_candidates) if cand])

# ---- BUILD PROMPT (verbatim logic) ----

full_block = (
    f"\nFULL AD EXCERPT (use only for concrete duties, tools, licences, ignore fluff):\n{str(full_excerpt)[:700]}\n"
    if full_excerpt else ""
)

prompt = f"""You are a Ruthless Occupation Auditor. Your success depends on ELIMINATING noise.
Your goal is to REJECT as many candidates as possible. Only an EXACT functional match survives.

Read the job context carefully.

JOB CONTEXT (priority order):
1) Job Title + Job Domain (primary anchor)
2) Job Tasks (evidence)
3) Job short description (evidence)
4) Job Category (weak evidence)
5) Raw job ad excerpt (noisy evidence)

Title: {title}
Job list of Tasks/Skills: {tasks_str}
Job Domain: {domain}
Job short description: {desc}
Job Category: {category}
{full_block}

RE-READ ANCHOR JOB CONTEXT:
Title: {title}
Domain: {domain}
Tasks/Skills: {tasks_str}

CANDIDATES (1-based)
{numbered_candidates}

STRICT AUDIT RULES:

1) THE "PROVE IT" DOCTRINE:
Assume the candidate is WRONG. You must find 2+ concrete keywords in the Tasks or Title to "rescue" it. If it is only "loosely related," you MUST DROP IT.

2) IT KILL SWITCH:
If Domain is NOT IT, you are FORBIDDEN from keeping Software/Data/IT roles. 
"Using a computer" or "Software literacy" is NOT a reason to keep an IT role. DROP THEM.

3) NO PARENT CATEGORIES:
If 'General Manager' and 'Food Service Manager' are both present for a restaurant job, you MUST DROP 'General Manager'. Keep only the most specific child.

4) SHARED NOUN TRAP:
Do not match on words like "Engineer" or "Analyst" alone. Match on the WORK performed (e.g., 'Mechanical' vs 'Software').

5) THE AGGRESSIVE BUDGET (1-2):
You are strictly limited. Aim to keep ONLY 1 candidate. 
Keeping 3 is a failure of selectivity. Keeping 4+ is a total system failure.

6) NEVER DROP THE ANCHOR:
Identify the one candidate that is the literal mirror of the Job Title. Keep it. Drop everything else.

OUTPUT FORMAT:
Return ONLY valid JSON. Every candidate you keep that isn't perfect makes you fail this audit.

Example for a list of 10 where only index 1 was correct:
{{"drop":[2,3,4,5,6,7,8,9,10]}}

REMEMBER ANCHOR JOB CONTEXT:
Title: {title}
Tasks/Skills: {tasks_str}
Domain: {domain}

CRITICAL: Every candidate you keep that is NOT an exact functional match will be considered a failure in this audit. If a candidate is a 'maybe,' you MUST drop it.

AUDIT VERDICT:
Return ONLY JSON:
{{"drop":[2,3,4,5,6,7,8,9,10]}}
""".strip()

# ---- PRINT ----
print("-" * 30)
print(f"VERIFIED MAXIMUM AGGRESSION PROMPT (ROW {ROW_IDX}):")
print("-" * 30)
print(prompt)
print("-" * 30)
# Out:
# ------------------------------
# VERIFIED MAXIMUM AGGRESSION PROMPT (ROW 35):
# ------------------------------
# You are a Ruthless Occupation Auditor. Your success depends on ELIMINATING noise.
# Your goal is to REJECT as many candidates as possible. Only an EXACT functional match survives.
#
# Read the job context carefully.
#
# JOB CONTEXT (priority order):
# 1) Job Title + Job Domain (primary anchor)
# 2) Job Tasks (evidence)
# 3) Job short description (evidence)
# 4) Job Category (weak evidence)
# 5) Raw job ad excerpt (noisy evidence)
#
# Title: Sommelier-Restaurant Gordon Ramsay
# Job list of Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
# Job Domain: Hospitality & Catering
# Job short description: [Hospitality & Catering] Sommelier for a Three Michelin Star restaurant
# Job Category: Hospitality & Catering Jobs
#
# FULL AD EXCERPT (use only for concrete duties, tools, licences, ignore fluff):
# Sommelier - Restaurant Gordon Ramsay, Three Michelin Star We are looking for an experienced Sommelier who has a real passion for delivering the highest levels of service and creating a fantastic dining experience for our guests. Restaurant Gordon Ramsay combines contemporary elegance, an intimate ambience and unparalleled service, all the hallmarks of true excellence. Each dish, beautifully presented, uses the best ingredients and sublime flavour combinations, demonstrating the outstanding technical skill of Chef Matt Abe and his team. The restaurant boasts twenty years of holding three Michelin stars and is now London’s longest running restaurant to hold this accolade. As Sommelier you will
#
#
# RE-READ ANCHOR JOB CONTEXT:
# Title: Sommelier-Restaurant Gordon Ramsay
# Domain: Hospitality & Catering
# Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
#
# CANDIDATES (1-based)
# 1) Waiters and Waitresses
# 2) Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 3) Food Service Managers
# 4) Dining Room and Cafeteria Attendants and Bartender Helpers
# 5) Chefs and Head Cooks
# 6) Bartenders
#
# STRICT AUDIT RULES:
#
# 1) THE "PROVE IT" DOCTRINE:
# Assume the candidate is WRONG. You must find 2+ concrete keywords in the Tasks or Title to "rescue" it. If it is only "loosely related," you MUST DROP IT.
#
# 2) IT KILL SWITCH:
# If Domain is NOT IT, you are FORBIDDEN from keeping Software/Data/IT roles.
# "Using a computer" or "Software literacy" is NOT a reason to keep an IT role. DROP THEM.
#
# 3) NO PARENT CATEGORIES:
# If 'General Manager' and 'Food Service Manager' are both present for a restaurant job, you MUST DROP 'General Manager'. Keep only the most specific child.
#
# 4) SHARED NOUN TRAP:
# Do not match on words like "Engineer" or "Analyst" alone. Match on the WORK performed (e.g., 'Mechanical' vs 'Software').
#
# 5) THE AGGRESSIVE BUDGET (1-2):
# You are strictly limited. Aim to keep ONLY 1 candidate.
# Keeping 3 is a failure of selectivity. Keeping 4+ is a total system failure.
#
# 6) NEVER DROP THE ANCHOR:
# Identify the one candidate that is the literal mirror of the Job Title. Keep it. Drop everything else.
#
# OUTPUT FORMAT:
# Return ONLY valid JSON. Every candidate you keep that isn't perfect makes you fail this audit.
#
# Example for a list of 10 where only index 1 was correct:
# {"drop":[2,3,4,5,6,7,8,9,10]}
#
# REMEMBER ANCHOR JOB CONTEXT:
# Title: Sommelier-Restaurant Gordon Ramsay
# Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
# Domain: Hospitality & Catering
#
# CRITICAL: Every candidate you keep that is NOT an exact functional match will be considered a failure in this audit. If a candidate is a 'maybe,' you MUST drop it.
#
# AUDIT VERDICT:
# Return ONLY JSON:
# {"drop":[2,3,4,5,6,7,8,9,10]}
# ------------------------------

# %% [markdown]
# # bge

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_bge.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
# Out:
# JOBID: 2151812

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()

while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:25    5:57:35     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:30    5:57:30     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:35    5:57:25     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:40    5:57:20     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:45    5:57:15     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:50    5:57:10     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:55    5:57:05     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       3:02    5:56:58     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       3:07    5:56:53     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       3:12    5:56:48     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       3:17    5:56:43     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151812 autonomyluiz     workq z_llama_drop_new_test_bg CG    6:00:00       3:22    5:56:38     1 nid010564
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151812_task0_20260205_053358.jsonl
# Allocated: 14.9913330078125 GB
# Reserved: 67.85546875 GB
# [END] 2026-02-05 05:37:11
# [RUNTIME] 3.22 minutes (193.0 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.40s/it]
# Batches:  25%|██▌       | 2/8 [01:06<03:16, 32.73s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:50, 34.14s/it]
# Batches:  50%|█████     | 4/8 [01:56<01:44, 26.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:10<01:05, 21.86s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.28s/it]
# Batches:  88%|████████▊ | 7/8 [02:38<00:17, 17.50s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 22.21s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 23.84s/it]
# [W205 05:37:12.175786769 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151812_task0_20260205_053358.jsonl
# Allocated: 14.9913330078125 GB
# Reserved: 67.85546875 GB
# [END] 2026-02-05 05:37:11
# [RUNTIME] 3.22 minutes (193.0 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.40s/it]
# Batches:  25%|██▌       | 2/8 [01:06<03:16, 32.73s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:50, 34.14s/it]
# Batches:  50%|█████     | 4/8 [01:56<01:44, 26.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:10<01:05, 21.86s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.28s/it]
# Batches:  88%|████████▊ | 7/8 [02:38<00:17, 17.50s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 22.21s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 23.84s/it]
# [W205 05:37:12.175786769 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151812_task0_20260205_053358.jsonl
# Allocated: 14.9913330078125 GB
# Reserved: 67.85546875 GB
# [END] 2026-02-05 05:37:11
# [RUNTIME] 3.22 minutes (193.0 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.40s/it]
# Batches:  25%|██▌       | 2/8 [01:06<03:16, 32.73s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:50, 34.14s/it]
# Batches:  50%|█████     | 4/8 [01:56<01:44, 26.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:10<01:05, 21.86s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.28s/it]
# Batches:  88%|████████▊ | 7/8 [02:38<00:17, 17.50s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 22.21s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 23.84s/it]
# [W205 05:37:12.175786769 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151812_task0_20260205_053358.jsonl
# Allocated: 14.9913330078125 GB
# Reserved: 67.85546875 GB
# [END] 2026-02-05 05:37:11
# [RUNTIME] 3.22 minutes (193.0 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.51it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.74it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.08it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.47it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.21it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.40s/it]
# Batches:  25%|██▌       | 2/8 [01:06<03:16, 32.73s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:50, 34.14s/it]
# Batches:  50%|█████     | 4/8 [01:56<01:44, 26.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:10<01:05, 21.86s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.28s/it]
# Batches:  88%|████████▊ | 7/8 [02:38<00:17, 17.50s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 22.21s/it]
# Batches: 100%|██████████| 8/8 [03:10<00:00, 23.84s/it]
# [W205 05:37:12.175786769 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 10
#       8 while True:
#       9     print("\n=== squeue ===")
# ---> 10     sq = sh(f"squeue -j {jobid}")
#      11     print(sq if sq else "<finished>")
#      13     out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
#
# Cell In[68], line 6, in sh(cmd)
#       5 def sh(cmd):
# ----> 6     return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
#
# File /opt/cray/pe/python/3.11.7/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/cray/pe/python/3.11.7/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/cray/pe/python/3.11.7/lib/python3.11/subprocess.py:2108, in Popen._communicate(self, input, endtime, orig_timeout)
#    2101     self._check_timeout(endtime, orig_timeout,
#    2102                         stdout, stderr,
#    2103                         skip_check_and_raise=True)
#    2104     raise RuntimeError(  # Impossible :)
#    2105         '_check_timeout(..., skip_check_and_raise=True) '
#    2106         'failed to raise TimeoutExpired.')
# -> 2108 ready = selector.select(timeout)
#    2109 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2111 # XXX Rewrite these to use non-blocking I/O on the file
#    2112 # objects; they are no longer using C stdio!
#
# File /opt/cray/pe/python/3.11.7/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
#gen_report("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151812_task0_20260205_053358.jsonl")

#from pathlib import Path
p = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/")
latest = max(p.glob("llama_drop_only_adzuna_month01_0_1000_job2151812_task0_20260205_053358_report.txt"), key=lambda x: x.stat().st_mtime)
print(latest.read_text())
# Out:
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.221
# avg_candidates_after: 1.344
# drop_rate: 0.8365
# empty_outputs_percent: 0.0
# it_leakage_share: 0.064
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 30  Personal Care Aides
# 27  Information Technology Project Managers
# 24  Software Developers
# 22  Sales Managers
# 21  Customer Service Representatives
# 19  Financial Managers
# 17  Helpers--Installation, Maintenance, and Repair Workers
# 16  Marketing Managers
# 16  First-Line Supervisors of Retail Sales Workers
# 15  Medical and Health Services Managers
# 15  Advertising and Promotions Managers
# 14  Childcare Workers
# 14  Chefs and Head Cooks
# 14  Social and Human Service Assistants
# 14  Web Developers
# 13  Maids and Housekeeping Cleaners
# 13  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 13  Healthcare Social Workers
# 13  Construction Managers
# 13  Bookkeeping, Accounting, and Auditing Clerks
# 12  Market Research Analysts and Marketing Specialists
# 12  Mental Health and Substance Abuse Social Workers
# 12  Advertising Sales Agents
# 12  Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 11  Software Quality Assurance Analysts and Testers
#
# === DOMAIN AVG KEPT ===
# Agriculture/Rural: 3
# Domestic Help & Cleaning: 3
# Domestic Services: 3
# Electronics Technology: 3
# Environmental Science: 3
# Health & Social Care: 3
# Healthcare Administration: 3
# Higher Education: 3
# IT and Consulting: 3
# IT/Software Development: 3
# Media: 3
# Online Surveys/Admin Jobs: 3
# Technology/Software: 3
# Public Relations: 2.5
# Admin Jobs: 2.2
# Finance: 2.143
# Agriculture: 2
# Construction/Engineering: 2
# Domestic help & Cleaning Jobs: 2
# Farming/Agribusiness: 2
# Fintech: 2
# Logistics & Transportation: 2
# Non-Profit: 2
# Renewable Energy: 2
# Scientific & QA Jobs: 2
# Legal: 1.889
# Social Work: 1.857
# Software Development: 1.857
# Market Research: 1.8
# Administration: 1.667
# Digital Marketing: 1.667
# Health and Fitness: 1.667
# Hospitality: 1.667
# Insurance: 1.667
# Recruitment: 1.667
# Sales: 1.643
# Construction: 1.625
# Domestic help & Cleaning: 1.5
# Financial Services: 1.5
# Healthcare/Social Work: 1.5
# Marketing/PR: 1.5
# Education: 1.474
# Accounting & Finance: 1.458
# Trade & Construction: 1.417
# Facilities Management: 1.4
# Transportation: 1.4
# IT: 1.369
# Customer Services: 1.333
# Technology: 1.333
# Engineering: 1.324
# Automotive: 1.308
# Logistics: 1.308
# Real Estate: 1.286
# Social work: 1.267
# HR & Recruitment: 1.25
# Human Resources: 1.25
# Retail: 1.222
# Healthcare & Nursing: 1.22
# Manufacturing: 1.211
# Healthcare: 1.204
# Sales and Marketing: 1.143
# Hospitality & Catering: 1.095
# Logistics & Warehouse: 1.07
# Administration/Office Support: 1
# Administrative/Office: 1
# Advertising and Marketing: 1
# Aerospace: 1
# Aerospace & Manufacturing: 1
# Automotive Retail: 1
# Beauty and Cosmetics: 1
# Biotechnology: 1
# Biotechnology/Pharmaceutical: 1
# Construction and Engineering: 1
# Construction and Infrastructure: 1
# Construction and Maintenance: 1
# Construction and Property: 1
# Construction/Property Maintenance: 1
# Construction/Rail: 1
# Construction/Real Estate: 1
# Consultancy: 1
# Consultancy Jobs: 1
# Consulting: 1
# Creative & Design: 1
# Customer Service: 1
# Cybersecurity: 1
# Data and Intelligence consultancy: 1
# Digital Media: 1
# Digital/Technology: 1
# Education Technology: 1
# Education and Training: 1
# Education/Training: 1
# Electrical Engineering: 1
# Energy: 1
# Energy Trading: 1
# Energy and Utilities: 1
# Engineering/Manufacturing: 1
# Estate Agency: 1
# Executive Search Firm: 1
# Fashion: 1
# Fashion Retail: 1
# Finance/Banking: 1
# Food Industry: 1
# Food Service: 1
# Food Service/Hospitality: 1
# Food and Beverage: 1
# Government: 1
# Health and Social Care: 1
# Healthcare & Nursing Jobs: 1
# Healthcare Advertising: 1
# Healthcare/Hospitality: 1
# Healthcare/Pharmaceutical: 1
# Healthcare/Social Care: 1
# Home Accessories Manufacturing: 1
# IT Jobs: 1
# IT and Technology: 1
# IT and Telecommunications: 1
# IT, Fintech, Blockchain, AI: 1
# Law: 1
# Leisure: 1
# Leisure and Fitness: 1
# Logistics and Supply Chain: 1
# Logistics and Transportation: 1
# Logistics/Transportation: 1
# Manufacturing and Engineering: 1
# Manufacturing/Engineering: 1
# Manufacturing/Industrial: 1
# Manufacturing/Production: 1
# Marketing: 1
# Marketing and Public Relations: 1
# Media and Advertising: 1
# Media and Communications: 1
# Media and Entertainment: 1
# Military/Defence: 1
# Non-Profit/Charity: 1
# Non-Profit/NGO: 1
# Non-profit/Charity: 1
# Nuclear Engineering: 1
# Other/General Jobs: 1
# PR: 1
# PR and Communications: 1
# Pharmaceutical: 1
# Property: 1
# Public Administration: 1
# Public Health: 1
# Public Sector/ Law Enforcement: 1
# Publishing: 1
# Real Estate/Property Management: 1
# Recruitment Consultancy: 1
# Recruitment/Consultancy: 1
# Remote Work/Online Opportunities: 1
# Renewable Energy/Electric Vehicle: 1
# Renewables: 1
# Research and Market Analysis: 1
# Retail Marketing: 1
# Retail/Food Industry: 1
# SaaS: 1
# Sales Jobs: 1
# Sales and Business Development: 1
# Sales and Customer Service: 1
# Sales and Events: 1
# Sales and Recruitment: 1
# Scientific & QA: 1
# Security: 1
# Security and Customer Service: 1
# Security and Law Enforcement: 1
# Security and Surveillance: 1
# Social Housing: 1
# Social Services/Social Work: 1
# Software Engineering: 1
# Sports/Leisure: 1
# Technology & Engineering: 1
# Telecommunications: 1
# Tourism/Hospitality: 1
# Trade and Construction: 1
# Translation and Interpreting: 1
# Transportation/Fleet Management: 1
# Transportation/Logistics: 1
# Travel and Tourism: 1
# Utilities: 1
# Utility: 1
# Waste Management: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Waiters and Waitresses']
# drop:   ['Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Food Service Managers', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Chefs and Head Cooks', 'Bartenders']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer']
# drop:   ['Microsystems Engineers', 'Electrical and Electronics Drafters', 'Electrical and Electronic Engineering Technologists and Technicians', 'Electrical and Electronics Repairers, Commercial and Industrial Equipment', 'Manufacturing Engineers', 'Nanosystems Engineers', 'Electrical Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Solar Photovoltaic Installers']
# drop:   ['Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Power-Line Installers and Repairers', 'Helpers--Electricians', 'Solar Sales Representatives and Assessors', 'Solar Energy Installation Managers', 'Solar Thermal Installers and Technicians', 'Electrical and Electronics Repairers, Powerhouse, Substation, and Relay']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Telephone Operators', 'Loan Interviewers and Clerks']
# drop:   ['Telemarketers', 'Human Resources Assistants, Except Payroll and Timekeeping', 'Receptionists and Information Clerks', 'New Accounts Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers', 'Child, Family, and School Social Workers']
# drop:   ['Personal Care Aides', 'Childcare Workers', 'Social and Human Service Assistants', 'Occupational Therapists']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Biological Technicians']
# drop:   ['Biochemists and Biophysicists', 'Bioengineers and Biomedical Engineers', 'Natural Sciences Managers', 'Chemical Technicians', 'Biofuels/Biodiesel Technology and Product Development Managers', 'Bioinformatics Technicians', 'Bioinformatics Scientists', 'Agricultural Technicians']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Robotics Engineers']
# drop:   ['Automotive Engineers', 'Software Developers', 'Photonics Engineers', 'Human Factors Engineers and Ergonomists', 'Telecommunications Engineering Specialists', 'Wind Energy Engineers', 'Talent Directors', 'Media Programming Directors', 'Web Developers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['First-Line Supervisors of Material-Moving Machine and Vehicle Operators']
# drop:   ['Industrial Truck and Tractor Operators', 'Heavy and Tractor-Trailer Truck Drivers', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Crane and Tower Operators', 'Driver/Sales Workers', 'Light Truck Drivers', 'Bus Drivers, Transit and Intercity', 'Cargo and Freight Agents']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers']
# drop:   ['Social and Community Service Managers', 'Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers', 'Recreation Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Rehabilitation Counselors', 'Compensation and Benefits Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mobile Heavy Equipment Mechanics, Except Engines']
# drop:   ['Outdoor Power Equipment and Other Small Engine Mechanics', 'Mechanical Engineering Technologists and Technicians', 'Bus and Truck Mechanics and Diesel Engine Specialists', 'Medical Equipment Repairers', 'Aircraft Mechanics and Service Technicians', 'Locomotive Engineers', 'Mechanical Engineers', 'Aerospace Engineers', 'Civil Engineers']

# %% [markdown]
# ### e5

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_e5.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
# Out:
# JOBID: 2151813

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")

def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()

while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl
# Allocated: 14.991302967071533 GB
# Reserved: 68.349609375 GB
# [END] 2026-02-05 05:41:00
# [RUNTIME] 3.27 minutes (196.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.01it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.34s/it]
# Batches:  25%|██▌       | 2/8 [01:10<03:30, 35.02s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.20s/it]
# Batches:  62%|██████▎   | 5/8 [02:14<01:07, 22.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:27<00:39, 19.60s/it]
# Batches:  88%|████████▊ | 7/8 [02:41<00:17, 17.81s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 22.32s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 24.24s/it]
# [W205 05:41:01.198442790 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl
# Allocated: 14.991302967071533 GB
# Reserved: 68.349609375 GB
# [END] 2026-02-05 05:41:00
# [RUNTIME] 3.27 minutes (196.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.01it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.34s/it]
# Batches:  25%|██▌       | 2/8 [01:10<03:30, 35.02s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.20s/it]
# Batches:  62%|██████▎   | 5/8 [02:14<01:07, 22.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:27<00:39, 19.60s/it]
# Batches:  88%|████████▊ | 7/8 [02:41<00:17, 17.81s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 22.32s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 24.24s/it]
# [W205 05:41:01.198442790 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl
# Allocated: 14.991302967071533 GB
# Reserved: 68.349609375 GB
# [END] 2026-02-05 05:41:00
# [RUNTIME] 3.27 minutes (196.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.01it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.34s/it]
# Batches:  25%|██▌       | 2/8 [01:10<03:30, 35.02s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.20s/it]
# Batches:  62%|██████▎   | 5/8 [02:14<01:07, 22.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:27<00:39, 19.60s/it]
# Batches:  88%|████████▊ | 7/8 [02:41<00:17, 17.81s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 22.32s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 24.24s/it]
# [W205 05:41:01.198442790 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl
# Allocated: 14.991302967071533 GB
# Reserved: 68.349609375 GB
# [END] 2026-02-05 05:41:00
# [RUNTIME] 3.27 minutes (196.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.01it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.34s/it]
# Batches:  25%|██▌       | 2/8 [01:10<03:30, 35.02s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.20s/it]
# Batches:  62%|██████▎   | 5/8 [02:14<01:07, 22.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:27<00:39, 19.60s/it]
# Batches:  88%|████████▊ | 7/8 [02:41<00:17, 17.81s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 22.32s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 24.24s/it]
# [W205 05:41:01.198442790 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl
# Allocated: 14.991302967071533 GB
# Reserved: 68.349609375 GB
# [END] 2026-02-05 05:41:00
# [RUNTIME] 3.27 minutes (196.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.01it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.34s/it]
# Batches:  25%|██▌       | 2/8 [01:10<03:30, 35.02s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.20s/it]
# Batches:  62%|██████▎   | 5/8 [02:14<01:07, 22.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:27<00:39, 19.60s/it]
# Batches:  88%|████████▊ | 7/8 [02:41<00:17, 17.81s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 22.32s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 24.24s/it]
# [W205 05:41:01.198442790 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl
# Allocated: 14.991302967071533 GB
# Reserved: 68.349609375 GB
# [END] 2026-02-05 05:41:00
# [RUNTIME] 3.27 minutes (196.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.01it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.34s/it]
# Batches:  25%|██▌       | 2/8 [01:10<03:30, 35.02s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.20s/it]
# Batches:  62%|██████▎   | 5/8 [02:14<01:07, 22.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:27<00:39, 19.60s/it]
# Batches:  88%|████████▊ | 7/8 [02:41<00:17, 17.81s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 22.32s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 24.24s/it]
# [W205 05:41:01.198442790 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl
# Allocated: 14.991302967071533 GB
# Reserved: 68.349609375 GB
# [END] 2026-02-05 05:41:00
# [RUNTIME] 3.27 minutes (196.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.01it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.98it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:07, 35.34s/it]
# Batches:  25%|██▌       | 2/8 [01:10<03:30, 35.02s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.20s/it]
# Batches:  62%|██████▎   | 5/8 [02:14<01:07, 22.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:27<00:39, 19.60s/it]
# Batches:  88%|████████▊ | 7/8 [02:41<00:17, 17.81s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 22.32s/it]
# Batches: 100%|██████████| 8/8 [03:13<00:00, 24.24s/it]
# [W205 05:41:01.198442790 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 28
#      25 if not sq:
#      26     break
# ---> 28 time.sleep(5)
#
# KeyboardInterrupt:

# %%
#gen_report("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl")

from pathlib import Path
p = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/")
latest = max(p.glob("llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744_report.json"), key=lambda x: x.stat().st_mtime)
print(latest.read_text())
# Out:
# {
#   "run": {
#     "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl",
#     "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz",
#     "generated_at": "2026-02-05T05:43:10"
#   },
#   "global_metrics": {
#     "jobs": 1000,
#     "avg_candidates_before": 8.618,
#     "avg_candidates_after": 1.329,
#     "drop_rate": 0.8458,
#     "empty_outputs_percent": 0.0,
#     "it_leakage_share": 0.0662,
#     "min_kept": 1,
#     "max_kept": 3
#   },
#   "top_kept_roles": [
#     [
#       "Accountants and Auditors",
#       28
#     ],
#     [
#       "Healthcare Social Workers",
#       26
#     ],
#     [
#       "Software Developers",
#       25
#     ],
#     [
#       "Software Quality Assurance Analysts and Testers",
#       22
#     ],
#     [
#       "Customer Service Representatives",
#       20
#     ],
#     [
#       "Sales Managers",
#       20
#     ],
#     [
#       "Financial Managers",
#       19
#     ],
#     [
#       "Nursing Assistants",
#       18
#     ],
#     [
#       "Cooks, Restaurant",
#       17
#     ],
#     [
#       "Treasurers and Controllers",
#       17
#     ],
#     [
#       "Transportation, Storage, and Distribution Managers",
#       17
#     ],
#     [
#       "Critical Care Nurses",
#       16
#     ],
#     [
#       "Childcare Workers",
#       16
#     ],
#     [
#       "Packers and Packagers, Hand",
#       16
#     ],
#     [
#       "Retail Salespersons",
#       15
#     ],
#     [
#       "Information Technology Project Managers",
#       15
#     ],
#     [
#       "Automotive Service Technicians and Mechanics",
#       14
#     ],
#     [
#       "Human Resources Specialists",
#       14
#     ],
#     [
#       "Marketing Managers",
#       13
#     ],
#     [
#       "Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products",
#       13
#     ],
#     [
#       "Maintenance Workers, Machinery",
#       13
#     ],
#     [
#       "Advertising and Promotions Managers",
#       12
#     ],
#     [
#       "Heating, Air Conditioning, and Refrigeration Mechanics and Installers",
#       12
#     ],
#     [
#       "Bookkeeping, Accounting, and Auditing Clerks",
#       12
#     ],
#     [
#       "Maids and Housekeeping Cleaners",
#       11
#     ]
#   ],
#   "domain_summary_avg_kept": {
#     "Agriculture/Rural": 3,
#     "Domestic Help & Cleaning": 3,
#     "Domestic Services": 3,
#     "Environmental Science": 3,
#     "Food and Beverage": 3,
#     "Health & Social Care": 3,
#     "Healthcare Administration": 3,
#     "Higher Education": 3,
#     "IT/Software Development": 3,
#     "Logistics and Supply Chain": 3,
#     "Media": 3,
#     "Online Surveys/Admin Jobs": 3,
#     "Publishing": 3,
#     "Technology/Software": 3,
#     "Admin Jobs": 2.6,
#     "Marketing and Public Relations": 2.5,
#     "Public Relations": 2.5,
#     "Agriculture": 2,
#     "Domestic help & Cleaning Jobs": 2,
#     "Logistics & Transportation": 2,
#     "Renewable Energy": 2,
#     "Security": 2,
#     "Hospitality": 1.667,
#     "Insurance": 1.667,
#     "Legal": 1.667,
#     "PR": 1.667,
#     "Public Administration": 1.667,
#     "Recruitment": 1.667,
#     "Sales": 1.643,
#     "Human Resources": 1.625,
#     "Finance": 1.571,
#     "Consulting": 1.5,
#     "Domestic help & Cleaning": 1.5,
#     "Financial Services": 1.5,
#     "Healthcare/Social Work": 1.5,
#     "Law": 1.5,
#     "Marketing/PR": 1.5,
#     "Automotive": 1.462,
#     "Accounting & Finance": 1.441,
#     "Construction": 1.438,
#     "Education": 1.434,
#     "Trade & Construction": 1.417,
#     "Consultancy": 1.4,
#     "Market Research": 1.4,
#     "Social work": 1.4,
#     "IT": 1.357,
#     "Administration": 1.333,
#     "Energy": 1.333,
#     "Technology": 1.333,
#     "Engineering": 1.324,
#     "Healthcare & Nursing": 1.317,
#     "Real Estate": 1.286,
#     "Sales and Marketing": 1.286,
#     "Social Work": 1.286,
#     "Software Development": 1.286,
#     "Healthcare": 1.265,
#     "HR & Recruitment": 1.25,
#     "Customer Services": 1.167,
#     "Manufacturing": 1.158,
#     "Logistics": 1.154,
#     "Retail": 1.139,
#     "Logistics & Warehouse": 1.093,
#     "Hospitality & Catering": 1.048,
#     "Administration/Office Support": 1,
#     "Administrative/Office": 1,
#     "Advertising and Marketing": 1,
#     "Aerospace": 1,
#     "Aerospace & Manufacturing": 1,
#     "Automotive Retail": 1,
#     "Beauty and Cosmetics": 1,
#     "Biotechnology": 1,
#     "Biotechnology/Pharmaceutical": 1,
#     "Construction and Engineering": 1,
#     "Construction and Infrastructure": 1,
#     "Construction and Maintenance": 1,
#     "Construction and Property": 1,
#     "Construction/Engineering": 1,
#     "Construction/Property Maintenance": 1,
#     "Construction/Rail": 1,
#     "Construction/Real Estate": 1,
#     "Consultancy Jobs": 1,
#     "Creative & Design": 1,
#     "Customer Service": 1,
#     "Cybersecurity": 1,
#     "Data and Intelligence consultancy": 1,
#     "Digital Marketing": 1,
#     "Digital Media": 1,
#     "Digital/Technology": 1,
#     "Education Technology": 1,
#     "Education and Training": 1,
#     "Education/Training": 1,
#     "Electrical Engineering": 1,
#     "Electronics Technology": 1,
#     "Energy Trading": 1,
#     "Energy and Utilities": 1,
#     "Engineering/Manufacturing": 1,
#     "Estate Agency": 1,
#     "Executive Search Firm": 1,
#     "Facilities Management": 1,
#     "Farming/Agribusiness": 1,
#     "Fashion": 1,
#     "Fashion Retail": 1,
#     "Finance/Banking": 1,
#     "Fintech": 1,
#     "Food Industry": 1,
#     "Food Service": 1,
#     "Food Service/Hospitality": 1,
#     "Government": 1,
#     "Health and Fitness": 1,
#     "Health and Social Care": 1,
#     "Healthcare & Nursing Jobs": 1,
#     "Healthcare Advertising": 1,
#     "Healthcare/Hospitality": 1,
#     "Healthcare/Pharmaceutical": 1,
#     "Healthcare/Social Care": 1,
#     "Home Accessories Manufacturing": 1,
#     "IT Jobs": 1,
#     "IT and Consulting": 1,
#     "IT and Technology": 1,
#     "IT and Telecommunications": 1,
#     "IT, Fintech, Blockchain, AI": 1,
#     "Leisure": 1,
#     "Leisure and Fitness": 1,
#     "Logistics and Transportation": 1,
#     "Logistics/Transportation": 1,
#     "Manufacturing and Engineering": 1,
#     "Manufacturing/Engineering": 1,
#     "Manufacturing/Industrial": 1,
#     "Manufacturing/Production": 1,
#     "Marketing": 1,
#     "Media and Advertising": 1,
#     "Media and Communications": 1,
#     "Media and Entertainment": 1,
#     "Military/Defence": 1,
#     "Non-Profit": 1,
#     "Non-Profit/Charity": 1,
#     "Non-Profit/NGO": 1,
#     "Non-profit/Charity": 1,
#     "Nuclear Engineering": 1,
#     "Other/General Jobs": 1,
#     "PR and Communications": 1,
#     "Pharmaceutical": 1,
#     "Property": 1,
#     "Public Health": 1,
#     "Public Sector/ Law Enforcement": 1,
#     "Real Estate/Property Management": 1,
#     "Recruitment Consultancy": 1,
#     "Recruitment/Consultancy": 1,
#     "Remote Work/Online Opportunities": 1,
#     "Renewable Energy/Electric Vehicle": 1,
#     "Renewables": 1,
#     "Research and Market Analysis": 1,
#     "Retail Marketing": 1,
#     "Retail/Food Industry": 1,
#     "SaaS": 1,
#     "Sales Jobs": 1,
#     "Sales and Business Development": 1,
#     "Sales and Customer Service": 1,
#     "Sales and Events": 1,
#     "Sales and Recruitment": 1,
#     "Scientific & QA": 1,
#     "Scientific & QA Jobs": 1,
#     "Security and Customer Service": 1,
#     "Security and Law Enforcement": 1,
#     "Security and Surveillance": 1,
#     "Social Housing": 1,
#     "Social Services/Social Work": 1,
#     "Software Engineering": 1,
#     "Sports/Leisure": 1,
#     "Technology & Engineering": 1,
#     "Telecommunications": 1,
#     "Tourism/Hospitality": 1,
#     "Trade and Construction": 1,
#     "Translation and Interpreting": 1,
#     "Transportation": 1,
#     "Transportation/Fleet Management": 1,
#     "Transportation/Logistics": 1,
#     "Travel and Tourism": 1,
#     "Utilities": 1,
#     "Utility": 1,
#     "Waste Management": 1
#   },
#   "sample_cases": [
#     {
#       "job_id": "2780653104",
#       "job_ad_title": "Sommelier-Restaurant Gordon Ramsay",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Sommelier for a Three Michelin Star restaurant",
#       "kept": [
#         "Waiters and Waitresses"
#       ],
#       "dropped": [
#         "Bartenders",
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop",
#         "Dining Room and Cafeteria Attendants and Bartender Helpers",
#         "Chefs and Head Cooks",
#         "Cooks, Private Household",
#         "Cooks, Restaurant"
#       ]
#     },
#     {
#       "job_id": "2813395527",
#       "job_ad_title": "Senior Electronic Design Engineer",
#       "domain": "Engineering/Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering/Manufacturing] Senior Electronic Design Engineer",
#       "kept": [
#         "Electronics Engineers, Except Computer"
#       ],
#       "dropped": [
#         "Computer Hardware Engineers",
#         "Electrical and Electronic Engineering Technologists and Technicians",
#         "Electrical and Electronic Equipment Assemblers",
#         "Model Makers, Metal and Plastic",
#         "Robotics Engineers",
#         "Microsystems Engineers",
#         "Electrical Engineers"
#       ]
#     },
#     {
#       "job_id": "2828669962",
#       "job_ad_title": "Electric Vehicle Charge Point Installer",
#       "domain": "Renewable Energy/Electric Vehicle",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Renewable Energy/Electric Vehicle] Install EV charging equipment in customers' homes, manage stock, and provide excellent customer service.",
#       "kept": [
#         "Electricians"
#       ],
#       "dropped": [
#         "Electric Motor, Power Tool, and Related Repairers",
#         "Electrical and Electronics Installers and Repairers, Transportation Equipment",
#         "Electrical and Electronic Engineering Technologists and Technicians",
#         "Recreational Vehicle Service Technicians",
#         "Solar Sales Representatives and Assessors",
#         "Solar Energy Installation Managers",
#         "Power Distributors and Dispatchers"
#       ]
#     },
#     {
#       "job_id": "2836679279",
#       "job_ad_title": "Telephone Interviewer",
#       "domain": "Recruitment",
#       "sector": "Admin Jobs",
#       "job_desc": "[Recruitment] Telephone Interviewer position in Dunfermline, conducting interviews and data entry.",
#       "kept": [
#         "Interviewers, Except Eligibility and Loan",
#         "Telemarketers",
#         "Telephone Operators"
#       ],
#       "dropped": [
#         "Word Processors and Typists",
#         "Bookkeeping, Accounting, and Auditing Clerks",
#         "Data Entry Keyers",
#         "Loan Interviewers and Clerks",
#         "Receptionists and Information Clerks"
#       ]
#     },
#     {
#       "job_id": "2825288483",
#       "job_ad_title": "Female Support Worker - Bank Staff",
#       "domain": "Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Social Work] Support Worker for individuals with learning disabilities, mental health, and autism in Ellesmere Port.",
#       "kept": [
#         "Healthcare Social Workers",
#         "Mental Health and Substance Abuse Social Workers",
#         "Child, Family, and School Social Workers"
#       ],
#       "dropped": [
#         "Childcare Workers",
#         "Community Health Workers",
#         "Psychiatric Technicians",
#         "Special Education Teachers, Preschool",
#         "Special Education Teachers, Middle School"
#       ]
#     },
#     {
#       "job_id": "2834732675",
#       "job_ad_title": "Senior Scientist - ATMP",
#       "domain": "Biotechnology/Pharmaceutical",
#       "sector": "Scientific & QA Jobs",
#       "job_desc": "[Biotechnology/Pharmaceutical] Senior Scientist - ATMP",
#       "kept": [
#         "Medical Scientists, Except Epidemiologists"
#       ],
#       "dropped": [
#         "Bioengineers and Biomedical Engineers",
#         "Chemists",
#         "Biochemists and Biophysicists",
#         "Physicians, Pathologists",
#         "Biomass Plant Technicians",
#         "Molecular and Cellular Biologists",
#         "Robotics Engineers",
#         "Embalmers",
#         "Animal Scientists"
#       ]
#     },
#     {
#       "job_id": "2822982103",
#       "job_ad_title": "Senior Android Developer",
#       "domain": "IT",
#       "sector": "IT Jobs",
#       "job_desc": "[IT] Senior Android Developer position at Europe's leading media and entertainment brand, Sky",
#       "kept": [
#         "Software Developers"
#       ],
#       "dropped": [
#         "Software Quality Assurance Analysts and Testers",
#         "Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products",
#         "Natural Sciences Managers",
#         "Human Factors Engineers and Ergonomists",
#         "Telecommunications Engineering Specialists",
#         "Media Programming Directors",
#         "Robotics Engineers",
#         "Dancers"
#       ]
#     },
#     {
#       "job_id": "2821136828",
#       "job_ad_title": "HGV 1 Driver",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] HGV Class 1 Driver for Class 1 store deliveries across the UK",
#       "kept": [
#         "Heavy and Tractor-Trailer Truck Drivers"
#       ],
#       "dropped": [
#         "Industrial Truck and Tractor Operators",
#         "Cargo and Freight Agents",
#         "Crane and Tower Operators",
#         "Couriers and Messengers",
#         "Power Distributors and Dispatchers",
#         "Tire Repairers and Changers",
#         "Parts Salespersons",
#         "Bus Drivers, Transit and Intercity",
#         "Tax Preparers"
#       ]
#     },
#     {
#       "job_id": "2824914939",
#       "job_ad_title": "Registered Manager Learning Disabilities",
#       "domain": "Healthcare/Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Healthcare/Social Work] Registered Manager for a residential and supported living service for adults with learning disabilities, Autism and physical disabilities.",
#       "kept": [
#         "Healthcare Social Workers"
#       ],
#       "dropped": [
#         "Personal Care Aides",
#         "Mental Health and Substance Abuse Social Workers",
#         "Recreation Workers",
#         "Home Health Aides",
#         "Social and Community Service Managers",
#         "Licensed Practical and Licensed Vocational Nurses",
#         "Registered Nurses",
#         "Medical and Health Services Managers",
#         "Administrative Services Managers"
#       ]
#     },
#     {
#       "job_id": "2831341197",
#       "job_ad_title": "Field Service Engineer Mechanical",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Field Service Engineer (Mechanical) for Aviation, Rail, Government, Industrial industries",
#       "kept": [
#         "Aircraft Mechanics and Service Technicians"
#       ],
#       "dropped": [
#         "Automotive Service Technicians and Mechanics",
#         "Maintenance Workers, Machinery",
#         "Mechanical Engineering Technologists and Technicians",
#         "Maintenance and Repair Workers, General",
#         "Robotics Engineers",
#         "Bicycle Repairers"
#       ]
#     },
#     {
#       "job_id": "2831089110",
#       "job_ad_title": "Head of Mathematics",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Head of Mathematics position at a grammar school in South East London",
#       "kept": [
#         "Mathematicians",
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Career/Technical Education Teachers, Secondary School"
#       ],
#       "dropped": [
#         "Mathematical Science Teachers, Postsecondary",
#         "Teaching Assistants, Preschool, Elementary, Middle, and Secondary School, Except Special Education",
#         "Middle School Teachers, Except Special and Career/Technical Education",
#         "Elementary School Teachers, Except Special Education"
#       ]
#     },
#     {
#       "job_id": "2828207338",
#       "job_ad_title": "Attention: Housekeeper Wanted In Walton-on-Thames KT12",
#       "domain": "Domestic help & Cleaning Jobs",
#       "sector": "Domestic help & Cleaning Jobs",
#       "job_desc": "[Domestic help & Cleaning Jobs] Housekeeper Wanted In Walton-on-Thames KT12",
#       "kept": [
#         "Maids and Housekeeping Cleaners",
#         "Dishwashers",
#         "Janitors and Cleaners, Except Maids and Housekeeping Cleaners"
#       ],
#       "dropped": [
#         "Cleaners of Vehicles and Equipment",
#         "Laundry and Dry-Cleaning Workers",
#         "Bicycle Repairers",
#         "Midwives",
#         "Tire Repairers and Changers"
#       ]
#     },
#     {
#       "job_id": "2828413415",
#       "job_ad_title": "Senior Bid Writer - facilities Management",
#       "domain": "Facilities Management",
#       "sector": "PR",
#       "job_desc": "[Facilities Management] Senior Bid Writer for Facilities Management in the Government Sector",
#       "kept": [
#         "Facilities Managers"
#       ],
#       "dropped": [
#         "Construction Managers",
#         "Lodging Managers",
#         "Transportation, Storage, and Distribution Managers",
#         "Fundraising Managers",
#         "Sustainability Specialists",
#         "Procurement Clerks",
#         "Tax Preparers",
#         "Regulatory Affairs Specialists"
#       ]
#     },
#     {
#       "job_id": "2821131872",
#       "job_ad_title": "Agency Nurse",
#       "domain": "Healthcare & Nursing",
#       "sector": "Healthcare & Nursing Jobs",
#       "job_desc": "[Healthcare & Nursing] Temp / Registered General Nurse",
#       "kept": [
#         "Critical Care Nurses"
#       ],
#       "dropped": [
#         "Nursing Assistants",
#         "Clinical Nurse Specialists",
#         "Nurse Practitioners",
#         "Acute Care Nurses",
#         "Registered Nurses",
#         "Midwives",
#         "Tire Repairers and Changers",
#         "Nurse Midwives"
#       ]
#     },
#     {
#       "job_id": "2822114154",
#       "job_ad_title": "Manual Machine Prepper",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Manual Machine Prepper",
#       "kept": [
#         "Lathe and Turning Machine Tool Setters, Operators, and Tenders, Metal and Plastic"
#       ],
#       "dropped": [
#         "Tool Grinders, Filers, and Sharpeners",
#         "Welders, Cutters, Solderers, and Brazers",
#         "Forging Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Operating Engineers and Other Construction Equipment Operators",
#         "Maintenance Workers, Machinery",
#         "Tire Builders",
#         "Tire Repairers and Changers",
#         "Medical Equipment Repairers",
#         "Bicycle Repairers"
#       ]
#     },
#     {
#       "job_id": "2832534421",
#       "job_ad_title": "Flt driver/ labourer",
#       "domain": "Construction",
#       "sector": "Trade & Construction Jobs",
#       "job_desc": "[Construction] FLT/General Labourer",
#       "kept": [
#         "Construction Laborers",
#         "Loading and Moving Machine Operators, Underground Mining",
#         "Laborers and Freight, Stock, and Material Movers, Hand"
#       ],
#       "dropped": [
#         "Landscaping and Groundskeeping Workers",
#         "Maintenance and Repair Workers, General",
#         "Maintenance Workers, Machinery",
#         "Tire Builders",
#         "Tire Repairers and Changers",
#         "Insulation Workers, Floor, Ceiling, and Wall"
#       ]
#     },
#     {
#       "job_id": "2740314480",
#       "job_ad_title": "Finance Service Manager (Children's Finance)",
#       "domain": "Accounting & Finance",
#       "sector": "Accounting & Finance Jobs",
#       "job_desc": "[Accounting & Finance] Finance Service Manager for a local authority supporting Children's services",
#       "kept": [
#         "Financial Managers"
#       ],
#       "dropped": [
#         "Treasurers and Controllers",
#         "Accountants and Auditors",
#         "Budget Analysts",
#         "Bookkeeping, Accounting, and Auditing Clerks",
#         "Fundraising Managers",
#         "Social and Community Service Managers",
#         "Wind Energy Operations Managers",
#         "Medical and Health Services Managers"
#       ]
#     },
#     {
#       "job_id": "2793906036",
#       "job_ad_title": "Department Supervisor - 30 Hours Per Week",
#       "domain": "Retail",
#       "sector": "Retail Jobs",
#       "job_desc": "[Retail] Department Supervisor for a retail store, responsible for day-to-day operations and customer service.",
#       "kept": [
#         "First-Line Supervisors of Retail Sales Workers"
#       ],
#       "dropped": [
#         "First-Line Supervisors of Non-Retail Sales Workers",
#         "Locker Room, Coatroom, and Dressing Room Attendants",
#         "Stockers and Order Fillers",
#         "Transportation, Storage, and Distribution Managers",
#         "First-Line Supervisors of Personal Service Workers",
#         "First-Line Supervisors of Security Workers",
#         "First-Line Supervisors of Food Preparation and Serving Workers"
#       ]
#     },
#     {
#       "job_id": "2813502724",
#       "job_ad_title": "Senior Sous Chef",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Senior Sous Chef position in an independent group of gastro pubs",
#       "kept": [
#         "Cooks, Restaurant"
#       ],
#       "dropped": [
#         "Chefs and Head Cooks",
#         "Food Preparation Workers",
#         "Food Service Managers",
#         "First-Line Supervisors of Food Preparation and Serving Workers",
#         "Cooks, Private Household",
#         "Cooks, Institution and Cafeteria"
#       ]
#     },
#     {
#       "job_id": "2780653010",
#       "job_ad_title": "Customer Success Executive - Remote",
#       "domain": "Customer Services",
#       "sector": "Customer Services Jobs",
#       "job_desc": "[Customer Services] Customer Success Executive - Remote",
#       "kept": [
#         "Customer Service Representatives"
#       ],
#       "dropped": [
#         "Property, Real Estate, and Community Association Managers",
#         "Real Estate Brokers",
#         "Home Appliance Repairers",
#         "Real Estate Sales Agents",
#         "Tax Preparers",
#         "Power Distributors and Dispatchers",
#         "Telemarketers",
#         "First-Line Supervisors of Personal Service Workers",
#         "Parts Salespersons"
#       ]
#     },
#     {
#       "job_id": "2639240590",
#       "job_ad_title": "Stock Controller/Supply Manager",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] Stock Controller/Supply Manager",
#       "kept": [
#         "Supply Chain Managers"
#       ],
#       "dropped": [
#         "Transportation, Storage, and Distribution Managers",
#         "Logistics Analysts",
#         "Production, Planning, and Expediting Clerks",
#         "Shipping, Receiving, and Inventory Clerks",
#         "Parts Salespersons",
#         "Stockers and Order Fillers",
#         "Packers and Packagers, Hand"
#       ]
#     },
#     {
#       "job_id": "2693450403",
#       "job_ad_title": "Nights Transport Planner",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] Transport Planner for a leading multi model logistics business",
#       "kept": [
#         "Transportation, Storage, and Distribution Managers"
#       ],
#       "dropped": [
#         "Logistics Analysts",
#         "Transportation Planners",
#         "Heavy and Tractor-Trailer Truck Drivers",
#         "Light Truck Drivers",
#         "Logistics Engineers",
#         "Logisticians"
#       ]
#     },
#     {
#       "job_id": "2791717253",
#       "job_ad_title": "Receptionist",
#       "domain": "Manufacturing",
#       "sector": "Admin Jobs",
#       "job_desc": "[Manufacturing] Receptionist for a manufacturing business in Rotherham",
#       "kept": [
#         "Production, Planning, and Expediting Clerks"
#       ],
#       "dropped": [
#         "Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers",
#         "Machine Feeders and Offbearers",
#         "Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders",
#         "First-Line Supervisors of Housekeeping and Janitorial Workers",
#         "Tire Builders",
#         "Maintenance Workers, Machinery",
#         "Receptionists and Information Clerks",
#         "Parts Salespersons",
#         "Stone Cutters and Carvers, Manufacturing"
#       ]
#     },
#     {
#       "job_id": "2742996472",
#       "job_ad_title": "Business Process Support (P2P)",
#       "domain": "Manufacturing",
#       "sector": "IT Jobs",
#       "job_desc": "[Manufacturing] Business Process Support (P2P) to drive implementation of new policies and processes across the organisation.",
#       "kept": [
#         "Team Assemblers"
#       ],
#       "dropped": [
#         "Machine Feeders and Offbearers",
#         "Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers",
#         "Milling and Planing Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Production, Planning, and Expediting Clerks",
#         "Patient Representatives",
#         "Packers and Packagers, Hand",
#         "Procurement Clerks",
#         "Business Continuity Planners",
#         "Pressers, Textile, Garment, and Related Materials"
#       ]
#     },
#     {
#       "job_id": "2791201272",
#       "job_ad_title": "Service Administrator",
#       "domain": "Automotive",
#       "sector": "Admin Jobs",
#       "job_desc": "[Automotive] Service Administrator",
#       "kept": [
#         "Automotive Service Technicians and Mechanics"
#       ],
#       "dropped": [
#         "Automotive and Watercraft Service Attendants",
#         "Automotive Body and Related Repairers",
#         "Cleaners of Vehicles and Equipment",
#         "Customer Service Representatives",
#         "Tire Repairers and Changers",
#         "Bicycle Repairers"
#       ]
#     },
#     {
#       "job_id": "2746664291",
#       "job_ad_title": "Multi Skilled Maintenance Engineer",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Multi Skilled Maintenance Engineer for an award-winning textiles processing company in West Yorkshire",
#       "kept": [
#         "Maintenance Workers, Machinery"
#       ],
#       "dropped": [
#         "Maintenance and Repair Workers, General",
#         "Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders",
#         "Electric Motor, Power Tool, and Related Repairers",
#         "Boilermakers",
#         "Manufacturing Engineers",
#         "Biomass Plant Technicians",
#         "Millwrights",
#         "Laundry and Dry-Cleaning Workers"
#       ]
#     },
#     {
#       "job_id": "2847461196",
#       "job_ad_title": "LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "kept": [
#         "Industrial Truck and Tractor Operators"
#       ],
#       "dropped": [
#         "Tank Car, Truck, and Ship Loaders",
#         "Pump Operators, Except Wellhead Pumpers",
#         "Transportation, Storage, and Distribution Managers",
#         "Cargo and Freight Agents",
#         "Maintenance Workers, Machinery",
#         "Packers and Packagers, Hand",
#         "Tire Builders",
#         "Chemical Plant and System Operators"
#       ]
#     },
#     {
#       "job_id": "2846431729",
#       "job_ad_title": "Operative",
#       "domain": "Manufacturing",
#       "sector": "Manufacturing Jobs",
#       "job_desc": "[Manufacturing] Temporary to permanent manufacturing operative role with a 2-shift system",
#       "kept": [
#         "Engine and Other Machine Assemblers"
#       ],
#       "dropped": [
#         "Machine Feeders and Offbearers",
#         "Packers and Packagers, Hand",
#         "Maintenance and Repair Workers, General",
#         "Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders",
#         "Maintenance Workers, Machinery",
#         "Tire Builders",
#         "Tire Repairers and Changers",
#         "First-Line Supervisors of Material-Moving Machine and Vehicle Operators",
#         "Chemical Plant and System Operators"
#       ]
#     },
#     {
#       "job_id": "2848376850",
#       "job_ad_title": "Engineering Stores / SAP Coordinator",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Engineering Stores / SAP Coordinator",
#       "kept": [
#         "Production, Planning, and Expediting Clerks"
#       ],
#       "dropped": [
#         "Team Assemblers",
#         "Inspectors, Testers, Sorters, Samplers, and Weighers",
#         "Weighers, Measurers, Checkers, and Samplers, Recordkeeping",
#         "Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders",
#         "Biomass Plant Technicians",
#         "Robotics Engineers",
#         "Tire Builders",
#         "Robotics Technicians",
#         "Parts Salespersons"
#       ]
#     },
#     {
#       "job_id": "2838003039",
#       "job_ad_title": "Teacher",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Experienced teacher required for a temporary position at Gee Cross Holy Trinity Primary and Nursery School.",
#       "kept": [
#         "Teaching Assistants, Preschool, Elementary, Middle, and Secondary School, Except Special Education"
#       ],
#       "dropped": [
#         "Career/Technical Education Teachers, Secondary School",
#         "Self-Enrichment Teachers",
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Elementary School Teachers, Except Special Education",
#         "Substitute Teachers, Short-Term",
#         "Special Education Teachers, Preschool",
#         "Kindergarten Teachers, Except Special Education",
#         "Middle School Teachers, Except Special and Career/Technical Education"
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## GTE

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_gte.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
# Out:
# JOBID: 2151815

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")

def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()

while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:05    5:59:55     1 nid010564
#
# --- STDOUT ---
# PROJECT=/projects/a5u/adu_dev/aisi-economy-index
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 05:17 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 05:17 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:18 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:18 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 05:19 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:19 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 05:20 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 05:20 adzuna_month08.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 05:21 adzuna_month09.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:10    5:59:50     1 nid010564
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 05:46:55
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:15    5:59:45     1 nid010564
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 05:46:55
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:20    5:59:40     1 nid010564
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 05:46:55
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:25    5:59:35     1 nid010564
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 05:46:55
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:32    5:59:28     1 nid010564
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 05:46:55
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:37    5:59:23     1 nid010564
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 05:46:55
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:42    5:59:18     1 nid010564
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 05:46:55
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:47    5:59:13     1 nid010564
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:52    5:59:08     1 nid010564
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:57    5:59:03     1 nid010564
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:02    5:58:58     1 nid010564
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:07    5:58:53     1 nid010564
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:12    5:58:48     1 nid010564
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:17    5:58:43     1 nid010564
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:22    5:58:38     1 nid010564
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:27    5:58:33     1 nid010564
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:32    5:58:28     1 nid010564
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:37    5:58:23     1 nid010564
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:42    5:58:18     1 nid010564
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:47    5:58:13     1 nid010564
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:52    5:58:08     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:57    5:58:03     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2151815 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       2:02    5:57:58     1 nid010564
#
# --- STDOUT ---
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# === squeue ===
# ...
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:08, 35.55s/it]
# Batches:  25%|██▌       | 2/8 [01:07<03:21, 33.59s/it]
# Batches:  38%|███▊      | 3/8 [01:41<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:55<01:43, 25.90s/it]
# Batches:  62%|██████▎   | 5/8 [02:09<01:04, 21.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.14s/it]
# Batches:  88%|████████▊ | 7/8 [02:37<00:17, 17.32s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 22.02s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 23.71s/it]
# [W205 05:50:07.756705654 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# Allocated: 14.991334915161133 GB
# Reserved: 67.98046875 GB
# [END] 2026-02-05 05:50:07
# [RUNTIME] 3.21 minutes (192.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:08, 35.55s/it]
# Batches:  25%|██▌       | 2/8 [01:07<03:21, 33.59s/it]
# Batches:  38%|███▊      | 3/8 [01:41<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:55<01:43, 25.90s/it]
# Batches:  62%|██████▎   | 5/8 [02:09<01:04, 21.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.14s/it]
# Batches:  88%|████████▊ | 7/8 [02:37<00:17, 17.32s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 22.02s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 23.71s/it]
# [W205 05:50:07.756705654 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# Allocated: 14.991334915161133 GB
# Reserved: 67.98046875 GB
# [END] 2026-02-05 05:50:07
# [RUNTIME] 3.21 minutes (192.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:08, 35.55s/it]
# Batches:  25%|██▌       | 2/8 [01:07<03:21, 33.59s/it]
# Batches:  38%|███▊      | 3/8 [01:41<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:55<01:43, 25.90s/it]
# Batches:  62%|██████▎   | 5/8 [02:09<01:04, 21.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.14s/it]
# Batches:  88%|████████▊ | 7/8 [02:37<00:17, 17.32s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 22.02s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 23.71s/it]
# [W205 05:50:07.756705654 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# Allocated: 14.991334915161133 GB
# Reserved: 67.98046875 GB
# [END] 2026-02-05 05:50:07
# [RUNTIME] 3.21 minutes (192.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:08, 35.55s/it]
# Batches:  25%|██▌       | 2/8 [01:07<03:21, 33.59s/it]
# Batches:  38%|███▊      | 3/8 [01:41<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:55<01:43, 25.90s/it]
# Batches:  62%|██████▎   | 5/8 [02:09<01:04, 21.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.14s/it]
# Batches:  88%|████████▊ | 7/8 [02:37<00:17, 17.32s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 22.02s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 23.71s/it]
# [W205 05:50:07.756705654 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# Allocated: 14.991334915161133 GB
# Reserved: 67.98046875 GB
# [END] 2026-02-05 05:50:07
# [RUNTIME] 3.21 minutes (192.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:08, 35.55s/it]
# Batches:  25%|██▌       | 2/8 [01:07<03:21, 33.59s/it]
# Batches:  38%|███▊      | 3/8 [01:41<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:55<01:43, 25.90s/it]
# Batches:  62%|██████▎   | 5/8 [02:09<01:04, 21.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.14s/it]
# Batches:  88%|████████▊ | 7/8 [02:37<00:17, 17.32s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 22.02s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 23.71s/it]
# [W205 05:50:07.756705654 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# Allocated: 14.991334915161133 GB
# Reserved: 67.98046875 GB
# [END] 2026-02-05 05:50:07
# [RUNTIME] 3.21 minutes (192.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:08, 35.55s/it]
# Batches:  25%|██▌       | 2/8 [01:07<03:21, 33.59s/it]
# Batches:  38%|███▊      | 3/8 [01:41<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:55<01:43, 25.90s/it]
# Batches:  62%|██████▎   | 5/8 [02:09<01:04, 21.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.14s/it]
# Batches:  88%|████████▊ | 7/8 [02:37<00:17, 17.32s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 22.02s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 23.71s/it]
# [W205 05:50:07.756705654 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# Allocated: 14.991334915161133 GB
# Reserved: 67.98046875 GB
# [END] 2026-02-05 05:50:07
# [RUNTIME] 3.21 minutes (192.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.23it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:01,  1.99it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:01<00:00,  2.57it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  3.12it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:35<04:08, 35.55s/it]
# Batches:  25%|██▌       | 2/8 [01:07<03:21, 33.59s/it]
# Batches:  38%|███▊      | 3/8 [01:41<02:49, 33.82s/it]
# Batches:  50%|█████     | 4/8 [01:55<01:43, 25.90s/it]
# Batches:  62%|██████▎   | 5/8 [02:09<01:04, 21.66s/it]
# Batches:  75%|███████▌  | 6/8 [02:24<00:38, 19.14s/it]
# Batches:  88%|████████▊ | 7/8 [02:37<00:17, 17.32s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 22.02s/it]
# Batches: 100%|██████████| 8/8 [03:09<00:00, 23.71s/it]
# [W205 05:50:07.756705654 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 28
#      25 if not sq:
#      26     break
# ---> 28 time.sleep(5)
#
# KeyboardInterrupt:

# %%
gen_report("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl")

#from pathlib import Path
p = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/")
latest = max(p.glob("llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654_report.json"), key=lambda x: x.stat().st_mtime)
print(latest.read_text())
# Out:
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654_report.txt
# {
#   "run": {
#     "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl",
#     "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz",
#     "generated_at": "2026-02-05T05:52:52"
#   },
#   "global_metrics": {
#     "jobs": 1000,
#     "avg_candidates_before": 8.229,
#     "avg_candidates_after": 1.384,
#     "drop_rate": 0.8318,
#     "empty_outputs_percent": 0.0,
#     "it_leakage_share": 0.0889,
#     "min_kept": 1,
#     "max_kept": 3
#   },
#   "top_kept_roles": [
#     [
#       "Software Developers",
#       31
#     ],
#     [
#       "Personal Care Aides",
#       26
#     ],
#     [
#       "Mental Health and Substance Abuse Social Workers",
#       20
#     ],
#     [
#       "Cooks, Institution and Cafeteria",
#       19
#     ],
#     [
#       "Human Resources Specialists",
#       19
#     ],
#     [
#       "Financial Managers",
#       19
#     ],
#     [
#       "Computer Systems Engineers/Architects",
#       19
#     ],
#     [
#       "Treasurers and Controllers",
#       17
#     ],
#     [
#       "Information Technology Project Managers",
#       17
#     ],
#     [
#       "Packers and Packagers, Hand",
#       16
#     ],
#     [
#       "Solar Sales Representatives and Assessors",
#       16
#     ],
#     [
#       "Public Relations Specialists",
#       15
#     ],
#     [
#       "Healthcare Social Workers",
#       15
#     ],
#     [
#       "Maids and Housekeeping Cleaners",
#       14
#     ],
#     [
#       "Secretaries and Administrative Assistants, Except Legal, Medical, and Executive",
#       14
#     ],
#     [
#       "Customer Service Representatives",
#       13
#     ],
#     [
#       "Childcare Workers",
#       13
#     ],
#     [
#       "Web Developers",
#       13
#     ],
#     [
#       "Sales Managers",
#       13
#     ],
#     [
#       "Medical and Health Services Managers",
#       12
#     ],
#     [
#       "Accountants and Auditors",
#       12
#     ],
#     [
#       "Software Quality Assurance Analysts and Testers",
#       11
#     ],
#     [
#       "Sales Engineers",
#       11
#     ],
#     [
#       "Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products",
#       11
#     ],
#     [
#       "Retail Salespersons",
#       11
#     ]
#   ],
#   "domain_summary_avg_kept": {
#     "Agriculture/Rural": 3,
#     "Construction/Real Estate": 3,
#     "Domestic Help & Cleaning": 3,
#     "Domestic Services": 3,
#     "Electronics Technology": 3,
#     "Environmental Science": 3,
#     "Estate Agency": 3,
#     "Food and Beverage": 3,
#     "Healthcare Administration": 3,
#     "Higher Education": 3,
#     "Hospitality": 3,
#     "Online Surveys/Admin Jobs": 3,
#     "Technology/Software": 3,
#     "Public Relations": 2.5,
#     "Finance": 2.143,
#     "Agriculture": 2,
#     "Construction and Engineering": 2,
#     "Construction and Property": 2,
#     "Domestic help & Cleaning Jobs": 2,
#     "Legal": 2,
#     "Logistics & Transportation": 2,
#     "Logistics/Transportation": 2,
#     "Non-Profit": 2,
#     "Renewable Energy": 2,
#     "Scientific & QA Jobs": 2,
#     "Social Work": 1.857,
#     "Software Development": 1.857,
#     "Admin Jobs": 1.8,
#     "Sales": 1.714,
#     "Administration": 1.667,
#     "Digital Marketing": 1.667,
#     "Energy": 1.667,
#     "Insurance": 1.667,
#     "Media and Entertainment": 1.667,
#     "Trade & Construction": 1.667,
#     "IT": 1.619,
#     "Construction": 1.562,
#     "Accounting & Finance": 1.542,
#     "Engineering": 1.541,
#     "Domestic help & Cleaning": 1.5,
#     "HR & Recruitment": 1.5,
#     "Healthcare/Social Work": 1.5,
#     "Human Resources": 1.5,
#     "Education": 1.474,
#     "Automotive": 1.462,
#     "Facilities Management": 1.4,
#     "Law": 1.4,
#     "Market Research": 1.4,
#     "Customer Services": 1.333,
#     "Recruitment": 1.333,
#     "Technology": 1.333,
#     "Real Estate": 1.286,
#     "Healthcare & Nursing": 1.268,
#     "Social work": 1.267,
#     "Financial Services": 1.25,
#     "Manufacturing": 1.211,
#     "Healthcare": 1.163,
#     "Logistics": 1.154,
#     "Retail": 1.111,
#     "Hospitality & Catering": 1.095,
#     "Logistics & Warehouse": 1.093,
#     "Administration/Office Support": 1,
#     "Administrative/Office": 1,
#     "Advertising and Marketing": 1,
#     "Aerospace": 1,
#     "Aerospace & Manufacturing": 1,
#     "Automotive Retail": 1,
#     "Beauty and Cosmetics": 1,
#     "Biotechnology": 1,
#     "Biotechnology/Pharmaceutical": 1,
#     "Construction and Infrastructure": 1,
#     "Construction and Maintenance": 1,
#     "Construction/Engineering": 1,
#     "Construction/Property Maintenance": 1,
#     "Construction/Rail": 1,
#     "Consultancy": 1,
#     "Consultancy Jobs": 1,
#     "Consulting": 1,
#     "Creative & Design": 1,
#     "Customer Service": 1,
#     "Cybersecurity": 1,
#     "Data and Intelligence consultancy": 1,
#     "Digital Media": 1,
#     "Digital/Technology": 1,
#     "Education Technology": 1,
#     "Education and Training": 1,
#     "Education/Training": 1,
#     "Electrical Engineering": 1,
#     "Energy Trading": 1,
#     "Energy and Utilities": 1,
#     "Engineering/Manufacturing": 1,
#     "Executive Search Firm": 1,
#     "Farming/Agribusiness": 1,
#     "Fashion": 1,
#     "Fashion Retail": 1,
#     "Finance/Banking": 1,
#     "Fintech": 1,
#     "Food Industry": 1,
#     "Food Service": 1,
#     "Food Service/Hospitality": 1,
#     "Government": 1,
#     "Health & Social Care": 1,
#     "Health and Fitness": 1,
#     "Health and Social Care": 1,
#     "Healthcare & Nursing Jobs": 1,
#     "Healthcare Advertising": 1,
#     "Healthcare/Hospitality": 1,
#     "Healthcare/Pharmaceutical": 1,
#     "Healthcare/Social Care": 1,
#     "Home Accessories Manufacturing": 1,
#     "IT Jobs": 1,
#     "IT and Consulting": 1,
#     "IT and Technology": 1,
#     "IT and Telecommunications": 1,
#     "IT, Fintech, Blockchain, AI": 1,
#     "IT/Software Development": 1,
#     "Leisure": 1,
#     "Leisure and Fitness": 1,
#     "Logistics and Supply Chain": 1,
#     "Logistics and Transportation": 1,
#     "Manufacturing and Engineering": 1,
#     "Manufacturing/Engineering": 1,
#     "Manufacturing/Industrial": 1,
#     "Manufacturing/Production": 1,
#     "Marketing": 1,
#     "Marketing and Public Relations": 1,
#     "Marketing/PR": 1,
#     "Media": 1,
#     "Media and Advertising": 1,
#     "Media and Communications": 1,
#     "Military/Defence": 1,
#     "Non-Profit/Charity": 1,
#     "Non-Profit/NGO": 1,
#     "Non-profit/Charity": 1,
#     "Nuclear Engineering": 1,
#     "Other/General Jobs": 1,
#     "PR": 1,
#     "PR and Communications": 1,
#     "Pharmaceutical": 1,
#     "Property": 1,
#     "Public Administration": 1,
#     "Public Health": 1,
#     "Public Sector/ Law Enforcement": 1,
#     "Publishing": 1,
#     "Real Estate/Property Management": 1,
#     "Recruitment Consultancy": 1,
#     "Recruitment/Consultancy": 1,
#     "Remote Work/Online Opportunities": 1,
#     "Renewable Energy/Electric Vehicle": 1,
#     "Renewables": 1,
#     "Research and Market Analysis": 1,
#     "Retail Marketing": 1,
#     "Retail/Food Industry": 1,
#     "SaaS": 1,
#     "Sales Jobs": 1,
#     "Sales and Business Development": 1,
#     "Sales and Customer Service": 1,
#     "Sales and Events": 1,
#     "Sales and Marketing": 1,
#     "Sales and Recruitment": 1,
#     "Scientific & QA": 1,
#     "Security": 1,
#     "Security and Customer Service": 1,
#     "Security and Law Enforcement": 1,
#     "Security and Surveillance": 1,
#     "Social Housing": 1,
#     "Social Services/Social Work": 1,
#     "Software Engineering": 1,
#     "Sports/Leisure": 1,
#     "Technology & Engineering": 1,
#     "Telecommunications": 1,
#     "Tourism/Hospitality": 1,
#     "Trade and Construction": 1,
#     "Translation and Interpreting": 1,
#     "Transportation": 1,
#     "Transportation/Fleet Management": 1,
#     "Transportation/Logistics": 1,
#     "Travel and Tourism": 1,
#     "Utilities": 1,
#     "Utility": 1,
#     "Waste Management": 1
#   },
#   "sample_cases": [
#     {
#       "job_id": "2780653104",
#       "job_ad_title": "Sommelier-Restaurant Gordon Ramsay",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Sommelier for a Three Michelin Star restaurant",
#       "kept": [
#         "Waiters and Waitresses"
#       ],
#       "dropped": [
#         "Food Service Managers",
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop",
#         "Chefs and Head Cooks",
#         "Dining Room and Cafeteria Attendants and Bartender Helpers",
#         "Bartenders",
#         "Cooks, Private Household",
#         "Baristas"
#       ]
#     },
#     {
#       "job_id": "2813395527",
#       "job_ad_title": "Senior Electronic Design Engineer",
#       "domain": "Engineering/Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering/Manufacturing] Senior Electronic Design Engineer",
#       "kept": [
#         "Electronics Engineers, Except Computer"
#       ],
#       "dropped": [
#         "Electrical and Electronic Engineering Technologists and Technicians",
#         "Electrical Engineers",
#         "Solar Energy Systems Engineers",
#         "Electrical and Electronics Drafters",
#         "Manufacturing Engineers",
#         "Microsystems Engineers"
#       ]
#     },
#     {
#       "job_id": "2828669962",
#       "job_ad_title": "Electric Vehicle Charge Point Installer",
#       "domain": "Renewable Energy/Electric Vehicle",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Renewable Energy/Electric Vehicle] Install EV charging equipment in customers' homes, manage stock, and provide excellent customer service.",
#       "kept": [
#         "Solar Photovoltaic Installers"
#       ],
#       "dropped": [
#         "Electrical Power-Line Installers and Repairers",
#         "Electrical and Electronics Installers and Repairers, Transportation Equipment",
#         "Electrical Engineers",
#         "Electrical and Electronic Engineering Technologists and Technicians",
#         "Solar Energy Installation Managers",
#         "Power Distributors and Dispatchers",
#         "Fuel Cell Engineers"
#       ]
#     },
#     {
#       "job_id": "2836679279",
#       "job_ad_title": "Telephone Interviewer",
#       "domain": "Recruitment",
#       "sector": "Admin Jobs",
#       "job_desc": "[Recruitment] Telephone Interviewer position in Dunfermline, conducting interviews and data entry.",
#       "kept": [
#         "Interviewers, Except Eligibility and Loan",
#         "Loan Interviewers and Clerks",
#         "Human Resources Assistants, Except Payroll and Timekeeping"
#       ],
#       "dropped": [
#         "Word Processors and Typists",
#         "Receptionists and Information Clerks",
#         "Human Resources Specialists",
#         "New Accounts Clerks",
#         "Archivists"
#       ]
#     },
#     {
#       "job_id": "2825288483",
#       "job_ad_title": "Female Support Worker - Bank Staff",
#       "domain": "Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Social Work] Support Worker for individuals with learning disabilities, mental health, and autism in Ellesmere Port.",
#       "kept": [
#         "Mental Health and Substance Abuse Social Workers",
#         "Healthcare Social Workers",
#         "Personal Care Aides"
#       ],
#       "dropped": [
#         "Community Health Workers",
#         "Nannies",
#         "Social and Human Service Assistants",
#         "Child, Family, and School Social Workers",
#         "First-Line Supervisors of Farming, Fishing, and Forestry Workers"
#       ]
#     },
#     {
#       "job_id": "2834732675",
#       "job_ad_title": "Senior Scientist - ATMP",
#       "domain": "Biotechnology/Pharmaceutical",
#       "sector": "Scientific & QA Jobs",
#       "job_desc": "[Biotechnology/Pharmaceutical] Senior Scientist - ATMP",
#       "kept": [
#         "Medical and Clinical Laboratory Technologists"
#       ],
#       "dropped": [
#         "Bioengineers and Biomedical Engineers",
#         "Molecular and Cellular Biologists",
#         "Chemical Technicians",
#         "Quality Control Analysts",
#         "Validation Engineers",
#         "Bioinformatics Scientists",
#         "Chemists",
#         "Medical Dosimetrists"
#       ]
#     },
#     {
#       "job_id": "2822982103",
#       "job_ad_title": "Senior Android Developer",
#       "domain": "IT",
#       "sector": "IT Jobs",
#       "job_desc": "[IT] Senior Android Developer position at Europe's leading media and entertainment brand, Sky",
#       "kept": [
#         "Software Developers"
#       ],
#       "dropped": [
#         "Computer Systems Engineers/Architects",
#         "Computer and Information Research Scientists",
#         "Computer Network Architects",
#         "Microsystems Engineers",
#         "Radio Frequency Identification Device Specialists",
#         "Telecommunications Engineering Specialists",
#         "Software Quality Assurance Analysts and Testers"
#       ]
#     },
#     {
#       "job_id": "2821136828",
#       "job_ad_title": "HGV 1 Driver",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] HGV Class 1 Driver for Class 1 store deliveries across the UK",
#       "kept": [
#         "Industrial Truck and Tractor Operators"
#       ],
#       "dropped": [
#         "Crane and Tower Operators",
#         "Tank Car, Truck, and Ship Loaders",
#         "Heavy and Tractor-Trailer Truck Drivers",
#         "Laborers and Freight, Stock, and Material Movers, Hand",
#         "Transportation, Storage, and Distribution Managers",
#         "Logistics Analysts",
#         "Light Truck Drivers",
#         "Logistics Engineers",
#         "Locomotive Engineers"
#       ]
#     },
#     {
#       "job_id": "2824914939",
#       "job_ad_title": "Registered Manager Learning Disabilities",
#       "domain": "Healthcare/Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Healthcare/Social Work] Registered Manager for a residential and supported living service for adults with learning disabilities, Autism and physical disabilities.",
#       "kept": [
#         "Medical and Health Services Managers"
#       ],
#       "dropped": [
#         "Healthcare Social Workers",
#         "Personal Care Aides",
#         "Community Health Workers",
#         "Mental Health and Substance Abuse Social Workers",
#         "Regulatory Affairs Managers",
#         "Social and Community Service Managers",
#         "Food Service Managers",
#         "Human Resources Managers"
#       ]
#     },
#     {
#       "job_id": "2831341197",
#       "job_ad_title": "Field Service Engineer Mechanical",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Field Service Engineer (Mechanical) for Aviation, Rail, Government, Industrial industries",
#       "kept": [
#         "Mechanical Engineering Technologists and Technicians"
#       ],
#       "dropped": [
#         "Control and Valve Installers and Repairers, Except Mechanical Door",
#         "Maintenance and Repair Workers, General",
#         "Mobile Heavy Equipment Mechanics, Except Engines",
#         "Bus and Truck Mechanics and Diesel Engine Specialists",
#         "Mechanical Engineers",
#         "Aircraft Mechanics and Service Technicians",
#         "Fuel Cell Engineers",
#         "Manufacturing Engineers"
#       ]
#     },
#     {
#       "job_id": "2831089110",
#       "job_ad_title": "Head of Mathematics",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Head of Mathematics position at a grammar school in South East London",
#       "kept": [
#         "Mathematicians"
#       ],
#       "dropped": [
#         "Mathematical Science Teachers, Postsecondary",
#         "Special Education Teachers, Elementary School",
#         "Teaching Assistants, Preschool, Elementary, Middle, and Secondary School, Except Special Education",
#         "Education Administrators, Kindergarten through Secondary",
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Tutors",
#         "Middle School Teachers, Except Special and Career/Technical Education"
#       ]
#     },
#     {
#       "job_id": "2828207338",
#       "job_ad_title": "Attention: Housekeeper Wanted In Walton-on-Thames KT12",
#       "domain": "Domestic help & Cleaning Jobs",
#       "sector": "Domestic help & Cleaning Jobs",
#       "job_desc": "[Domestic help & Cleaning Jobs] Housekeeper Wanted In Walton-on-Thames KT12",
#       "kept": [
#         "Maids and Housekeeping Cleaners",
#         "Dishwashers",
#         "Janitors and Cleaners, Except Maids and Housekeeping Cleaners"
#       ],
#       "dropped": [
#         "Personal Care Aides",
#         "Orderlies",
#         "Cooks, Private Household",
#         "First-Line Supervisors of Housekeeping and Janitorial Workers",
#         "Baggage Porters and Bellhops"
#       ]
#     },
#     {
#       "job_id": "2828413415",
#       "job_ad_title": "Senior Bid Writer - facilities Management",
#       "domain": "Facilities Management",
#       "sector": "PR",
#       "job_desc": "[Facilities Management] Senior Bid Writer for Facilities Management in the Government Sector",
#       "kept": [
#         "Facilities Managers",
#         "Brownfield Redevelopment Specialists and Site Managers",
#         "Locker Room, Coatroom, and Dressing Room Attendants"
#       ],
#       "dropped": [
#         "Writers and Authors",
#         "Property, Real Estate, and Community Association Managers",
#         "Sustainability Specialists",
#         "Meter Readers, Utilities",
#         "Procurement Clerks"
#       ]
#     },
#     {
#       "job_id": "2821131872",
#       "job_ad_title": "Agency Nurse",
#       "domain": "Healthcare & Nursing",
#       "sector": "Healthcare & Nursing Jobs",
#       "job_desc": "[Healthcare & Nursing] Temp / Registered General Nurse",
#       "kept": [
#         "Acute Care Nurses"
#       ],
#       "dropped": [
#         "Registered Nurses",
#         "Family Medicine Physicians",
#         "Nursing Assistants",
#         "Personal Care Aides",
#         "Medical Equipment Repairers",
#         "Pharmacy Technicians",
#         "Medical Equipment Preparers"
#       ]
#     },
#     {
#       "job_id": "2822114154",
#       "job_ad_title": "Manual Machine Prepper",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Manual Machine Prepper",
#       "kept": [
#         "Lathe and Turning Machine Tool Setters, Operators, and Tenders, Metal and Plastic"
#       ],
#       "dropped": [
#         "Boilermakers",
#         "Drilling and Boring Machine Tool Setters, Operators, and Tenders, Metal and Plastic",
#         "Sawing Machine Setters, Operators, and Tenders, Wood",
#         "Welders, Cutters, Solderers, and Brazers",
#         "Mechanical Drafters",
#         "Mechanical Engineers",
#         "Millwrights",
#         "Engine and Other Machine Assemblers",
#         "Technical Writers"
#       ]
#     },
#     {
#       "job_id": "2832534421",
#       "job_ad_title": "Flt driver/ labourer",
#       "domain": "Construction",
#       "sector": "Trade & Construction Jobs",
#       "job_desc": "[Construction] FLT/General Labourer",
#       "kept": [
#         "Construction Laborers",
#         "Roustabouts, Oil and Gas",
#         "Painters, Construction and Maintenance"
#       ],
#       "dropped": [
#         "Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters",
#         "Helpers--Painters, Paperhangers, Plasterers, and Stucco Masons",
#         "Millwrights",
#         "Tire Builders",
#         "Riggers"
#       ]
#     },
#     {
#       "job_id": "2740314480",
#       "job_ad_title": "Finance Service Manager (Children's Finance)",
#       "domain": "Accounting & Finance",
#       "sector": "Accounting & Finance Jobs",
#       "job_desc": "[Accounting & Finance] Finance Service Manager for a local authority supporting Children's services",
#       "kept": [
#         "Treasurers and Controllers"
#       ],
#       "dropped": [
#         "Financial Managers",
#         "Budget Analysts",
#         "Bookkeeping, Accounting, and Auditing Clerks",
#         "Chief Executives",
#         "Food Service Managers",
#         "Compensation and Benefits Managers",
#         "Fundraising Managers"
#       ]
#     },
#     {
#       "job_id": "2793906036",
#       "job_ad_title": "Department Supervisor - 30 Hours Per Week",
#       "domain": "Retail",
#       "sector": "Retail Jobs",
#       "job_desc": "[Retail] Department Supervisor for a retail store, responsible for day-to-day operations and customer service.",
#       "kept": [
#         "First-Line Supervisors of Retail Sales Workers"
#       ],
#       "dropped": [
#         "First-Line Supervisors of Non-Retail Sales Workers",
#         "Loss Prevention Managers",
#         "Stockers and Order Fillers",
#         "Spa Managers",
#         "Retail Loss Prevention Specialists",
#         "Retail Salespersons",
#         "Online Merchants"
#       ]
#     },
#     {
#       "job_id": "2813502724",
#       "job_ad_title": "Senior Sous Chef",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Senior Sous Chef position in an independent group of gastro pubs",
#       "kept": [
#         "Cooks, Institution and Cafeteria"
#       ],
#       "dropped": [
#         "Chefs and Head Cooks",
#         "Cooks, Restaurant",
#         "Food Preparation Workers",
#         "First-Line Supervisors of Food Preparation and Serving Workers",
#         "Cooks, Private Household",
#         "Food Service Managers",
#         "Waiters and Waitresses",
#         "Bartenders"
#       ]
#     },
#     {
#       "job_id": "2780653010",
#       "job_ad_title": "Customer Success Executive - Remote",
#       "domain": "Customer Services",
#       "sector": "Customer Services Jobs",
#       "job_desc": "[Customer Services] Customer Success Executive - Remote",
#       "kept": [
#         "Customer Service Representatives"
#       ],
#       "dropped": [
#         "Property, Real Estate, and Community Association Managers",
#         "Home Appliance Repairers",
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop",
#         "Social and Human Service Assistants",
#         "Human Resources Specialists",
#         "Telecommunications Engineering Specialists",
#         "Fuel Cell Engineers",
#         "Online Merchants"
#       ]
#     },
#     {
#       "job_id": "2639240590",
#       "job_ad_title": "Stock Controller/Supply Manager",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] Stock Controller/Supply Manager",
#       "kept": [
#         "Supply Chain Managers"
#       ],
#       "dropped": [
#         "Shipping, Receiving, and Inventory Clerks",
#         "Production, Planning, and Expediting Clerks",
#         "Transportation, Storage, and Distribution Managers",
#         "Logistics Engineers",
#         "Logistics Analysts",
#         "Logisticians",
#         "Stockers and Order Fillers"
#       ]
#     },
#     {
#       "job_id": "2693450403",
#       "job_ad_title": "Nights Transport Planner",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] Transport Planner for a leading multi model logistics business",
#       "kept": [
#         "Transportation, Storage, and Distribution Managers"
#       ],
#       "dropped": [
#         "Light Truck Drivers",
#         "Industrial Truck and Tractor Operators",
#         "Railroad Conductors and Yardmasters",
#         "First-Line Supervisors of Material-Moving Machine and Vehicle Operators",
#         "Logistics Engineers",
#         "Logistics Analysts",
#         "Logisticians",
#         "Freight Forwarders"
#       ]
#     },
#     {
#       "job_id": "2791717253",
#       "job_ad_title": "Receptionist",
#       "domain": "Manufacturing",
#       "sector": "Admin Jobs",
#       "job_desc": "[Manufacturing] Receptionist for a manufacturing business in Rotherham",
#       "kept": [
#         "Receptionists and Information Clerks"
#       ],
#       "dropped": [
#         "Hotel, Motel, and Resort Desk Clerks",
#         "Lodging Managers",
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop",
#         "Concierges",
#         "Structural Metal Fabricators and Fitters",
#         "Manufacturing Engineers",
#         "Patternmakers, Metal and Plastic",
#         "Tool and Die Makers"
#       ]
#     },
#     {
#       "job_id": "2742996472",
#       "job_ad_title": "Business Process Support (P2P)",
#       "domain": "Manufacturing",
#       "sector": "IT Jobs",
#       "job_desc": "[Manufacturing] Business Process Support (P2P) to drive implementation of new policies and processes across the organisation.",
#       "kept": [
#         "Manufacturing Engineers"
#       ],
#       "dropped": [
#         "Team Assemblers",
#         "Rolling Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Industrial Production Managers",
#         "Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Document Management Specialists",
#         "Industrial Engineers",
#         "Regulatory Affairs Managers",
#         "Logistics Analysts"
#       ]
#     },
#     {
#       "job_id": "2791201272",
#       "job_ad_title": "Service Administrator",
#       "domain": "Automotive",
#       "sector": "Admin Jobs",
#       "job_desc": "[Automotive] Service Administrator",
#       "kept": [
#         "Automotive Service Technicians and Mechanics"
#       ],
#       "dropped": [
#         "Automotive and Watercraft Service Attendants",
#         "Automotive Engineering Technicians",
#         "Cleaners of Vehicles and Equipment",
#         "Parking Attendants",
#         "Automotive Engineers",
#         "Automotive Body and Related Repairers"
#       ]
#     },
#     {
#       "job_id": "2746664291",
#       "job_ad_title": "Multi Skilled Maintenance Engineer",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Multi Skilled Maintenance Engineer for an award-winning textiles processing company in West Yorkshire",
#       "kept": [
#         "Maintenance Workers, Machinery"
#       ],
#       "dropped": [
#         "Maintenance and Repair Workers, General",
#         "Boilermakers",
#         "Control and Valve Installers and Repairers, Except Mechanical Door",
#         "Stationary Engineers and Boiler Operators",
#         "Manufacturing Engineers",
#         "Mechanical Engineers",
#         "Engine and Other Machine Assemblers",
#         "Aircraft Mechanics and Service Technicians"
#       ]
#     },
#     {
#       "job_id": "2847461196",
#       "job_ad_title": "LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "kept": [
#         "Tank Car, Truck, and Ship Loaders"
#       ],
#       "dropped": [
#         "Septic Tank Servicers and Sewer Pipe Cleaners",
#         "Conveyor Operators and Tenders",
#         "Roustabouts, Oil and Gas",
#         "Refuse and Recyclable Material Collectors",
#         "Industrial Truck and Tractor Operators",
#         "Freight Forwarders",
#         "Wellhead Pumpers",
#         "Petroleum Pump System Operators, Refinery Operators, and Gaugers"
#       ]
#     },
#     {
#       "job_id": "2846431729",
#       "job_ad_title": "Operative",
#       "domain": "Manufacturing",
#       "sector": "Manufacturing Jobs",
#       "job_desc": "[Manufacturing] Temporary to permanent manufacturing operative role with a 2-shift system",
#       "kept": [
#         "Team Assemblers"
#       ],
#       "dropped": [
#         "Engine and Other Machine Assemblers",
#         "Electromechanical Equipment Assemblers",
#         "Packers and Packagers, Hand",
#         "Machine Feeders and Offbearers",
#         "Industrial Production Managers",
#         "Millwrights",
#         "Packaging and Filling Machine Operators and Tenders",
#         "Structural Metal Fabricators and Fitters",
#         "Robotics Technicians"
#       ]
#     },
#     {
#       "job_id": "2848376850",
#       "job_ad_title": "Engineering Stores / SAP Coordinator",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Engineering Stores / SAP Coordinator",
#       "kept": [
#         "Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic"
#       ],
#       "dropped": [
#         "Rolling Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Production, Planning, and Expediting Clerks",
#         "Machine Feeders and Offbearers",
#         "Shipping, Receiving, and Inventory Clerks",
#         "Manufacturing Engineers",
#         "Industrial Engineers",
#         "Industrial Production Managers",
#         "Logisticians",
#         "Structural Metal Fabricators and Fitters"
#       ]
#     },
#     {
#       "job_id": "2838003039",
#       "job_ad_title": "Teacher",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Experienced teacher required for a temporary position at Gee Cross Holy Trinity Primary and Nursery School.",
#       "kept": [
#         "Kindergarten Teachers, Except Special Education"
#       ],
#       "dropped": [
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Special Education Teachers, Secondary School",
#         "Art, Drama, and Music Teachers, Postsecondary",
#         "Special Education Teachers, Elementary School",
#         "Substitute Teachers, Short-Term",
#         "Preschool Teachers, Except Special Education",
#         "Special Education Teachers, Preschool",
#         "Elementary School Teachers, Except Special Education"
#       ]
#     }
#   ]
# }

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: matplotlib in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib-venn) (3.10.6)
# Requirement already satisfied: numpy in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib-venn) (2.3.3)
# Requirement already satisfied: scipy in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib-venn) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (25.0)
# Requirement already satisfied: pillow>=8 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /lus/lfs1aip2/projects/a5u/adu_dev/aisi-economy-index/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn3
from pathlib import Path

# ---- CONFIG: Update these paths to your actual files ----
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151812_task0_20260205_053358.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151815_task0_20260205_054654.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2151813_task0_20260205_053744.jsonl"
}

def load_final_occupations(filepath):
    """Loads job_id -> set of kept occupations mapping."""
    data = {}
    if not filepath.exists():
        print(f"Warning: File {filepath} not found.")
        return data
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            # Store the 'final' list as a frozen set for easy comparison
            data[obj['job_id']] = set(obj['final'])
    return data

def calculate_jaccard(set1, set2):
    """Intersection over Union."""
    if not set1 and not set2: return 1.0
    return len(set1 & set2) / len(set1 | set2)

# 1. Load Data
results = {name: load_final_occupations(path) for name, path in PATHS.items()}
common_jobs = set.intersection(*[set(d.keys()) for d in results.values() if d])

print(f"Analyzing {len(common_jobs)} common jobs across models...")

# 2. Calculate Jaccard Matrix
model_names = list(results.keys())
matrix = np.zeros((len(model_names), len(model_names)))

for i, name1 in enumerate(model_names):
    for j, name2 in enumerate(model_names):
        similarities = [
            calculate_jaccard(results[name1][jid], results[name2][jid]) 
            for jid in common_jobs
        ]
        matrix[i, j] = np.mean(similarities)

# 3. Visualization: Jaccard Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(matrix, annot=True, xticklabels=model_names, yticklabels=model_names, cmap="YlGnBu")
plt.title("Mean Jaccard Agreement (Consensus) Matrix")
plt.savefig("model_agreement_heatmap.png")
print("Saved Heatmap: model_agreement_heatmap.png")

# 4. Visualization: 3-Way Venn Diagram
# Prepare sets of (job_id, occupation) tuples for global intersection
sets_for_venn = {}
for name in model_names:
    global_set = set()
    for jid in common_jobs:
        for occ in results[name][jid]:
            global_set.add((jid, occ)) # Unique key is Job + Occ
    sets_for_venn[name] = global_set

plt.figure(figsize=(10, 8))
venn3([sets_for_venn[m] for m in model_names], set_labels=model_names)
plt.title("Overlap of Job-Occupation Assignments")
plt.savefig("model_overlap_venn.png")
print("Saved Venn: model_overlap_venn.png")

# 5. Generate Disagreement Report (Top 5 Divergent Cases)
print("\n=== TOP DISAGREEMENTS (E5 vs BGE) ===")
disagreements = []
for jid in list(common_jobs)[:100]: # Sample first 100 for speed
    score = calculate_jaccard(results['E5'][jid], results['BGE'][jid])
    if score < 0.5:
        disagreements.append({
            "job_id": jid,
            "E5_kept": results['E5'][jid],
            "BGE_kept": results['BGE'][jid]
        })

for d in disagreements[:5]:
    print(f"Job ID: {d['job_id']}")
    print(f"  E5 Kept : {d['E5_kept']}")
    print(f"  BGE Kept: {d['BGE_kept']}")
    print("-" * 30)
# Out:
# Analyzing 1000 common jobs across models...
# Saved Heatmap: model_agreement_heatmap.png
# Saved Venn: model_overlap_venn.png
#
# === TOP DISAGREEMENTS (E5 vs BGE) ===
# Job ID: 2791962545
#   E5 Kept : {'Retail Salespersons'}
#   BGE Kept: {'First-Line Supervisors of Retail Sales Workers', 'Retail Salespersons', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products'}
# ------------------------------
# Job ID: 2811598043
#   E5 Kept : {'Psychiatric Aides'}
#   BGE Kept: {'Advanced Practice Psychiatric Nurses'}
# ------------------------------
# Job ID: 2833240507
#   E5 Kept : {'Software Quality Assurance Analysts and Testers'}
#   BGE Kept: {'Software Developers'}
# ------------------------------
# Job ID: 2719570720
#   E5 Kept : {'Nurse Practitioners'}
#   BGE Kept: {'Health Education Specialists'}
# ------------------------------
# Job ID: 2732647910
#   E5 Kept : {'Parts Salespersons'}
#   BGE Kept: {'Logisticians'}
# ------------------------------
