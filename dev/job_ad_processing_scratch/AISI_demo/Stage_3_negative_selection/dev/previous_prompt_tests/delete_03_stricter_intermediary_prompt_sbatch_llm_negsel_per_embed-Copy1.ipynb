# %% [markdown]
# # Helpers

# %%
import json
import re
import random
import statistics
from pathlib import Path
from collections import Counter, defaultdict
from datetime import datetime

import numpy as np

# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------
_RUN_RE = re.compile(
    r"llama_drop_only_(?P<month>adzuna_month\d{2})_(?P<start>\d+)_(?P<stop>\d+)_job(?P<jobid>\d+)_task(?P<taskid>\d+)_\d{8}_\d{6}\.jsonl$"
)

IT_PATTERNS = [
    r"\bsoftware\b", r"\bdeveloper\b", r"\bengineer\b", r"\bdata\b", r"\bml\b", r"\bai\b",
    r"\bcloud\b", r"\bcyber\b", r"\bsecurity\b", r"\bnetwork\b", r"\bsystems?\b",
    r"\bdatabase\b", r"\bit\b", r"\bdevops\b"
]
_IT_RE = re.compile("|".join(IT_PATTERNS), flags=re.I)

def _is_it_role(title: str) -> bool:
    if not title:
        return False
    return bool(_IT_RE.search(title))


def _infer_npz_from_jsonl(jsonl_path: Path) -> Path:
    """
    NEW layout:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>/llama_drop_only_....jsonl
    NPZ sits at:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>.npz
    """
    m = _RUN_RE.search(jsonl_path.name)
    if not m:
        raise ValueError(f"JSONL filename doesn't match expected pattern: {jsonl_path.name}")

    month = m.group("month")
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    return embed_root / f"{month}.npz"


def _get_job_ids(z) -> np.ndarray:
    """
    Supports both schemas:
      new: job_ids
      old: job_id
    Returns np.ndarray[str]
    """
    if "job_ids" in z.files:
        return z["job_ids"].astype(str)
    if "job_id" in z.files:
        return z["job_id"].astype(str)
    raise KeyError(f"NPZ missing job id key. Need job_ids or job_id. Have={sorted(z.files)}")


def _load_npz_lookup(npz_path: Path):
    """
    Expects stage3-prep NPZ keys (canonical):
      job_ids (or job_id), job_ad_title, job_desc, job_tasks, domain, job_sector_category, job_description
    """
    with np.load(npz_path, allow_pickle=True) as z:
        job_ids = _get_job_ids(z)

        # canonical (your stage3-prep)
        job_ad_title = z["job_ad_title"]
        job_desc = z["job_desc"]
        job_tasks = z["job_tasks"]

        domain = z["domain"] if "domain" in z.files else None
        job_sector_category = z["job_sector_category"] if "job_sector_category" in z.files else None
        job_description = z["job_description"] if "job_description" in z.files else None

    lookup = {}
    for i, jid in enumerate(job_ids):
        lookup[jid] = {
            "job_ad_title": None if job_ad_title[i] is None else str(job_ad_title[i]),
            "job_desc": None if job_desc[i] is None else str(job_desc[i]),
            "job_tasks": None if job_tasks[i] is None else str(job_tasks[i]),
            "job_description": None if job_description is None or job_description[i] is None else str(job_description[i]),
            "domain": None if domain is None or domain[i] is None else str(domain[i]),
            "job_sector_category": None if job_sector_category is None or job_sector_category[i] is None else str(job_sector_category[i]),
        }
    return lookup


# ---------------------------------------------------------------------
# Main: report generator
# ---------------------------------------------------------------------
def gen_report(jsonl_path: str, *, npz_path: str | None = None, sample_n: int = 30, seed: int = 0):
    """
    jsonl_path: path to llama_drop_only_*.jsonl
    npz_path  : optional explicit context NPZ. If None, inferred from jsonl name/dir.
    """
    random.seed(seed)

    jsonl_path = Path(jsonl_path)
    if not jsonl_path.exists():
        raise FileNotFoundError(f"Missing JSONL: {jsonl_path}")

    inferred_npz = _infer_npz_from_jsonl(jsonl_path)
    npz_path = Path(npz_path) if npz_path else inferred_npz
    if not npz_path.exists():
        raise FileNotFoundError(f"Missing NPZ: {npz_path}")

    # report folder: put it under .../llm_negative_selection/<EMBED>/evaluation_reports/
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    report_dir = embed_root / "evaluation_reports"
    report_dir.mkdir(parents=True, exist_ok=True)

    print("JSONL:", jsonl_path)
    print("NPZ :", npz_path)
    print("OUT :", report_dir)

    lookup = _load_npz_lookup(npz_path)

    before_counts = []
    after_counts = []
    kept_titles = Counter()
    domain_kept = defaultdict(list)

    it_leak = 0
    total_kept = 0
    empty_outputs = 0

    samples = []
    seen_sample_ids = set()

    with jsonl_path.open("r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            try:
                r = json.loads(line)
            except Exception:
                continue

            jid = str(r.get("job_id", "")).strip()
            if not jid:
                continue

            ctx = lookup.get(jid, {})

            cand = r.get("candidates") or []
            final = r.get("final") or []

            before_counts.append(len(cand))
            after_counts.append(len(final))

            if len(final) == 0:
                empty_outputs += 1

            for t in final:
                kept_titles[t] += 1
                total_kept += 1
                if _is_it_role(t):
                    it_leak += 1

            dom = ctx.get("domain") or "UNKNOWN"
            domain_kept[dom].append(len(final))

            # sample gate
            if len(samples) < sample_n and jid not in seen_sample_ids and random.random() < 0.05:
                seen_sample_ids.add(jid)
                samples.append({
                    "job_id": jid,
                    "job_ad_title": ctx.get("job_ad_title"),
                    "domain": ctx.get("domain"),
                    "sector": ctx.get("job_sector_category"),
                    "job_desc": ctx.get("job_desc"),
                    "kept": final,
                    "dropped": r.get("drop") or [],
                })

    if not before_counts:
        raise RuntimeError("No valid rows parsed from JSONL.")

    before_avg = statistics.mean(before_counts)
    after_avg = statistics.mean(after_counts)
    drop_rate = 1.0 - (after_avg / before_avg if before_avg else 0.0)
    it_share = it_leak / max(total_kept, 1)

    metrics = {
        "jobs": len(before_counts),
        "avg_candidates_before": round(before_avg, 3),
        "avg_candidates_after": round(after_avg, 3),
        "drop_rate": round(drop_rate, 4),
        "empty_outputs_percent": round(100.0 * empty_outputs / len(before_counts), 3),
        "it_leakage_share": round(it_share, 4),
        "min_kept": int(min(after_counts)),
        "max_kept": int(max(after_counts)),
    }

    domain_summary = {d: round(statistics.mean(v), 3) for d, v in domain_kept.items()}

    report = {
        "run": {
            "jsonl": str(jsonl_path),
            "npz": str(npz_path),
            "generated_at": datetime.now().isoformat(timespec="seconds"),
        },
        "global_metrics": metrics,
        "top_kept_roles": kept_titles.most_common(25),
        "domain_summary_avg_kept": dict(sorted(domain_summary.items(), key=lambda x: (-x[1], x[0]))),
        "sample_cases": samples,
    }

    base = jsonl_path.stem
    report_json = report_dir / f"{base}_report.json"
    report_txt = report_dir / f"{base}_report.txt"

    with report_json.open("w", encoding="utf-8") as f:
        json.dump(report, f, indent=2, ensure_ascii=False)

    with report_txt.open("w", encoding="utf-8") as f:
        f.write("=== GLOBAL METRICS ===\n")
        for k, v in metrics.items():
            f.write(f"{k}: {v}\n")

        f.write("\n=== TOP KEPT OCCUPATIONS ===\n")
        for title, cnt in kept_titles.most_common(25):
            f.write(f"{cnt}  {title}\n")

        f.write("\n=== DOMAIN AVG KEPT ===\n")
        for d, v in sorted(domain_summary.items(), key=lambda x: (-x[1], x[0])):
            f.write(f"{d}: {v}\n")

        f.write("\n=== SAMPLE CASES (truncated) ===\n")
        for s in samples[:10]:
            f.write(f"\njob_id: {s['job_id']}\n")
            f.write(f"title:  {s.get('job_ad_title')}\n")
            f.write(f"domain: {s.get('domain')} | sector: {s.get('sector')}\n")
            f.write(f"kept:   {s.get('kept')}\n")
            f.write(f"drop:   {s.get('dropped')}\n")

    print("\nSaved:")
    print(" ", report_json)
    print(" ", report_txt)

    return report_json, report_txt

# %% [markdown]
# # Prompt 3 -  strict intermediary - Embeddings weight 0.6 tasks e 0.4 roles;

# %%
# ===== Prompt printer: EXACT wiring check (single row) =====

import numpy as np
from pathlib import Path

# ---- CONFIG ----
NPZ_PATH = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz")
ROW_IDX = 35  # Change this to inspect different samples

# ---- LOAD ----
data = np.load(NPZ_PATH, allow_pickle=True)

# Map keys
job_ad_titles = data["job_ad_title"]
job_tasks_arr = data["job_tasks"]
domains = data["domain"]
job_descs = data["job_desc"]
job_sector_categories = data["job_sector_category"]
job_full_ads = data["job_description"]
candidates_matrix = data["titles"]  # 2D array [N, K]

# ---- EXTRACT ROW ----
title = job_ad_titles[ROW_IDX]
domain = domains[ROW_IDX]
tasks = job_tasks_arr[ROW_IDX]
desc = job_descs[ROW_IDX]
category = job_sector_categories[ROW_IDX]
full_excerpt = job_full_ads[ROW_IDX]
row_candidates = candidates_matrix[ROW_IDX]

# Clean up tasks
if isinstance(tasks, (list, np.ndarray)):
    tasks_str = ", ".join([str(t) for t in tasks if t])
else:
    tasks_str = str(tasks)

# Format candidates as a 1-based numbered list
numbered_candidates = "\n".join([f"{i+1}) {cand}" for i, cand in enumerate(row_candidates) if cand])

# ---- BUILD PROMPT (verbatim logic) ----

full_block = (
    f"\nFULL AD EXCERPT (use only for concrete duties, tools, licences, ignore fluff):\n{str(full_excerpt)[:700]}\n"
    if full_excerpt else ""
)

prompt = f"""You are a Precise Occupation Specialist. Your goal is to DROP as many candidates as possible. Only an functional match survives.

Read the job context carefully.

JOB CONTEXT (priority order):
1) Job Title + Job Domain (primary anchor)
2) Job Tasks (evidence)
3) Job short description (evidence)
4) Job Category (weak evidence)
5) Raw job ad excerpt (noisy evidence)

Title: {title}
Job list of Tasks/Skills: {tasks_str}
Job Domain: {domain}
Job short description: {desc}
Job Category: {category}
{full_block}

RE-READ ANCHOR JOB CONTEXT:
Title: {title}
Domain: {domain}
Tasks/Skills: {tasks_str}

CANDIDATES (1-based)
{numbered_candidates}

DECISION GUIDELINES:

1) THE ANCHOR PROTECTION RULE (Priority):
Identify the candidate that most directly mirrors the Job Title. You are strictly forbidden from dropping a direct functional match (e.g., if the job is 'Android Developer', you MUST keep 'Software Developers').

2) FUNCTIONAL ALIGNMENT:
Only keep candidates where the day-to-day work (Tasks) matches the candidate occupation. If a candidate is only "vaguely related" or in the same industry but a different role, DROP IT.

3) SPECIFICITY HIERARCHY:
If a specific role (e.g., 'Hospitalist') and its parent category (e.g., 'Physician') are both present, keep the specific one and DROP the generic parent.

4) IT DOMAIN FILTER:
If the Domain is NOT IT, be skeptical of Software/Data roles unless the 'Tasks' section explicitly describes technical work like coding or system administration.

5) REASONABLE BUDGET (1-3):
Aim for the most concise list possible, ideally 2 or 3 roles. You may keep 3 only if they are distinct but equally valid functional matches. NEVER keep 5+.

OUTPUT FORMAT:
Return ONLY valid JSON. 
Example for a list where only the second candidate was the actual match:
{{"drop":[2,3,5,6,7,8,9,10]}}

AUDIT VERDICT:
Return ONLY JSON:
{{"drop":[2,3,5,7,8,9,10]}}
""".strip()

# ---- PRINT ----
print("-" * 30)
print(f"VERIFIED MAXIMUM AGGRESSION PROMPT (ROW {ROW_IDX}):")
print("-" * 30)
print(prompt)
print("-" * 30)
# Out:
# ------------------------------
# VERIFIED MAXIMUM AGGRESSION PROMPT (ROW 35):
# ------------------------------
# You are a Precise Occupation Specialist. Your goal is to DROP as many candidates as possible. Only an functional match survives.
#
# Read the job context carefully.
#
# JOB CONTEXT (priority order):
# 1) Job Title + Job Domain (primary anchor)
# 2) Job Tasks (evidence)
# 3) Job short description (evidence)
# 4) Job Category (weak evidence)
# 5) Raw job ad excerpt (noisy evidence)
#
# Title: Sommelier-Restaurant Gordon Ramsay
# Job list of Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
# Job Domain: Hospitality & Catering
# Job short description: [Hospitality & Catering] Sommelier for a Three Michelin Star restaurant
# Job Category: Hospitality & Catering Jobs
#
# FULL AD EXCERPT (use only for concrete duties, tools, licences, ignore fluff):
# Sommelier - Restaurant Gordon Ramsay, Three Michelin Star We are looking for an experienced Sommelier who has a real passion for delivering the highest levels of service and creating a fantastic dining experience for our guests. Restaurant Gordon Ramsay combines contemporary elegance, an intimate ambience and unparalleled service, all the hallmarks of true excellence. Each dish, beautifully presented, uses the best ingredients and sublime flavour combinations, demonstrating the outstanding technical skill of Chef Matt Abe and his team. The restaurant boasts twenty years of holding three Michelin stars and is now London’s longest running restaurant to hold this accolade. As Sommelier you will
#
#
# RE-READ ANCHOR JOB CONTEXT:
# Title: Sommelier-Restaurant Gordon Ramsay
# Domain: Hospitality & Catering
# Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
#
# CANDIDATES (1-based)
# 1) Waiters and Waitresses
# 2) Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 3) Food Service Managers
# 4) Dining Room and Cafeteria Attendants and Bartender Helpers
# 5) Chefs and Head Cooks
# 6) Bartenders
#
# DECISION GUIDELINES:
#
# 1) THE ANCHOR PROTECTION RULE (Priority):
# Identify the candidate that most directly mirrors the Job Title. You are strictly forbidden from dropping a direct functional match (e.g., if the job is 'Android Developer', you MUST keep 'Software Developers').
#
# 2) FUNCTIONAL ALIGNMENT:
# Only keep candidates where the day-to-day work (Tasks) matches the candidate occupation. If a candidate is only "vaguely related" or in the same industry but a different role, DROP IT.
#
# 3) SPECIFICITY HIERARCHY:
# If a specific role (e.g., 'Hospitalist') and its parent category (e.g., 'Physician') are both present, keep the specific one and DROP the generic parent.
#
# 4) IT DOMAIN FILTER:
# If the Domain is NOT IT, be skeptical of Software/Data roles unless the 'Tasks' section explicitly describes technical work like coding or system administration.
#
# 5) REASONABLE BUDGET (1-3):
# Aim for the most concise list possible, ideally 2 or 3 roles. You may keep 3 only if they are distinct but equally valid functional matches. NEVER keep 5+.
#
# OUTPUT FORMAT:
# Return ONLY valid JSON.
# Example for a list where only the second candidate was the actual match:
# {"drop":[2,3,5,6,7,8,9,10]}
#
# AUDIT VERDICT:
# Return ONLY JSON:
# {"drop":[2,3,5,7,8,9,10]}
# ------------------------------

# %% [markdown]
# # bge

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_bge.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
# Out:
# JOBID: 2152607

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152607 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:27    5:57:33     1 nid010467
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152607 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:32    5:57:28     1 nid010467
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152607 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:37    5:57:23     1 nid010467
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152607 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:42    5:57:18     1 nid010467
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152607 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:47    5:57:13     1 nid010467
#
# --- STDOUT ---
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152607 autonomyluiz     workq z_llama_drop_new_test_bg  R    6:00:00       2:54    5:57:06     1 nid010467
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# Allocated: 14.990819454193115 GB
# Reserved: 55.681640625 GB
# [END] 2026-02-05 06:51:59
# [RUNTIME] 2.67 minutes (160.1 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:47, 32.50s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:15, 22.50s/it]
# Batches:  38%|███▊      | 3/8 [01:16<02:06, 25.35s/it]
# Batches:  50%|█████     | 4/8 [01:28<01:19, 19.85s/it]
# Batches:  62%|██████▎   | 5/8 [01:39<00:50, 16.81s/it]
# Batches:  75%|███████▌  | 6/8 [01:54<00:32, 16.16s/it]
# Batches:  88%|████████▊ | 7/8 [02:05<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.37s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.42s/it]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# Allocated: 14.990819454193115 GB
# Reserved: 55.681640625 GB
# [END] 2026-02-05 06:51:59
# [RUNTIME] 2.67 minutes (160.1 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:47, 32.50s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:15, 22.50s/it]
# Batches:  38%|███▊      | 3/8 [01:16<02:06, 25.35s/it]
# Batches:  50%|█████     | 4/8 [01:28<01:19, 19.85s/it]
# Batches:  62%|██████▎   | 5/8 [01:39<00:50, 16.81s/it]
# Batches:  75%|███████▌  | 6/8 [01:54<00:32, 16.16s/it]
# Batches:  88%|████████▊ | 7/8 [02:05<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.37s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.42s/it]
# [W205 06:51:59.351748486 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# Allocated: 14.990819454193115 GB
# Reserved: 55.681640625 GB
# [END] 2026-02-05 06:51:59
# [RUNTIME] 2.67 minutes (160.1 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:47, 32.50s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:15, 22.50s/it]
# Batches:  38%|███▊      | 3/8 [01:16<02:06, 25.35s/it]
# Batches:  50%|█████     | 4/8 [01:28<01:19, 19.85s/it]
# Batches:  62%|██████▎   | 5/8 [01:39<00:50, 16.81s/it]
# Batches:  75%|███████▌  | 6/8 [01:54<00:32, 16.16s/it]
# Batches:  88%|████████▊ | 7/8 [02:05<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.37s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.42s/it]
# [W205 06:51:59.351748486 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# Allocated: 14.990819454193115 GB
# Reserved: 55.681640625 GB
# [END] 2026-02-05 06:51:59
# [RUNTIME] 2.67 minutes (160.1 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:47, 32.50s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:15, 22.50s/it]
# Batches:  38%|███▊      | 3/8 [01:16<02:06, 25.35s/it]
# Batches:  50%|█████     | 4/8 [01:28<01:19, 19.85s/it]
# Batches:  62%|██████▎   | 5/8 [01:39<00:50, 16.81s/it]
# Batches:  75%|███████▌  | 6/8 [01:54<00:32, 16.16s/it]
# Batches:  88%|████████▊ | 7/8 [02:05<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.37s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.42s/it]
# [W205 06:51:59.351748486 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# Allocated: 14.990819454193115 GB
# Reserved: 55.681640625 GB
# [END] 2026-02-05 06:51:59
# [RUNTIME] 2.67 minutes (160.1 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:47, 32.50s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:15, 22.50s/it]
# Batches:  38%|███▊      | 3/8 [01:16<02:06, 25.35s/it]
# Batches:  50%|█████     | 4/8 [01:28<01:19, 19.85s/it]
# Batches:  62%|██████▎   | 5/8 [01:39<00:50, 16.81s/it]
# Batches:  75%|███████▌  | 6/8 [01:54<00:32, 16.16s/it]
# Batches:  88%|████████▊ | 7/8 [02:05<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.37s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.42s/it]
# [W205 06:51:59.351748486 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# Allocated: 14.990819454193115 GB
# Reserved: 55.681640625 GB
# [END] 2026-02-05 06:51:59
# [RUNTIME] 2.67 minutes (160.1 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:47, 32.50s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:15, 22.50s/it]
# Batches:  38%|███▊      | 3/8 [01:16<02:06, 25.35s/it]
# Batches:  50%|█████     | 4/8 [01:28<01:19, 19.85s/it]
# Batches:  62%|██████▎   | 5/8 [01:39<00:50, 16.81s/it]
# Batches:  75%|███████▌  | 6/8 [01:54<00:32, 16.16s/it]
# Batches:  88%|████████▊ | 7/8 [02:05<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.37s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.42s/it]
# [W205 06:51:59.351748486 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# Allocated: 14.990819454193115 GB
# Reserved: 55.681640625 GB
# [END] 2026-02-05 06:51:59
# [RUNTIME] 2.67 minutes (160.1 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.18it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.15it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:47, 32.50s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:15, 22.50s/it]
# Batches:  38%|███▊      | 3/8 [01:16<02:06, 25.35s/it]
# Batches:  50%|█████     | 4/8 [01:28<01:19, 19.85s/it]
# Batches:  62%|██████▎   | 5/8 [01:39<00:50, 16.81s/it]
# Batches:  75%|███████▌  | 6/8 [01:54<00:32, 16.16s/it]
# Batches:  88%|████████▊ | 7/8 [02:05<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.37s/it]
# Batches: 100%|██████████| 8/8 [02:35<00:00, 19.42s/it]
# [W205 06:51:59.351748486 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 27
#      24 if not sq:
#      25     break
# ---> 27 time.sleep(5)
#
# KeyboardInterrupt:

# %%
gen_report("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl")
# Out:
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918_report.txt
# (PosixPath('/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918_report.json'),
#  PosixPath('/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918_report.txt'))

# %%
from pathlib import Path
p = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/")
latest = max(p.glob("llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918_report.txt"), key=lambda x: x.stat().st_mtime)
print(latest.read_text())
# Out:
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.221
# avg_candidates_after: 2.477
# drop_rate: 0.6987
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0694
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 50  Information Technology Project Managers
# 41  Software Developers
# 33  Personal Care Aides
# 33  Advertising and Promotions Managers
# 31  Mental Health and Substance Abuse Social Workers
# 28  Sales Managers
# 26  Marketing Managers
# 24  Customer Service Representatives
# 24  Childcare Workers
# 24  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 23  Healthcare Social Workers
# 23  Advertising Sales Agents
# 23  Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 22  Administrative Services Managers
# 21  Software Quality Assurance Analysts and Testers
# 20  Food Service Managers
# 20  Home Health Aides
# 19  Acute Care Nurses
# 19  Financial Managers
# 19  First-Line Supervisors of Office and Administrative Support Workers
# 19  Helpers--Installation, Maintenance, and Repair Workers
# 19  Computer Systems Engineers/Architects
# 19  Stockers and Order Fillers
# 18  Cooks, Institution and Cafeteria
# 18  Child, Family, and School Social Workers
#
# === DOMAIN AVG KEPT ===
# Administration/Office Support: 3
# Administrative/Office: 3
# Advertising and Marketing: 3
# Aerospace & Manufacturing: 3
# Automotive Retail: 3
# Beauty and Cosmetics: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction and Property: 3
# Construction/Engineering: 3
# Construction/Property Maintenance: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consulting: 3
# Cybersecurity: 3
# Data and Intelligence consultancy: 3
# Digital Marketing: 3
# Digital Media: 3
# Domestic Services: 3
# Domestic help & Cleaning: 3
# Education Technology: 3
# Education and Training: 3
# Electronics Technology: 3
# Energy Trading: 3
# Engineering/Manufacturing: 3
# Environmental Science: 3
# Fashion: 3
# Fashion Retail: 3
# Finance/Banking: 3
# Food Industry: 3
# Food Service: 3
# Food Service/Hospitality: 3
# Food and Beverage: 3
# Government: 3
# Health & Social Care: 3
# Health and Fitness: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Hospitality: 3
# Higher Education: 3
# Home Accessories Manufacturing: 3
# IT and Consulting: 3
# IT and Technology: 3
# IT, Fintech, Blockchain, AI: 3
# IT/Software Development: 3
# Leisure: 3
# Leisure and Fitness: 3
# Logistics: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Logistics and Transportation: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Manufacturing/Production: 3
# Marketing: 3
# Media and Communications: 3
# Media and Entertainment: 3
# Non-Profit: 3
# Non-Profit/NGO: 3
# Non-profit/Charity: 3
# Online Surveys/Admin Jobs: 3
# PR: 3
# PR and Communications: 3
# Pharmaceutical: 3
# Property: 3
# Public Relations: 3
# Publishing: 3
# Real Estate/Property Management: 3
# Remote Work/Online Opportunities: 3
# Renewable Energy: 3
# Renewables: 3
# Research and Market Analysis: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# Sales Jobs: 3
# Sales and Business Development: 3
# Scientific & QA: 3
# Security: 3
# Security and Customer Service: 3
# Security and Law Enforcement: 3
# Social Housing: 3
# Social Services/Social Work: 3
# Software Development: 3
# Software Engineering: 3
# Sports/Leisure: 3
# Technology/Software: 3
# Telecommunications: 3
# Tourism/Hospitality: 3
# Trade and Construction: 3
# Translation and Interpreting: 3
# Transportation: 3
# Transportation/Fleet Management: 3
# Travel and Tourism: 3
# Utility: 3
# Waste Management: 3
# Automotive: 2.846
# Consultancy: 2.8
# Social work: 2.8
# Human Resources: 2.75
# Finance: 2.714
# Social Work: 2.714
# Logistics & Warehouse: 2.674
# Customer Services: 2.667
# Energy: 2.667
# Hospitality: 2.667
# Hospitality & Catering: 2.667
# Recruitment: 2.667
# Admin Jobs: 2.6
# Facilities Management: 2.6
# IT: 2.583
# Sales: 2.571
# Manufacturing: 2.526
# Construction: 2.5
# Financial Services: 2.5
# Real Estate: 2.429
# Sales and Marketing: 2.429
# Education: 2.421
# Retail: 2.417
# Trade & Construction: 2.417
# Healthcare: 2.388
# Administration: 2.333
# Biotechnology: 2.333
# Creative & Design: 2.333
# IT Jobs: 2.333
# Insurance: 2.333
# Public Administration: 2.333
# Engineering: 2.297
# HR & Recruitment: 2.25
# Legal: 2.222
# Accounting & Finance: 2.186
# Healthcare & Nursing: 2.073
# Agriculture: 2
# Customer Service: 2
# Domestic help & Cleaning Jobs: 2
# Energy and Utilities: 2
# Fintech: 2
# Healthcare/Social Care: 2
# Healthcare/Social Work: 2
# Logistics/Transportation: 2
# Marketing/PR: 2
# Media and Advertising: 2
# Non-Profit/Charity: 2
# Scientific & QA Jobs: 2
# Technology: 2
# Transportation/Logistics: 2
# Market Research: 1.8
# Law: 1.7
# Aerospace: 1
# Agriculture/Rural: 1
# Biotechnology/Pharmaceutical: 1
# Construction and Maintenance: 1
# Consultancy Jobs: 1
# Digital/Technology: 1
# Domestic Help & Cleaning: 1
# Education/Training: 1
# Electrical Engineering: 1
# Estate Agency: 1
# Executive Search Firm: 1
# Farming/Agribusiness: 1
# Health and Social Care: 1
# Healthcare/Pharmaceutical: 1
# IT and Telecommunications: 1
# Marketing and Public Relations: 1
# Media: 1
# Military/Defence: 1
# Nuclear Engineering: 1
# Other/General Jobs: 1
# Public Health: 1
# Public Sector/ Law Enforcement: 1
# Recruitment Consultancy: 1
# Recruitment/Consultancy: 1
# Renewable Energy/Electric Vehicle: 1
# SaaS: 1
# Sales and Customer Service: 1
# Sales and Events: 1
# Sales and Recruitment: 1
# Security and Surveillance: 1
# Technology & Engineering: 1
# Utilities: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Waiters and Waitresses', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Food Service Managers']
# drop:   ['Dining Room and Cafeteria Attendants and Bartender Helpers', 'Chefs and Head Cooks', 'Bartenders']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Microsystems Engineers', 'Electrical and Electronics Drafters']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Electrical and Electronics Repairers, Commercial and Industrial Equipment', 'Manufacturing Engineers', 'Nanosystems Engineers', 'Electrical Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians']
# drop:   ['Solar Photovoltaic Installers', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Power-Line Installers and Repairers', 'Helpers--Electricians', 'Solar Sales Representatives and Assessors', 'Solar Energy Installation Managers', 'Solar Thermal Installers and Technicians', 'Electrical and Electronics Repairers, Powerhouse, Substation, and Relay']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Telephone Operators', 'Loan Interviewers and Clerks']
# drop:   ['Telemarketers', 'Human Resources Assistants, Except Payroll and Timekeeping', 'Receptionists and Information Clerks', 'New Accounts Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers', 'Child, Family, and School Social Workers']
# drop:   ['Personal Care Aides', 'Childcare Workers', 'Social and Human Service Assistants', 'Occupational Therapists']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Biochemists and Biophysicists']
# drop:   ['Biological Technicians', 'Bioengineers and Biomedical Engineers', 'Natural Sciences Managers', 'Chemical Technicians', 'Biofuels/Biodiesel Technology and Product Development Managers', 'Bioinformatics Technicians', 'Bioinformatics Scientists', 'Agricultural Technicians']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Robotics Engineers', 'Automotive Engineers', 'Software Developers']
# drop:   ['Photonics Engineers', 'Human Factors Engineers and Ergonomists', 'Telecommunications Engineering Specialists', 'Wind Energy Engineers', 'Talent Directors', 'Media Programming Directors', 'Web Developers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['First-Line Supervisors of Material-Moving Machine and Vehicle Operators', 'Industrial Truck and Tractor Operators', 'Heavy and Tractor-Trailer Truck Drivers']
# drop:   ['Laborers and Freight, Stock, and Material Movers, Hand', 'Crane and Tower Operators', 'Driver/Sales Workers', 'Light Truck Drivers', 'Bus Drivers, Transit and Intercity', 'Cargo and Freight Agents']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers', 'Social and Community Service Managers', 'Healthcare Social Workers']
# drop:   ['Mental Health and Substance Abuse Social Workers', 'Recreation Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Rehabilitation Counselors', 'Compensation and Benefits Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mobile Heavy Equipment Mechanics, Except Engines', 'Outdoor Power Equipment and Other Small Engine Mechanics', 'Mechanical Engineering Technologists and Technicians']
# drop:   ['Bus and Truck Mechanics and Diesel Engine Specialists', 'Medical Equipment Repairers', 'Aircraft Mechanics and Service Technicians', 'Locomotive Engineers', 'Mechanical Engineers', 'Aerospace Engineers', 'Civil Engineers']

# %% [markdown]
# ### e5

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_e5.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
# Out:
# JOBID: 2152609

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl
# Allocated: 14.990770816802979 GB
# Reserved: 56.177734375 GB
# [END] 2026-02-05 06:52:07
# [RUNTIME] 2.71 minutes (162.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.24it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:45, 32.21s/it]
# Batches:  25%|██▌       | 2/8 [00:54<02:36, 26.13s/it]
# Batches:  38%|███▊      | 3/8 [01:19<02:09, 25.86s/it]
# Batches:  50%|█████     | 4/8 [01:31<01:20, 20.20s/it]
# Batches:  62%|██████▎   | 5/8 [01:42<00:50, 16.98s/it]
# Batches:  75%|███████▌  | 6/8 [01:56<00:31, 15.94s/it]
# Batches:  88%|████████▊ | 7/8 [02:07<00:14, 14.48s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.33s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.69s/it]
# [W205 06:52:07.135167872 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl
# Allocated: 14.990770816802979 GB
# Reserved: 56.177734375 GB
# [END] 2026-02-05 06:52:07
# [RUNTIME] 2.71 minutes (162.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.24it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:45, 32.21s/it]
# Batches:  25%|██▌       | 2/8 [00:54<02:36, 26.13s/it]
# Batches:  38%|███▊      | 3/8 [01:19<02:09, 25.86s/it]
# Batches:  50%|█████     | 4/8 [01:31<01:20, 20.20s/it]
# Batches:  62%|██████▎   | 5/8 [01:42<00:50, 16.98s/it]
# Batches:  75%|███████▌  | 6/8 [01:56<00:31, 15.94s/it]
# Batches:  88%|████████▊ | 7/8 [02:07<00:14, 14.48s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.33s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.69s/it]
# [W205 06:52:07.135167872 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl
# Allocated: 14.990770816802979 GB
# Reserved: 56.177734375 GB
# [END] 2026-02-05 06:52:07
# [RUNTIME] 2.71 minutes (162.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.24it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:45, 32.21s/it]
# Batches:  25%|██▌       | 2/8 [00:54<02:36, 26.13s/it]
# Batches:  38%|███▊      | 3/8 [01:19<02:09, 25.86s/it]
# Batches:  50%|█████     | 4/8 [01:31<01:20, 20.20s/it]
# Batches:  62%|██████▎   | 5/8 [01:42<00:50, 16.98s/it]
# Batches:  75%|███████▌  | 6/8 [01:56<00:31, 15.94s/it]
# Batches:  88%|████████▊ | 7/8 [02:07<00:14, 14.48s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.33s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.69s/it]
# [W205 06:52:07.135167872 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl
# Allocated: 14.990770816802979 GB
# Reserved: 56.177734375 GB
# [END] 2026-02-05 06:52:07
# [RUNTIME] 2.71 minutes (162.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.24it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:32<03:45, 32.21s/it]
# Batches:  25%|██▌       | 2/8 [00:54<02:36, 26.13s/it]
# Batches:  38%|███▊      | 3/8 [01:19<02:09, 25.86s/it]
# Batches:  50%|█████     | 4/8 [01:31<01:20, 20.20s/it]
# Batches:  62%|██████▎   | 5/8 [01:42<00:50, 16.98s/it]
# Batches:  75%|███████▌  | 6/8 [01:56<00:31, 15.94s/it]
# Batches:  88%|████████▊ | 7/8 [02:07<00:14, 14.48s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.33s/it]
# Batches: 100%|██████████| 8/8 [02:37<00:00, 19.69s/it]
# [W205 06:52:07.135167872 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 27
#      24 if not sq:
#      25     break
# ---> 27 time.sleep(5)
#
# KeyboardInterrupt:

# %%
gen_report("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl")
# Out:
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924_report.txt
# (PosixPath('/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924_report.json'),
#  PosixPath('/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924_report.txt'))

# %%
from pathlib import Path
p = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/")
latest = max(p.glob("llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924_report.json"), key=lambda x: x.stat().st_mtime)
print(latest.read_text())
# Out:
# {
#   "run": {
#     "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl",
#     "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz",
#     "generated_at": "2026-02-05T06:55:49"
#   },
#   "global_metrics": {
#     "jobs": 1000,
#     "avg_candidates_before": 8.618,
#     "avg_candidates_after": 2.337,
#     "drop_rate": 0.7288,
#     "empty_outputs_percent": 0.0,
#     "it_leakage_share": 0.0629,
#     "min_kept": 1,
#     "max_kept": 3
#   },
#   "top_kept_roles": [
#     [
#       "Transportation, Storage, and Distribution Managers",
#       39
#     ],
#     [
#       "Software Quality Assurance Analysts and Testers",
#       39
#     ],
#     [
#       "Software Developers",
#       37
#     ],
#     [
#       "Treasurers and Controllers",
#       36
#     ],
#     [
#       "Accountants and Auditors",
#       34
#     ],
#     [
#       "Customer Service Representatives",
#       33
#     ],
#     [
#       "Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products",
#       33
#     ],
#     [
#       "Healthcare Social Workers",
#       32
#     ],
#     [
#       "Cooks, Restaurant",
#       30
#     ],
#     [
#       "Mental Health and Substance Abuse Social Workers",
#       29
#     ],
#     [
#       "Financial Managers",
#       28
#     ],
#     [
#       "Sales Managers",
#       28
#     ],
#     [
#       "Personal Care Aides",
#       27
#     ],
#     [
#       "Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products",
#       24
#     ],
#     [
#       "First-Line Supervisors of Retail Sales Workers",
#       24
#     ],
#     [
#       "Advertising and Promotions Managers",
#       23
#     ],
#     [
#       "Packers and Packagers, Hand",
#       22
#     ],
#     [
#       "Bookkeeping, Accounting, and Auditing Clerks",
#       22
#     ],
#     [
#       "Construction and Building Inspectors",
#       22
#     ],
#     [
#       "Home Health Aides",
#       21
#     ],
#     [
#       "Nursing Assistants",
#       20
#     ],
#     [
#       "Clinical Nurse Specialists",
#       20
#     ],
#     [
#       "Child, Family, and School Social Workers",
#       19
#     ],
#     [
#       "Word Processors and Typists",
#       18
#     ],
#     [
#       "Information Technology Project Managers",
#       18
#     ]
#   ],
#   "domain_summary_avg_kept": {
#     "Administrative/Office": 3,
#     "Advertising and Marketing": 3,
#     "Aerospace": 3,
#     "Aerospace & Manufacturing": 3,
#     "Automotive Retail": 3,
#     "Beauty and Cosmetics": 3,
#     "Construction and Engineering": 3,
#     "Construction and Infrastructure": 3,
#     "Construction and Property": 3,
#     "Construction/Engineering": 3,
#     "Construction/Property Maintenance": 3,
#     "Construction/Rail": 3,
#     "Construction/Real Estate": 3,
#     "Consulting": 3,
#     "Customer Service": 3,
#     "Cybersecurity": 3,
#     "Data and Intelligence consultancy": 3,
#     "Digital Marketing": 3,
#     "Digital Media": 3,
#     "Domestic Services": 3,
#     "Education Technology": 3,
#     "Electronics Technology": 3,
#     "Energy Trading": 3,
#     "Engineering/Manufacturing": 3,
#     "Environmental Science": 3,
#     "Estate Agency": 3,
#     "Fashion": 3,
#     "Fashion Retail": 3,
#     "Finance/Banking": 3,
#     "Food Industry": 3,
#     "Food Service": 3,
#     "Food Service/Hospitality": 3,
#     "Food and Beverage": 3,
#     "Government": 3,
#     "Health & Social Care": 3,
#     "Healthcare & Nursing Jobs": 3,
#     "Healthcare Administration": 3,
#     "Healthcare Advertising": 3,
#     "Healthcare/Hospitality": 3,
#     "Healthcare/Social Care": 3,
#     "Higher Education": 3,
#     "Home Accessories Manufacturing": 3,
#     "IT and Consulting": 3,
#     "IT and Technology": 3,
#     "IT/Software Development": 3,
#     "Leisure": 3,
#     "Logistics & Transportation": 3,
#     "Logistics and Supply Chain": 3,
#     "Logistics/Transportation": 3,
#     "Manufacturing/Engineering": 3,
#     "Manufacturing/Industrial": 3,
#     "Media": 3,
#     "Media and Communications": 3,
#     "Non-Profit": 3,
#     "Non-Profit/NGO": 3,
#     "Non-profit/Charity": 3,
#     "Online Surveys/Admin Jobs": 3,
#     "PR and Communications": 3,
#     "Property": 3,
#     "Public Health": 3,
#     "Public Relations": 3,
#     "Public Sector/ Law Enforcement": 3,
#     "Publishing": 3,
#     "Real Estate/Property Management": 3,
#     "Remote Work/Online Opportunities": 3,
#     "Renewable Energy": 3,
#     "Renewables": 3,
#     "Research and Market Analysis": 3,
#     "Retail Marketing": 3,
#     "Retail/Food Industry": 3,
#     "Sales Jobs": 3,
#     "Sales and Business Development": 3,
#     "Sales and Customer Service": 3,
#     "Security": 3,
#     "Security and Customer Service": 3,
#     "Security and Law Enforcement": 3,
#     "Social Services/Social Work": 3,
#     "Software Engineering": 3,
#     "Sports/Leisure": 3,
#     "Technology/Software": 3,
#     "Telecommunications": 3,
#     "Trade and Construction": 3,
#     "Translation and Interpreting": 3,
#     "Transportation/Fleet Management": 3,
#     "Travel and Tourism": 3,
#     "Utility": 3,
#     "Waste Management": 3,
#     "Financial Services": 2.75,
#     "Social work": 2.733,
#     "Logistics & Warehouse": 2.721,
#     "Finance": 2.714,
#     "Social Work": 2.714,
#     "Software Development": 2.714,
#     "Logistics": 2.692,
#     "Customer Services": 2.667,
#     "Energy": 2.667,
#     "Hospitality & Catering": 2.667,
#     "Admin Jobs": 2.6,
#     "Consultancy": 2.6,
#     "Transportation": 2.6,
#     "Domestic help & Cleaning Jobs": 2.5,
#     "Healthcare": 2.49,
#     "Retail": 2.444,
#     "Construction": 2.438,
#     "Real Estate": 2.429,
#     "Facilities Management": 2.4,
#     "Manufacturing": 2.368,
#     "Biotechnology": 2.333,
#     "Creative & Design": 2.333,
#     "IT": 2.333,
#     "Insurance": 2.333,
#     "Logistics and Transportation": 2.333,
#     "Marketing": 2.333,
#     "Media and Entertainment": 2.333,
#     "PR": 2.333,
#     "Public Administration": 2.333,
#     "Recruitment": 2.333,
#     "Technology": 2.333,
#     "Trade & Construction": 2.292,
#     "Sales": 2.286,
#     "Human Resources": 2.25,
#     "Education": 2.237,
#     "Automotive": 2.231,
#     "Engineering": 2.108,
#     "Accounting & Finance": 2.085,
#     "Healthcare & Nursing": 2.049,
#     "Domestic help & Cleaning": 2,
#     "Marketing and Public Relations": 2,
#     "Marketing/PR": 2,
#     "Media and Advertising": 2,
#     "Non-Profit/Charity": 2,
#     "HR & Recruitment": 1.75,
#     "Administration": 1.667,
#     "Health and Fitness": 1.667,
#     "Hospitality": 1.667,
#     "IT Jobs": 1.667,
#     "Scientific & QA": 1.667,
#     "Sales and Marketing": 1.571,
#     "Healthcare/Social Work": 1.5,
#     "Law": 1.5,
#     "Utilities": 1.5,
#     "Legal": 1.444,
#     "Market Research": 1.4,
#     "Administration/Office Support": 1,
#     "Agriculture": 1,
#     "Agriculture/Rural": 1,
#     "Biotechnology/Pharmaceutical": 1,
#     "Construction and Maintenance": 1,
#     "Consultancy Jobs": 1,
#     "Digital/Technology": 1,
#     "Domestic Help & Cleaning": 1,
#     "Education and Training": 1,
#     "Education/Training": 1,
#     "Electrical Engineering": 1,
#     "Energy and Utilities": 1,
#     "Executive Search Firm": 1,
#     "Farming/Agribusiness": 1,
#     "Fintech": 1,
#     "Health and Social Care": 1,
#     "Healthcare/Pharmaceutical": 1,
#     "IT and Telecommunications": 1,
#     "IT, Fintech, Blockchain, AI": 1,
#     "Leisure and Fitness": 1,
#     "Manufacturing and Engineering": 1,
#     "Manufacturing/Production": 1,
#     "Military/Defence": 1,
#     "Nuclear Engineering": 1,
#     "Other/General Jobs": 1,
#     "Pharmaceutical": 1,
#     "Recruitment Consultancy": 1,
#     "Recruitment/Consultancy": 1,
#     "Renewable Energy/Electric Vehicle": 1,
#     "SaaS": 1,
#     "Sales and Events": 1,
#     "Sales and Recruitment": 1,
#     "Scientific & QA Jobs": 1,
#     "Security and Surveillance": 1,
#     "Social Housing": 1,
#     "Technology & Engineering": 1,
#     "Tourism/Hospitality": 1,
#     "Transportation/Logistics": 1
#   },
#   "sample_cases": [
#     {
#       "job_id": "2780653104",
#       "job_ad_title": "Sommelier-Restaurant Gordon Ramsay",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Sommelier for a Three Michelin Star restaurant",
#       "kept": [
#         "Waiters and Waitresses",
#         "Bartenders",
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop"
#       ],
#       "dropped": [
#         "Dining Room and Cafeteria Attendants and Bartender Helpers",
#         "Chefs and Head Cooks",
#         "Cooks, Private Household",
#         "Cooks, Restaurant"
#       ]
#     },
#     {
#       "job_id": "2813395527",
#       "job_ad_title": "Senior Electronic Design Engineer",
#       "domain": "Engineering/Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering/Manufacturing] Senior Electronic Design Engineer",
#       "kept": [
#         "Electronics Engineers, Except Computer",
#         "Computer Hardware Engineers",
#         "Electrical and Electronic Engineering Technologists and Technicians"
#       ],
#       "dropped": [
#         "Electrical and Electronic Equipment Assemblers",
#         "Model Makers, Metal and Plastic",
#         "Robotics Engineers",
#         "Microsystems Engineers",
#         "Electrical Engineers"
#       ]
#     },
#     {
#       "job_id": "2828669962",
#       "job_ad_title": "Electric Vehicle Charge Point Installer",
#       "domain": "Renewable Energy/Electric Vehicle",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Renewable Energy/Electric Vehicle] Install EV charging equipment in customers' homes, manage stock, and provide excellent customer service.",
#       "kept": [
#         "Electric Motor, Power Tool, and Related Repairers"
#       ],
#       "dropped": [
#         "Electricians",
#         "Electrical and Electronics Installers and Repairers, Transportation Equipment",
#         "Electrical and Electronic Engineering Technologists and Technicians",
#         "Recreational Vehicle Service Technicians",
#         "Solar Sales Representatives and Assessors",
#         "Solar Energy Installation Managers",
#         "Power Distributors and Dispatchers"
#       ]
#     },
#     {
#       "job_id": "2836679279",
#       "job_ad_title": "Telephone Interviewer",
#       "domain": "Recruitment",
#       "sector": "Admin Jobs",
#       "job_desc": "[Recruitment] Telephone Interviewer position in Dunfermline, conducting interviews and data entry.",
#       "kept": [
#         "Interviewers, Except Eligibility and Loan",
#         "Telemarketers",
#         "Telephone Operators"
#       ],
#       "dropped": [
#         "Word Processors and Typists",
#         "Bookkeeping, Accounting, and Auditing Clerks",
#         "Data Entry Keyers",
#         "Loan Interviewers and Clerks",
#         "Receptionists and Information Clerks"
#       ]
#     },
#     {
#       "job_id": "2825288483",
#       "job_ad_title": "Female Support Worker - Bank Staff",
#       "domain": "Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Social Work] Support Worker for individuals with learning disabilities, mental health, and autism in Ellesmere Port.",
#       "kept": [
#         "Healthcare Social Workers",
#         "Mental Health and Substance Abuse Social Workers",
#         "Child, Family, and School Social Workers"
#       ],
#       "dropped": [
#         "Childcare Workers",
#         "Community Health Workers",
#         "Psychiatric Technicians",
#         "Special Education Teachers, Preschool",
#         "Special Education Teachers, Middle School"
#       ]
#     },
#     {
#       "job_id": "2834732675",
#       "job_ad_title": "Senior Scientist - ATMP",
#       "domain": "Biotechnology/Pharmaceutical",
#       "sector": "Scientific & QA Jobs",
#       "job_desc": "[Biotechnology/Pharmaceutical] Senior Scientist - ATMP",
#       "kept": [
#         "Bioengineers and Biomedical Engineers"
#       ],
#       "dropped": [
#         "Medical Scientists, Except Epidemiologists",
#         "Chemists",
#         "Biochemists and Biophysicists",
#         "Physicians, Pathologists",
#         "Biomass Plant Technicians",
#         "Molecular and Cellular Biologists",
#         "Robotics Engineers",
#         "Embalmers",
#         "Animal Scientists"
#       ]
#     },
#     {
#       "job_id": "2822982103",
#       "job_ad_title": "Senior Android Developer",
#       "domain": "IT",
#       "sector": "IT Jobs",
#       "job_desc": "[IT] Senior Android Developer position at Europe's leading media and entertainment brand, Sky",
#       "kept": [
#         "Software Developers",
#         "Software Quality Assurance Analysts and Testers",
#         "Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products"
#       ],
#       "dropped": [
#         "Natural Sciences Managers",
#         "Human Factors Engineers and Ergonomists",
#         "Telecommunications Engineering Specialists",
#         "Media Programming Directors",
#         "Robotics Engineers",
#         "Dancers"
#       ]
#     },
#     {
#       "job_id": "2821136828",
#       "job_ad_title": "HGV 1 Driver",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] HGV Class 1 Driver for Class 1 store deliveries across the UK",
#       "kept": [
#         "Heavy and Tractor-Trailer Truck Drivers",
#         "Industrial Truck and Tractor Operators",
#         "Cargo and Freight Agents"
#       ],
#       "dropped": [
#         "Crane and Tower Operators",
#         "Couriers and Messengers",
#         "Power Distributors and Dispatchers",
#         "Tire Repairers and Changers",
#         "Parts Salespersons",
#         "Bus Drivers, Transit and Intercity",
#         "Tax Preparers"
#       ]
#     },
#     {
#       "job_id": "2824914939",
#       "job_ad_title": "Registered Manager Learning Disabilities",
#       "domain": "Healthcare/Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Healthcare/Social Work] Registered Manager for a residential and supported living service for adults with learning disabilities, Autism and physical disabilities.",
#       "kept": [
#         "Healthcare Social Workers",
#         "Personal Care Aides",
#         "Mental Health and Substance Abuse Social Workers"
#       ],
#       "dropped": [
#         "Recreation Workers",
#         "Home Health Aides",
#         "Social and Community Service Managers",
#         "Licensed Practical and Licensed Vocational Nurses",
#         "Registered Nurses",
#         "Medical and Health Services Managers",
#         "Administrative Services Managers"
#       ]
#     },
#     {
#       "job_id": "2831341197",
#       "job_ad_title": "Field Service Engineer Mechanical",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Field Service Engineer (Mechanical) for Aviation, Rail, Government, Industrial industries",
#       "kept": [
#         "Aircraft Mechanics and Service Technicians",
#         "Automotive Service Technicians and Mechanics",
#         "Maintenance Workers, Machinery"
#       ],
#       "dropped": [
#         "Mechanical Engineering Technologists and Technicians",
#         "Maintenance and Repair Workers, General",
#         "Robotics Engineers",
#         "Bicycle Repairers"
#       ]
#     },
#     {
#       "job_id": "2831089110",
#       "job_ad_title": "Head of Mathematics",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Head of Mathematics position at a grammar school in South East London",
#       "kept": [
#         "Mathematicians",
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Career/Technical Education Teachers, Secondary School"
#       ],
#       "dropped": [
#         "Mathematical Science Teachers, Postsecondary",
#         "Teaching Assistants, Preschool, Elementary, Middle, and Secondary School, Except Special Education",
#         "Middle School Teachers, Except Special and Career/Technical Education",
#         "Elementary School Teachers, Except Special Education"
#       ]
#     },
#     {
#       "job_id": "2828207338",
#       "job_ad_title": "Attention: Housekeeper Wanted In Walton-on-Thames KT12",
#       "domain": "Domestic help & Cleaning Jobs",
#       "sector": "Domestic help & Cleaning Jobs",
#       "job_desc": "[Domestic help & Cleaning Jobs] Housekeeper Wanted In Walton-on-Thames KT12",
#       "kept": [
#         "Dishwashers"
#       ],
#       "dropped": [
#         "Maids and Housekeeping Cleaners",
#         "Janitors and Cleaners, Except Maids and Housekeeping Cleaners",
#         "Cleaners of Vehicles and Equipment",
#         "Laundry and Dry-Cleaning Workers",
#         "Bicycle Repairers",
#         "Midwives",
#         "Tire Repairers and Changers"
#       ]
#     },
#     {
#       "job_id": "2828413415",
#       "job_ad_title": "Senior Bid Writer - facilities Management",
#       "domain": "Facilities Management",
#       "sector": "PR",
#       "job_desc": "[Facilities Management] Senior Bid Writer for Facilities Management in the Government Sector",
#       "kept": [
#         "Facilities Managers",
#         "Construction Managers",
#         "Lodging Managers"
#       ],
#       "dropped": [
#         "Transportation, Storage, and Distribution Managers",
#         "Fundraising Managers",
#         "Sustainability Specialists",
#         "Procurement Clerks",
#         "Tax Preparers",
#         "Regulatory Affairs Specialists"
#       ]
#     },
#     {
#       "job_id": "2821131872",
#       "job_ad_title": "Agency Nurse",
#       "domain": "Healthcare & Nursing",
#       "sector": "Healthcare & Nursing Jobs",
#       "job_desc": "[Healthcare & Nursing] Temp / Registered General Nurse",
#       "kept": [
#         "Critical Care Nurses",
#         "Nursing Assistants",
#         "Clinical Nurse Specialists"
#       ],
#       "dropped": [
#         "Nurse Practitioners",
#         "Acute Care Nurses",
#         "Registered Nurses",
#         "Midwives",
#         "Tire Repairers and Changers",
#         "Nurse Midwives"
#       ]
#     },
#     {
#       "job_id": "2822114154",
#       "job_ad_title": "Manual Machine Prepper",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Manual Machine Prepper",
#       "kept": [
#         "Tool Grinders, Filers, and Sharpeners"
#       ],
#       "dropped": [
#         "Lathe and Turning Machine Tool Setters, Operators, and Tenders, Metal and Plastic",
#         "Welders, Cutters, Solderers, and Brazers",
#         "Forging Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Operating Engineers and Other Construction Equipment Operators",
#         "Maintenance Workers, Machinery",
#         "Tire Builders",
#         "Tire Repairers and Changers",
#         "Medical Equipment Repairers",
#         "Bicycle Repairers"
#       ]
#     },
#     {
#       "job_id": "2832534421",
#       "job_ad_title": "Flt driver/ labourer",
#       "domain": "Construction",
#       "sector": "Trade & Construction Jobs",
#       "job_desc": "[Construction] FLT/General Labourer",
#       "kept": [
#         "Construction Laborers",
#         "Loading and Moving Machine Operators, Underground Mining",
#         "Laborers and Freight, Stock, and Material Movers, Hand"
#       ],
#       "dropped": [
#         "Landscaping and Groundskeeping Workers",
#         "Maintenance and Repair Workers, General",
#         "Maintenance Workers, Machinery",
#         "Tire Builders",
#         "Tire Repairers and Changers",
#         "Insulation Workers, Floor, Ceiling, and Wall"
#       ]
#     },
#     {
#       "job_id": "2740314480",
#       "job_ad_title": "Finance Service Manager (Children's Finance)",
#       "domain": "Accounting & Finance",
#       "sector": "Accounting & Finance Jobs",
#       "job_desc": "[Accounting & Finance] Finance Service Manager for a local authority supporting Children's services",
#       "kept": [
#         "Financial Managers",
#         "Treasurers and Controllers",
#         "Accountants and Auditors"
#       ],
#       "dropped": [
#         "Budget Analysts",
#         "Bookkeeping, Accounting, and Auditing Clerks",
#         "Fundraising Managers",
#         "Social and Community Service Managers",
#         "Wind Energy Operations Managers",
#         "Medical and Health Services Managers"
#       ]
#     },
#     {
#       "job_id": "2793906036",
#       "job_ad_title": "Department Supervisor - 30 Hours Per Week",
#       "domain": "Retail",
#       "sector": "Retail Jobs",
#       "job_desc": "[Retail] Department Supervisor for a retail store, responsible for day-to-day operations and customer service.",
#       "kept": [
#         "First-Line Supervisors of Retail Sales Workers",
#         "First-Line Supervisors of Non-Retail Sales Workers",
#         "Locker Room, Coatroom, and Dressing Room Attendants"
#       ],
#       "dropped": [
#         "Stockers and Order Fillers",
#         "Transportation, Storage, and Distribution Managers",
#         "First-Line Supervisors of Personal Service Workers",
#         "First-Line Supervisors of Security Workers",
#         "First-Line Supervisors of Food Preparation and Serving Workers"
#       ]
#     },
#     {
#       "job_id": "2813502724",
#       "job_ad_title": "Senior Sous Chef",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Senior Sous Chef position in an independent group of gastro pubs",
#       "kept": [
#         "Cooks, Restaurant",
#         "Chefs and Head Cooks",
#         "Food Preparation Workers"
#       ],
#       "dropped": [
#         "Food Service Managers",
#         "First-Line Supervisors of Food Preparation and Serving Workers",
#         "Cooks, Private Household",
#         "Cooks, Institution and Cafeteria"
#       ]
#     },
#     {
#       "job_id": "2780653010",
#       "job_ad_title": "Customer Success Executive - Remote",
#       "domain": "Customer Services",
#       "sector": "Customer Services Jobs",
#       "job_desc": "[Customer Services] Customer Success Executive - Remote",
#       "kept": [
#         "Customer Service Representatives",
#         "Property, Real Estate, and Community Association Managers",
#         "Real Estate Brokers"
#       ],
#       "dropped": [
#         "Home Appliance Repairers",
#         "Real Estate Sales Agents",
#         "Tax Preparers",
#         "Power Distributors and Dispatchers",
#         "Telemarketers",
#         "First-Line Supervisors of Personal Service Workers",
#         "Parts Salespersons"
#       ]
#     },
#     {
#       "job_id": "2639240590",
#       "job_ad_title": "Stock Controller/Supply Manager",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] Stock Controller/Supply Manager",
#       "kept": [
#         "Supply Chain Managers",
#         "Transportation, Storage, and Distribution Managers",
#         "Logistics Analysts"
#       ],
#       "dropped": [
#         "Production, Planning, and Expediting Clerks",
#         "Shipping, Receiving, and Inventory Clerks",
#         "Parts Salespersons",
#         "Stockers and Order Fillers",
#         "Packers and Packagers, Hand"
#       ]
#     },
#     {
#       "job_id": "2693450403",
#       "job_ad_title": "Nights Transport Planner",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] Transport Planner for a leading multi model logistics business",
#       "kept": [
#         "Transportation, Storage, and Distribution Managers",
#         "Logistics Analysts",
#         "Transportation Planners"
#       ],
#       "dropped": [
#         "Heavy and Tractor-Trailer Truck Drivers",
#         "Light Truck Drivers",
#         "Logistics Engineers",
#         "Logisticians"
#       ]
#     },
#     {
#       "job_id": "2791717253",
#       "job_ad_title": "Receptionist",
#       "domain": "Manufacturing",
#       "sector": "Admin Jobs",
#       "job_desc": "[Manufacturing] Receptionist for a manufacturing business in Rotherham",
#       "kept": [
#         "Production, Planning, and Expediting Clerks",
#         "Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers",
#         "Machine Feeders and Offbearers"
#       ],
#       "dropped": [
#         "Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders",
#         "First-Line Supervisors of Housekeeping and Janitorial Workers",
#         "Tire Builders",
#         "Maintenance Workers, Machinery",
#         "Receptionists and Information Clerks",
#         "Parts Salespersons",
#         "Stone Cutters and Carvers, Manufacturing"
#       ]
#     },
#     {
#       "job_id": "2742996472",
#       "job_ad_title": "Business Process Support (P2P)",
#       "domain": "Manufacturing",
#       "sector": "IT Jobs",
#       "job_desc": "[Manufacturing] Business Process Support (P2P) to drive implementation of new policies and processes across the organisation.",
#       "kept": [
#         "Team Assemblers",
#         "Machine Feeders and Offbearers",
#         "Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers"
#       ],
#       "dropped": [
#         "Milling and Planing Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Production, Planning, and Expediting Clerks",
#         "Patient Representatives",
#         "Packers and Packagers, Hand",
#         "Procurement Clerks",
#         "Business Continuity Planners",
#         "Pressers, Textile, Garment, and Related Materials"
#       ]
#     },
#     {
#       "job_id": "2791201272",
#       "job_ad_title": "Service Administrator",
#       "domain": "Automotive",
#       "sector": "Admin Jobs",
#       "job_desc": "[Automotive] Service Administrator",
#       "kept": [
#         "Automotive and Watercraft Service Attendants"
#       ],
#       "dropped": [
#         "Automotive Service Technicians and Mechanics",
#         "Automotive Body and Related Repairers",
#         "Cleaners of Vehicles and Equipment",
#         "Customer Service Representatives",
#         "Tire Repairers and Changers",
#         "Bicycle Repairers"
#       ]
#     },
#     {
#       "job_id": "2746664291",
#       "job_ad_title": "Multi Skilled Maintenance Engineer",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Multi Skilled Maintenance Engineer for an award-winning textiles processing company in West Yorkshire",
#       "kept": [
#         "Maintenance and Repair Workers, General"
#       ],
#       "dropped": [
#         "Maintenance Workers, Machinery",
#         "Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders",
#         "Electric Motor, Power Tool, and Related Repairers",
#         "Boilermakers",
#         "Manufacturing Engineers",
#         "Biomass Plant Technicians",
#         "Millwrights",
#         "Laundry and Dry-Cleaning Workers"
#       ]
#     },
#     {
#       "job_id": "2847461196",
#       "job_ad_title": "LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "kept": [
#         "Industrial Truck and Tractor Operators",
#         "Tank Car, Truck, and Ship Loaders",
#         "Pump Operators, Except Wellhead Pumpers"
#       ],
#       "dropped": [
#         "Transportation, Storage, and Distribution Managers",
#         "Cargo and Freight Agents",
#         "Maintenance Workers, Machinery",
#         "Packers and Packagers, Hand",
#         "Tire Builders",
#         "Chemical Plant and System Operators"
#       ]
#     },
#     {
#       "job_id": "2846431729",
#       "job_ad_title": "Operative",
#       "domain": "Manufacturing",
#       "sector": "Manufacturing Jobs",
#       "job_desc": "[Manufacturing] Temporary to permanent manufacturing operative role with a 2-shift system",
#       "kept": [
#         "Machine Feeders and Offbearers"
#       ],
#       "dropped": [
#         "Engine and Other Machine Assemblers",
#         "Packers and Packagers, Hand",
#         "Maintenance and Repair Workers, General",
#         "Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders",
#         "Maintenance Workers, Machinery",
#         "Tire Builders",
#         "Tire Repairers and Changers",
#         "First-Line Supervisors of Material-Moving Machine and Vehicle Operators",
#         "Chemical Plant and System Operators"
#       ]
#     },
#     {
#       "job_id": "2848376850",
#       "job_ad_title": "Engineering Stores / SAP Coordinator",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Engineering Stores / SAP Coordinator",
#       "kept": [
#         "Team Assemblers"
#       ],
#       "dropped": [
#         "Production, Planning, and Expediting Clerks",
#         "Inspectors, Testers, Sorters, Samplers, and Weighers",
#         "Weighers, Measurers, Checkers, and Samplers, Recordkeeping",
#         "Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders",
#         "Biomass Plant Technicians",
#         "Robotics Engineers",
#         "Tire Builders",
#         "Robotics Technicians",
#         "Parts Salespersons"
#       ]
#     },
#     {
#       "job_id": "2838003039",
#       "job_ad_title": "Teacher",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Experienced teacher required for a temporary position at Gee Cross Holy Trinity Primary and Nursery School.",
#       "kept": [
#         "Teaching Assistants, Preschool, Elementary, Middle, and Secondary School, Except Special Education",
#         "Career/Technical Education Teachers, Secondary School",
#         "Self-Enrichment Teachers"
#       ],
#       "dropped": [
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Elementary School Teachers, Except Special Education",
#         "Substitute Teachers, Short-Term",
#         "Special Education Teachers, Preschool",
#         "Kindergarten Teachers, Except Special Education",
#         "Middle School Teachers, Except Special and Career/Technical Education"
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## GTE

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_gte.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
# Out:
# JOBID: 2152759

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:02    5:59:58     1 nid010551
#
# --- STDOUT ---
# PROJECT=/projects/a5u/adu_dev/aisi-economy-index
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  5 06:49 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 05:17 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 05:17 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:18 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:18 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 05:19 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:19 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 05:20 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 05:20 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:07    5:59:53     1 nid010551
#
# --- STDOUT ---
# PROJECT=/projects/a5u/adu_dev/aisi-economy-index
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  5 06:49 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 05:17 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 05:17 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:18 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:18 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 05:19 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 05:19 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 05:20 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 05:20 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:12    5:59:48     1 nid010551
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 06:57:31
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:17    5:59:43     1 nid010551
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 06:57:31
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:22    5:59:38     1 nid010551
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 06:57:31
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:27    5:59:33     1 nid010551
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 06:57:31
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:32    5:59:28     1 nid010551
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 06:57:31
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:37    5:59:23     1 nid010551
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 06:57:31
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:42    5:59:18     1 nid010551
#
# --- STDOUT ---
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-05 06:57:31
# [CFG] EMBED: gte_large
# [CFG] MONTH_TAG: adzuna_month01
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:47    5:59:13     1 nid010551
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:52    5:59:08     1 nid010551
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:58    5:59:02     1 nid010551
#
# --- STDOUT ---
# [CFG] OUT_DIR: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01
# [CFG] OUT_JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# [ENV] torch: 2.9.1+cu126
# [ENV] cuda available: True
# [ENV] gpu: NVIDIA GH200 120GB
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:03    5:58:57     1 nid010551
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:08    5:58:52     1 nid010551
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:13    5:58:47     1 nid010551
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:18    5:58:42     1 nid010551
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:23    5:58:37     1 nid010551
#
# --- STDOUT ---
# [RANGE] 0:1000 (n=1000) -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DBG] job_id: 2804978349
# [DBG] title: 'Meter Reader'
# [DBG] domain: 'Energy'
# [DBG] category: 'Energy'
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:28    5:58:32     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:33    5:58:27     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Energy] Meter Reader for a utility company, requiring good customer service ski'
# [DBG] tasks_head: "[Energy] Read gas and electricity meters in customers' homes and businesses Enga"
# [DBG] job_id: 2820703059
# [DBG] title: 'IQA Internal Quality Assurer (Apprenticeship ICT)'
# [DBG] domain: 'Education'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:38    5:58:22     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:43    5:58:17     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Education] IQA Internal Quality Assurer (Apprenticeship ICT) role in a home-bas'
# [DBG] tasks_head: '[Education] Drive quality excellence and expertise across delivery, curriculum, '
# [DBG] job_id: 2827261059
# [DBG] title: 'FM Delivery Manager'
# [DBG] domain: 'Facilities Management'
# [DBG] category: 'Property Jobs'
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:48    5:58:12     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:53    5:58:07     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:58    5:58:02     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       2:03    5:57:57     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Facilities Management] FM Delivery Manager'
# [DBG] tasks_head: '[Facilities Management] Ensure delivery of an excellent facilities management se'
# [DBG] job_id: 2795381535
# [DBG] title: 'Customer Advisor- Decorative'
# [DBG] domain: 'Retail'
# [DBG] category: 'Customer Services Jobs'
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2152759 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       2:08    5:57:52     1 nid010551
#
# --- STDOUT ---
# [DBG] desc_head: '[Retail] Customer Advisor- Decorative'
# [DBG] tasks_head: '[Retail] Manage stock Set up displays Provide great customer service Sell produc'
# [DBG] job_id: 2765635125
# [DBG] title: 'Driver weekend London'
# [DBG] domain: 'Logistics & Transportation'
# [DBG] category: 'Logistics & Warehouse Jobs'
# [DBG] desc_head: '[Logistics & Transportation] Deliver food across London as a courier for Just Ea'
# [DBG] tasks_head: '[Logistics & Transportation] Deliver food across the city Use own bike or moped '
# [DBG] job_id: 2780177874
# [DBG] title: 'Locum Consultant Physician - Care of the Elderly'
# [DBG] domain: 'Healthcare'
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# ...
# Allocated: 14.990772724151611 GB
# Reserved: 55.802734375 GB
# [END] 2026-02-05 07:00:08
# [RUNTIME] 2.61 minutes (156.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.77s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:17, 22.95s/it]
# Batches:  38%|███▊      | 3/8 [01:15<02:02, 24.56s/it]
# Batches:  50%|█████     | 4/8 [01:26<01:17, 19.33s/it]
# Batches:  62%|██████▎   | 5/8 [01:37<00:48, 16.26s/it]
# Batches:  75%|███████▌  | 6/8 [01:53<00:32, 16.24s/it]
# Batches:  88%|████████▊ | 7/8 [02:04<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.25s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.21s/it]
# [W205 07:00:08.841120648 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# Allocated: 14.990772724151611 GB
# Reserved: 55.802734375 GB
# [END] 2026-02-05 07:00:08
# [RUNTIME] 2.61 minutes (156.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.77s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:17, 22.95s/it]
# Batches:  38%|███▊      | 3/8 [01:15<02:02, 24.56s/it]
# Batches:  50%|█████     | 4/8 [01:26<01:17, 19.33s/it]
# Batches:  62%|██████▎   | 5/8 [01:37<00:48, 16.26s/it]
# Batches:  75%|███████▌  | 6/8 [01:53<00:32, 16.24s/it]
# Batches:  88%|████████▊ | 7/8 [02:04<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.25s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.21s/it]
# [W205 07:00:08.841120648 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# Allocated: 14.990772724151611 GB
# Reserved: 55.802734375 GB
# [END] 2026-02-05 07:00:08
# [RUNTIME] 2.61 minutes (156.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.77s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:17, 22.95s/it]
# Batches:  38%|███▊      | 3/8 [01:15<02:02, 24.56s/it]
# Batches:  50%|█████     | 4/8 [01:26<01:17, 19.33s/it]
# Batches:  62%|██████▎   | 5/8 [01:37<00:48, 16.26s/it]
# Batches:  75%|███████▌  | 6/8 [01:53<00:32, 16.24s/it]
# Batches:  88%|████████▊ | 7/8 [02:04<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.25s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.21s/it]
# [W205 07:00:08.841120648 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# Allocated: 14.990772724151611 GB
# Reserved: 55.802734375 GB
# [END] 2026-02-05 07:00:08
# [RUNTIME] 2.61 minutes (156.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.77s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:17, 22.95s/it]
# Batches:  38%|███▊      | 3/8 [01:15<02:02, 24.56s/it]
# Batches:  50%|█████     | 4/8 [01:26<01:17, 19.33s/it]
# Batches:  62%|██████▎   | 5/8 [01:37<00:48, 16.26s/it]
# Batches:  75%|███████▌  | 6/8 [01:53<00:32, 16.24s/it]
# Batches:  88%|████████▊ | 7/8 [02:04<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.25s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.21s/it]
# [W205 07:00:08.841120648 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# Allocated: 14.990772724151611 GB
# Reserved: 55.802734375 GB
# [END] 2026-02-05 07:00:08
# [RUNTIME] 2.61 minutes (156.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.77s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:17, 22.95s/it]
# Batches:  38%|███▊      | 3/8 [01:15<02:02, 24.56s/it]
# Batches:  50%|█████     | 4/8 [01:26<01:17, 19.33s/it]
# Batches:  62%|██████▎   | 5/8 [01:37<00:48, 16.26s/it]
# Batches:  75%|███████▌  | 6/8 [01:53<00:32, 16.24s/it]
# Batches:  88%|████████▊ | 7/8 [02:04<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.25s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.21s/it]
# [W205 07:00:08.841120648 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# Allocated: 14.990772724151611 GB
# Reserved: 55.802734375 GB
# [END] 2026-02-05 07:00:08
# [RUNTIME] 2.61 minutes (156.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.77s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:17, 22.95s/it]
# Batches:  38%|███▊      | 3/8 [01:15<02:02, 24.56s/it]
# Batches:  50%|█████     | 4/8 [01:26<01:17, 19.33s/it]
# Batches:  62%|██████▎   | 5/8 [01:37<00:48, 16.26s/it]
# Batches:  75%|███████▌  | 6/8 [01:53<00:32, 16.24s/it]
# Batches:  88%|████████▊ | 7/8 [02:04<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.25s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.21s/it]
# [W205 07:00:08.841120648 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# Allocated: 14.990772724151611 GB
# Reserved: 55.802734375 GB
# [END] 2026-02-05 07:00:08
# [RUNTIME] 2.61 minutes (156.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  4.09it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  4.31it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  5.47it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.77s/it]
# Batches:  25%|██▌       | 2/8 [00:48<02:17, 22.95s/it]
# Batches:  38%|███▊      | 3/8 [01:15<02:02, 24.56s/it]
# Batches:  50%|█████     | 4/8 [01:26<01:17, 19.33s/it]
# Batches:  62%|██████▎   | 5/8 [01:37<00:48, 16.26s/it]
# Batches:  75%|███████▌  | 6/8 [01:53<00:32, 16.24s/it]
# Batches:  88%|████████▊ | 7/8 [02:04<00:14, 14.52s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.25s/it]
# Batches: 100%|██████████| 8/8 [02:33<00:00, 19.21s/it]
# [W205 07:00:08.841120648 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 26
#      23 if not sq:
#      24     break
# ---> 26 time.sleep(5)
#
# KeyboardInterrupt:

# %%
gen_report("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl")
# Out:
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731_report.txt
# (PosixPath('/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731_report.json'),
#  PosixPath('/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731_report.txt'))

# %%
#from pathlib import Path
p = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/")
latest = max(p.glob("llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731_report.json"), key=lambda x: x.stat().st_mtime)
print(latest.read_text())
# Out:
# {
#   "run": {
#     "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl",
#     "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz",
#     "generated_at": "2026-02-05T07:01:50"
#   },
#   "global_metrics": {
#     "jobs": 1000,
#     "avg_candidates_before": 8.229,
#     "avg_candidates_after": 2.41,
#     "drop_rate": 0.7071,
#     "empty_outputs_percent": 0.0,
#     "it_leakage_share": 0.0817,
#     "min_kept": 1,
#     "max_kept": 3
#   },
#   "top_kept_roles": [
#     [
#       "Software Developers",
#       45
#     ],
#     [
#       "Information Technology Project Managers",
#       32
#     ],
#     [
#       "Healthcare Social Workers",
#       31
#     ],
#     [
#       "Personal Care Aides",
#       28
#     ],
#     [
#       "Mental Health and Substance Abuse Social Workers",
#       28
#     ],
#     [
#       "Treasurers and Controllers",
#       26
#     ],
#     [
#       "Nursing Assistants",
#       24
#     ],
#     [
#       "Chefs and Head Cooks",
#       24
#     ],
#     [
#       "Computer Systems Engineers/Architects",
#       24
#     ],
#     [
#       "Financial Managers",
#       23
#     ],
#     [
#       "Advertising and Promotions Managers",
#       21
#     ],
#     [
#       "Cooks, Institution and Cafeteria",
#       21
#     ],
#     [
#       "Human Resources Specialists",
#       20
#     ],
#     [
#       "Packers and Packagers, Hand",
#       20
#     ],
#     [
#       "Solar Sales Representatives and Assessors",
#       19
#     ],
#     [
#       "Transportation, Storage, and Distribution Managers",
#       19
#     ],
#     [
#       "Financial Quantitative Analysts",
#       18
#     ],
#     [
#       "Laborers and Freight, Stock, and Material Movers, Hand",
#       18
#     ],
#     [
#       "Industrial Truck and Tractor Operators",
#       18
#     ],
#     [
#       "Web Developers",
#       18
#     ],
#     [
#       "First-Line Supervisors of Non-Retail Sales Workers",
#       17
#     ],
#     [
#       "Dining Room and Cafeteria Attendants and Bartender Helpers",
#       17
#     ],
#     [
#       "Customer Service Representatives",
#       16
#     ],
#     [
#       "Accountants and Auditors",
#       16
#     ],
#     [
#       "Acute Care Nurses",
#       16
#     ]
#   ],
#   "domain_summary_avg_kept": {
#     "Administration/Office Support": 3,
#     "Advertising and Marketing": 3,
#     "Aerospace": 3,
#     "Aerospace & Manufacturing": 3,
#     "Agriculture/Rural": 3,
#     "Automotive Retail": 3,
#     "Beauty and Cosmetics": 3,
#     "Biotechnology/Pharmaceutical": 3,
#     "Construction and Engineering": 3,
#     "Construction and Infrastructure": 3,
#     "Construction and Property": 3,
#     "Construction/Engineering": 3,
#     "Construction/Property Maintenance": 3,
#     "Construction/Rail": 3,
#     "Construction/Real Estate": 3,
#     "Creative & Design": 3,
#     "Customer Service": 3,
#     "Cybersecurity": 3,
#     "Data and Intelligence consultancy": 3,
#     "Digital Marketing": 3,
#     "Digital Media": 3,
#     "Domestic Help & Cleaning": 3,
#     "Domestic Services": 3,
#     "Domestic help & Cleaning": 3,
#     "Education Technology": 3,
#     "Education/Training": 3,
#     "Electrical Engineering": 3,
#     "Electronics Technology": 3,
#     "Energy Trading": 3,
#     "Engineering/Manufacturing": 3,
#     "Environmental Science": 3,
#     "Estate Agency": 3,
#     "Fashion": 3,
#     "Fashion Retail": 3,
#     "Finance/Banking": 3,
#     "Financial Services": 3,
#     "Food Industry": 3,
#     "Food Service": 3,
#     "Food and Beverage": 3,
#     "Government": 3,
#     "Health & Social Care": 3,
#     "Healthcare & Nursing Jobs": 3,
#     "Healthcare Administration": 3,
#     "Healthcare Advertising": 3,
#     "Healthcare/Hospitality": 3,
#     "Healthcare/Social Care": 3,
#     "Higher Education": 3,
#     "Home Accessories Manufacturing": 3,
#     "IT, Fintech, Blockchain, AI": 3,
#     "IT/Software Development": 3,
#     "Leisure": 3,
#     "Logistics": 3,
#     "Logistics & Transportation": 3,
#     "Logistics and Supply Chain": 3,
#     "Logistics and Transportation": 3,
#     "Logistics/Transportation": 3,
#     "Manufacturing/Industrial": 3,
#     "Media and Communications": 3,
#     "Non-Profit": 3,
#     "Non-Profit/NGO": 3,
#     "Non-profit/Charity": 3,
#     "Property": 3,
#     "Public Relations": 3,
#     "Public Sector/ Law Enforcement": 3,
#     "Real Estate/Property Management": 3,
#     "Remote Work/Online Opportunities": 3,
#     "Renewable Energy": 3,
#     "Renewables": 3,
#     "Research and Market Analysis": 3,
#     "Retail/Food Industry": 3,
#     "SaaS": 3,
#     "Sales Jobs": 3,
#     "Sales and Business Development": 3,
#     "Sales and Events": 3,
#     "Sales and Recruitment": 3,
#     "Scientific & QA": 3,
#     "Security": 3,
#     "Security and Customer Service": 3,
#     "Security and Law Enforcement": 3,
#     "Social Housing": 3,
#     "Social Services/Social Work": 3,
#     "Software Development": 3,
#     "Sports/Leisure": 3,
#     "Technology & Engineering": 3,
#     "Technology/Software": 3,
#     "Telecommunications": 3,
#     "Tourism/Hospitality": 3,
#     "Trade and Construction": 3,
#     "Translation and Interpreting": 3,
#     "Transportation": 3,
#     "Utilities": 3,
#     "Utility": 3,
#     "Waste Management": 3,
#     "Logistics & Warehouse": 2.721,
#     "Finance": 2.714,
#     "Real Estate": 2.714,
#     "Social Work": 2.714,
#     "Energy": 2.667,
#     "Recruitment": 2.667,
#     "Trade & Construction": 2.667,
#     "Admin Jobs": 2.6,
#     "Consultancy": 2.6,
#     "Hospitality & Catering": 2.571,
#     "Social work": 2.567,
#     "IT": 2.548,
#     "Automotive": 2.538,
#     "Consulting": 2.5,
#     "Customer Services": 2.5,
#     "Human Resources": 2.5,
#     "Sales": 2.429,
#     "Construction": 2.375,
#     "Healthcare": 2.347,
#     "Manufacturing": 2.342,
#     "Health and Fitness": 2.333,
#     "IT Jobs": 2.333,
#     "IT and Technology": 2.333,
#     "Insurance": 2.333,
#     "Marketing": 2.333,
#     "Media and Entertainment": 2.333,
#     "PR": 2.333,
#     "Public Administration": 2.333,
#     "Engineering": 2.297,
#     "Education": 2.289,
#     "Retail": 2.278,
#     "Accounting & Finance": 2.254,
#     "HR & Recruitment": 2.25,
#     "Facilities Management": 2.2,
#     "Administration": 2,
#     "Administrative/Office": 2,
#     "Agriculture": 2,
#     "Domestic help & Cleaning Jobs": 2,
#     "Energy and Utilities": 2,
#     "Fintech": 2,
#     "Health and Social Care": 2,
#     "Hospitality": 2,
#     "Law": 2,
#     "Marketing/PR": 2,
#     "Media and Advertising": 2,
#     "Non-Profit/Charity": 2,
#     "Pharmaceutical": 2,
#     "Scientific & QA Jobs": 2,
#     "Software Engineering": 2,
#     "Technology": 2,
#     "Travel and Tourism": 2,
#     "Healthcare & Nursing": 1.927,
#     "Sales and Marketing": 1.857,
#     "Market Research": 1.8,
#     "Biotechnology": 1.667,
#     "Legal": 1.667,
#     "Healthcare/Social Work": 1.5,
#     "Construction and Maintenance": 1,
#     "Consultancy Jobs": 1,
#     "Digital/Technology": 1,
#     "Education and Training": 1,
#     "Executive Search Firm": 1,
#     "Farming/Agribusiness": 1,
#     "Food Service/Hospitality": 1,
#     "Healthcare/Pharmaceutical": 1,
#     "IT and Consulting": 1,
#     "IT and Telecommunications": 1,
#     "Leisure and Fitness": 1,
#     "Manufacturing and Engineering": 1,
#     "Manufacturing/Engineering": 1,
#     "Manufacturing/Production": 1,
#     "Marketing and Public Relations": 1,
#     "Media": 1,
#     "Military/Defence": 1,
#     "Nuclear Engineering": 1,
#     "Online Surveys/Admin Jobs": 1,
#     "Other/General Jobs": 1,
#     "PR and Communications": 1,
#     "Public Health": 1,
#     "Publishing": 1,
#     "Recruitment Consultancy": 1,
#     "Recruitment/Consultancy": 1,
#     "Renewable Energy/Electric Vehicle": 1,
#     "Retail Marketing": 1,
#     "Sales and Customer Service": 1,
#     "Security and Surveillance": 1,
#     "Transportation/Fleet Management": 1,
#     "Transportation/Logistics": 1
#   },
#   "sample_cases": [
#     {
#       "job_id": "2780653104",
#       "job_ad_title": "Sommelier-Restaurant Gordon Ramsay",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Sommelier for a Three Michelin Star restaurant",
#       "kept": [
#         "Food Service Managers"
#       ],
#       "dropped": [
#         "Waiters and Waitresses",
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop",
#         "Chefs and Head Cooks",
#         "Dining Room and Cafeteria Attendants and Bartender Helpers",
#         "Bartenders",
#         "Cooks, Private Household",
#         "Baristas"
#       ]
#     },
#     {
#       "job_id": "2813395527",
#       "job_ad_title": "Senior Electronic Design Engineer",
#       "domain": "Engineering/Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering/Manufacturing] Senior Electronic Design Engineer",
#       "kept": [
#         "Electronics Engineers, Except Computer",
#         "Electrical and Electronic Engineering Technologists and Technicians",
#         "Electrical Engineers"
#       ],
#       "dropped": [
#         "Solar Energy Systems Engineers",
#         "Electrical and Electronics Drafters",
#         "Manufacturing Engineers",
#         "Microsystems Engineers"
#       ]
#     },
#     {
#       "job_id": "2828669962",
#       "job_ad_title": "Electric Vehicle Charge Point Installer",
#       "domain": "Renewable Energy/Electric Vehicle",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Renewable Energy/Electric Vehicle] Install EV charging equipment in customers' homes, manage stock, and provide excellent customer service.",
#       "kept": [
#         "Electrical Power-Line Installers and Repairers"
#       ],
#       "dropped": [
#         "Solar Photovoltaic Installers",
#         "Electrical and Electronics Installers and Repairers, Transportation Equipment",
#         "Electrical Engineers",
#         "Electrical and Electronic Engineering Technologists and Technicians",
#         "Solar Energy Installation Managers",
#         "Power Distributors and Dispatchers",
#         "Fuel Cell Engineers"
#       ]
#     },
#     {
#       "job_id": "2836679279",
#       "job_ad_title": "Telephone Interviewer",
#       "domain": "Recruitment",
#       "sector": "Admin Jobs",
#       "job_desc": "[Recruitment] Telephone Interviewer position in Dunfermline, conducting interviews and data entry.",
#       "kept": [
#         "Interviewers, Except Eligibility and Loan",
#         "Loan Interviewers and Clerks",
#         "Human Resources Assistants, Except Payroll and Timekeeping"
#       ],
#       "dropped": [
#         "Word Processors and Typists",
#         "Receptionists and Information Clerks",
#         "Human Resources Specialists",
#         "New Accounts Clerks",
#         "Archivists"
#       ]
#     },
#     {
#       "job_id": "2825288483",
#       "job_ad_title": "Female Support Worker - Bank Staff",
#       "domain": "Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Social Work] Support Worker for individuals with learning disabilities, mental health, and autism in Ellesmere Port.",
#       "kept": [
#         "Mental Health and Substance Abuse Social Workers",
#         "Healthcare Social Workers",
#         "Personal Care Aides"
#       ],
#       "dropped": [
#         "Community Health Workers",
#         "Nannies",
#         "Social and Human Service Assistants",
#         "Child, Family, and School Social Workers",
#         "First-Line Supervisors of Farming, Fishing, and Forestry Workers"
#       ]
#     },
#     {
#       "job_id": "2834732675",
#       "job_ad_title": "Senior Scientist - ATMP",
#       "domain": "Biotechnology/Pharmaceutical",
#       "sector": "Scientific & QA Jobs",
#       "job_desc": "[Biotechnology/Pharmaceutical] Senior Scientist - ATMP",
#       "kept": [
#         "Medical and Clinical Laboratory Technologists",
#         "Bioengineers and Biomedical Engineers",
#         "Molecular and Cellular Biologists"
#       ],
#       "dropped": [
#         "Chemical Technicians",
#         "Quality Control Analysts",
#         "Validation Engineers",
#         "Bioinformatics Scientists",
#         "Chemists",
#         "Medical Dosimetrists"
#       ]
#     },
#     {
#       "job_id": "2822982103",
#       "job_ad_title": "Senior Android Developer",
#       "domain": "IT",
#       "sector": "IT Jobs",
#       "job_desc": "[IT] Senior Android Developer position at Europe's leading media and entertainment brand, Sky",
#       "kept": [
#         "Software Developers",
#         "Computer Systems Engineers/Architects",
#         "Computer and Information Research Scientists"
#       ],
#       "dropped": [
#         "Computer Network Architects",
#         "Microsystems Engineers",
#         "Radio Frequency Identification Device Specialists",
#         "Telecommunications Engineering Specialists",
#         "Software Quality Assurance Analysts and Testers"
#       ]
#     },
#     {
#       "job_id": "2821136828",
#       "job_ad_title": "HGV 1 Driver",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] HGV Class 1 Driver for Class 1 store deliveries across the UK",
#       "kept": [
#         "Industrial Truck and Tractor Operators",
#         "Crane and Tower Operators",
#         "Tank Car, Truck, and Ship Loaders"
#       ],
#       "dropped": [
#         "Heavy and Tractor-Trailer Truck Drivers",
#         "Laborers and Freight, Stock, and Material Movers, Hand",
#         "Transportation, Storage, and Distribution Managers",
#         "Logistics Analysts",
#         "Light Truck Drivers",
#         "Logistics Engineers",
#         "Locomotive Engineers"
#       ]
#     },
#     {
#       "job_id": "2824914939",
#       "job_ad_title": "Registered Manager Learning Disabilities",
#       "domain": "Healthcare/Social Work",
#       "sector": "Social work Jobs",
#       "job_desc": "[Healthcare/Social Work] Registered Manager for a residential and supported living service for adults with learning disabilities, Autism and physical disabilities.",
#       "kept": [
#         "Healthcare Social Workers"
#       ],
#       "dropped": [
#         "Medical and Health Services Managers",
#         "Personal Care Aides",
#         "Community Health Workers",
#         "Mental Health and Substance Abuse Social Workers",
#         "Regulatory Affairs Managers",
#         "Social and Community Service Managers",
#         "Food Service Managers",
#         "Human Resources Managers"
#       ]
#     },
#     {
#       "job_id": "2831341197",
#       "job_ad_title": "Field Service Engineer Mechanical",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Field Service Engineer (Mechanical) for Aviation, Rail, Government, Industrial industries",
#       "kept": [
#         "Mechanical Engineering Technologists and Technicians",
#         "Control and Valve Installers and Repairers, Except Mechanical Door",
#         "Maintenance and Repair Workers, General"
#       ],
#       "dropped": [
#         "Mobile Heavy Equipment Mechanics, Except Engines",
#         "Bus and Truck Mechanics and Diesel Engine Specialists",
#         "Mechanical Engineers",
#         "Aircraft Mechanics and Service Technicians",
#         "Fuel Cell Engineers",
#         "Manufacturing Engineers"
#       ]
#     },
#     {
#       "job_id": "2831089110",
#       "job_ad_title": "Head of Mathematics",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Head of Mathematics position at a grammar school in South East London",
#       "kept": [
#         "Mathematicians",
#         "Mathematical Science Teachers, Postsecondary",
#         "Special Education Teachers, Elementary School"
#       ],
#       "dropped": [
#         "Teaching Assistants, Preschool, Elementary, Middle, and Secondary School, Except Special Education",
#         "Education Administrators, Kindergarten through Secondary",
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Tutors",
#         "Middle School Teachers, Except Special and Career/Technical Education"
#       ]
#     },
#     {
#       "job_id": "2828207338",
#       "job_ad_title": "Attention: Housekeeper Wanted In Walton-on-Thames KT12",
#       "domain": "Domestic help & Cleaning Jobs",
#       "sector": "Domestic help & Cleaning Jobs",
#       "job_desc": "[Domestic help & Cleaning Jobs] Housekeeper Wanted In Walton-on-Thames KT12",
#       "kept": [
#         "Dishwashers"
#       ],
#       "dropped": [
#         "Maids and Housekeeping Cleaners",
#         "Janitors and Cleaners, Except Maids and Housekeeping Cleaners",
#         "Personal Care Aides",
#         "Orderlies",
#         "Cooks, Private Household",
#         "First-Line Supervisors of Housekeeping and Janitorial Workers",
#         "Baggage Porters and Bellhops"
#       ]
#     },
#     {
#       "job_id": "2828413415",
#       "job_ad_title": "Senior Bid Writer - facilities Management",
#       "domain": "Facilities Management",
#       "sector": "PR",
#       "job_desc": "[Facilities Management] Senior Bid Writer for Facilities Management in the Government Sector",
#       "kept": [
#         "Facilities Managers",
#         "Brownfield Redevelopment Specialists and Site Managers",
#         "Locker Room, Coatroom, and Dressing Room Attendants"
#       ],
#       "dropped": [
#         "Writers and Authors",
#         "Property, Real Estate, and Community Association Managers",
#         "Sustainability Specialists",
#         "Meter Readers, Utilities",
#         "Procurement Clerks"
#       ]
#     },
#     {
#       "job_id": "2821131872",
#       "job_ad_title": "Agency Nurse",
#       "domain": "Healthcare & Nursing",
#       "sector": "Healthcare & Nursing Jobs",
#       "job_desc": "[Healthcare & Nursing] Temp / Registered General Nurse",
#       "kept": [
#         "Acute Care Nurses",
#         "Registered Nurses",
#         "Family Medicine Physicians"
#       ],
#       "dropped": [
#         "Nursing Assistants",
#         "Personal Care Aides",
#         "Medical Equipment Repairers",
#         "Pharmacy Technicians",
#         "Medical Equipment Preparers"
#       ]
#     },
#     {
#       "job_id": "2822114154",
#       "job_ad_title": "Manual Machine Prepper",
#       "domain": "Engineering",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Engineering] Manual Machine Prepper",
#       "kept": [
#         "Boilermakers"
#       ],
#       "dropped": [
#         "Lathe and Turning Machine Tool Setters, Operators, and Tenders, Metal and Plastic",
#         "Drilling and Boring Machine Tool Setters, Operators, and Tenders, Metal and Plastic",
#         "Sawing Machine Setters, Operators, and Tenders, Wood",
#         "Welders, Cutters, Solderers, and Brazers",
#         "Mechanical Drafters",
#         "Mechanical Engineers",
#         "Millwrights",
#         "Engine and Other Machine Assemblers",
#         "Technical Writers"
#       ]
#     },
#     {
#       "job_id": "2832534421",
#       "job_ad_title": "Flt driver/ labourer",
#       "domain": "Construction",
#       "sector": "Trade & Construction Jobs",
#       "job_desc": "[Construction] FLT/General Labourer",
#       "kept": [
#         "Construction Laborers",
#         "Roustabouts, Oil and Gas",
#         "Painters, Construction and Maintenance"
#       ],
#       "dropped": [
#         "Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters",
#         "Helpers--Painters, Paperhangers, Plasterers, and Stucco Masons",
#         "Millwrights",
#         "Tire Builders",
#         "Riggers"
#       ]
#     },
#     {
#       "job_id": "2740314480",
#       "job_ad_title": "Finance Service Manager (Children's Finance)",
#       "domain": "Accounting & Finance",
#       "sector": "Accounting & Finance Jobs",
#       "job_desc": "[Accounting & Finance] Finance Service Manager for a local authority supporting Children's services",
#       "kept": [
#         "Treasurers and Controllers",
#         "Financial Managers",
#         "Budget Analysts"
#       ],
#       "dropped": [
#         "Bookkeeping, Accounting, and Auditing Clerks",
#         "Chief Executives",
#         "Food Service Managers",
#         "Compensation and Benefits Managers",
#         "Fundraising Managers"
#       ]
#     },
#     {
#       "job_id": "2793906036",
#       "job_ad_title": "Department Supervisor - 30 Hours Per Week",
#       "domain": "Retail",
#       "sector": "Retail Jobs",
#       "job_desc": "[Retail] Department Supervisor for a retail store, responsible for day-to-day operations and customer service.",
#       "kept": [
#         "First-Line Supervisors of Retail Sales Workers",
#         "First-Line Supervisors of Non-Retail Sales Workers",
#         "Loss Prevention Managers"
#       ],
#       "dropped": [
#         "Stockers and Order Fillers",
#         "Spa Managers",
#         "Retail Loss Prevention Specialists",
#         "Retail Salespersons",
#         "Online Merchants"
#       ]
#     },
#     {
#       "job_id": "2813502724",
#       "job_ad_title": "Senior Sous Chef",
#       "domain": "Hospitality & Catering",
#       "sector": "Hospitality & Catering Jobs",
#       "job_desc": "[Hospitality & Catering] Senior Sous Chef position in an independent group of gastro pubs",
#       "kept": [
#         "Chefs and Head Cooks"
#       ],
#       "dropped": [
#         "Cooks, Institution and Cafeteria",
#         "Cooks, Restaurant",
#         "Food Preparation Workers",
#         "First-Line Supervisors of Food Preparation and Serving Workers",
#         "Cooks, Private Household",
#         "Food Service Managers",
#         "Waiters and Waitresses",
#         "Bartenders"
#       ]
#     },
#     {
#       "job_id": "2780653010",
#       "job_ad_title": "Customer Success Executive - Remote",
#       "domain": "Customer Services",
#       "sector": "Customer Services Jobs",
#       "job_desc": "[Customer Services] Customer Success Executive - Remote",
#       "kept": [
#         "Customer Service Representatives",
#         "Property, Real Estate, and Community Association Managers",
#         "Home Appliance Repairers"
#       ],
#       "dropped": [
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop",
#         "Social and Human Service Assistants",
#         "Human Resources Specialists",
#         "Telecommunications Engineering Specialists",
#         "Fuel Cell Engineers",
#         "Online Merchants"
#       ]
#     },
#     {
#       "job_id": "2639240590",
#       "job_ad_title": "Stock Controller/Supply Manager",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] Stock Controller/Supply Manager",
#       "kept": [
#         "Shipping, Receiving, and Inventory Clerks"
#       ],
#       "dropped": [
#         "Supply Chain Managers",
#         "Production, Planning, and Expediting Clerks",
#         "Transportation, Storage, and Distribution Managers",
#         "Logistics Engineers",
#         "Logistics Analysts",
#         "Logisticians",
#         "Stockers and Order Fillers"
#       ]
#     },
#     {
#       "job_id": "2693450403",
#       "job_ad_title": "Nights Transport Planner",
#       "domain": "Logistics",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics] Transport Planner for a leading multi model logistics business",
#       "kept": [
#         "Transportation, Storage, and Distribution Managers",
#         "Light Truck Drivers",
#         "Industrial Truck and Tractor Operators"
#       ],
#       "dropped": [
#         "Railroad Conductors and Yardmasters",
#         "First-Line Supervisors of Material-Moving Machine and Vehicle Operators",
#         "Logistics Engineers",
#         "Logistics Analysts",
#         "Logisticians",
#         "Freight Forwarders"
#       ]
#     },
#     {
#       "job_id": "2791717253",
#       "job_ad_title": "Receptionist",
#       "domain": "Manufacturing",
#       "sector": "Admin Jobs",
#       "job_desc": "[Manufacturing] Receptionist for a manufacturing business in Rotherham",
#       "kept": [
#         "Receptionists and Information Clerks",
#         "Hotel, Motel, and Resort Desk Clerks",
#         "Lodging Managers"
#       ],
#       "dropped": [
#         "Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop",
#         "Concierges",
#         "Structural Metal Fabricators and Fitters",
#         "Manufacturing Engineers",
#         "Patternmakers, Metal and Plastic",
#         "Tool and Die Makers"
#       ]
#     },
#     {
#       "job_id": "2742996472",
#       "job_ad_title": "Business Process Support (P2P)",
#       "domain": "Manufacturing",
#       "sector": "IT Jobs",
#       "job_desc": "[Manufacturing] Business Process Support (P2P) to drive implementation of new policies and processes across the organisation.",
#       "kept": [
#         "Manufacturing Engineers",
#         "Team Assemblers",
#         "Rolling Machine Setters, Operators, and Tenders, Metal and Plastic"
#       ],
#       "dropped": [
#         "Industrial Production Managers",
#         "Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Document Management Specialists",
#         "Industrial Engineers",
#         "Regulatory Affairs Managers",
#         "Logistics Analysts"
#       ]
#     },
#     {
#       "job_id": "2791201272",
#       "job_ad_title": "Service Administrator",
#       "domain": "Automotive",
#       "sector": "Admin Jobs",
#       "job_desc": "[Automotive] Service Administrator",
#       "kept": [
#         "Automotive and Watercraft Service Attendants"
#       ],
#       "dropped": [
#         "Automotive Service Technicians and Mechanics",
#         "Automotive Engineering Technicians",
#         "Cleaners of Vehicles and Equipment",
#         "Parking Attendants",
#         "Automotive Engineers",
#         "Automotive Body and Related Repairers"
#       ]
#     },
#     {
#       "job_id": "2746664291",
#       "job_ad_title": "Multi Skilled Maintenance Engineer",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Multi Skilled Maintenance Engineer for an award-winning textiles processing company in West Yorkshire",
#       "kept": [
#         "Maintenance and Repair Workers, General"
#       ],
#       "dropped": [
#         "Maintenance Workers, Machinery",
#         "Boilermakers",
#         "Control and Valve Installers and Repairers, Except Mechanical Door",
#         "Stationary Engineers and Boiler Operators",
#         "Manufacturing Engineers",
#         "Mechanical Engineers",
#         "Engine and Other Machine Assemblers",
#         "Aircraft Mechanics and Service Technicians"
#       ]
#     },
#     {
#       "job_id": "2847461196",
#       "job_ad_title": "LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "domain": "Logistics & Warehouse",
#       "sector": "Logistics & Warehouse Jobs",
#       "job_desc": "[Logistics & Warehouse] LGV Class C Jet-Vac / Vacuum tanker Driver/Operator",
#       "kept": [
#         "Tank Car, Truck, and Ship Loaders",
#         "Septic Tank Servicers and Sewer Pipe Cleaners",
#         "Conveyor Operators and Tenders"
#       ],
#       "dropped": [
#         "Roustabouts, Oil and Gas",
#         "Refuse and Recyclable Material Collectors",
#         "Industrial Truck and Tractor Operators",
#         "Freight Forwarders",
#         "Wellhead Pumpers",
#         "Petroleum Pump System Operators, Refinery Operators, and Gaugers"
#       ]
#     },
#     {
#       "job_id": "2846431729",
#       "job_ad_title": "Operative",
#       "domain": "Manufacturing",
#       "sector": "Manufacturing Jobs",
#       "job_desc": "[Manufacturing] Temporary to permanent manufacturing operative role with a 2-shift system",
#       "kept": [
#         "Engine and Other Machine Assemblers"
#       ],
#       "dropped": [
#         "Team Assemblers",
#         "Electromechanical Equipment Assemblers",
#         "Packers and Packagers, Hand",
#         "Machine Feeders and Offbearers",
#         "Industrial Production Managers",
#         "Millwrights",
#         "Packaging and Filling Machine Operators and Tenders",
#         "Structural Metal Fabricators and Fitters",
#         "Robotics Technicians"
#       ]
#     },
#     {
#       "job_id": "2848376850",
#       "job_ad_title": "Engineering Stores / SAP Coordinator",
#       "domain": "Manufacturing",
#       "sector": "Engineering Jobs",
#       "job_desc": "[Manufacturing] Engineering Stores / SAP Coordinator",
#       "kept": [
#         "Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Rolling Machine Setters, Operators, and Tenders, Metal and Plastic",
#         "Production, Planning, and Expediting Clerks"
#       ],
#       "dropped": [
#         "Machine Feeders and Offbearers",
#         "Shipping, Receiving, and Inventory Clerks",
#         "Manufacturing Engineers",
#         "Industrial Engineers",
#         "Industrial Production Managers",
#         "Logisticians",
#         "Structural Metal Fabricators and Fitters"
#       ]
#     },
#     {
#       "job_id": "2838003039",
#       "job_ad_title": "Teacher",
#       "domain": "Education",
#       "sector": "Teaching Jobs",
#       "job_desc": "[Education] Experienced teacher required for a temporary position at Gee Cross Holy Trinity Primary and Nursery School.",
#       "kept": [
#         "Kindergarten Teachers, Except Special Education",
#         "Secondary School Teachers, Except Special and Career/Technical Education",
#         "Special Education Teachers, Secondary School"
#       ],
#       "dropped": [
#         "Art, Drama, and Music Teachers, Postsecondary",
#         "Special Education Teachers, Elementary School",
#         "Substitute Teachers, Short-Term",
#         "Preschool Teachers, Except Special Education",
#         "Special Education Teachers, Preschool",
#         "Elementary School Teachers, Except Special Education"
#       ]
#     }
#   ]
# }

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn3
from pathlib import Path

# ---- CONFIG: Update these paths to your actual files ----
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# Update these to your exact latest filenames
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl",
    "E5": BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl",
    "GTE":  BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl"
}

def load_final_occupations(filepath):
    """Loads job_id -> set of kept occupations mapping."""
    data = {}
    if not filepath.exists():
        print(f"Warning: File {filepath} not found.")
        return data
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            # Store the 'final' list as a frozen set for easy comparison
            data[obj['job_id']] = set(obj['final'])
    return data

def calculate_jaccard(set1, set2):
    """Intersection over Union."""
    if not set1 and not set2: return 1.0
    return len(set1 & set2) / len(set1 | set2)

# 1. Load Data
results = {name: load_final_occupations(path) for name, path in PATHS.items()}
common_jobs = set.intersection(*[set(d.keys()) for d in results.values() if d])

print(f"Analyzing {len(common_jobs)} common jobs across models...")

# 2. Calculate Jaccard Matrix
model_names = list(results.keys())
matrix = np.zeros((len(model_names), len(model_names)))

for i, name1 in enumerate(model_names):
    for j, name2 in enumerate(model_names):
        similarities = [
            calculate_jaccard(results[name1][jid], results[name2][jid]) 
            for jid in common_jobs
        ]
        matrix[i, j] = np.mean(similarities)

# 3. Visualization: Jaccard Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(matrix, annot=True, xticklabels=model_names, yticklabels=model_names, cmap="YlGnBu")
plt.title("Mean Jaccard Agreement (Consensus) Matrix")
plt.savefig("model_agreement_heatmap.png")
print("Saved Heatmap: model_agreement_heatmap.png")

# 4. Visualization: 3-Way Venn Diagram
# Prepare sets of (job_id, occupation) tuples for global intersection
sets_for_venn = {}
for name in model_names:
    global_set = set()
    for jid in common_jobs:
        for occ in results[name][jid]:
            global_set.add((jid, occ)) # Unique key is Job + Occ
    sets_for_venn[name] = global_set

plt.figure(figsize=(10, 8))
venn3([sets_for_venn[m] for m in model_names], set_labels=model_names)
plt.title("Overlap of Job-Occupation Assignments")
plt.savefig("model_overlap_venn.png")
print("Saved Venn: model_overlap_venn.png")

# 5. Generate Disagreement Report (Top 5 Divergent Cases)
print("\n=== TOP DISAGREEMENTS (E5 vs BGE) ===")
disagreements = []
for jid in list(common_jobs)[:100]: # Sample first 100 for speed
    score = calculate_jaccard(results['E5'][jid], results['BGE'][jid])
    if score < 0.5:
        disagreements.append({
            "job_id": jid,
            "E5_kept": results['E5'][jid],
            "BGE_kept": results['BGE'][jid]
        })

for d in disagreements[:5]:
    print(f"Job ID: {d['job_id']}")
    print(f"  E5 Kept : {d['E5_kept']}")
    print(f"  BGE Kept: {d['BGE_kept']}")
    print("-" * 30)
# Out:
# Analyzing 1000 common jobs across models...
# Saved Heatmap: model_agreement_heatmap.png
# Saved Venn: model_overlap_venn.png
#
# === TOP DISAGREEMENTS (E5 vs BGE) ===
# Job ID: 2739517243
#   E5 Kept : {'Child, Family, and School Social Workers', 'Social and Human Service Assistants', 'Mental Health and Substance Abuse Social Workers'}
#   BGE Kept: {'Sustainability Specialists', 'Social and Community Service Managers', 'Mental Health and Substance Abuse Social Workers'}
# ------------------------------
# Job ID: 2698672876
#   E5 Kept : {'Construction Managers', 'Construction and Building Inspectors', 'Construction Laborers'}
#   BGE Kept: {'Construction Managers', 'First-Line Supervisors of Mechanics, Installers, and Repairers', 'First-Line Supervisors of Construction Trades and Extraction Workers'}
# ------------------------------
# Job ID: 2786595185
#   E5 Kept : {'Sales Managers'}
#   BGE Kept: {'Sales Managers', 'Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products', 'Advertising Sales Agents'}
# ------------------------------
# Job ID: 2834742201
#   E5 Kept : {'Loading and Moving Machine Operators, Underground Mining'}
#   BGE Kept: {'Construction Laborers', 'Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters', 'First-Line Supervisors of Construction Trades and Extraction Workers'}
# ------------------------------
# Job ID: 2828413415
#   E5 Kept : {'Facilities Managers', 'Construction Managers', 'Lodging Managers'}
#   BGE Kept: {'Facilities Managers', 'Writers and Authors', 'Technical Writers'}
# ------------------------------

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn3
from pathlib import Path

# ---- CONFIG ----
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# Update these to your exact latest filenames
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152607_task0_20260205_064918.jsonl",
    "E5": BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152609_task0_20260205_064924.jsonl",
    "GTE":  BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2152759_task0_20260205_065731.jsonl"
}

def load_data(filepath):
    data = {}
    if not filepath.exists(): return data
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            data[obj['job_id']] = set(obj['final'])
    return data

# 1. Load and Intersect
results = {name: load_data(path) for name, path in PATHS.items()}
loaded = [n for n, d in results.items() if d]
common_ids = set.intersection(*[set(results[m].keys()) for m in loaded])

# 2. Extract Commonalities and Differences
report_data = []
for jid in common_ids:
    bge_set = results["BGE"].get(jid, set())
    e5_set = results["E5"].get(jid, set())
    gte_set = results["GTE"].get(jid, set())
    
    # Are they identical?
    all_agree = (bge_set == e5_set == gte_set)
    
    # Who is the outlier?
    outlier = "None"
    if bge_set == e5_set != gte_set: outlier = "GTE"
    elif bge_set == gte_set != e5_set: outlier = "E5"
    elif e5_set == gte_set != bge_set: outlier = "BGE"
    elif not all_agree: outlier = "All Diverged"

    report_data.append({
        "job_id": jid,
        "all_agree": all_agree,
        "outlier": outlier,
        "bge_count": len(bge_set),
        "e5_count": len(e5_set),
        "gte_count": len(gte_set),
        "consensus_count": len(bge_set & e5_set & gte_set)
    })

df = pd.DataFrame(report_data)

# 3. Print Statistical Summary
print("=== COMPREHENSIVE COMPARISON REPORT ===")
print(f"Total Common Jobs: {len(df)}")
print(f"Absolute Consensus: {df['all_agree'].sum()} ({df['all_agree'].mean():.1%})")
print("\n--- Outlier Frequency (Who disagrees with the majority?) ---")
print(df[df['outlier'] != "None"]['outlier'].value_counts())

# 4. Generate Visualizations
# Jaccard Heatmap
model_names = list(results.keys())
j_matrix = np.zeros((3, 3))
for i, m1 in enumerate(model_names):
    for j, m2 in enumerate(model_names):
        scores = [len(results[m1][jid] & results[m2][jid]) / len(results[m1][jid] | results[m2][jid]) 
                  for jid in common_ids]
        j_matrix[i, j] = np.mean(scores)

plt.figure(figsize=(8, 6))
sns.heatmap(j_matrix, annot=True, xticklabels=model_names, yticklabels=model_names, cmap="YlGnBu")
plt.title("Jaccard Similarity Matrix (Semantic Overlap)")
plt.savefig("semantic_overlap_heatmap.png")

# Venn Diagram
venn_sets = []
for name in model_names:
    s = set()
    for jid in common_ids:
        for occ in results[name][jid]:
            s.add(f"{jid}|{occ}")
    venn_sets.append(s)

plt.figure(figsize=(10, 8))
venn3(venn_sets, set_labels=model_names)
plt.title("Consensus Core vs. Model-Specific Hallucinations")
plt.savefig("assignment_venn.png")
# Out:
# === COMPREHENSIVE COMPARISON REPORT ===
# Total Common Jobs: 1000
# Absolute Consensus: 24 (2.4%)
#
# --- Outlier Frequency (Who disagrees with the majority?) ---
# outlier
# All Diverged    736
# E5               87
# GTE              81
# BGE              72
# Name: count, dtype: int64
