# %%
# Rumando ao fim update a partir do prompt 6
#Default pipeline: E5 + Llama, with union (E5 top5 + BGE top5 → ≤10) only for uncertain jobs.

#Prompt rule: return 2–3 by default; return only 1 if very sure; never 0 or >3.

#Hard gates: JSON ≥99.5%, empty ≤0.5%, max kept ≤3, avg kept ≤2.2, latency ≤1.2×.

#Quality + fallback triggers: IT leakage ≤5%, hierarchy ≤0.5%, anchor ≤1%, low margin ≤25%; fallback ≤10–15%.

#Next steps: lock prompt + thresholds, run 50k stratified validation, then launch 20M run with audit logging.

# %% [markdown]
# # Helpers

# %%
import json
import re
import random
import statistics
from pathlib import Path
from collections import Counter, defaultdict
from datetime import datetime

import numpy as np

# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------
_RUN_RE = re.compile(
    r"llama_drop_only_(?P<month>adzuna_month\d{2})_(?P<start>\d+)_(?P<stop>\d+)_job(?P<jobid>\d+)_task(?P<taskid>\d+)_\d{8}_\d{6}\.jsonl$"
)

IT_PATTERNS = [
    r"\bsoftware\b", r"\bdeveloper\b", r"\bengineer\b", r"\bdata\b", r"\bml\b", r"\bai\b",
    r"\bcloud\b", r"\bcyber\b", r"\bsecurity\b", r"\bnetwork\b", r"\bsystems?\b",
    r"\bdatabase\b", r"\bit\b", r"\bdevops\b"
]
_IT_RE = re.compile("|".join(IT_PATTERNS), flags=re.I)

def _is_it_role(title: str) -> bool:
    if not title:
        return False
    return bool(_IT_RE.search(title))


def _infer_npz_from_jsonl(jsonl_path: Path) -> Path:
    """
    NEW layout:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>/llama_drop_only_....jsonl
    NPZ sits at:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>.npz
    """
    m = _RUN_RE.search(jsonl_path.name)
    if not m:
        raise ValueError(f"JSONL filename doesn't match expected pattern: {jsonl_path.name}")

    month = m.group("month")
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    return embed_root / f"{month}.npz"


def _get_job_ids(z) -> np.ndarray:
    """
    Supports both schemas:
      new: job_ids
      old: job_id
    Returns np.ndarray[str]
    """
    if "job_ids" in z.files:
        return z["job_ids"].astype(str)
    if "job_id" in z.files:
        return z["job_id"].astype(str)
    raise KeyError(f"NPZ missing job id key. Need job_ids or job_id. Have={sorted(z.files)}")


def _load_npz_lookup(npz_path: Path):
    """
    Expects stage3-prep NPZ keys (canonical):
      job_ids (or job_id), job_ad_title, job_desc, job_tasks, domain, job_sector_category, job_description
    """
    with np.load(npz_path, allow_pickle=True) as z:
        job_ids = _get_job_ids(z)

        # canonical (your stage3-prep)
        job_ad_title = z["job_ad_title"]
        job_desc = z["job_desc"]
        job_tasks = z["job_tasks"]

        domain = z["domain"] if "domain" in z.files else None
        job_sector_category = z["job_sector_category"] if "job_sector_category" in z.files else None
        job_description = z["job_description"] if "job_description" in z.files else None

    lookup = {}
    for i, jid in enumerate(job_ids):
        lookup[jid] = {
            "job_ad_title": None if job_ad_title[i] is None else str(job_ad_title[i]),
            "job_desc": None if job_desc[i] is None else str(job_desc[i]),
            "job_tasks": None if job_tasks[i] is None else str(job_tasks[i]),
            "job_description": None if job_description is None or job_description[i] is None else str(job_description[i]),
            "domain": None if domain is None or domain[i] is None else str(domain[i]),
            "job_sector_category": None if job_sector_category is None or job_sector_category[i] is None else str(job_sector_category[i]),
        }
    return lookup


# ---------------------------------------------------------------------
# Main: report generator
# ---------------------------------------------------------------------
def gen_report(jsonl_path: str, *, npz_path: str | None = None, sample_n: int = 30, seed: int = 0):
    """
    jsonl_path: path to llama_drop_only_*.jsonl
    npz_path  : optional explicit context NPZ. If None, inferred from jsonl name/dir.
    """
    random.seed(seed)

    jsonl_path = Path(jsonl_path)
    if not jsonl_path.exists():
        raise FileNotFoundError(f"Missing JSONL: {jsonl_path}")

    inferred_npz = _infer_npz_from_jsonl(jsonl_path)
    npz_path = Path(npz_path) if npz_path else inferred_npz
    if not npz_path.exists():
        raise FileNotFoundError(f"Missing NPZ: {npz_path}")

    # report folder: put it under .../llm_negative_selection/<EMBED>/evaluation_reports/
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    report_dir = embed_root / "evaluation_reports"
    report_dir.mkdir(parents=True, exist_ok=True)

    print("JSONL:", jsonl_path)
    print("NPZ :", npz_path)
    print("OUT :", report_dir)

    lookup = _load_npz_lookup(npz_path)

    before_counts = []
    after_counts = []
    kept_titles = Counter()
    domain_kept = defaultdict(list)

    it_leak = 0
    total_kept = 0
    empty_outputs = 0

    samples = []
    seen_sample_ids = set()

    with jsonl_path.open("r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            try:
                r = json.loads(line)
            except Exception:
                continue

            jid = str(r.get("job_id", "")).strip()
            if not jid:
                continue

            ctx = lookup.get(jid, {})

            cand = r.get("candidates") or []
            final = r.get("final") or []

            before_counts.append(len(cand))
            after_counts.append(len(final))

            if len(final) == 0:
                empty_outputs += 1

            for t in final:
                kept_titles[t] += 1
                total_kept += 1
                if _is_it_role(t):
                    it_leak += 1

            dom = ctx.get("domain") or "UNKNOWN"
            domain_kept[dom].append(len(final))

            # sample gate
            if len(samples) < sample_n and jid not in seen_sample_ids and random.random() < 0.05:
                seen_sample_ids.add(jid)
                samples.append({
                    "job_id": jid,
                    "job_ad_title": ctx.get("job_ad_title"),
                    "domain": ctx.get("domain"),
                    "sector": ctx.get("job_sector_category"),
                    "job_desc": ctx.get("job_desc"),
                    "kept": final,
                    "dropped": r.get("drop") or [],
                })

    if not before_counts:
        raise RuntimeError("No valid rows parsed from JSONL.")

    before_avg = statistics.mean(before_counts)
    after_avg = statistics.mean(after_counts)
    drop_rate = 1.0 - (after_avg / before_avg if before_avg else 0.0)
    it_share = it_leak / max(total_kept, 1)

    metrics = {
        "jobs": len(before_counts),
        "avg_candidates_before": round(before_avg, 3),
        "avg_candidates_after": round(after_avg, 3),
        "drop_rate": round(drop_rate, 4),
        "empty_outputs_percent": round(100.0 * empty_outputs / len(before_counts), 3),
        "it_leakage_share": round(it_share, 4),
        "min_kept": int(min(after_counts)),
        "max_kept": int(max(after_counts)),
    }

    domain_summary = {d: round(statistics.mean(v), 3) for d, v in domain_kept.items()}

    report = {
        "run": {
            "jsonl": str(jsonl_path),
            "npz": str(npz_path),
            "generated_at": datetime.now().isoformat(timespec="seconds"),
        },
        "global_metrics": metrics,
        "top_kept_roles": kept_titles.most_common(25),
        "domain_summary_avg_kept": dict(sorted(domain_summary.items(), key=lambda x: (-x[1], x[0]))),
        "sample_cases": samples,
    }

    base = jsonl_path.stem
    report_json = report_dir / f"{base}_report.json"
    report_txt = report_dir / f"{base}_report.txt"

    with report_json.open("w", encoding="utf-8") as f:
        json.dump(report, f, indent=2, ensure_ascii=False)

    with report_txt.open("w", encoding="utf-8") as f:
        f.write("=== GLOBAL METRICS ===\n")
        for k, v in metrics.items():
            f.write(f"{k}: {v}\n")

        f.write("\n=== TOP KEPT OCCUPATIONS ===\n")
        for title, cnt in kept_titles.most_common(25):
            f.write(f"{cnt}  {title}\n")

        f.write("\n=== DOMAIN AVG KEPT ===\n")
        for d, v in sorted(domain_summary.items(), key=lambda x: (-x[1], x[0])):
            f.write(f"{d}: {v}\n")

        f.write("\n=== SAMPLE CASES (truncated) ===\n")
        for s in samples[:10]:
            f.write(f"\njob_id: {s['job_id']}\n")
            f.write(f"title:  {s.get('job_ad_title')}\n")
            f.write(f"domain: {s.get('domain')} | sector: {s.get('sector')}\n")
            f.write(f"kept:   {s.get('kept')}\n")
            f.write(f"drop:   {s.get('dropped')}\n")

    print("\nSaved:")
    print(" ", report_json)
    print(" ", report_txt)

    return report_json, report_txt

# %% [markdown]
# # Prompt 4 - A bit less strict than prompt 3

# %%
# ===== Prompt printer: OCCUPATION MATCHER (Inclusive 2-3 Goal) =====

import numpy as np
from pathlib import Path

# ---- CONFIG ----
# Update this path to your specific E5 or BGE .npz file
NPZ_PATH = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz")
ROW_IDX = 35  # Sample row for verification

# ---- LOAD ----
data = np.load(NPZ_PATH, allow_pickle=True)

# Map NPZ keys to prompt variables
job_ad_title = data["job_ad_title"][ROW_IDX]
domain = data["domain"][ROW_IDX]
job_sector_category = data["job_sector_category"][ROW_IDX]
job_desc = data["job_desc"][ROW_IDX]
job_tasks = data["job_tasks"][ROW_IDX]
job_full_ads = data["job_description"][ROW_IDX]
row_candidates = data["titles"][ROW_IDX]

# Normalize tasks to a clean string
if isinstance(job_tasks, (list, np.ndarray)):
    job_tasks_str = ", ".join([str(t).strip() for t in job_tasks if t])
else:
    job_tasks_str = str(job_tasks)

# Format candidates as a 1-based numbered list
numbered = "\n".join([f"{i+1}. {cand}" for i, cand in enumerate(row_candidates) if cand])

# ---- BUILD PROMPT (Inclusive 2-3 Version) ----

full_excerpt = str(job_full_ads).strip()[:700] if job_full_ads else ""
full_block = (
    f"\nFULL AD EXCERPT (only for concrete duties, tools, licences; ignore fluff):\n{full_excerpt}\n"
    if full_excerpt else ""
)

prompt = f"""
TASK
You are an Occupation Matcher. Evaluate the candidates and DROP those that are NOT functional matches for the job.

GOAL
- Default: keep 2–3 best matches if they represent valid aspects of the role.
- Selectivity: return exactly 1 ONLY if you are extremely sure it is the only correct match.
- Constraint: Never return 0 candidates. Never return more than 3.

JOB CONTEXT (SOURCE OF TRUTH)
Title: {job_ad_title}
Sector/Domain: {job_sector_category} | {domain}

CORE EVIDENCE (use this first):
Tasks/Skills: {job_tasks_str}

Secondary (supporting only):
Short Desc: {job_desc}
{full_block}

CANDIDATES (1-based)
{numbered}

ANCHOR RULE
1) Identify the ANCHOR (the candidate most similar to the job title).
2) The ANCHOR must be kept unless CORE EVIDENCE explicitly proves it is a wrong match.
3) Keyword Priority: if the title has "Software" or "Engineer," prioritize candidates with those words.

PRUNING RULES
1) Specificity: Keep specialists alongside generic parents if both are valid (e.g., keep "Software Developer" AND "Web Developer").
2) IT Gatekeeper: Drop IT roles ONLY if there is zero evidence of technical work (coding, architecture, data engineering). If the job involves building/maintaining tech, keep the IT candidates.
3) Domain Fit: Ensure the kept candidates make sense within the {domain} sector.
4) Synonym Collapsing: If you have more than 3 matches, drop the most generic ones to fit the limit.

OUTPUT
Return ONLY valid JSON. No text. No explanation.
Schema:
{{"drop":[...]}}
""".strip()

# ---- PRINT ----
print("-" * 50)
print(f"VERIFIED PRODUCTION PROMPT (ROW {ROW_IDX}):")
print("-" * 50)
print(prompt)
print("-" * 50)
# Out:
# --------------------------------------------------
# VERIFIED PRODUCTION PROMPT (ROW 35):
# --------------------------------------------------
# TASK
# You are an Occupation Matcher. Evaluate the candidates and DROP those that are NOT functional matches for the job.
#
# GOAL
# - Default: keep 2–3 best matches if they represent valid aspects of the role.
# - Selectivity: return exactly 1 ONLY if you are extremely sure it is the only correct match.
# - Constraint: Never return 0 candidates. Never return more than 3.
#
# JOB CONTEXT (SOURCE OF TRUTH)
# Title: Sommelier-Restaurant Gordon Ramsay
# Sector/Domain: Hospitality & Catering Jobs | Hospitality & Catering
#
# CORE EVIDENCE (use this first):
# Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
#
# Secondary (supporting only):
# Short Desc: [Hospitality & Catering] Sommelier for a Three Michelin Star restaurant
#
# FULL AD EXCERPT (only for concrete duties, tools, licences; ignore fluff):
# Sommelier - Restaurant Gordon Ramsay, Three Michelin Star We are looking for an experienced Sommelier who has a real passion for delivering the highest levels of service and creating a fantastic dining experience for our guests. Restaurant Gordon Ramsay combines contemporary elegance, an intimate ambience and unparalleled service, all the hallmarks of true excellence. Each dish, beautifully presented, uses the best ingredients and sublime flavour combinations, demonstrating the outstanding technical skill of Chef Matt Abe and his team. The restaurant boasts twenty years of holding three Michelin stars and is now London’s longest running restaurant to hold this accolade. As Sommelier you will
#
#
# CANDIDATES (1-based)
# 1. Waiters and Waitresses
# 2. Bartenders
# 3. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 4. Dining Room and Cafeteria Attendants and Bartender Helpers
# 5. First-Line Supervisors of Personal Service Workers
# 6. First-Line Supervisors of Food Preparation and Serving Workers
#
# ANCHOR RULE
# 1) Identify the ANCHOR (the candidate most similar to the job title).
# 2) The ANCHOR must be kept unless CORE EVIDENCE explicitly proves it is a wrong match.
# 3) Keyword Priority: if the title has "Software" or "Engineer," prioritize candidates with those words.
#
# PRUNING RULES
# 1) Specificity: Keep specialists alongside generic parents if both are valid (e.g., keep "Software Developer" AND "Web Developer").
# 2) IT Gatekeeper: Drop IT roles ONLY if there is zero evidence of technical work (coding, architecture, data engineering). If the job involves building/maintaining tech, keep the IT candidates.
# 3) Domain Fit: Ensure the kept candidates make sense within the Hospitality & Catering sector.
# 4) Synonym Collapsing: If you have more than 3 matches, drop the most generic ones to fit the limit.
#
# OUTPUT
# Return ONLY valid JSON. No text. No explanation.
# Schema:
# {"drop":[...]}
# --------------------------------------------------

# %% [markdown]
# ## bge

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_bge.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
bge_jobid = jobid
# Out:
# JOBID: 2185798

# %% [markdown]
# ## e5

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_e5.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
e5_jobid = jobid
# Out:
# JOBID: 2185799

# %% [markdown]
# ## gte

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_gte.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
gte_jobid = jobid
# Out:
# JOBID: 2185800

# %%
# monitoring

# %%
import time, subprocess
from pathlib import Path
jobid= 2167539
LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# <finished>
#
# --- STDOUT ---
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2167539_task0_20260205_174858.jsonl
# [METRICS] jobs: 1000
# [METRICS] parse_fail_rate: 0.0
# [METRICS] forced_anchor_rate: 0.012
# [METRICS] avg_kept: 1.796
# [METRICS] avg_dropped: 6.433
# [CUDA] allocated_gb: 14.991
# [CUDA] reserved_gb: 58.24
# [END] 2026-02-05 17:50:51
# [RUNTIME] 1.88 minutes (112.9 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:02,  1.43it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:01<00:01,  1.37it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:02<00:00,  1.44it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.84it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:20<02:23, 20.44s/it]
# Batches:  25%|██▌       | 2/8 [00:34<01:39, 16.52s/it]
# Batches:  38%|███▊      | 3/8 [00:56<01:34, 18.96s/it]
# Batches:  50%|█████     | 4/8 [01:04<00:58, 14.75s/it]
# Batches:  62%|██████▎   | 5/8 [01:12<00:37, 12.42s/it]
# Batches:  75%|███████▌  | 6/8 [01:21<00:22, 11.04s/it]
# Batches:  88%|████████▊ | 7/8 [01:29<00:10, 10.16s/it]
# Batches: 100%|██████████| 8/8 [01:48<00:00, 12.97s/it]
# Batches: 100%|██████████| 8/8 [01:48<00:00, 13.55s/it]
# [W205 17:50:52.559341330 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())

# %%
#bge_jobid, e5_jobid, gte_jobid = 2167537,2167538,2167539

# %%
import time, subprocess
from pathlib import Path

for jobid in [bge_jobid, e5_jobid, gte_jobid]:
    LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
    
    DONE_TAG = "DONE] wrote:"
    
    def sh(cmd: str) -> str:
        return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout
    
    def tail(path: Path, n: int = 80) -> str:
        return sh(f"tail -n {n} {path}")
    
    def latest_log(jobid: int, suffix: str) -> Path | None:
        logs = sorted(LOG_DIR.glob(f"*{jobid}*{suffix}"))
        return logs[-1] if logs else None
    
    seen = set()
    
    import time
    
    done_path = None
    
    while True:
        out_log = latest_log(jobid, ".out")
    
        if out_log and out_log.exists():
            chunk = tail(out_log, 120)
            for line in chunk.splitlines():
                if DONE_TAG in line:
                    done_path = line.split(DONE_TAG, 1)[1].strip()
                    print(f"[DONE] {done_path}")
                    break
    
            if done_path:
                break
    
        time.sleep(5)
    
    
    done_path
    print('**'*50)
# Out:
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522.jsonl
# ****************************************************************************************************
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522.jsonl
# ****************************************************************************************************
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519.jsonl
# ****************************************************************************************************

# %% [markdown]
# ## Results comparison

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn3
from pathlib import Path

# ---- CONFIG ----
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# 1. Define once (Update these only)
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519.jsonl"
}

# 2. Run reports automatically for each
for model_name, file_path in PATHS.items():
    print(f"\n--- {model_name} ---")
    if file_path.exists():
        gen_report(str(file_path))
    else:
        print(f"Error: File for {model_name} not found at {file_path}")
def load_data(filepath):
    data = {}
    if not filepath.exists(): return data
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            data[obj['job_id']] = set(obj['final'])
    return data

# 1. Load and Intersect
results = {name: load_data(path) for name, path in PATHS.items()}
loaded = [n for n, d in results.items() if d]
common_ids = set.intersection(*[set(results[m].keys()) for m in loaded])

# 2. Extract Commonalities and Differences
report_data = []
for jid in common_ids:
    bge_set = results["BGE"].get(jid, set())
    e5_set = results["E5"].get(jid, set())
    gte_set = results["GTE"].get(jid, set())
    
    # Are they identical?
    all_agree = (bge_set == e5_set == gte_set)
    
    # Who is the outlier?
    outlier = "None"
    if bge_set == e5_set != gte_set: outlier = "GTE"
    elif bge_set == gte_set != e5_set: outlier = "E5"
    elif e5_set == gte_set != bge_set: outlier = "BGE"
    elif not all_agree: outlier = "All Diverged"

    report_data.append({
        "job_id": jid,
        "all_agree": all_agree,
        "outlier": outlier,
        "bge_count": len(bge_set),
        "e5_count": len(e5_set),
        "gte_count": len(gte_set),
        "consensus_count": len(bge_set & e5_set & gte_set)
    })

df = pd.DataFrame(report_data)

# 3. Print Statistical Summary
print("=== COMPREHENSIVE COMPARISON REPORT ===")
print(f"Total Common Jobs: {len(df)}")
print(f"Absolute Consensus: {df['all_agree'].sum()} ({df['all_agree'].mean():.1%})")
print("\n--- Outlier Frequency (Who disagrees with the majority?) ---")
print(df[df['outlier'] != "None"]['outlier'].value_counts())

# 4. Generate Visualizations
# Jaccard Heatmap
model_names = list(results.keys())
j_matrix = np.zeros((3, 3))
for i, m1 in enumerate(model_names):
    for j, m2 in enumerate(model_names):
        scores = [len(results[m1][jid] & results[m2][jid]) / len(results[m1][jid] | results[m2][jid]) 
                  for jid in common_ids]
        j_matrix[i, j] = np.mean(scores)

plt.figure(figsize=(8, 6))
sns.heatmap(j_matrix, annot=True, xticklabels=model_names, yticklabels=model_names, cmap="YlGnBu")
plt.title("Jaccard Similarity Matrix (Semantic Overlap)")
plt.savefig("semantic_overlap_heatmap.png")

# Venn Diagram
venn_sets = []
for name in model_names:
    s = set()
    for jid in common_ids:
        for occ in results[name][jid]:
            s.add(f"{jid}|{occ}")
    venn_sets.append(s)

plt.figure(figsize=(10, 8))
venn3(venn_sets, set_labels=model_names)
plt.title("Consensus Core vs. Model-Specific Hallucinations")
plt.savefig("assignment_venn.png")
# Out:
# --- BGE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522_report.txt
#
# --- E5 ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522_report.txt
#
# --- GTE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519_report.txt
# === COMPREHENSIVE COMPARISON REPORT ===
# Total Common Jobs: 1000
# Absolute Consensus: 36 (3.6%)
#
# --- Outlier Frequency (Who disagrees with the majority?) ---
# outlier
# All Diverged    761
# E5               74
# BGE              65
# GTE              64
# Name: count, dtype: int64

# %%
from pathlib import Path

# 1. Define your specific report files once
REPORTS = {
    "BGE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522_report.txt",
    "E5_LARGE":  "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522_report.txt",
    "GTE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519_report.txt"
}

# 2. Loop through and print with clear headers
for model_name, file_path in REPORTS.items():
    p = Path(file_path)
    
    # Visual Header for scannability
    print("\n" + "="*60)
    print(f"****** {model_name} ******")
    print("="*60)
    
    if p.exists():
        print(p.read_text())
    else:
        print(f"FILE NOT FOUND: {file_path}")
# Out:
# ============================================================
# ****** BGE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.221
# avg_candidates_after: 2.591
# drop_rate: 0.6848
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0737
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 45  Information Technology Project Managers
# 41  Sales Managers
# 39  Personal Care Aides
# 35  Software Developers
# 32  Financial Managers
# 30  Computer Systems Engineers/Architects
# 29  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 28  Customer Service Representatives
# 28  Mental Health and Substance Abuse Social Workers
# 28  Architectural and Engineering Managers
# 27  Marketing Managers
# 26  Healthcare Social Workers
# 26  Administrative Services Managers
# 23  Acute Care Nurses
# 22  Accountants and Auditors
# 22  Food Service Managers
# 22  First-Line Supervisors of Retail Sales Workers
# 21  Nursing Assistants
# 21  Social and Human Service Assistants
# 21  First-Line Supervisors of Office and Administrative Support Workers
# 21  Chefs and Head Cooks
# 21  Advertising and Promotions Managers
# 21  Human Resources Specialists
# 20  Home Health Aides
# 19  Registered Nurses
#
# === DOMAIN AVG KEPT ===
# Administration/Office Support: 3
# Administrative/Office: 3
# Advertising and Marketing: 3
# Agriculture/Rural: 3
# Automotive Retail: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Property: 3
# Construction/Engineering: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Consulting: 3
# Customer Service: 3
# Cybersecurity: 3
# Data and Intelligence consultancy: 3
# Digital Marketing: 3
# Digital/Technology: 3
# Domestic Services: 3
# Domestic help & Cleaning: 3
# Education and Training: 3
# Electronics Technology: 3
# Energy Trading: 3
# Engineering/Manufacturing: 3
# Environmental Science: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Farming/Agribusiness: 3
# Fashion: 3
# Fashion Retail: 3
# Finance/Banking: 3
# Fintech: 3
# Food Industry: 3
# Food Service/Hospitality: 3
# Food and Beverage: 3
# Government: 3
# Health & Social Care: 3
# Health and Fitness: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Pharmaceutical: 3
# Healthcare/Social Care: 3
# Healthcare/Social Work: 3
# Higher Education: 3
# IT Jobs: 3
# IT and Consulting: 3
# IT and Telecommunications: 3
# IT/Software Development: 3
# Leisure and Fitness: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Logistics/Transportation: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Marketing: 3
# Marketing and Public Relations: 3
# Marketing/PR: 3
# Military/Defence: 3
# Non-Profit/Charity: 3
# Non-profit/Charity: 3
# Nuclear Engineering: 3
# Other/General Jobs: 3
# PR and Communications: 3
# Pharmaceutical: 3
# Property: 3
# Public Health: 3
# Publishing: 3
# Real Estate/Property Management: 3
# Recruitment Consultancy: 3
# Remote Work/Online Opportunities: 3
# Renewable Energy/Electric Vehicle: 3
# Renewables: 3
# Research and Market Analysis: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# SaaS: 3
# Sales Jobs: 3
# Sales and Customer Service: 3
# Sales and Recruitment: 3
# Scientific & QA Jobs: 3
# Security: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Social Housing: 3
# Social Work: 3
# Sports/Leisure: 3
# Telecommunications: 3
# Tourism/Hospitality: 3
# Trade and Construction: 3
# Transportation/Fleet Management: 3
# Transportation/Logistics: 3
# Utilities: 3
# Waste Management: 3
# HR & Recruitment: 2.875
# Human Resources: 2.875
# Administration: 2.833
# Retail: 2.806
# Consultancy: 2.8
# Financial Services: 2.75
# Social work: 2.733
# Real Estate: 2.714
# Sales and Marketing: 2.714
# Software Development: 2.714
# Accounting & Finance: 2.678
# Hospitality: 2.667
# IT and Technology: 2.667
# Logistics and Transportation: 2.667
# Media and Entertainment: 2.667
# Scientific & QA: 2.667
# Education: 2.658
# Engineering: 2.649
# Hospitality & Catering: 2.619
# Sales: 2.607
# Admin Jobs: 2.6
# Market Research: 2.6
# Transportation: 2.6
# Customer Services: 2.583
# Finance: 2.571
# IT: 2.571
# Healthcare: 2.551
# Automotive: 2.538
# Logistics & Warehouse: 2.535
# Agriculture: 2.5
# Construction and Maintenance: 2.5
# Digital Media: 2.5
# Domestic help & Cleaning Jobs: 2.5
# Manufacturing: 2.5
# Non-Profit: 2.5
# Software Engineering: 2.5
# Travel and Tourism: 2.5
# Healthcare & Nursing: 2.488
# Construction: 2.469
# Facilities Management: 2.4
# Creative & Design: 2.333
# Insurance: 2.333
# PR: 2.333
# Public Administration: 2.333
# Recruitment: 2.333
# Trade & Construction: 2.333
# Legal: 2.222
# Law: 2.2
# Energy: 2.167
# Aerospace & Manufacturing: 2
# Beauty and Cosmetics: 2
# Biotechnology: 2
# Construction and Infrastructure: 2
# Construction/Property Maintenance: 2
# Education Technology: 2
# Education/Training: 2
# Electrical Engineering: 2
# Home Accessories Manufacturing: 2
# IT, Fintech, Blockchain, AI: 2
# Leisure: 2
# Logistics: 2
# Manufacturing/Industrial: 2
# Manufacturing/Production: 2
# Media and Communications: 2
# Non-Profit/NGO: 2
# Public Sector/ Law Enforcement: 2
# Renewable Energy: 2
# Sales and Business Development: 2
# Security and Customer Service: 2
# Social Services/Social Work: 2
# Technology & Engineering: 2
# Technology/Software: 2
# Utility: 2
# Public Relations: 1.75
# Energy and Utilities: 1.5
# Media and Advertising: 1.5
# Technology: 1.5
# Aerospace: 1
# Domestic Help & Cleaning: 1
# Food Service: 1
# Healthcare/Hospitality: 1
# Media: 1
# Online Surveys/Admin Jobs: 1
# Recruitment/Consultancy: 1
# Sales and Events: 1
# Translation and Interpreting: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Food Service Managers']
# drop:   ['Waiters and Waitresses', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Chefs and Head Cooks', 'Bartenders']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Microsystems Engineers', 'Electrical and Electronics Drafters']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Electrical and Electronics Repairers, Commercial and Industrial Equipment', 'Manufacturing Engineers', 'Nanosystems Engineers', 'Electrical Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Power-Line Installers and Repairers']
# drop:   ['Solar Photovoltaic Installers', 'Helpers--Electricians', 'Solar Sales Representatives and Assessors', 'Solar Energy Installation Managers', 'Solar Thermal Installers and Technicians', 'Electrical and Electronics Repairers, Powerhouse, Substation, and Relay']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Human Resources Assistants, Except Payroll and Timekeeping']
# drop:   ['Telephone Operators', 'Loan Interviewers and Clerks', 'Telemarketers', 'Receptionists and Information Clerks', 'New Accounts Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers', 'Personal Care Aides']
# drop:   ['Child, Family, and School Social Workers', 'Childcare Workers', 'Social and Human Service Assistants', 'Occupational Therapists']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Biochemists and Biophysicists', 'Bioengineers and Biomedical Engineers', 'Natural Sciences Managers']
# drop:   ['Biological Technicians', 'Chemical Technicians', 'Biofuels/Biodiesel Technology and Product Development Managers', 'Bioinformatics Technicians', 'Bioinformatics Scientists', 'Agricultural Technicians']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Robotics Engineers', 'Software Developers', 'Telecommunications Engineering Specialists']
# drop:   ['Automotive Engineers', 'Photonics Engineers', 'Human Factors Engineers and Ergonomists', 'Wind Energy Engineers', 'Talent Directors', 'Media Programming Directors', 'Web Developers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Heavy and Tractor-Trailer Truck Drivers']
# drop:   ['First-Line Supervisors of Material-Moving Machine and Vehicle Operators', 'Industrial Truck and Tractor Operators', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Crane and Tower Operators', 'Driver/Sales Workers', 'Light Truck Drivers', 'Bus Drivers, Transit and Intercity', 'Cargo and Freight Agents']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers', 'Social and Community Service Managers', 'Rehabilitation Counselors']
# drop:   ['Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers', 'Recreation Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Compensation and Benefits Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mobile Heavy Equipment Mechanics, Except Engines', 'Mechanical Engineering Technologists and Technicians', 'Bus and Truck Mechanics and Diesel Engine Specialists']
# drop:   ['Outdoor Power Equipment and Other Small Engine Mechanics', 'Medical Equipment Repairers', 'Aircraft Mechanics and Service Technicians', 'Locomotive Engineers', 'Mechanical Engineers', 'Aerospace Engineers', 'Civil Engineers']
#
#
# ============================================================
# ****** E5_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.599
# avg_candidates_after: 2.604
# drop_rate: 0.6972
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0668
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 45  Customer Service Representatives
# 44  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 43  Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products
# 43  Software Developers
# 37  Personal Care Aides
# 36  Accountants and Auditors
# 31  Treasurers and Controllers
# 30  Home Health Aides
# 30  Financial Managers
# 29  First-Line Supervisors of Material-Moving Machine and Vehicle Operators
# 26  Sales Managers
# 25  Healthcare Social Workers
# 25  Information Technology Project Managers
# 24  Secretaries and Administrative Assistants, Except Legal, Medical, and Executive
# 23  Architectural and Engineering Managers
# 21  Advertising and Promotions Managers
# 20  Sales Engineers
# 20  First-Line Supervisors of Food Preparation and Serving Workers
# 19  First-Line Supervisors of Retail Sales Workers
# 18  Critical Care Nurses
# 18  Clinical Nurse Specialists
# 18  Cost Estimators
# 18  Web Developers
# 18  Computer Systems Engineers/Architects
# 18  Nursing Assistants
#
# === DOMAIN AVG KEPT ===
# Admin Jobs: 3
# Administration/Office Support: 3
# Advertising and Marketing: 3
# Aerospace: 3
# Agriculture: 3
# Agriculture/Rural: 3
# Automotive Retail: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction and Maintenance: 3
# Construction/Engineering: 3
# Construction/Property Maintenance: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Creative & Design: 3
# Cybersecurity: 3
# Digital/Technology: 3
# Domestic Help & Cleaning: 3
# Domestic help & Cleaning: 3
# Education Technology: 3
# Education and Training: 3
# Education/Training: 3
# Electrical Engineering: 3
# Electronics Technology: 3
# Energy Trading: 3
# Engineering/Manufacturing: 3
# Environmental Science: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Facilities Management: 3
# Farming/Agribusiness: 3
# Fashion: 3
# Fashion Retail: 3
# Finance/Banking: 3
# Food Industry: 3
# Food Service: 3
# Food Service/Hospitality: 3
# Food and Beverage: 3
# Health & Social Care: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Social Care: 3
# Higher Education: 3
# Hospitality: 3
# Human Resources: 3
# IT and Telecommunications: 3
# IT, Fintech, Blockchain, AI: 3
# Leisure: 3
# Leisure and Fitness: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Marketing/PR: 3
# Media: 3
# Media and Advertising: 3
# Media and Communications: 3
# Military/Defence: 3
# Non-Profit: 3
# Non-Profit/Charity: 3
# Non-Profit/NGO: 3
# Non-profit/Charity: 3
# Online Surveys/Admin Jobs: 3
# Other/General Jobs: 3
# Public Administration: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Publishing: 3
# Real Estate/Property Management: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Renewables: 3
# Research and Market Analysis: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# Sales Jobs: 3
# Sales and Business Development: 3
# Sales and Customer Service: 3
# Sales and Recruitment: 3
# Scientific & QA Jobs: 3
# Security: 3
# Security and Customer Service: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Social Housing: 3
# Social Services/Social Work: 3
# Sports/Leisure: 3
# Technology: 3
# Technology & Engineering: 3
# Technology/Software: 3
# Telecommunications: 3
# Tourism/Hospitality: 3
# Trade and Construction: 3
# Transportation/Logistics: 3
# Waste Management: 3
# HR & Recruitment: 2.875
# Finance: 2.857
# Sales and Marketing: 2.857
# Manufacturing: 2.842
# Healthcare & Nursing: 2.805
# Accounting & Finance: 2.78
# Sales: 2.75
# Software Development: 2.714
# Social work: 2.7
# Administration: 2.667
# Biotechnology: 2.667
# Customer Services: 2.667
# Health and Fitness: 2.667
# IT and Technology: 2.667
# Marketing: 2.667
# Logistics & Warehouse: 2.628
# Financial Services: 2.625
# Automotive: 2.615
# Retail: 2.611
# Consultancy: 2.6
# Transportation: 2.6
# Social Work: 2.571
# Legal: 2.556
# Construction: 2.531
# Administrative/Office: 2.5
# Construction and Property: 2.5
# Consulting: 2.5
# Domestic help & Cleaning Jobs: 2.5
# Education: 2.5
# Energy: 2.5
# Healthcare/Social Work: 2.5
# Logistics/Transportation: 2.5
# Marketing and Public Relations: 2.5
# Pharmaceutical: 2.5
# Recruitment: 2.5
# Software Engineering: 2.5
# Hospitality & Catering: 2.476
# Logistics: 2.462
# Engineering: 2.459
# Healthcare: 2.449
# Real Estate: 2.429
# IT: 2.405
# Market Research: 2.4
# Digital Marketing: 2.333
# IT Jobs: 2.333
# Insurance: 2.333
# Media and Entertainment: 2.333
# Trade & Construction: 2.25
# Law: 2.1
# Aerospace & Manufacturing: 2
# Beauty and Cosmetics: 2
# Biotechnology/Pharmaceutical: 2
# Customer Service: 2
# Data and Intelligence consultancy: 2
# Digital Media: 2
# Domestic Services: 2
# Energy and Utilities: 2
# Fintech: 2
# Government: 2
# Healthcare/Hospitality: 2
# Healthcare/Pharmaceutical: 2
# Home Accessories Manufacturing: 2
# IT and Consulting: 2
# IT/Software Development: 2
# Logistics and Transportation: 2
# Manufacturing/Production: 2
# Nuclear Engineering: 2
# PR: 2
# PR and Communications: 2
# Property: 2
# Public Relations: 2
# Recruitment Consultancy: 2
# Recruitment/Consultancy: 2
# Remote Work/Online Opportunities: 2
# SaaS: 2
# Sales and Events: 2
# Scientific & QA: 2
# Translation and Interpreting: 2
# Transportation/Fleet Management: 2
# Travel and Tourism: 2
# Utilities: 2
# Utility: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['First-Line Supervisors of Personal Service Workers']
# drop:   ['Waiters and Waitresses', 'Bartenders', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'First-Line Supervisors of Food Preparation and Serving Workers']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Electrical Engineers', 'Telecommunications Engineering Specialists']
# drop:   ['Microsystems Engineers', 'Computer Hardware Engineers', 'Electrical and Electronic Engineering Technologists and Technicians', 'Model Makers, Metal and Plastic']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical and Electronic Engineering Technologists and Technicians']
# drop:   ['Electrical Power-Line Installers and Repairers', 'Helpers--Installation, Maintenance, and Repair Workers', 'Solar Sales Representatives and Assessors', 'Shampooers', 'Solar Energy Installation Managers', 'Tire Repairers and Changers', 'Tire Builders']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Word Processors and Typists', 'Secretaries and Administrative Assistants, Except Legal, Medical, and Executive']
# drop:   ['Telephone Operators', 'Billing and Posting Clerks', 'Data Entry Keyers', 'Telemarketers', 'Procurement Clerks', 'Receptionists and Information Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers']
# drop:   ['Personal Care Aides', 'Locker Room, Coatroom, and Dressing Room Attendants', 'Home Health Aides', 'Maids and Housekeeping Cleaners', 'Community Health Workers', 'Psychiatrists', 'Psychiatric Technicians', 'Social and Human Service Assistants', 'Mental Health and Substance Abuse Social Workers']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Bioengineers and Biomedical Engineers', 'Medical Scientists, Except Epidemiologists']
# drop:   ['Chemists', 'Natural Sciences Managers', 'Physicians, Pathologists', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products', 'Agricultural Technicians', 'Bioinformatics Scientists', 'Materials Scientists', 'Molecular and Cellular Biologists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Software Developers', 'Telecommunications Engineering Specialists']
# drop:   ['Natural Sciences Managers', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products', 'Grinding and Polishing Workers, Hand', 'Software Quality Assurance Analysts and Testers', 'Dancers', 'Robotics Engineers', 'Tire Builders']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Heavy and Tractor-Trailer Truck Drivers', 'Industrial Truck and Tractor Operators', 'First-Line Supervisors of Material-Moving Machine and Vehicle Operators']
# drop:   ['Crane and Tower Operators', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Loading and Moving Machine Operators, Underground Mining', 'Light Truck Drivers', 'Driver/Sales Workers', 'Pile Driver Operators']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Social and Community Service Managers', 'Registered Nurses']
# drop:   ['Personal Care Aides', 'Recreation Workers', 'Home Health Aides', 'Healthcare Social Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Psychiatrists', 'Medical and Health Services Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Aircraft Mechanics and Service Technicians', 'Wind Energy Engineers']
# drop:   ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Maintenance and Repair Workers, General', 'Outdoor Power Equipment and Other Small Engine Mechanics', 'Heating, Air Conditioning, and Refrigeration Mechanics and Installers', 'Electric Motor, Power Tool, and Related Repairers', 'Maintenance Workers, Machinery', 'Industrial Machinery Mechanics', 'Mechanical Engineers']
#
#
# ============================================================
# ****** GTE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.229
# avg_candidates_after: 2.617
# drop_rate: 0.682
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0932
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 43  Software Developers
# 40  Computer Systems Engineers/Architects
# 38  Personal Care Aides
# 37  Information Technology Project Managers
# 36  Healthcare Social Workers
# 33  Treasurers and Controllers
# 31  Nursing Assistants
# 30  Financial Managers
# 25  Sales Managers
# 24  Mental Health and Substance Abuse Social Workers
# 23  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 23  Human Resources Specialists
# 22  Advertising and Promotions Managers
# 22  Cooks, Institution and Cafeteria
# 21  Customer Service Representatives
# 21  Accountants and Auditors
# 20  Database Architects
# 19  Acute Care Nurses
# 19  Human Resources Managers
# 19  Registered Nurses
# 19  Secretaries and Administrative Assistants, Except Legal, Medical, and Executive
# 19  Computer Network Architects
# 18  Sales Engineers
# 18  First-Line Supervisors of Non-Retail Sales Workers
# 18  Web Developers
#
# === DOMAIN AVG KEPT ===
# Administration: 3
# Administration/Office Support: 3
# Administrative/Office: 3
# Advertising and Marketing: 3
# Aerospace: 3
# Aerospace & Manufacturing: 3
# Agriculture/Rural: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Consulting: 3
# Customer Service: 3
# Cybersecurity: 3
# Data and Intelligence consultancy: 3
# Domestic help & Cleaning: 3
# Education and Training: 3
# Education/Training: 3
# Electrical Engineering: 3
# Electronics Technology: 3
# Energy Trading: 3
# Engineering/Manufacturing: 3
# Environmental Science: 3
# Executive Search Firm: 3
# Facilities Management: 3
# Fashion: 3
# Fashion Retail: 3
# Finance/Banking: 3
# Food Service: 3
# Food and Beverage: 3
# Government: 3
# Health & Social Care: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Advertising: 3
# Healthcare/Social Care: 3
# Healthcare/Social Work: 3
# Higher Education: 3
# Home Accessories Manufacturing: 3
# Human Resources: 3
# IT Jobs: 3
# IT and Consulting: 3
# IT and Telecommunications: 3
# IT, Fintech, Blockchain, AI: 3
# IT/Software Development: 3
# Leisure: 3
# Leisure and Fitness: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Manufacturing/Production: 3
# Media: 3
# Media and Advertising: 3
# Military/Defence: 3
# Non-Profit/NGO: 3
# PR and Communications: 3
# Pharmaceutical: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Publishing: 3
# Real Estate/Property Management: 3
# Recruitment Consultancy: 3
# Recruitment/Consultancy: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Renewables: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# Sales and Business Development: 3
# Sales and Customer Service: 3
# Sales and Events: 3
# Sales and Recruitment: 3
# Security and Customer Service: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Social Services/Social Work: 3
# Software Engineering: 3
# Sports/Leisure: 3
# Technology & Engineering: 3
# Telecommunications: 3
# Trade and Construction: 3
# Transportation: 3
# Transportation/Logistics: 3
# Utility: 3
# Waste Management: 3
# HR & Recruitment: 2.875
# Social Work: 2.857
# Customer Services: 2.833
# Recruitment: 2.833
# Consultancy: 2.8
# Construction: 2.781
# Accounting & Finance: 2.78
# Manufacturing: 2.763
# IT: 2.738
# Social work: 2.733
# Finance: 2.714
# Software Development: 2.714
# Biotechnology: 2.667
# Creative & Design: 2.667
# Health and Fitness: 2.667
# Hospitality: 2.667
# IT and Technology: 2.667
# Insurance: 2.667
# Retail: 2.667
# Scientific & QA: 2.667
# Technology: 2.667
# Trade & Construction: 2.667
# Healthcare: 2.653
# Sales: 2.643
# Admin Jobs: 2.6
# Hospitality & Catering: 2.595
# Healthcare & Nursing: 2.585
# Education: 2.579
# Sales and Marketing: 2.571
# Legal: 2.556
# Automotive: 2.538
# Agriculture: 2.5
# Beauty and Cosmetics: 2.5
# Construction and Maintenance: 2.5
# Construction and Property: 2.5
# Domestic help & Cleaning Jobs: 2.5
# Energy and Utilities: 2.5
# Financial Services: 2.5
# Marketing and Public Relations: 2.5
# Marketing/PR: 2.5
# Non-Profit: 2.5
# Public Relations: 2.5
# Scientific & QA Jobs: 2.5
# Security: 2.5
# Utilities: 2.5
# Engineering: 2.486
# Real Estate: 2.429
# Digital Marketing: 2.333
# Logistics and Transportation: 2.333
# Media and Entertainment: 2.333
# PR: 2.333
# Energy: 2.167
# Logistics & Warehouse: 2.163
# Logistics: 2.154
# Automotive Retail: 2
# Construction/Engineering: 2
# Construction/Property Maintenance: 2
# Digital/Technology: 2
# Domestic Help & Cleaning: 2
# Domestic Services: 2
# Education Technology: 2
# Farming/Agribusiness: 2
# Food Industry: 2
# Food Service/Hospitality: 2
# Healthcare Administration: 2
# Healthcare/Hospitality: 2
# Law: 2
# Marketing: 2
# Media and Communications: 2
# Non-Profit/Charity: 2
# Non-profit/Charity: 2
# Nuclear Engineering: 2
# Other/General Jobs: 2
# Property: 2
# Public Administration: 2
# Remote Work/Online Opportunities: 2
# Research and Market Analysis: 2
# Sales Jobs: 2
# Social Housing: 2
# Translation and Interpreting: 2
# Transportation/Fleet Management: 2
# Travel and Tourism: 2
# Digital Media: 1.5
# Fintech: 1.5
# Market Research: 1.4
# Estate Agency: 1
# Healthcare/Pharmaceutical: 1
# Logistics/Transportation: 1
# Online Surveys/Admin Jobs: 1
# SaaS: 1
# Technology/Software: 1
# Tourism/Hospitality: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Food Service Managers', 'Bartenders']
# drop:   ['Waiters and Waitresses', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Chefs and Head Cooks', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Cooks, Private Household', 'Baristas']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Electrical Engineers', 'Solar Energy Systems Engineers']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Electrical and Electronics Drafters', 'Manufacturing Engineers', 'Microsystems Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electrical Power-Line Installers and Repairers', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Engineers']
# drop:   ['Solar Photovoltaic Installers', 'Electrical and Electronic Engineering Technologists and Technicians', 'Solar Energy Installation Managers', 'Power Distributors and Dispatchers', 'Fuel Cell Engineers']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Human Resources Assistants, Except Payroll and Timekeeping', 'Word Processors and Typists']
# drop:   ['Loan Interviewers and Clerks', 'Receptionists and Information Clerks', 'Human Resources Specialists', 'New Accounts Clerks', 'Archivists']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Mental Health and Substance Abuse Social Workers', 'Personal Care Aides', 'Community Health Workers']
# drop:   ['Healthcare Social Workers', 'Nannies', 'Social and Human Service Assistants', 'Child, Family, and School Social Workers', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Bioengineers and Biomedical Engineers', 'Molecular and Cellular Biologists', 'Bioinformatics Scientists']
# drop:   ['Medical and Clinical Laboratory Technologists', 'Chemical Technicians', 'Quality Control Analysts', 'Validation Engineers', 'Chemists', 'Medical Dosimetrists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Software Developers', 'Computer Systems Engineers/Architects', 'Computer and Information Research Scientists']
# drop:   ['Computer Network Architects', 'Microsystems Engineers', 'Radio Frequency Identification Device Specialists', 'Telecommunications Engineering Specialists', 'Software Quality Assurance Analysts and Testers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Industrial Truck and Tractor Operators', 'Heavy and Tractor-Trailer Truck Drivers']
# drop:   ['Crane and Tower Operators', 'Tank Car, Truck, and Ship Loaders', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Transportation, Storage, and Distribution Managers', 'Logistics Analysts', 'Light Truck Drivers', 'Logistics Engineers', 'Locomotive Engineers']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers', 'Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers']
# drop:   ['Personal Care Aides', 'Community Health Workers', 'Regulatory Affairs Managers', 'Social and Community Service Managers', 'Food Service Managers', 'Human Resources Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mechanical Engineering Technologists and Technicians', 'Mechanical Engineers', 'Aircraft Mechanics and Service Technicians']
# drop:   ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Maintenance and Repair Workers, General', 'Mobile Heavy Equipment Mechanics, Except Engines', 'Bus and Truck Mechanics and Diesel Engine Specialists', 'Fuel Cell Engineers', 'Manufacturing Engineers']

# %%
notebook_name = "06_prompt"
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519.jsonl"
}

# %%
import json
import sys
from pathlib import Path
import numpy as np
import pandas as pd

# 1. EXACT CONFIGURATION
PATHS = {
    "BGE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185798_task0_20260206_145522.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz",
    },
    "E5": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185799_task0_20260206_145522.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz",
    },
    "GTE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2185800_task0_20260206_145519.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz",
    },
}

# 2. HELPER FUNCTIONS
def _to_str_array(x: np.ndarray) -> np.ndarray:
    if x.dtype == object:
        return np.array([v.decode("utf-8") if isinstance(v, (bytes, bytearray)) else str(v) for v in x])
    if np.issubdtype(x.dtype, np.bytes_):
        return np.array([v.decode("utf-8") for v in x])
    return x.astype(str)

def load_meta_from_npz(npz_path: str) -> pd.DataFrame:
    with np.load(npz_path, allow_pickle=True) as npz:
        job_id_key = "job_id" if "job_id" in npz.files else ("job_ids" if "job_ids" in npz.files else None)
        title_key = "job_ad_title" if "job_ad_title" in npz.files else ("title" if "title" in npz.files else None)
        domain_key = "domain" if "domain" in npz.files else None
        sector_key = "job_sector_category" if "job_sector_category" in npz.files else None

        meta = {
            "job_id": _to_str_array(npz[job_id_key]),
            "title": _to_str_array(npz[title_key]),
        }
        meta["domain"] = _to_str_array(npz[domain_key]) if domain_key else ""
        meta["sector"] = _to_str_array(npz[sector_key]) if sector_key else ""
    return pd.DataFrame(meta)

def load_results_from_jsonl(jsonl_path: str) -> pd.DataFrame:
    rows = []
    with open(jsonl_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            try: rows.append(json.loads(line))
            except: continue

    df = pd.DataFrame(rows)
    df["job_id"] = df["job_id"].astype(str)

    if "final" in df.columns: df = df.rename(columns={"final": "kept"})
    if "drop" in df.columns: df = df.rename(columns={"drop": "dropped"})
    
    if "kept" not in df.columns: df["kept"] = None
    if "dropped" not in df.columns: df["dropped"] = None

    def _list_to_csv(x):
        if isinstance(x, list): return ", ".join(map(str, x))
        return "" if x is None else str(x)

    df["kept"] = df["kept"].apply(_list_to_csv)
    df["dropped"] = df["dropped"].apply(_list_to_csv)
    return df[["job_id", "kept", "dropped"]]

# 3. CORE BUILDER
def build_audit_dataset(paths_by_model: dict, n_jobs_per_model: int = 100, seed: int = 42) -> pd.DataFrame:
    all_frames = []
    for model, p in paths_by_model.items():
        print(f"Lendo dados para {model}...")
        meta = load_meta_from_npz(p["npz"])
        res = load_results_from_jsonl(p["jsonl"])
        
        merged = res.merge(meta, on="job_id", how="inner")
        if merged.empty:
            print(f"!!! [AVISO] {model} resultou em merge vazio.")
            continue
            
        sample_size = min(n_jobs_per_model, len(merged))
        sampled = merged.sample(n=sample_size, random_state=seed).copy()
        sampled["model"] = model
        all_frames.append(sampled)

    out = pd.concat(all_frames, ignore_index=True)
    cols = ["job_id", "model", "title", "domain", "sector", "kept", "dropped"]
    for c in cols:
        if c not in out.columns: out[c] = ""
            
    return out[cols].sort_values(["model", "job_id"]).reset_index(drop=True)

# 4. EXECUTION
if __name__ == "__main__":
    # Dinamicamente tenta pegar o nome do arquivo/notebook
    try:
        # Se for um script .py
        prefix = Path(__file__).stem
    except NameError:
        # Fallback para Jupyter Notebook (ajuste manualmente se preferir)
        prefix = notebook_name

    # Gera o dataset
    audit_df = build_audit_dataset(PATHS, n_jobs_per_model=100, seed=42)
    
    # Define o nome do arquivo com o prefixo
    out_filename = f"{prefix}_sanity_check_300_jobs_FINAL.csv"
    out_path = Path(out_filename)
    
    # Salva o CSV
    audit_df.to_csv(out_path, index=False)
    
    print("-" * 30)
    print(f"[SUCESSO] Arquivo escrito: {out_path}")
    print(f"Total de linhas: {len(audit_df)}")
    print(f"Distribuição por modelo:\n{audit_df['model'].value_counts()}")
    print("-" * 30)
# Out:
# Lendo dados para BGE...
# Lendo dados para E5...
# Lendo dados para GTE...
# ------------------------------
# [SUCESSO] Arquivo escrito: 06_prompt_sanity_check_300_jobs_FINAL.csv
# Total de linhas: 300
# Distribuição por modelo:
# model
# BGE    100
# E5     100
# GTE    100
# Name: count, dtype: int64
# ------------------------------

# %%
import pandas as pd
import re
import ast

# =============================================================================
# Load
# =============================================================================
file_path = "05_prompt_sanity_check_300_jobs_FINAL.csv"
df = pd.read_csv(file_path)

# Normalise model names so pivot columns are predictable
df["model"] = df["model"].astype(str).str.strip().str.lower()

# =============================================================================
# Robust parser for `kept` (handles: "['a','b']" AND "a, b")
# =============================================================================
def parse_kept(x):
    if pd.isna(x):
        return []

    s = str(x).strip()

    # Case 1: Python list literal
    if s.startswith("[") and s.endswith("]"):
        try:
            out = ast.literal_eval(s)
            if isinstance(out, list):
                return [str(i).strip() for i in out if str(i).strip()]
        except Exception:
            pass

    # Case 2: plain comma-separated
    items = re.split(r",\s*(?=[A-Z0-9])", s)
    return [i.strip().strip("[]'\"") for i in items if i.strip()]

df["kept_list"] = df["kept"].apply(parse_kept)

# =============================================================================
# Pivot: one row per job, one column per model
# =============================================================================
pivot = df.pivot_table(
    index=["job_id", "title", "domain", "sector"],
    columns="model",
    values="kept_list",
    aggfunc="first"
).reset_index()

need_models = ['bge', 'e5', 'gte']
missing_cols = [c for c in need_models if c not in pivot.columns]
if missing_cols:
    raise ValueError(
        f"Missing model columns in pivot: {missing_cols}. "
        f"Available: {sorted([c for c in pivot.columns if c not in ['job_id','title','domain','sector']])}"
    )

pivot = pivot.dropna(subset=need_models)

# =============================================================================
# Helpers
# =============================================================================
def top1(lst):
    return lst[0] if isinstance(lst, list) and len(lst) else None

def jaccard(a, b):
    sa = set(a) if isinstance(a, list) else set()
    sb = set(b) if isinstance(b, list) else set()
    if not sa and not sb:
        return 1.0
    return len(sa & sb) / len(sa | sb)

# =============================================================================
# Divergence metrics
# =============================================================================
pivot["top1_bge"] = pivot["bge"].apply(top1)
pivot["top1_e5"]  = pivot["e5"].apply(top1)
pivot["top1_gte"] = pivot["gte"].apply(top1)

pivot["all_top1_same"] = (
    (pivot["top1_bge"] == pivot["top1_e5"]) &
    (pivot["top1_bge"] == pivot["top1_gte"])
)

pivot["jac_bge_e5"] = pivot.apply(lambda r: jaccard(r["bge"], r["e5"]), axis=1)
pivot["jac_bge_gte"] = pivot.apply(lambda r: jaccard(r["bge"], r["gte"]), axis=1)
pivot["jac_e5_gte"] = pivot.apply(lambda r: jaccard(r["e5"], r["gte"]), axis=1)

pivot["avg_jaccard"] = pivot[["jac_bge_e5", "jac_bge_gte", "jac_e5_gte"]].mean(axis=1)

# =============================================================================
# Most divergent jobs
# =============================================================================
divergent = pivot.sort_values(
    by=["avg_jaccard", "all_top1_same"],
    ascending=[True, True]
).head(20)

divergent[[
    "job_id",
    "title",
    "top1_bge",
    "top1_e5",
    "top1_gte",
    "avg_jaccard",
    "jac_bge_e5",
    "jac_bge_gte",
    "jac_e5_gte",
]]
# Out:
# model      job_id                                              title  \
# 0      2192398821                         Driving Instructor Trainee
# 10     2669419357                                     HGV Technician
# 12     2678422149                                       Dental Nurse
# 15     2700403944  Real Estate Finance Associate - London/Manches...
# 16     2716366432                        Product Manager - Immediacy
# 18     2719570720                        Public Health Officer Roles
# 30     2746699682                Case Manager - Fully Remote Working
# 34     2751637709              Warehouse / Stores Despatch Assistant
# 78     2826459971             AD Primary Care Transformation Manager
# 29     2744113462            Information Governance Officer - Police
# 61     2802937564                     Junior Compliance co-ordinator
# 45     2780613096    Frontend Engineering Leader (OPEN TO UK REMOTE)
# 35     2751651440                                   Business Analyst
# 59     2794085129                                       Receptionist
# 80     2828239237          Domestic Gas Service & Breakdown Engineer
# 23     2722116449                           Commission Administrator
# 38     2761893938                    Business Improvement Specialist
# 50     2790612570                                    Window Cleaners
# 58     2794078811                         Post litigation Fee Earner
# 26     2738958402                           Senior Investment Broker
#
# model                                           top1_bge  \
# 0                                  Adult Basic Education
# 10              Recreational Vehicle Service Technicians
# 12                                     Registered Nurses
# 15                                         Loan Officers
# 16                                    Marketing Managers
# 18                          Health Education Specialists
# 30            Occupational Health and Safety Technicians
# 34                                              Weighers
# 78                  Medical and Health Services Managers
# 29                        Information Security Engineers
# 61                                   Compliance Managers
# 45                                   Software Developers
# 35               Information Technology Project Managers
# 59     First-Line Supervisors of Office and Administr...
# 80                                   Gas Plant Operators
# 23                        Payroll and Timekeeping Clerks
# 38                                   Logistics Engineers
# 50                       Maids and Housekeeping Cleaners
# 58                       Paralegals and Legal Assistants
# 26                           Personal Financial Advisors
#
# model                                           top1_e5  \
# 0                    Cleaners of Vehicles and Equipment
# 10              Heavy and Tractor-Trailer Truck Drivers
# 12                                             Dentists
# 15                                  Financial Examiners
# 16              Information Technology Project Managers
# 18                             Community Health Workers
# 30                              Occupational Therapists
# 34                                           Inspectors
# 78                           Clinical Nurse Specialists
# 29                       Regulatory Affairs Specialists
# 61                       Regulatory Affairs Specialists
# 45               Architectural and Engineering Managers
# 35              Human Factors Engineers and Ergonomists
# 59            Secretaries and Administrative Assistants
# 80     Gas Compressor and Gas Pumping Station Operators
# 23                       Payroll and Timekeeping Clerks
# 38                                           Production
# 50                                Janitors and Cleaners
# 58                                     Claims Adjusters
# 26                                           Securities
#
# model                                           top1_gte  avg_jaccard  \
# 0                                            Bus Drivers     0.000000
# 10     Bus and Truck Mechanics and Diesel Engine Spec...     0.000000
# 12                                     Dental Hygienists     0.000000
# 15                                               Lawyers     0.000000
# 16                   Commercial and Industrial Designers     0.000000
# 18                                       Epidemiologists     0.000000
# 30            Occupational Health and Safety Specialists     0.000000
# 34                           Medical Equipment Repairers     0.000000
# 78                        Health Informatics Specialists     0.000000
# 29                           Regulatory Affairs Managers     0.055556
# 61                        Payroll and Timekeeping Clerks     0.055556
# 45                     Training and Development Managers     0.066667
# 35                             Computer Systems Analysts     0.083333
# 59                  Receptionists and Information Clerks     0.083333
# 80                              Home Appliance Repairers     0.083333
# 23                                               Tellers     0.111111
# 38                                  Validation Engineers     0.111111
# 50                       Maids and Housekeeping Cleaners     0.111111
# 58                       Paralegals and Legal Assistants     0.111111
# 26                                            Securities     0.133333
#
# model  jac_bge_e5  jac_bge_gte  jac_e5_gte
# 0        0.000000     0.000000        0.00
# 10       0.000000     0.000000        0.00
# 12       0.000000     0.000000        0.00
# 15       0.000000     0.000000        0.00
# 16       0.000000     0.000000        0.00
# 18       0.000000     0.000000        0.00
# 30       0.000000     0.000000        0.00
# 34       0.000000     0.000000        0.00
# 78       0.000000     0.000000        0.00
# 29       0.166667     0.000000        0.00
# 61       0.166667     0.000000        0.00
# 45       0.200000     0.000000        0.00
# 35       0.000000     0.250000        0.00
# 59       0.000000     0.000000        0.25
# 80       0.000000     0.000000        0.25
# 23       0.333333     0.000000        0.00
# 38       0.000000     0.333333        0.00
# 50       0.000000     0.333333        0.00
# 58       0.000000     0.333333        0.00
# 26       0.000000     0.000000        0.40

# %% [markdown]
# This output is a Conflict Audit, measuring the Jaccard similarity (agreement) between the Top 1 results of your three models (BGE, E5, and GTE).The Verdict: High Conflict, Low ConsensusThe results show that the models are frequently disagreeing on the primary occupation. This confirms that relying on a single embedding model—even with an LLM pruner—leaves room for error.
#
# The Anchor Rule impact: Even with the LLM pruning, the models are starting from different "Top 1" candidates provided by the embeddings. The LLM is essentially trying to fix three different sets of mistakes.3. RecommendationPrioritize E5/BGE Agreement: These two models seem to have the most logical overlap in your snippet.Flag "Zero Consensus" Jobs: Any job where the Jaccard is 0.0 across the board (like the first 9 rows) should be flagged for a Gemini 1.5 Pro tie-breaker. These are the jobs where the embeddings are too confused for Llama-8B to solve alone.Would you like me to provide the Python logic to automatically "vote" on the final occupation based on this table?
