# %% [markdown]
# # prompt apos diversos testes do prompt 9 inspirado no 7 ta bom mas precisa ficar um pouco mais hard!
#
# also changed the code structure!
#
# Net effect summary
# Dimension	Before	Now
# Index safety	❌ fragile	✅ correct
# Crash risk	⚠️ medium	✅ low
# Anchor stability	⚠️ noisy	✅ strong
# Manager leakage	❌ high	✅ controlled
# IT leakage	⚠️ uneven	✅ bounded
# Scale readiness	❌ risky	✅ safe for 28M

# %% [markdown]
# # Helpers

# %%
import json
import re
import random
import statistics
from pathlib import Path
from collections import Counter, defaultdict
from datetime import datetime

import numpy as np

# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------
_RUN_RE = re.compile(
    r"llama_drop_only_(?P<month>adzuna_month\d{2})_(?P<start>\d+)_(?P<stop>\d+)_job(?P<jobid>\d+)_task(?P<taskid>\d+)_\d{8}_\d{6}\.jsonl$"
)

IT_PATTERNS = [
    r"\bsoftware\b", r"\bdeveloper\b", r"\bengineer\b", r"\bdata\b", r"\bml\b", r"\bai\b",
    r"\bcloud\b", r"\bcyber\b", r"\bsecurity\b", r"\bnetwork\b", r"\bsystems?\b",
    r"\bdatabase\b", r"\bit\b", r"\bdevops\b"
]
_IT_RE = re.compile("|".join(IT_PATTERNS), flags=re.I)

def _is_it_role(title: str) -> bool:
    if not title:
        return False
    return bool(_IT_RE.search(title))


def _infer_npz_from_jsonl(jsonl_path: Path) -> Path:
    """
    NEW layout:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>/llama_drop_only_....jsonl
    NPZ sits at:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>.npz
    """
    m = _RUN_RE.search(jsonl_path.name)
    if not m:
        raise ValueError(f"JSONL filename doesn't match expected pattern: {jsonl_path.name}")

    month = m.group("month")
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    return embed_root / f"{month}.npz"


def _get_job_ids(z) -> np.ndarray:
    """
    Supports both schemas:
      new: job_ids
      old: job_id
    Returns np.ndarray[str]
    """
    if "job_ids" in z.files:
        return z["job_ids"].astype(str)
    if "job_id" in z.files:
        return z["job_id"].astype(str)
    raise KeyError(f"NPZ missing job id key. Need job_ids or job_id. Have={sorted(z.files)}")


def _load_npz_lookup(npz_path: Path):
    """
    Expects stage3-prep NPZ keys (canonical):
      job_ids (or job_id), job_ad_title, job_desc, job_tasks, domain, job_sector_category, job_description
    """
    with np.load(npz_path, allow_pickle=True) as z:
        job_ids = _get_job_ids(z)

        # canonical (your stage3-prep)
        job_ad_title = z["job_ad_title"]
        job_desc = z["job_desc"]
        job_tasks = z["job_tasks"]

        domain = z["domain"] if "domain" in z.files else None
        job_sector_category = z["job_sector_category"] if "job_sector_category" in z.files else None
        job_description = z["job_description"] if "job_description" in z.files else None

    lookup = {}
    for i, jid in enumerate(job_ids):
        lookup[jid] = {
            "job_ad_title": None if job_ad_title[i] is None else str(job_ad_title[i]),
            "job_desc": None if job_desc[i] is None else str(job_desc[i]),
            "job_tasks": None if job_tasks[i] is None else str(job_tasks[i]),
            "job_description": None if job_description is None or job_description[i] is None else str(job_description[i]),
            "domain": None if domain is None or domain[i] is None else str(domain[i]),
            "job_sector_category": None if job_sector_category is None or job_sector_category[i] is None else str(job_sector_category[i]),
        }
    return lookup


# ---------------------------------------------------------------------
# Main: report generator
# ---------------------------------------------------------------------
def gen_report(jsonl_path: str, *, npz_path: str | None = None, sample_n: int = 30, seed: int = 0):
    """
    jsonl_path: path to llama_drop_only_*.jsonl
    npz_path  : optional explicit context NPZ. If None, inferred from jsonl name/dir.
    """
    random.seed(seed)

    jsonl_path = Path(jsonl_path)
    if not jsonl_path.exists():
        raise FileNotFoundError(f"Missing JSONL: {jsonl_path}")

    inferred_npz = _infer_npz_from_jsonl(jsonl_path)
    npz_path = Path(npz_path) if npz_path else inferred_npz
    if not npz_path.exists():
        raise FileNotFoundError(f"Missing NPZ: {npz_path}")

    # report folder: put it under .../llm_negative_selection/<EMBED>/evaluation_reports/
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    report_dir = embed_root / "evaluation_reports"
    report_dir.mkdir(parents=True, exist_ok=True)

    print("JSONL:", jsonl_path)
    print("NPZ :", npz_path)
    print("OUT :", report_dir)

    lookup = _load_npz_lookup(npz_path)

    before_counts = []
    after_counts = []
    kept_titles = Counter()
    domain_kept = defaultdict(list)

    it_leak = 0
    total_kept = 0
    empty_outputs = 0

    samples = []
    seen_sample_ids = set()

    with jsonl_path.open("r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            try:
                r = json.loads(line)
            except Exception:
                continue

            jid = str(r.get("job_id", "")).strip()
            if not jid:
                continue

            ctx = lookup.get(jid, {})

            cand = r.get("candidates") or []
            final = r.get("final") or []

            before_counts.append(len(cand))
            after_counts.append(len(final))

            if len(final) == 0:
                empty_outputs += 1

            for t in final:
                kept_titles[t] += 1
                total_kept += 1
                if _is_it_role(t):
                    it_leak += 1

            dom = ctx.get("domain") or "UNKNOWN"
            domain_kept[dom].append(len(final))

            # sample gate
            if len(samples) < sample_n and jid not in seen_sample_ids and random.random() < 0.05:
                seen_sample_ids.add(jid)
                samples.append({
                    "job_id": jid,
                    "job_ad_title": ctx.get("job_ad_title"),
                    "domain": ctx.get("domain"),
                    "sector": ctx.get("job_sector_category"),
                    "job_desc": ctx.get("job_desc"),
                    "kept": final,
                    "dropped": r.get("drop") or [],
                })

    if not before_counts:
        raise RuntimeError("No valid rows parsed from JSONL.")

    before_avg = statistics.mean(before_counts)
    after_avg = statistics.mean(after_counts)
    drop_rate = 1.0 - (after_avg / before_avg if before_avg else 0.0)
    it_share = it_leak / max(total_kept, 1)

    metrics = {
        "jobs": len(before_counts),
        "avg_candidates_before": round(before_avg, 3),
        "avg_candidates_after": round(after_avg, 3),
        "drop_rate": round(drop_rate, 4),
        "empty_outputs_percent": round(100.0 * empty_outputs / len(before_counts), 3),
        "it_leakage_share": round(it_share, 4),
        "min_kept": int(min(after_counts)),
        "max_kept": int(max(after_counts)),
    }

    domain_summary = {d: round(statistics.mean(v), 3) for d, v in domain_kept.items()}

    report = {
        "run": {
            "jsonl": str(jsonl_path),
            "npz": str(npz_path),
            "generated_at": datetime.now().isoformat(timespec="seconds"),
        },
        "global_metrics": metrics,
        "top_kept_roles": kept_titles.most_common(25),
        "domain_summary_avg_kept": dict(sorted(domain_summary.items(), key=lambda x: (-x[1], x[0]))),
        "sample_cases": samples,
    }

    base = jsonl_path.stem
    report_json = report_dir / f"{base}_report.json"
    report_txt = report_dir / f"{base}_report.txt"

    with report_json.open("w", encoding="utf-8") as f:
        json.dump(report, f, indent=2, ensure_ascii=False)

    with report_txt.open("w", encoding="utf-8") as f:
        f.write("=== GLOBAL METRICS ===\n")
        for k, v in metrics.items():
            f.write(f"{k}: {v}\n")

        f.write("\n=== TOP KEPT OCCUPATIONS ===\n")
        for title, cnt in kept_titles.most_common(25):
            f.write(f"{cnt}  {title}\n")

        f.write("\n=== DOMAIN AVG KEPT ===\n")
        for d, v in sorted(domain_summary.items(), key=lambda x: (-x[1], x[0])):
            f.write(f"{d}: {v}\n")

        f.write("\n=== SAMPLE CASES (truncated) ===\n")
        for s in samples[:10]:
            f.write(f"\njob_id: {s['job_id']}\n")
            f.write(f"title:  {s.get('job_ad_title')}\n")
            f.write(f"domain: {s.get('domain')} | sector: {s.get('sector')}\n")
            f.write(f"kept:   {s.get('kept')}\n")
            f.write(f"drop:   {s.get('dropped')}\n")

    print("\nSaved:")
    print(" ", report_json)
    print(" ", report_txt)

    return report_json, report_txt

# %% [markdown]
# def build_prompt(
#     job_desc: str,
#     tasks_str: str,
#     clean_titles: list[str],
#     domain: str,
#     job_ad_title: str,
#     job_sector_category: str,
#     full_ad_text: str,
# ) -> str:
#     n_candidates = len(clean_titles)
#     numbered = "\n".join(f"{i+1}. {t}" for i, t in enumerate(clean_titles))
#
#     full_excerpt = full_ad_text.strip()[:700] if full_ad_text else ""
#     full_block = f"\nFULL AD EXCERPT (use for concrete tools/duties only):\n{full_excerpt}\n" if full_excerpt else ""
#
#     return f"""
# TASK
# You are a Senior Labor Market Economist auditing SOC matches. Evaluate candidates and DROP those that are NOT functional matches for the job.
#
# GOAL: THE 2.5 TARGET
# There are {n_candidates} candidates.
# - Most modern roles are HYBRID. Your goal is to keep 2 to 3 candidates for every job.
# - Only keep 1 candidate if you are really sure all others are wrong.
# - If more than 3 are valid, drop the most generic ones to fit the 3-candidate cap.
#
# JOB CONTEXT (SOURCE OF TRUTH)
# Title: {job_ad_title}
# Sector/Domain: {job_sector_category} | {domain}
# Functional Tasks: {tasks_str}
# {full_block}
#
# CANDIDATES (1-based)
# {numbered}
#
# ANCHOR PROTECTION (FUNCTION FIRST)
# 1) The ANCHOR is the candidate whose FUNCTION best matches the title’s role type (not seniority, not niche specialism).
# 2) You MUST KEEP the ANCHOR unless CORE EVIDENCE explicitly contradicts it.
# 3) TITLE KEYWORD LOCK: If the job title contains a functional keyword (e.g. driver, nurse, electrician, developer, sommelier), and a candidate directly matching that function exists, you MUST keep it.
#
# KEEPING LOGIC (HYBRID RECALL)
# - Keep a secondary candidate if it is in the same functional family (e.g. sommelier <-> waiter; care worker <-> home health aide).
# - Keep a secondary candidate if it represents a different level of the same family (e.g. engineer <-> technologist).
# - Keep a secondary candidate if the tasks describe duties unique to that occupation.
#
# HIERARCHY & IT GATES
# 1) MANAGER RULE: If the title does NOT include Manager/Lead/Director, only keep a managerial candidate if tasks explicitly describe staff oversight, rotas, or budgeting.
# 2) IT DOMAIN LOCK: If the title is explicitly IT, do NOT drop the IT anchor regardless of domain. For non-IT domains, only keep tech roles if tasks mention specific tools (Python, SQL, APIs, etc).
#
# RE-ANCHOR
# Title: {job_ad_title}
# Count: {n_candidates} candidates.
# Keep 2-3. Only keep 1 if you are really sure all others are wrong. Use the above rules.
#
# OUTPUT
# Return ONLY a valid JSON object with exactly one key: "drop".
# Schema:
# {{"drop":[...]}}
# """.strip()

# %%
# -*- coding: utf-8 -*-
from pathlib import Path
import numpy as np

# ---- CONFIG ----
NPZ_PATH = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz")
ROW_IDX = 35  # row to inspect

# ---- LOAD ----
data = np.load(NPZ_PATH, allow_pickle=True)

job_ad_title = str(data["job_ad_title"][ROW_IDX])
domain = str(data["domain"][ROW_IDX])
job_sector_category = str(data["job_sector_category"][ROW_IDX])

job_tasks_raw = data["job_tasks"][ROW_IDX]
job_desc = str(data["job_desc"][ROW_IDX]) if "job_desc" in data.files else ""
job_full_ads = data["job_description"][ROW_IDX] if "job_description" in data.files else ""

titles_raw = data["titles"][ROW_IDX]

# ---- CLEAN TITLES (1-based indexing must match prompt) ----
titles_raw = list(titles_raw) if titles_raw is not None else []
clean_titles = [str(t).strip() for t in titles_raw if t and str(t).strip()]
numbered = "\n".join(f"{i+1}. {t}" for i, t in enumerate(clean_titles))

# ---- CLEAN TASKS ----
if isinstance(job_tasks_raw, (list, np.ndarray)):
    tasks_str = ", ".join([str(t).strip() for t in job_tasks_raw if t and str(t).strip()])
else:
    tasks_str = str(job_tasks_raw).strip()

# ---- FULL AD EXCERPT ----
full_text = str(job_full_ads) if job_full_ads is not None else ""
full_excerpt = full_text.strip()[:700] if full_text else ""
full_block = (
    f"\nFULL AD EXCERPT (use for concrete tools/duties only):\n{full_excerpt}\n"
    if full_excerpt else ""
)

# ---- BUILD PROMPT ----
prompt = f"""
TASK
You are a Senior Labor Market Economist auditing SOC matches. Evaluate candidates and DROP those that are NOT functional matches for the job.

GOAL: THE N-BASED DROP RULE
There are {n_candidates} candidates. To keep between 1 and 3 candidates:
- You MUST drop at least {max(0, n_candidates - 3)} candidates.
- If more than 3 are valid, drop the most generic ones to fit the limit.

KEEP FLOOR (RAISE RECALL)
- If at least 2 candidates are plausibly correct, KEEP 2.
- Keep only 1 candidate ONLY when all others are clearly incorrect.
- Aim for 2-3 matches for hybrid roles, provided they pass the HARD family tests below.

JOB CONTEXT (SOURCE OF TRUTH)
Title: {job_ad_title}
Sector/Domain: {job_sector_category} | {domain}
Functional Tasks: {tasks_str}
{full_block}

CANDIDATES (1-based)
{numbered}

ANCHOR PROTECTION (FUNCTION FIRST)
1) The ANCHOR is the candidate whose FUNCTION best matches the title’s role type (not seniority, not niche specialism).
2) You MUST KEEP the ANCHOR unless CORE EVIDENCE explicitly contradicts it.
3) TITLE KEYWORD LOCK (HARD): If the job title contains a clear functional keyword (e.g. driver, nurse, electrician, installer, developer, android, ios, sommelier), and a candidate directly matching that function exists, you MUST keep that candidate and MUST NOT replace it with managers, engineers, or specialists.
4) Do NOT replace a general functional match with a niche specialty (e.g. robotics engineer, nanosystems) unless tasks explicitly describe it.

SECONDARY KEEP (CONDITIONAL)
After selecting the ANCHOR, a secondary candidate may be kept ONLY if it is in the same functional family as the ANCHOR (e.g. sommelier <-> waiter; care worker <-> home health aide) OR CORE EVIDENCE explicitly mentions duties unique to that occupation. Otherwise, DROP it.

HIERARCHY & IT GATES
1) HARD MANAGER RULE
   - If the title does NOT include Manager, Lead, Head, Director, Supervisor, Team Leader, or Foreman AND CORE EVIDENCE does NOT explicitly describe people management or budgets (supervise, rota, training, audits, performance), you MUST DROP ALL managerial candidates.
   - If explicit oversight evidence exists, you MAY keep ONE manager candidate as a secondary keep.

2) IT DOMAIN LOCK
   - If the title is explicitly IT (developer, software engineer, programmer, frontend/backend, android/ios), DO NOT drop the IT anchor regardless of domain.
   - Otherwise, if Sector/Domain is NOT IT-related, DROP "Software Developer" / "IT Project Manager" UNLESS CORE EVIDENCE mentions building/coding AND at least TWO technical terms (Python/Java/SQL/APIs/Git/React/etc).
   - Simple tool usage (Excel, SAP) is NOT IT work.

3) CRAFT PREFERENCE (TIE-BREAK ONLY)
   - Apply ONLY if the title is ambiguous.
   - If the title explicitly says "Engineer", do NOT drop the Engineer candidate unless tasks clearly contradict it.

PRUNING RULES
1) Specificity: Keep specialists alongside generic parents if both match the tasks, within the 3 cap.
2) If more than 3 are valid, drop the most generic/vague ones first (broad managers, broad admins, broad "helpers").

ORDER OF OPERATIONS (TIE-BREAKERS)
1. ANCHOR PROTECTION & TITLE LOCK: Highest priority. A clear title keyword overrides all gates.
2. HARD MANAGER RULE: Second priority. Stop seniority drift immediately.
3. DOMAIN GATES: Final noise filter.

RE-ANCHOR (Final Check)
Title: {job_ad_title}
Primary Tasks: {tasks_str}
Count: {n_candidates} candidates. Keep 1-3. Prefer 2 when plausible.

OUTPUT
Return ONLY a valid JSON object with exactly one key: "drop". No explanation.
Schema:
{{"drop":[...]}}
""".strip()

# ---- PRINT ----
print("-" * 80)
print(f"VERIFIED PRODUCTION PROMPT (ROW {ROW_IDX})")
print(f"NPZ: {NPZ_PATH}")
print(f"Candidates: {len(clean_titles)}")
print("-" * 80)
print(prompt)
print("-" * 80)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 47
#      36 full_block = (
#      37     f"\nFULL AD EXCERPT (use for concrete tools/duties only):\n{full_excerpt}\n"
#      38     if full_excerpt else ""
#      39 )
#      41 # ---- BUILD PROMPT ----
#      42 prompt = f"""
#      43 TASK
#      44 You are a Senior Labor Market Economist auditing SOC matches. Evaluate candidates and DROP those that are NOT functional matches for the job.
#      45
#      46 GOAL: THE N-BASED DROP RULE
# ---> 47 There are {n_candidates} candidates. To keep between 1 and 3 candidates:
#      48 - You MUST drop at least {max(0, n_candidates - 3)} candidates.
#      49 - If more than 3 are valid, drop the most generic ones to fit the limit.
#      50
#      51 KEEP FLOOR (RAISE RECALL)
#      52 - If at least 2 candidates are plausibly correct, KEEP 2.
#      53 - Keep only 1 candidate ONLY when all others are clearly incorrect.
#      54 - Aim for 2-3 matches for hybrid roles, provided they pass the HARD family tests below.
#      55
#      56 JOB CONTEXT (SOURCE OF TRUTH)
#      57 Title: {job_ad_title}
#      58 Sector/Domain: {job_sector_category} | {domain}
#      59 Functional Tasks: {tasks_str}
#      60 {full_block}
#      61
#      62 CANDIDATES (1-based)
#      63 {numbered}
#      64
#      65 ANCHOR PROTECTION (FUNCTION FIRST)
#      66 1) The ANCHOR is the candidate whose FUNCTION best matches the title’s role type (not seniority, not niche specialism).
#      67 2) You MUST KEEP the ANCHOR unless CORE EVIDENCE explicitly contradicts it.
#      68 3) TITLE KEYWORD LOCK (HARD): If the job title contains a clear functional keyword (e.g. driver, nurse, electrician, installer, developer, android, ios, sommelier), and a candidate directly matching that function exists, you MUST keep that candidate and MUST NOT replace it with managers, engineers, or specialists.
#      69 4) Do NOT replace a general functional match with a niche specialty (e.g. robotics engineer, nanosystems) unless tasks explicitly describe it.
#      70
#      71 SECONDARY KEEP (CONDITIONAL)
#      72 After selecting the ANCHOR, a secondary candidate may be kept ONLY if it is in the same functional family as the ANCHOR (e.g. sommelier <-> waiter; care worker <-> home health aide) OR CORE EVIDENCE explicitly mentions duties unique to that occupation. Otherwise, DROP it.
#      73
#      74 HIERARCHY & IT GATES
#      75 1) HARD MANAGER RULE
#      76    - If the title does NOT include Manager, Lead, Head, Director, Supervisor, Team Leader, or Foreman AND CORE EVIDENCE does NOT explicitly describe people management or budgets (supervise, rota, training, audits, performance), you MUST DROP ALL managerial candidates.
#      77    - If explicit oversight evidence exists, you MAY keep ONE manager candidate as a secondary keep.
#      78
#      79 2) IT DOMAIN LOCK
#      80    - If the title is explicitly IT (developer, software engineer, programmer, frontend/backend, android/ios), DO NOT drop the IT anchor regardless of domain.
#      81    - Otherwise, if Sector/Domain is NOT IT-related, DROP "Software Developer" / "IT Project Manager" UNLESS CORE EVIDENCE mentions building/coding AND at least TWO technical terms (Python/Java/SQL/APIs/Git/React/etc).
#      82    - Simple tool usage (Excel, SAP) is NOT IT work.
#      83
#      84 3) CRAFT PREFERENCE (TIE-BREAK ONLY)
#      85    - Apply ONLY if the title is ambiguous.
#      86    - If the title explicitly says "Engineer", do NOT drop the Engineer candidate unless tasks clearly contradict it.
#      87
#      88 PRUNING RULES
#      89 1) Specificity: Keep specialists alongside generic parents if both match the tasks, within the 3 cap.
#      90 2) If more than 3 are valid, drop the most generic/vague ones first (broad managers, broad admins, broad "helpers").
#      91
#      92 ORDER OF OPERATIONS (TIE-BREAKERS)
#      93 1. ANCHOR PROTECTION & TITLE LOCK: Highest priority. A clear title keyword overrides all gates.
#      94 2. HARD MANAGER RULE: Second priority. Stop seniority drift immediately.
#      95 3. DOMAIN GATES: Final noise filter.
#      96
#      97 RE-ANCHOR (Final Check)
#      98 Title: {job_ad_title}
#      99 Primary Tasks: {tasks_str}
#     100 Count: {n_candidates} candidates. Keep 1-3. Prefer 2 when plausible.
#     101
#     102 OUTPUT
#     103 Return ONLY a valid JSON object with exactly one key: "drop". No explanation.
#     104 Schema:
#     105 {{"drop":[...]}}
#     106 """.strip()
#     108 # ---- PRINT ----
#     109 print("-" * 80)
#
# NameError: name 'n_candidates' is not defined

# %% [markdown]
# ## bge

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_bge.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
bge_jobid = jobid
# Out:
# JOBID: 2187283

# %% [markdown]
# ## e5

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_e5.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
e5_jobid = jobid
# Out:
# JOBID: 2187284

# %% [markdown]
# ## gte

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_gte.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
gte_jobid = jobid
# Out:
# JOBID: 2187285

# %%
# monitoring

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2187285 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       3:19    5:56:41     1 nid011261
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2187285 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       3:24    5:56:36     1 nid011261
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2187285 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       3:29    5:56:31     1 nid011261
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2187285 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       3:34    5:56:26     1 nid011261
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2187285 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       3:39    5:56:21     1 nid011261
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2187285 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       3:44    5:56:16     1 nid011261
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2187285 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       3:49    5:56:11     1 nid011261
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# ...
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 19:54 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 20:02:03
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.68 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:00<00:00,  3.98it/s]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:00<00:00,  4.19it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.99it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:45<05:15, 45.05s/it]
# Batches:  25%|██▌       | 2/8 [01:04<03:01, 30.20s/it]
# Batches:  38%|███▊      | 3/8 [01:42<02:46, 33.37s/it]
# Batches:  50%|█████     | 4/8 [01:59<01:48, 27.24s/it]
# Batches:  62%|██████▎   | 5/8 [02:16<01:10, 23.47s/it]
# Batches:  75%|███████▌  | 6/8 [02:38<00:45, 22.78s/it]
# Batches:  88%|████████▊ | 7/8 [02:55<00:21, 21.08s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.82s/it]
# Batches: 100%|██████████| 8/8 [03:37<00:00, 27.24s/it]
# [W206 20:05:44.157682079 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 26
#      23 if not sq:
#      24     break
# ---> 26 time.sleep(5)
#
# KeyboardInterrupt:

# %%
import time, subprocess
from pathlib import Path

for jobid in [bge_jobid, e5_jobid, gte_jobid]:
    LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
    
    DONE_TAG = "DONE] wrote:"
    
    def sh(cmd: str) -> str:
        return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout
    
    def tail(path: Path, n: int = 80) -> str:
        return sh(f"tail -n {n} {path}")
    
    def latest_log(jobid: int, suffix: str) -> Path | None:
        logs = sorted(LOG_DIR.glob(f"*{jobid}*{suffix}"))
        return logs[-1] if logs else None
    
    seen = set()
    
    import time
    
    done_path = None
    
    while True:
        out_log = latest_log(jobid, ".out")
    
        if out_log and out_log.exists():
            chunk = tail(out_log, 120)
            for line in chunk.splitlines():
                if DONE_TAG in line:
                    done_path = line.split(DONE_TAG, 1)[1].strip()
                    print(f"[DONE] {done_path}")
                    break
    
            if done_path:
                break
    
        time.sleep(5)
    
    
    done_path
    print('**'*50)
# Out:
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213.jsonl
# ****************************************************************************************************
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213.jsonl
# ****************************************************************************************************
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
# ****************************************************************************************************

# %%
import os
import json
from pathlib import Path

# Base directory for your production runs
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# Models to check
MODELS = ["bge_large", "e5_large", "gte_large"]

def print_most_recent_outputs():
    print(f"{'MODEL':<10} | {'LATEST FILENAME'}")
    print("-" * 60)
    
    for model_dir_name in MODELS:
        # Construct path to the month folder
        target_path = BASE_DIR / model_dir_name / "adzuna_month01"
        
        if not target_path.exists():
            print(f"{model_dir_name:<10} | Path not found: {target_path}")
            continue
            
        # Get all jsonl files in the directory
        files = list(target_path.glob("*.jsonl"))
        
        if not files:
            print(f"{model_dir_name:<10} | No .jsonl files found.")
            continue
            
        # Find the most recent file based on modification time (mtime)
        latest_file = max(files, key=os.path.getmtime)
        
        print(f"{model_dir_name:<10} | {latest_file.name}")
        
        # Optional: Print the last 2 records from this specific latest file
        try:
            with open(latest_file, 'r', encoding='utf-8') as f:
                lines = f.readlines()
                if lines:
                    last_record = json.loads(lines[-1])
                    print(f"   -> Last Job ID: {last_record.get('job_id')}")
                    print(f"   -> Kept: {last_record.get('final')}")
        except Exception as e:
            print(f"   -> Error reading file: {e}")
        print("-" * 60)

if __name__ == "__main__":
    print_most_recent_outputs()
# Out:
# MODEL      | LATEST FILENAME
# ------------------------------------------------------------
# bge_large  | llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213.jsonl
#    -> Last Job ID: 2767917838
#    -> Kept: ['First-Line Supervisors of Retail Sales Workers', 'Logisticians', 'First-Line Supervisors of Non-Retail Sales Workers']
# ------------------------------------------------------------
# e5_large   | llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213.jsonl
#    -> Last Job ID: 2767917838
#    -> Kept: ['Stockers and Order Fillers', 'Transportation, Storage, and Distribution Managers', 'Sales Managers']
# ------------------------------------------------------------
# gte_large  | llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
#    -> Last Job ID: 2767917838
#    -> Kept: ['Stockers and Order Fillers', 'First-Line Supervisors of Non-Retail Sales Workers', 'Transportation, Storage, and Distribution Managers']
# ------------------------------------------------------------

# %% [markdown]
# ## Results comparison

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn3
from pathlib import Path

# ---- CONFIG ----
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# 1. Define once (Update these only)
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl"
}

# 2. Run reports automatically for each
for model_name, file_path in PATHS.items():
    print(f"\n--- {model_name} ---")
    if file_path.exists():
        gen_report(str(file_path))
    else:
        print(f"Error: File for {model_name} not found at {file_path}")
def load_data(filepath):
    data = {}
    if not filepath.exists(): return data
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            data[obj['job_id']] = set(obj['final'])
    return data

# 1. Load and Intersect
results = {name: load_data(path) for name, path in PATHS.items()}
loaded = [n for n, d in results.items() if d]
common_ids = set.intersection(*[set(results[m].keys()) for m in loaded])

# 2. Extract Commonalities and Differences
report_data = []
for jid in common_ids:
    bge_set = results["BGE"].get(jid, set())
    e5_set = results["E5"].get(jid, set())
    gte_set = results["GTE"].get(jid, set())
    
    # Are they identical?
    all_agree = (bge_set == e5_set == gte_set)
    
    # Who is the outlier?
    outlier = "None"
    if bge_set == e5_set != gte_set: outlier = "GTE"
    elif bge_set == gte_set != e5_set: outlier = "E5"
    elif e5_set == gte_set != bge_set: outlier = "BGE"
    elif not all_agree: outlier = "All Diverged"

    report_data.append({
        "job_id": jid,
        "all_agree": all_agree,
        "outlier": outlier,
        "bge_count": len(bge_set),
        "e5_count": len(e5_set),
        "gte_count": len(gte_set),
        "consensus_count": len(bge_set & e5_set & gte_set)
    })

df = pd.DataFrame(report_data)

# 3. Print Statistical Summary
print("=== COMPREHENSIVE COMPARISON REPORT ===")
print(f"Total Common Jobs: {len(df)}")
print(f"Absolute Consensus: {df['all_agree'].sum()} ({df['all_agree'].mean():.1%})")
print("\n--- Outlier Frequency (Who disagrees with the majority?) ---")
print(df[df['outlier'] != "None"]['outlier'].value_counts())

# 4. Generate Visualizations
# Jaccard Heatmap
model_names = list(results.keys())
j_matrix = np.zeros((3, 3))
for i, m1 in enumerate(model_names):
    for j, m2 in enumerate(model_names):
        scores = [len(results[m1][jid] & results[m2][jid]) / len(results[m1][jid] | results[m2][jid]) 
                  for jid in common_ids]
        j_matrix[i, j] = np.mean(scores)

plt.figure(figsize=(8, 6))
sns.heatmap(j_matrix, annot=True, xticklabels=model_names, yticklabels=model_names, cmap="YlGnBu")
plt.title("Jaccard Similarity Matrix (Semantic Overlap)")
plt.savefig("semantic_overlap_heatmap.png")

# Venn Diagram
venn_sets = []
for name in model_names:
    s = set()
    for jid in common_ids:
        for occ in results[name][jid]:
            s.add(f"{jid}|{occ}")
    venn_sets.append(s)

plt.figure(figsize=(10, 8))
venn3(venn_sets, set_labels=model_names)
plt.title("Consensus Core vs. Model-Specific Hallucinations")
plt.savefig("assignment_venn.png")
# Out:
# --- BGE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213_report.txt
#
# --- E5 ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213_report.txt
#
# --- GTE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203_report.txt
# === COMPREHENSIVE COMPARISON REPORT ===
# Total Common Jobs: 1000
# Absolute Consensus: 30 (3.0%)
#
# --- Outlier Frequency (Who disagrees with the majority?) ---
# outlier
# All Diverged    804
# E5               57
# BGE              56
# GTE              53
# Name: count, dtype: int64

# %%
from pathlib import Path

# 1. Define your specific report files once
REPORTS = {
    "BGE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213_report.txt",
    "E5_LARGE":  "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213_report.txt",
    "GTE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203_report.txt"
}
# 1. Define once (Update these only)


# 2. Loop through and print with clear headers
for model_name, file_path in REPORTS.items():
    p = Path(file_path)
    
    # Visual Header for scannability
    print("\n" + "="*60)
    print(f"****** {model_name} ******")
    print("="*60)
    
    if p.exists():
        print(p.read_text())
    else:
        print(f"FILE NOT FOUND: {file_path}")
# Out:
# ============================================================
# ****** BGE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.221
# avg_candidates_after: 2.288
# drop_rate: 0.7217
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0699
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 47  Information Technology Project Managers
# 40  Personal Care Aides
# 32  Sales Managers
# 31  Financial Managers
# 30  Software Developers
# 29  Customer Service Representatives
# 27  Healthcare Social Workers
# 25  Marketing Managers
# 25  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 24  Administrative Services Managers
# 23  Computer Systems Engineers/Architects
# 21  Architectural and Engineering Managers
# 20  Mental Health and Substance Abuse Social Workers
# 20  Food Service Managers
# 19  Home Health Aides
# 19  Chefs and Head Cooks
# 19  Registered Nurses
# 18  First-Line Supervisors of Office and Administrative Support Workers
# 18  Market Research Analysts and Marketing Specialists
# 18  First-Line Supervisors of Retail Sales Workers
# 16  Nursing Assistants
# 16  Social and Human Service Assistants
# 16  Medical and Health Services Managers
# 16  Acute Care Nurses
# 16  Accountants and Auditors
#
# === DOMAIN AVG KEPT ===
# Administrative/Office: 3
# Advertising and Marketing: 3
# Aerospace & Manufacturing: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Customer Service: 3
# Cybersecurity: 3
# Data and Intelligence consultancy: 3
# Digital/Technology: 3
# Domestic Services: 3
# Education and Training: 3
# Education/Training: 3
# Electronics Technology: 3
# Energy and Utilities: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Farming/Agribusiness: 3
# Fashion: 3
# Finance/Banking: 3
# Food Industry: 3
# Food Service: 3
# Food Service/Hospitality: 3
# Food and Beverage: 3
# Government: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Social Care: 3
# Higher Education: 3
# IT and Consulting: 3
# IT and Technology: 3
# IT and Telecommunications: 3
# IT/Software Development: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Logistics/Transportation: 3
# Manufacturing/Engineering: 3
# Manufacturing/Production: 3
# Media: 3
# Military/Defence: 3
# Nuclear Engineering: 3
# Online Surveys/Admin Jobs: 3
# PR and Communications: 3
# Pharmaceutical: 3
# Property: 3
# Public Health: 3
# Publishing: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Research and Market Analysis: 3
# Retail Marketing: 3
# SaaS: 3
# Sales Jobs: 3
# Sales and Customer Service: 3
# Sales and Recruitment: 3
# Scientific & QA Jobs: 3
# Security: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Sports/Leisure: 3
# Telecommunications: 3
# Transportation/Logistics: 3
# Utilities: 3
# Waste Management: 3
# Recruitment: 2.833
# Admin Jobs: 2.8
# Domestic help & Cleaning Jobs: 2.75
# Administration: 2.667
# HR & Recruitment: 2.625
# Logistics: 2.615
# Customer Services: 2.583
# Social work: 2.567
# Agriculture: 2.5
# Beauty and Cosmetics: 2.5
# Construction/Engineering: 2.5
# Healthcare/Social Work: 2.5
# Law: 2.5
# Non-Profit/Charity: 2.5
# Public Relations: 2.5
# Software Engineering: 2.5
# Automotive: 2.462
# Retail: 2.444
# Healthcare & Nursing: 2.439
# Healthcare: 2.429
# Social Work: 2.429
# Software Development: 2.429
# Consultancy: 2.4
# Market Research: 2.4
# Logistics & Warehouse: 2.372
# Accounting & Finance: 2.339
# Health and Fitness: 2.333
# IT Jobs: 2.333
# Public Administration: 2.333
# Sales and Marketing: 2.286
# IT: 2.274
# Consulting: 2.25
# Marketing/PR: 2.25
# Education: 2.184
# Hospitality & Catering: 2.143
# Manufacturing: 2.132
# Construction: 2.125
# Financial Services: 2.125
# Sales: 2.107
# Engineering: 2.054
# Agriculture/Rural: 2
# Biotechnology: 2
# Construction and Maintenance: 2
# Construction and Property: 2
# Construction/Property Maintenance: 2
# Creative & Design: 2
# Digital Media: 2
# Domestic Help & Cleaning: 2
# Domestic help & Cleaning: 2
# Education Technology: 2
# Energy: 2
# Environmental Science: 2
# Facilities Management: 2
# Finance: 2
# Fintech: 2
# Health & Social Care: 2
# Healthcare/Hospitality: 2
# Home Accessories Manufacturing: 2
# Human Resources: 2
# IT, Fintech, Blockchain, AI: 2
# Logistics and Transportation: 2
# Marketing: 2
# Marketing and Public Relations: 2
# Media and Advertising: 2
# Media and Communications: 2
# Media and Entertainment: 2
# Non-Profit: 2
# Non-profit/Charity: 2
# Other/General Jobs: 2
# Real Estate: 2
# Real Estate/Property Management: 2
# Remote Work/Online Opportunities: 2
# Renewables: 2
# Sales and Events: 2
# Scientific & QA: 2
# Security and Customer Service: 2
# Social Housing: 2
# Social Services/Social Work: 2
# Technology/Software: 2
# Tourism/Hospitality: 2
# Trade and Construction: 2
# Translation and Interpreting: 2
# Utility: 2
# Legal: 1.889
# Technology: 1.833
# Trade & Construction: 1.833
# Transportation: 1.8
# Digital Marketing: 1.667
# Hospitality: 1.667
# Insurance: 1.667
# PR: 1.667
# Travel and Tourism: 1.5
# Administration/Office Support: 1
# Aerospace: 1
# Automotive Retail: 1
# Consultancy Jobs: 1
# Electrical Engineering: 1
# Energy Trading: 1
# Engineering/Manufacturing: 1
# Fashion Retail: 1
# Healthcare/Pharmaceutical: 1
# Leisure: 1
# Leisure and Fitness: 1
# Manufacturing and Engineering: 1
# Manufacturing/Industrial: 1
# Non-Profit/NGO: 1
# Public Sector/ Law Enforcement: 1
# Recruitment Consultancy: 1
# Recruitment/Consultancy: 1
# Retail/Food Industry: 1
# Sales and Business Development: 1
# Technology & Engineering: 1
# Transportation/Fleet Management: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Waiters and Waitresses', 'Food Service Managers']
# drop:   ['Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Chefs and Head Cooks', 'Bartenders']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer']
# drop:   ['Microsystems Engineers', 'Electrical and Electronics Drafters', 'Electrical and Electronic Engineering Technologists and Technicians', 'Electrical and Electronics Repairers, Commercial and Industrial Equipment', 'Manufacturing Engineers', 'Nanosystems Engineers', 'Electrical Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Power-Line Installers and Repairers']
# drop:   ['Solar Photovoltaic Installers', 'Helpers--Electricians', 'Solar Sales Representatives and Assessors', 'Solar Energy Installation Managers', 'Solar Thermal Installers and Technicians', 'Electrical and Electronics Repairers, Powerhouse, Substation, and Relay']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Human Resources Assistants, Except Payroll and Timekeeping']
# drop:   ['Telephone Operators', 'Loan Interviewers and Clerks', 'Telemarketers', 'Receptionists and Information Clerks', 'New Accounts Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers', 'Personal Care Aides', 'Social and Human Service Assistants']
# drop:   ['Mental Health and Substance Abuse Social Workers', 'Child, Family, and School Social Workers', 'Childcare Workers', 'Occupational Therapists']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Biochemists and Biophysicists', 'Bioengineers and Biomedical Engineers', 'Natural Sciences Managers']
# drop:   ['Biological Technicians', 'Chemical Technicians', 'Biofuels/Biodiesel Technology and Product Development Managers', 'Bioinformatics Technicians', 'Bioinformatics Scientists', 'Agricultural Technicians']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Robotics Engineers', 'Software Developers', 'Photonics Engineers']
# drop:   ['Automotive Engineers', 'Human Factors Engineers and Ergonomists', 'Telecommunications Engineering Specialists', 'Wind Energy Engineers', 'Talent Directors', 'Media Programming Directors', 'Web Developers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Heavy and Tractor-Trailer Truck Drivers']
# drop:   ['First-Line Supervisors of Material-Moving Machine and Vehicle Operators', 'Industrial Truck and Tractor Operators', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Crane and Tower Operators', 'Driver/Sales Workers', 'Light Truck Drivers', 'Bus Drivers, Transit and Intercity', 'Cargo and Freight Agents']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers']
# drop:   ['Social and Community Service Managers', 'Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers', 'Recreation Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Rehabilitation Counselors', 'Compensation and Benefits Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mobile Heavy Equipment Mechanics, Except Engines', 'Mechanical Engineering Technologists and Technicians', 'Bus and Truck Mechanics and Diesel Engine Specialists']
# drop:   ['Outdoor Power Equipment and Other Small Engine Mechanics', 'Medical Equipment Repairers', 'Aircraft Mechanics and Service Technicians', 'Locomotive Engineers', 'Mechanical Engineers', 'Aerospace Engineers', 'Civil Engineers']
#
#
# ============================================================
# ****** E5_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.599
# avg_candidates_after: 2.312
# drop_rate: 0.7311
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0644
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 42  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 42  Software Developers
# 41  Customer Service Representatives
# 35  Personal Care Aides
# 30  Sales Managers
# 29  Accountants and Auditors
# 29  Treasurers and Controllers
# 29  Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products
# 28  First-Line Supervisors of Material-Moving Machine and Vehicle Operators
# 27  Home Health Aides
# 26  Financial Managers
# 24  Information Technology Project Managers
# 21  Secretaries and Administrative Assistants, Except Legal, Medical, and Executive
# 20  Advertising and Promotions Managers
# 20  Healthcare Social Workers
# 20  Teaching Assistants, Special Education
# 19  First-Line Supervisors of Retail Sales Workers
# 19  Architectural and Engineering Managers
# 18  First-Line Supervisors of Non-Retail Sales Workers
# 18  Online Merchants
# 17  Transportation, Storage, and Distribution Managers
# 17  Clinical Nurse Specialists
# 17  First-Line Supervisors of Food Preparation and Serving Workers
# 17  Computer Systems Engineers/Architects
# 16  Web Developers
#
# === DOMAIN AVG KEPT ===
# Advertising and Marketing: 3
# Agriculture: 3
# Agriculture/Rural: 3
# Automotive Retail: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction and Maintenance: 3
# Construction/Engineering: 3
# Construction/Property Maintenance: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Digital/Technology: 3
# Domestic Services: 3
# Education Technology: 3
# Energy Trading: 3
# Energy and Utilities: 3
# Environmental Science: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Facilities Management: 3
# Finance/Banking: 3
# Food Industry: 3
# Food Service/Hospitality: 3
# Health & Social Care: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Higher Education: 3
# Home Accessories Manufacturing: 3
# IT, Fintech, Blockchain, AI: 3
# IT/Software Development: 3
# Leisure: 3
# Leisure and Fitness: 3
# Logistics and Supply Chain: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Marketing: 3
# Marketing and Public Relations: 3
# Marketing/PR: 3
# Media: 3
# Media and Advertising: 3
# Media and Communications: 3
# Non-Profit: 3
# Non-profit/Charity: 3
# Nuclear Engineering: 3
# Online Surveys/Admin Jobs: 3
# Other/General Jobs: 3
# PR: 3
# PR and Communications: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Renewables: 3
# Research and Market Analysis: 3
# Retail/Food Industry: 3
# SaaS: 3
# Sales Jobs: 3
# Sales and Customer Service: 3
# Sales and Events: 3
# Sales and Recruitment: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Social Housing: 3
# Social Services/Social Work: 3
# Sports/Leisure: 3
# Technology/Software: 3
# Telecommunications: 3
# Tourism/Hospitality: 3
# Transportation/Logistics: 3
# Waste Management: 3
# Social Work: 2.857
# Administration: 2.833
# Admin Jobs: 2.8
# Sales and Marketing: 2.714
# Creative & Design: 2.667
# Insurance: 2.667
# Public Administration: 2.667
# Financial Services: 2.625
# Transportation: 2.6
# Finance: 2.571
# Software Development: 2.571
# Administrative/Office: 2.5
# Construction and Property: 2.5
# Digital Media: 2.5
# HR & Recruitment: 2.5
# Healthcare/Social Care: 2.5
# Human Resources: 2.5
# Pharmaceutical: 2.5
# Retail: 2.5
# Security: 2.5
# Healthcare & Nursing: 2.415
# Accounting & Finance: 2.407
# Hospitality & Catering: 2.405
# Law: 2.4
# Market Research: 2.4
# Social work: 2.4
# Logistics: 2.385
# Healthcare: 2.367
# Customer Services: 2.333
# Energy: 2.333
# Health and Fitness: 2.333
# IT and Technology: 2.333
# Logistics and Transportation: 2.333
# Media and Entertainment: 2.333
# IT: 2.274
# Consulting: 2.25
# Domestic help & Cleaning: 2.25
# Manufacturing: 2.237
# Construction: 2.219
# Sales: 2.214
# Consultancy: 2.2
# Trade & Construction: 2.167
# Engineering: 2.162
# Education: 2.145
# Legal: 2.111
# Logistics & Warehouse: 2.023
# Administration/Office Support: 2
# Automotive: 2
# Biotechnology: 2
# Cybersecurity: 2
# Domestic help & Cleaning Jobs: 2
# Education/Training: 2
# Electronics Technology: 2
# Engineering/Manufacturing: 2
# Government: 2
# Health and Social Care: 2
# Healthcare/Social Work: 2
# Hospitality: 2
# Logistics & Transportation: 2
# Logistics/Transportation: 2
# Manufacturing/Production: 2
# Military/Defence: 2
# Non-Profit/NGO: 2
# Property: 2
# Publishing: 2
# Real Estate/Property Management: 2
# Recruitment: 2
# Recruitment/Consultancy: 2
# Scientific & QA Jobs: 2
# Security and Customer Service: 2
# Software Engineering: 2
# Technology & Engineering: 2
# Transportation/Fleet Management: 2
# Utility: 2
# Real Estate: 1.857
# Public Relations: 1.75
# Digital Marketing: 1.667
# IT Jobs: 1.667
# Scientific & QA: 1.667
# Technology: 1.667
# Beauty and Cosmetics: 1.5
# Customer Service: 1.5
# Fintech: 1.5
# Non-Profit/Charity: 1.5
# Travel and Tourism: 1.5
# Utilities: 1.5
# Aerospace: 1
# Aerospace & Manufacturing: 1
# Data and Intelligence consultancy: 1
# Domestic Help & Cleaning: 1
# Education and Training: 1
# Electrical Engineering: 1
# Farming/Agribusiness: 1
# Fashion: 1
# Fashion Retail: 1
# Food Service: 1
# Food and Beverage: 1
# Healthcare & Nursing Jobs: 1
# Healthcare/Hospitality: 1
# Healthcare/Pharmaceutical: 1
# IT and Consulting: 1
# IT and Telecommunications: 1
# Recruitment Consultancy: 1
# Remote Work/Online Opportunities: 1
# Retail Marketing: 1
# Sales and Business Development: 1
# Trade and Construction: 1
# Translation and Interpreting: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Waiters and Waitresses']
# drop:   ['Bartenders', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'First-Line Supervisors of Personal Service Workers', 'First-Line Supervisors of Food Preparation and Serving Workers']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Computer Hardware Engineers', 'Electrical Engineers']
# drop:   ['Electronics Engineers, Except Computer', 'Microsystems Engineers', 'Electrical and Electronic Engineering Technologists and Technicians', 'Model Makers, Metal and Plastic', 'Telecommunications Engineering Specialists']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Solar Energy Installation Managers']
# drop:   ['Electrical Power-Line Installers and Repairers', 'Helpers--Installation, Maintenance, and Repair Workers', 'Electrical and Electronic Engineering Technologists and Technicians', 'Solar Sales Representatives and Assessors', 'Shampooers', 'Tire Repairers and Changers', 'Tire Builders']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Secretaries and Administrative Assistants, Except Legal, Medical, and Executive', 'Telemarketers']
# drop:   ['Word Processors and Typists', 'Telephone Operators', 'Billing and Posting Clerks', 'Data Entry Keyers', 'Procurement Clerks', 'Receptionists and Information Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Personal Care Aides', 'Locker Room, Coatroom, and Dressing Room Attendants', 'Home Health Aides']
# drop:   ['Maids and Housekeeping Cleaners', 'Community Health Workers', 'Psychiatrists', 'Healthcare Social Workers', 'Psychiatric Technicians', 'Social and Human Service Assistants', 'Mental Health and Substance Abuse Social Workers']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Medical Scientists, Except Epidemiologists', 'Natural Sciences Managers', 'Physicians, Pathologists']
# drop:   ['Bioengineers and Biomedical Engineers', 'Chemists', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products', 'Agricultural Technicians', 'Bioinformatics Scientists', 'Materials Scientists', 'Molecular and Cellular Biologists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Software Developers', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products', 'Software Quality Assurance Analysts and Testers']
# drop:   ['Natural Sciences Managers', 'Grinding and Polishing Workers, Hand', 'Telecommunications Engineering Specialists', 'Dancers', 'Robotics Engineers', 'Tire Builders']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Heavy and Tractor-Trailer Truck Drivers', 'Industrial Truck and Tractor Operators']
# drop:   ['Crane and Tower Operators', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Loading and Moving Machine Operators, Underground Mining', 'Light Truck Drivers', 'First-Line Supervisors of Material-Moving Machine and Vehicle Operators', 'Driver/Sales Workers', 'Pile Driver Operators']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Social and Community Service Managers']
# drop:   ['Personal Care Aides', 'Recreation Workers', 'Home Health Aides', 'Healthcare Social Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Psychiatrists', 'Registered Nurses', 'Medical and Health Services Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Aircraft Mechanics and Service Technicians']
# drop:   ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Maintenance and Repair Workers, General', 'Outdoor Power Equipment and Other Small Engine Mechanics', 'Heating, Air Conditioning, and Refrigeration Mechanics and Installers', 'Electric Motor, Power Tool, and Related Repairers', 'Maintenance Workers, Machinery', 'Industrial Machinery Mechanics', 'Wind Energy Engineers', 'Mechanical Engineers']
#
#
# ============================================================
# ****** GTE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.229
# avg_candidates_after: 2.311
# drop_rate: 0.7192
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0922
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 36  Personal Care Aides
# 34  Information Technology Project Managers
# 33  Software Developers
# 31  Computer Systems Engineers/Architects
# 29  Healthcare Social Workers
# 28  Treasurers and Controllers
# 26  Mental Health and Substance Abuse Social Workers
# 26  Sales Managers
# 24  Nursing Assistants
# 22  Financial Managers
# 21  Customer Service Representatives
# 21  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 20  Accountants and Auditors
# 20  Cooks, Institution and Cafeteria
# 20  Computer Network Architects
# 19  Solar Sales Representatives and Assessors
# 19  Human Resources Specialists
# 19  Food Service Managers
# 19  Registered Nurses
# 18  Advertising and Promotions Managers
# 18  Human Resources Managers
# 17  Medical and Health Services Managers
# 16  Market Research Analysts and Marketing Specialists
# 16  Chefs and Head Cooks
# 16  Sales Engineers
#
# === DOMAIN AVG KEPT ===
# Advertising and Marketing: 3
# Agriculture/Rural: 3
# Beauty and Cosmetics: 3
# Construction and Infrastructure: 3
# Construction/Property Maintenance: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Cybersecurity: 3
# Domestic Services: 3
# Education and Training: 3
# Electronics Technology: 3
# Engineering/Manufacturing: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Farming/Agribusiness: 3
# Fashion: 3
# Food Industry: 3
# Government: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Social Care: 3
# Home Accessories Manufacturing: 3
# IT Jobs: 3
# IT and Consulting: 3
# Insurance: 3
# Leisure: 3
# Leisure and Fitness: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Manufacturing/Production: 3
# Marketing and Public Relations: 3
# Media: 3
# Media and Advertising: 3
# Military/Defence: 3
# Non-Profit: 3
# Non-Profit/NGO: 3
# Nuclear Engineering: 3
# Other/General Jobs: 3
# PR and Communications: 3
# Property: 3
# Public Health: 3
# Publishing: 3
# Recruitment/Consultancy: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Renewables: 3
# Research and Market Analysis: 3
# Retail/Food Industry: 3
# SaaS: 3
# Sales and Business Development: 3
# Sales and Events: 3
# Sales and Recruitment: 3
# Security and Customer Service: 3
# Security and Law Enforcement: 3
# Social Services/Social Work: 3
# Sports/Leisure: 3
# Trade and Construction: 3
# Transportation/Fleet Management: 3
# Transportation/Logistics: 3
# Utilities: 3
# Utility: 3
# Waste Management: 3
# Human Resources: 2.875
# Recruitment: 2.833
# Scientific & QA: 2.667
# Technology: 2.667
# Consultancy: 2.6
# Software Development: 2.571
# Legal: 2.556
# Retail: 2.528
# Administrative/Office: 2.5
# Agriculture: 2.5
# Construction and Property: 2.5
# Consulting: 2.5
# Energy and Utilities: 2.5
# Healthcare/Social Work: 2.5
# Hospitality & Catering: 2.5
# Scientific & QA Jobs: 2.5
# Security: 2.5
# Software Engineering: 2.5
# Healthcare: 2.469
# Social work: 2.467
# IT: 2.464
# Sales: 2.429
# Customer Services: 2.417
# Accounting & Finance: 2.39
# HR & Recruitment: 2.375
# Trade & Construction: 2.375
# IT and Technology: 2.333
# Marketing: 2.333
# Media and Entertainment: 2.333
# Public Administration: 2.333
# Engineering: 2.324
# Construction: 2.312
# Domestic help & Cleaning Jobs: 2.25
# Marketing/PR: 2.25
# Automotive: 2.231
# Healthcare & Nursing: 2.22
# Manufacturing: 2.211
# Admin Jobs: 2.2
# Facilities Management: 2.2
# Transportation: 2.2
# Social Work: 2.143
# Education: 2.132
# Logistics & Warehouse: 2.116
# Law: 2.1
# Logistics: 2.077
# Administration: 2
# Automotive Retail: 2
# Biotechnology: 2
# Biotechnology/Pharmaceutical: 2
# Construction and Engineering: 2
# Construction and Maintenance: 2
# Consultancy Jobs: 2
# Data and Intelligence consultancy: 2
# Digital Media: 2
# Digital/Technology: 2
# Domestic Help & Cleaning: 2
# Education Technology: 2
# Education/Training: 2
# Energy Trading: 2
# Finance: 2
# Fintech: 2
# Food Service: 2
# Food Service/Hospitality: 2
# Food and Beverage: 2
# Health and Fitness: 2
# Health and Social Care: 2
# Healthcare & Nursing Jobs: 2
# Healthcare/Hospitality: 2
# Hospitality: 2
# IT and Telecommunications: 2
# IT, Fintech, Blockchain, AI: 2
# Logistics/Transportation: 2
# Media and Communications: 2
# Non-profit/Charity: 2
# PR: 2
# Pharmaceutical: 2
# Public Relations: 2
# Public Sector/ Law Enforcement: 2
# Real Estate: 2
# Real Estate/Property Management: 2
# Recruitment Consultancy: 2
# Remote Work/Online Opportunities: 2
# Sales and Customer Service: 2
# Sales and Marketing: 2
# Security and Surveillance: 2
# Technology & Engineering: 2
# Telecommunications: 2
# Market Research: 1.8
# Financial Services: 1.75
# Energy: 1.667
# Logistics and Transportation: 1.667
# Domestic help & Cleaning: 1.5
# Logistics & Transportation: 1.5
# Creative & Design: 1.333
# Administration/Office Support: 1
# Aerospace: 1
# Aerospace & Manufacturing: 1
# Construction/Engineering: 1
# Customer Service: 1
# Digital Marketing: 1
# Electrical Engineering: 1
# Environmental Science: 1
# Fashion Retail: 1
# Finance/Banking: 1
# Health & Social Care: 1
# Healthcare/Pharmaceutical: 1
# Higher Education: 1
# IT/Software Development: 1
# Logistics and Supply Chain: 1
# Non-Profit/Charity: 1
# Online Surveys/Admin Jobs: 1
# Retail Marketing: 1
# Sales Jobs: 1
# Social Housing: 1
# Technology/Software: 1
# Tourism/Hospitality: 1
# Translation and Interpreting: 1
# Travel and Tourism: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Food Service Managers', 'Bartenders']
# drop:   ['Waiters and Waitresses', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Chefs and Head Cooks', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Cooks, Private Household', 'Baristas']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Electrical Engineers', 'Solar Energy Systems Engineers']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Electrical and Electronics Drafters', 'Manufacturing Engineers', 'Microsystems Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Engineers', 'Electrical and Electronic Engineering Technologists and Technicians']
# drop:   ['Solar Photovoltaic Installers', 'Electrical Power-Line Installers and Repairers', 'Solar Energy Installation Managers', 'Power Distributors and Dispatchers', 'Fuel Cell Engineers']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Human Resources Assistants, Except Payroll and Timekeeping', 'Human Resources Specialists']
# drop:   ['Loan Interviewers and Clerks', 'Word Processors and Typists', 'Receptionists and Information Clerks', 'New Accounts Clerks', 'Archivists']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Mental Health and Substance Abuse Social Workers', 'Healthcare Social Workers', 'Personal Care Aides']
# drop:   ['Community Health Workers', 'Nannies', 'Social and Human Service Assistants', 'Child, Family, and School Social Workers', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Bioengineers and Biomedical Engineers', 'Molecular and Cellular Biologists']
# drop:   ['Medical and Clinical Laboratory Technologists', 'Chemical Technicians', 'Quality Control Analysts', 'Validation Engineers', 'Bioinformatics Scientists', 'Chemists', 'Medical Dosimetrists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Software Developers', 'Computer and Information Research Scientists', 'Microsystems Engineers']
# drop:   ['Computer Systems Engineers/Architects', 'Computer Network Architects', 'Radio Frequency Identification Device Specialists', 'Telecommunications Engineering Specialists', 'Software Quality Assurance Analysts and Testers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Industrial Truck and Tractor Operators', 'Tank Car, Truck, and Ship Loaders', 'Heavy and Tractor-Trailer Truck Drivers']
# drop:   ['Crane and Tower Operators', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Transportation, Storage, and Distribution Managers', 'Logistics Analysts', 'Light Truck Drivers', 'Logistics Engineers', 'Locomotive Engineers']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers']
# drop:   ['Healthcare Social Workers', 'Personal Care Aides', 'Community Health Workers', 'Mental Health and Substance Abuse Social Workers', 'Regulatory Affairs Managers', 'Social and Community Service Managers', 'Food Service Managers', 'Human Resources Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mechanical Engineering Technologists and Technicians', 'Aircraft Mechanics and Service Technicians']
# drop:   ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Maintenance and Repair Workers, General', 'Mobile Heavy Equipment Mechanics, Except Engines', 'Bus and Truck Mechanics and Diesel Engine Specialists', 'Mechanical Engineers', 'Fuel Cell Engineers', 'Manufacturing Engineers']

# %%
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl"
}

notebook_name ='10_prompt'

# %%
import json
import sys
from pathlib import Path
import numpy as np
import pandas as pd



# 1. EXACT CONFIGURATION
PATHS = {
    "BGE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187283_task0_20260206_200213.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz",
    },
    "E5": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187284_task0_20260206_200213.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz",
    },
    "GTE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187285_task0_20260206_200203.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz",
    },
}

# 2. HELPER FUNCTIONS
def _to_str_array(x: np.ndarray) -> np.ndarray:
    if x.dtype == object:
        return np.array([v.decode("utf-8") if isinstance(v, (bytes, bytearray)) else str(v) for v in x])
    if np.issubdtype(x.dtype, np.bytes_):
        return np.array([v.decode("utf-8") for v in x])
    return x.astype(str)

def load_meta_from_npz(npz_path: str) -> pd.DataFrame:
    with np.load(npz_path, allow_pickle=True) as npz:
        job_id_key = "job_id" if "job_id" in npz.files else ("job_ids" if "job_ids" in npz.files else None)
        title_key = "job_ad_title" if "job_ad_title" in npz.files else ("title" if "title" in npz.files else None)
        domain_key = "domain" if "domain" in npz.files else None
        sector_key = "job_sector_category" if "job_sector_category" in npz.files else None

        meta = {
            "job_id": _to_str_array(npz[job_id_key]),
            "title": _to_str_array(npz[title_key]),
        }
        meta["domain"] = _to_str_array(npz[domain_key]) if domain_key else ""
        meta["sector"] = _to_str_array(npz[sector_key]) if sector_key else ""
    return pd.DataFrame(meta)

def load_results_from_jsonl(jsonl_path: str) -> pd.DataFrame:
    rows = []
    with open(jsonl_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            try: rows.append(json.loads(line))
            except: continue

    df = pd.DataFrame(rows)
    df["job_id"] = df["job_id"].astype(str)

    if "final" in df.columns: df = df.rename(columns={"final": "kept"})
    if "drop" in df.columns: df = df.rename(columns={"drop": "dropped"})
    
    if "kept" not in df.columns: df["kept"] = None
    if "dropped" not in df.columns: df["dropped"] = None

    def _list_to_csv(x):
        if isinstance(x, list): return ", ".join(map(str, x))
        return "" if x is None else str(x)

    df["kept"] = df["kept"].apply(_list_to_csv)
    df["dropped"] = df["dropped"].apply(_list_to_csv)
    return df[["job_id", "kept", "dropped"]]

# 3. CORE BUILDER
def build_audit_dataset(paths_by_model: dict, n_jobs_per_model: int = 100, seed: int = 42) -> pd.DataFrame:
    all_frames = []
    for model, p in paths_by_model.items():
        print(f"Lendo dados para {model}...")
        meta = load_meta_from_npz(p["npz"])
        res = load_results_from_jsonl(p["jsonl"])
        
        merged = res.merge(meta, on="job_id", how="inner")
        if merged.empty:
            print(f"!!! [AVISO] {model} resultou em merge vazio.")
            continue
            
        sample_size = min(n_jobs_per_model, len(merged))
        sampled = merged.sample(n=sample_size, random_state=seed).copy()
        sampled["model"] = model
        all_frames.append(sampled)

    out = pd.concat(all_frames, ignore_index=True)
    cols = ["job_id", "model", "title", "domain", "sector", "kept", "dropped"]
    for c in cols:
        if c not in out.columns: out[c] = ""
            
    return out[cols].sort_values(["model", "job_id"]).reset_index(drop=True)

# 4. EXECUTION
if __name__ == "__main__":
    # Dinamicamente tenta pegar o nome do arquivo/notebook
    try:
        # Se for um script .py
        prefix = Path(__file__).stem
    except NameError:
        # Fallback para Jupyter Notebook (ajuste manualmente se preferir)
        prefix = notebook_name

    # Gera o dataset
    audit_df = build_audit_dataset(PATHS, n_jobs_per_model=100, seed=42)
    
    # Define o nome do arquivo com o prefixo
    out_filename = f"{prefix}_sanity_check_300_jobs_FINAL.csv"
    out_path = Path(out_filename)
    
    # Salva o CSV
    audit_df.to_csv(out_path, index=False)
    
    print("-" * 30)
    print(f"[SUCESSO] Arquivo escrito: {out_path}")
    print(f"Total de linhas: {len(audit_df)}")
    print(f"Distribuição por modelo:\n{audit_df['model'].value_counts()}")
    print("-" * 30)
# Out:
# Lendo dados para BGE...
# Lendo dados para E5...
# Lendo dados para GTE...
# ------------------------------
# [SUCESSO] Arquivo escrito: 10_prompt_sanity_check_300_jobs_FINAL.csv
# Total de linhas: 300
# Distribuição por modelo:
# model
# BGE    100
# E5     100
# GTE    100
# Name: count, dtype: int64
# ------------------------------

# %%
import pandas as pd
import re
import ast

# =============================================================================
# Load
# =============================================================================
file_path = "10_prompt_sanity_check_300_jobs_FINAL.csv"
df = pd.read_csv(file_path)

# Normalise model names so pivot columns are predictable
df["model"] = df["model"].astype(str).str.strip().str.lower()

# =============================================================================
# Robust parser for `kept` (handles: "['a','b']" AND "a, b")
# =============================================================================
def parse_kept(x):
    if pd.isna(x):
        return []

    s = str(x).strip()

    # Case 1: Python list literal
    if s.startswith("[") and s.endswith("]"):
        try:
            out = ast.literal_eval(s)
            if isinstance(out, list):
                return [str(i).strip() for i in out if str(i).strip()]
        except Exception:
            pass

    # Case 2: plain comma-separated
    items = re.split(r",\s*(?=[A-Z0-9])", s)
    return [i.strip().strip("[]'\"") for i in items if i.strip()]

df["kept_list"] = df["kept"].apply(parse_kept)

# =============================================================================
# Pivot: one row per job, one column per model
# =============================================================================
pivot = df.pivot_table(
    index=["job_id", "title", "domain", "sector"],
    columns="model",
    values="kept_list",
    aggfunc="first"
).reset_index()

need_models = ['bge', 'e5', 'gte']
missing_cols = [c for c in need_models if c not in pivot.columns]
if missing_cols:
    raise ValueError(
        f"Missing model columns in pivot: {missing_cols}. "
        f"Available: {sorted([c for c in pivot.columns if c not in ['job_id','title','domain','sector']])}"
    )

pivot = pivot.dropna(subset=need_models)

# =============================================================================
# Helpers
# =============================================================================
def top1(lst):
    return lst[0] if isinstance(lst, list) and len(lst) else None

def jaccard(a, b):
    sa = set(a) if isinstance(a, list) else set()
    sb = set(b) if isinstance(b, list) else set()
    if not sa and not sb:
        return 1.0
    return len(sa & sb) / len(sa | sb)

# =============================================================================
# Divergence metrics
# =============================================================================
pivot["top1_bge"] = pivot["bge"].apply(top1)
pivot["top1_e5"]  = pivot["e5"].apply(top1)
pivot["top1_gte"] = pivot["gte"].apply(top1)

pivot["all_top1_same"] = (
    (pivot["top1_bge"] == pivot["top1_e5"]) &
    (pivot["top1_bge"] == pivot["top1_gte"])
)

pivot["jac_bge_e5"] = pivot.apply(lambda r: jaccard(r["bge"], r["e5"]), axis=1)
pivot["jac_bge_gte"] = pivot.apply(lambda r: jaccard(r["bge"], r["gte"]), axis=1)
pivot["jac_e5_gte"] = pivot.apply(lambda r: jaccard(r["e5"], r["gte"]), axis=1)

pivot["avg_jaccard"] = pivot[["jac_bge_e5", "jac_bge_gte", "jac_e5_gte"]].mean(axis=1)

# =============================================================================
# Most divergent jobs
# =============================================================================
divergent = pivot.sort_values(
    by=["avg_jaccard", "all_top1_same"],
    ascending=[True, True]
).head(20)

divergent[[
    "job_id",
    "title",
    "top1_bge",
    "top1_e5",
    "top1_gte",
    "avg_jaccard",
    "jac_bge_e5",
    "jac_bge_gte",
    "jac_e5_gte",
]]
# Out:
# model      job_id                                              title  \
# 0      2192398821                         Driving Instructor Trainee
# 16     2716366432                        Product Manager - Immediacy
# 29     2744113462            Information Governance Officer - Police
# 30     2746699682                Case Manager - Fully Remote Working
# 33     2751488551  Estimator / Contracts Manager- internal fit ou...
# 50     2790612570                                    Window Cleaners
# 57     2793920315                         Transactions Administrator
# 83     2832370799                       FITTERS MATE/JUNIOR ENGINEER
# 59     2794085129                                       Receptionist
# 60     2795409084      Temporary Administrator – Children’s Services
# 3      2523525298             Valuation Surveyor / Registered Valuer
# 18     2719570720                        Public Health Officer Roles
# 38     2761893938                    Business Improvement Specialist
# 55     2791854042                                       Gas Engineer
# 34     2751637709              Warehouse / Stores Despatch Assistant
# 26     2738958402                           Senior Investment Broker
# 51     2790614821                                       Gas Engineer
# 52     2790925260                           Progressed Social Worker
# 1      2335527037  Voluntary Tutor - Walton on the Naze, Essex, E...
# 20     2719871758                           ADMINISTRATION ASSISTANT
#
# model                                           top1_bge  \
# 0                                  Adult Basic Education
# 16                                    Marketing Managers
# 29                        Information Security Engineers
# 30                  Medical and Health Services Managers
# 33                                 Construction Managers
# 50                       Maids and Housekeeping Cleaners
# 57                  Private Detectives and Investigators
# 83              Structural Metal Fabricators and Fitters
# 59     First-Line Supervisors of Office and Administr...
# 60     First-Line Supervisors of Office and Administr...
# 3                                              Surveyors
# 18                          Health Education Specialists
# 38                                   Logistics Engineers
# 55                        Maintenance and Repair Workers
# 34                                              Weighers
# 26                           Personal Financial Advisors
# 51                                               Heating
# 52                             Rehabilitation Counselors
# 1                               Self-Enrichment Teachers
# 20                      Customer Service Representatives
#
# model                                            top1_e5  \
# 0                     Cleaners of Vehicles and Equipment
# 16                   Demonstrators and Product Promoters
# 29                        Regulatory Affairs Specialists
# 30                               Occupational Therapists
# 33                                       Cost Estimators
# 50                                 Janitors and Cleaners
# 57     Reservation and Transportation Ticket Agents a...
# 83                             Mechanical Door Repairers
# 59             Secretaries and Administrative Assistants
# 60                                   Telephone Operators
# 3                Appraisers and Assessors of Real Estate
# 18                                   Nurse Practitioners
# 38                               Manufacturing Engineers
# 55      Manufactured Building and Mobile Home Installers
# 34                                            Inspectors
# 26                                            Securities
# 51                                   Gas Plant Operators
# 52                             Healthcare Social Workers
# 1                Recreation and Fitness Studies Teachers
# 20                      Customer Service Representatives
#
# model                                           top1_gte  avg_jaccard  \
# 0                                            Bus Drivers     0.000000
# 16                   Commercial and Industrial Designers     0.000000
# 29                           Regulatory Affairs Managers     0.000000
# 30            Occupational Health and Safety Specialists     0.000000
# 33     First-Line Supervisors of Construction Trades ...     0.000000
# 50            Merchandise Displayers and Window Trimmers     0.000000
# 57             Secretaries and Administrative Assistants     0.000000
# 83                             Mechanical Door Repairers     0.047619
# 59            Occupational Health and Safety Specialists     0.066667
# 60                      Administrative Services Managers     0.066667
# 3                Appraisers and Assessors of Real Estate     0.083333
# 18                                       Epidemiologists     0.083333
# 38                                  Validation Engineers     0.083333
# 55                                  Mechanical Engineers     0.103175
# 34                           Medical Equipment Repairers     0.108734
# 26                                            Securities     0.111111
# 51                                               Heating     0.111111
# 52      Mental Health and Substance Abuse Social Workers     0.111111
# 1                               Self-Enrichment Teachers     0.114286
# 20                                 Correspondence Clerks     0.114286
#
# model  jac_bge_e5  jac_bge_gte  jac_e5_gte
# 0        0.000000     0.000000    0.000000
# 16       0.000000     0.000000    0.000000
# 29       0.000000     0.000000    0.000000
# 30       0.000000     0.000000    0.000000
# 33       0.000000     0.000000    0.000000
# 50       0.000000     0.000000    0.000000
# 57       0.000000     0.000000    0.000000
# 83       0.000000     0.000000    0.142857
# 59       0.000000     0.000000    0.200000
# 60       0.000000     0.200000    0.000000
# 3        0.000000     0.000000    0.250000
# 18       0.000000     0.250000    0.000000
# 38       0.000000     0.250000    0.000000
# 55       0.000000     0.142857    0.166667
# 34       0.235294     0.000000    0.090909
# 26       0.000000     0.000000    0.333333
# 51       0.000000     0.333333    0.000000
# 52       0.000000     0.000000    0.333333
# 1        0.000000     0.200000    0.142857
# 20       0.200000     0.142857    0.000000
