# %% [markdown]
# # Helpers

# %%
import json
import re
import random
import statistics
from pathlib import Path
from collections import Counter, defaultdict
from datetime import datetime

import numpy as np

# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------
_RUN_RE = re.compile(
    r"llama_drop_only_(?P<month>adzuna_month\d{2})_(?P<start>\d+)_(?P<stop>\d+)_job(?P<jobid>\d+)_task(?P<taskid>\d+)_\d{8}_\d{6}\.jsonl$"
)

IT_PATTERNS = [
    r"\bsoftware\b", r"\bdeveloper\b", r"\bengineer\b", r"\bdata\b", r"\bml\b", r"\bai\b",
    r"\bcloud\b", r"\bcyber\b", r"\bsecurity\b", r"\bnetwork\b", r"\bsystems?\b",
    r"\bdatabase\b", r"\bit\b", r"\bdevops\b"
]
_IT_RE = re.compile("|".join(IT_PATTERNS), flags=re.I)

def _is_it_role(title: str) -> bool:
    if not title:
        return False
    return bool(_IT_RE.search(title))


def _infer_npz_from_jsonl(jsonl_path: Path) -> Path:
    """
    NEW layout:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>/llama_drop_only_....jsonl
    NPZ sits at:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>.npz
    """
    m = _RUN_RE.search(jsonl_path.name)
    if not m:
        raise ValueError(f"JSONL filename doesn't match expected pattern: {jsonl_path.name}")

    month = m.group("month")
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    return embed_root / f"{month}.npz"


def _get_job_ids(z) -> np.ndarray:
    """
    Supports both schemas:
      new: job_ids
      old: job_id
    Returns np.ndarray[str]
    """
    if "job_ids" in z.files:
        return z["job_ids"].astype(str)
    if "job_id" in z.files:
        return z["job_id"].astype(str)
    raise KeyError(f"NPZ missing job id key. Need job_ids or job_id. Have={sorted(z.files)}")


def _load_npz_lookup(npz_path: Path):
    """
    Expects stage3-prep NPZ keys (canonical):
      job_ids (or job_id), job_ad_title, job_desc, job_tasks, domain, job_sector_category, job_description
    """
    with np.load(npz_path, allow_pickle=True) as z:
        job_ids = _get_job_ids(z)

        # canonical (your stage3-prep)
        job_ad_title = z["job_ad_title"]
        job_desc = z["job_desc"]
        job_tasks = z["job_tasks"]

        domain = z["domain"] if "domain" in z.files else None
        job_sector_category = z["job_sector_category"] if "job_sector_category" in z.files else None
        job_description = z["job_description"] if "job_description" in z.files else None

    lookup = {}
    for i, jid in enumerate(job_ids):
        lookup[jid] = {
            "job_ad_title": None if job_ad_title[i] is None else str(job_ad_title[i]),
            "job_desc": None if job_desc[i] is None else str(job_desc[i]),
            "job_tasks": None if job_tasks[i] is None else str(job_tasks[i]),
            "job_description": None if job_description is None or job_description[i] is None else str(job_description[i]),
            "domain": None if domain is None or domain[i] is None else str(domain[i]),
            "job_sector_category": None if job_sector_category is None or job_sector_category[i] is None else str(job_sector_category[i]),
        }
    return lookup


# ---------------------------------------------------------------------
# Main: report generator
# ---------------------------------------------------------------------
def gen_report(jsonl_path: str, *, npz_path: str | None = None, sample_n: int = 30, seed: int = 0):
    """
    jsonl_path: path to llama_drop_only_*.jsonl
    npz_path  : optional explicit context NPZ. If None, inferred from jsonl name/dir.
    """
    random.seed(seed)

    jsonl_path = Path(jsonl_path)
    if not jsonl_path.exists():
        raise FileNotFoundError(f"Missing JSONL: {jsonl_path}")

    inferred_npz = _infer_npz_from_jsonl(jsonl_path)
    npz_path = Path(npz_path) if npz_path else inferred_npz
    if not npz_path.exists():
        raise FileNotFoundError(f"Missing NPZ: {npz_path}")

    # report folder: put it under .../llm_negative_selection/<EMBED>/evaluation_reports/
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    report_dir = embed_root / "evaluation_reports"
    report_dir.mkdir(parents=True, exist_ok=True)

    print("JSONL:", jsonl_path)
    print("NPZ :", npz_path)
    print("OUT :", report_dir)

    lookup = _load_npz_lookup(npz_path)

    before_counts = []
    after_counts = []
    kept_titles = Counter()
    domain_kept = defaultdict(list)

    it_leak = 0
    total_kept = 0
    empty_outputs = 0

    samples = []
    seen_sample_ids = set()

    with jsonl_path.open("r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            try:
                r = json.loads(line)
            except Exception:
                continue

            jid = str(r.get("job_id", "")).strip()
            if not jid:
                continue

            ctx = lookup.get(jid, {})

            cand = r.get("candidates") or []
            final = r.get("final") or []

            before_counts.append(len(cand))
            after_counts.append(len(final))

            if len(final) == 0:
                empty_outputs += 1

            for t in final:
                kept_titles[t] += 1
                total_kept += 1
                if _is_it_role(t):
                    it_leak += 1

            dom = ctx.get("domain") or "UNKNOWN"
            domain_kept[dom].append(len(final))

            # sample gate
            if len(samples) < sample_n and jid not in seen_sample_ids and random.random() < 0.05:
                seen_sample_ids.add(jid)
                samples.append({
                    "job_id": jid,
                    "job_ad_title": ctx.get("job_ad_title"),
                    "domain": ctx.get("domain"),
                    "sector": ctx.get("job_sector_category"),
                    "job_desc": ctx.get("job_desc"),
                    "kept": final,
                    "dropped": r.get("drop") or [],
                })

    if not before_counts:
        raise RuntimeError("No valid rows parsed from JSONL.")

    before_avg = statistics.mean(before_counts)
    after_avg = statistics.mean(after_counts)
    drop_rate = 1.0 - (after_avg / before_avg if before_avg else 0.0)
    it_share = it_leak / max(total_kept, 1)

    metrics = {
        "jobs": len(before_counts),
        "avg_candidates_before": round(before_avg, 3),
        "avg_candidates_after": round(after_avg, 3),
        "drop_rate": round(drop_rate, 4),
        "empty_outputs_percent": round(100.0 * empty_outputs / len(before_counts), 3),
        "it_leakage_share": round(it_share, 4),
        "min_kept": int(min(after_counts)),
        "max_kept": int(max(after_counts)),
    }

    domain_summary = {d: round(statistics.mean(v), 3) for d, v in domain_kept.items()}

    report = {
        "run": {
            "jsonl": str(jsonl_path),
            "npz": str(npz_path),
            "generated_at": datetime.now().isoformat(timespec="seconds"),
        },
        "global_metrics": metrics,
        "top_kept_roles": kept_titles.most_common(25),
        "domain_summary_avg_kept": dict(sorted(domain_summary.items(), key=lambda x: (-x[1], x[0]))),
        "sample_cases": samples,
    }

    base = jsonl_path.stem
    report_json = report_dir / f"{base}_report.json"
    report_txt = report_dir / f"{base}_report.txt"

    with report_json.open("w", encoding="utf-8") as f:
        json.dump(report, f, indent=2, ensure_ascii=False)

    with report_txt.open("w", encoding="utf-8") as f:
        f.write("=== GLOBAL METRICS ===\n")
        for k, v in metrics.items():
            f.write(f"{k}: {v}\n")

        f.write("\n=== TOP KEPT OCCUPATIONS ===\n")
        for title, cnt in kept_titles.most_common(25):
            f.write(f"{cnt}  {title}\n")

        f.write("\n=== DOMAIN AVG KEPT ===\n")
        for d, v in sorted(domain_summary.items(), key=lambda x: (-x[1], x[0])):
            f.write(f"{d}: {v}\n")

        f.write("\n=== SAMPLE CASES (truncated) ===\n")
        for s in samples[:10]:
            f.write(f"\njob_id: {s['job_id']}\n")
            f.write(f"title:  {s.get('job_ad_title')}\n")
            f.write(f"domain: {s.get('domain')} | sector: {s.get('sector')}\n")
            f.write(f"kept:   {s.get('kept')}\n")
            f.write(f"drop:   {s.get('dropped')}\n")

    print("\nSaved:")
    print(" ", report_json)
    print(" ", report_txt)

    return report_json, report_txt

# %% [markdown]
# # Prompt 4 - A bit less strict than prompt 3

# %%
 # ===== Prompt printer: OCCUPATION MATCHER (E5 Production) =====

import numpy as np
from pathlib import Path

# ---- CONFIG ----
NPZ_PATH = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz")
ROW_IDX = 35  # Inspect any sample row

# ---- LOAD ----
data = np.load(NPZ_PATH, allow_pickle=True)

# Map NPZ keys to variables
title = data["job_ad_title"][ROW_IDX]
domain = data["domain"][ROW_IDX]
category = data["job_sector_category"][ROW_IDX]
desc = data["job_desc"][ROW_IDX]
tasks = data["job_tasks"][ROW_IDX]
full_excerpt = data["job_description"][ROW_IDX]
row_candidates = data["titles"][ROW_IDX]

# Clean up tasks string
if isinstance(tasks, (list, np.ndarray)):
    tasks_str = ", ".join([str(t) for t in tasks if t])
else:
    tasks_str = str(tasks)

# Format candidates as a 1-based numbered list
numbered_candidates = "\n".join([f"{i+1}) {cand}" for i, cand in enumerate(row_candidates) if cand])

# ---- BUILD PROMPT (Verbatim Production Version) ----

full_block = (
    f"\nFULL AD EXCERPT:\n{str(full_excerpt)[:700]}\n"
    if full_excerpt else ""
)

prompt = f"""You are an Occupation Matcher. Your job is to DROP candidates that do NOT fit the job.
Default outcome: keep ONE best match. Keep 2–3 only if tasks clearly show distinct roles (not synonyms).

JOB CONTEXT
Title: {title}
Domain: {domain}
Category: {category}
Short Desc: {desc}
Tasks/Skills: {tasks_str}
{full_block}

CANDIDATES (1-based)
{numbered_candidates}

RE-READ ANCHOR JOB CONTEXT:
Title: {title}
Domain: {domain}
Tasks/Skills: {tasks_str}

DECISION GUIDELINES
1) Anchor first: prefer the candidate that most directly matches the job title, unless tasks clearly contradict it.
2) Specificity: if both a specialist and a generic parent are present, keep the specialist and drop the generic.
3) Primary role bias: keep one candidate unless tasks prove truly multi-functional work.
4) Non-IT domains: drop Software/Data roles unless there is explicit evidence of building software (coding, pipelines, systems, APIs, models). Using tools (Excel, CRM, SAP) is not enough.
5) Max kept: never keep more than 3.

OUTPUT FORMAT
Return ONLY valid JSON with exactly this key:
{{"drop":[...]}}
""".strip()

# ---- PRINT ----
print("-" * 30)
print(f"VERIFIED PRODUCTION PROMPT (ROW {ROW_IDX}):")
print("-" * 30)
print(prompt)
print("-" * 30)
# Out:
# ------------------------------
# VERIFIED PRODUCTION PROMPT (ROW 35):
# ------------------------------
# You are an Occupation Matcher. Your job is to DROP candidates that do NOT fit the job.
# Default outcome: keep ONE best match. Keep 2–3 only if tasks clearly show distinct roles (not synonyms).
#
# JOB CONTEXT
# Title: Sommelier-Restaurant Gordon Ramsay
# Domain: Hospitality & Catering
# Category: Hospitality & Catering Jobs
# Short Desc: [Hospitality & Catering] Sommelier for a Three Michelin Star restaurant
# Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
#
# FULL AD EXCERPT:
# Sommelier - Restaurant Gordon Ramsay, Three Michelin Star We are looking for an experienced Sommelier who has a real passion for delivering the highest levels of service and creating a fantastic dining experience for our guests. Restaurant Gordon Ramsay combines contemporary elegance, an intimate ambience and unparalleled service, all the hallmarks of true excellence. Each dish, beautifully presented, uses the best ingredients and sublime flavour combinations, demonstrating the outstanding technical skill of Chef Matt Abe and his team. The restaurant boasts twenty years of holding three Michelin stars and is now London’s longest running restaurant to hold this accolade. As Sommelier you will
#
#
# CANDIDATES (1-based)
# 1) Waiters and Waitresses
# 2) Bartenders
# 3) Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 4) Dining Room and Cafeteria Attendants and Bartender Helpers
# 5) Chefs and Head Cooks
# 6) Cooks, Private Household
# 7) Cooks, Restaurant
#
# RE-READ ANCHOR JOB CONTEXT:
# Title: Sommelier-Restaurant Gordon Ramsay
# Domain: Hospitality & Catering
# Tasks/Skills: [Hospitality & Catering] Assist the Head Sommelier with wine and beverage service Supervise setting up and clearing down after each service Recommend and sell wines to guests Engage with customers to deliver high levels of service Supervise wine and beverage service WSET certification Wine knowledge Customer service Communication Leadership
#
# DECISION GUIDELINES
# 1) Anchor first: prefer the candidate that most directly matches the job title, unless tasks clearly contradict it.
# 2) Specificity: if both a specialist and a generic parent are present, keep the specialist and drop the generic.
# 3) Primary role bias: keep one candidate unless tasks prove truly multi-functional work.
# 4) Non-IT domains: drop Software/Data roles unless there is explicit evidence of building software (coding, pipelines, systems, APIs, models). Using tools (Excel, CRM, SAP) is not enough.
# 5) Max kept: never keep more than 3.
#
# OUTPUT FORMAT
# Return ONLY valid JSON with exactly this key:
# {"drop":[...]}
# ------------------------------

# %% [markdown]
# ## bge

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_bge.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
bge_jobid = jobid
# Out:
# JOBID: 2161851

# %% [markdown]
# ## e5

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_e5.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
e5_jobid = jobid
# Out:
# JOBID: 2161866

# %% [markdown]
# ## gte

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_gte.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
gte_jobid = jobid
# Out:
# JOBID: 2161867

# %%
# monitoring

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl
# Allocated: 14.99052906036377 GB
# Reserved: 50.923828125 GB
# [END] 2026-02-05 13:12:23
# [RUNTIME] 2.30 minutes (138.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:03,  1.22s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.30s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.42s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.06it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.74s/it]
# Batches:  25%|██▌       | 2/8 [00:45<02:08, 21.39s/it]
# Batches:  38%|███▊      | 3/8 [01:01<01:34, 18.85s/it]
# Batches:  50%|█████     | 4/8 [01:11<01:01, 15.28s/it]
# Batches:  62%|██████▎   | 5/8 [01:18<00:37, 12.36s/it]
# Batches:  75%|███████▌  | 6/8 [01:33<00:26, 13.25s/it]
# Batches:  88%|████████▊ | 7/8 [01:41<00:11, 11.55s/it]
# Batches: 100%|██████████| 8/8 [02:11<00:00, 17.26s/it]
# Batches: 100%|██████████| 8/8 [02:11<00:00, 16.40s/it]
# [W205 13:12:23.391535616 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl
# Allocated: 14.99052906036377 GB
# Reserved: 50.923828125 GB
# [END] 2026-02-05 13:12:23
# [RUNTIME] 2.30 minutes (138.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:03,  1.22s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.30s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.42s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.06it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.74s/it]
# Batches:  25%|██▌       | 2/8 [00:45<02:08, 21.39s/it]
# Batches:  38%|███▊      | 3/8 [01:01<01:34, 18.85s/it]
# Batches:  50%|█████     | 4/8 [01:11<01:01, 15.28s/it]
# Batches:  62%|██████▎   | 5/8 [01:18<00:37, 12.36s/it]
# Batches:  75%|███████▌  | 6/8 [01:33<00:26, 13.25s/it]
# Batches:  88%|████████▊ | 7/8 [01:41<00:11, 11.55s/it]
# Batches: 100%|██████████| 8/8 [02:11<00:00, 17.26s/it]
# Batches: 100%|██████████| 8/8 [02:11<00:00, 16.40s/it]
# [W205 13:12:23.391535616 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# [DBG] category: 'Healthcare & Nursing Jobs'
# [DBG] desc_head: '[Healthcare] Locum Consultant Physician - Care of the Elderly'
# [DBG] tasks_head: '[Healthcare] Provide high-quality medical care to elderly patients Develop and i'
# [DBG] job_id: 2789319749
# [DBG] title: 'Apprentice Nursery Assistant'
# [DBG] domain: 'Education'
# [DBG] category: 'Teaching Jobs'
# [DBG] desc_head: '[Education] Apprentice Nursery Assistant'
# [DBG] tasks_head: '[Education] Interact with children in an appropriate and structured way Play alo'
# [DBG] job_id: 2817223307
# [DBG] title: 'IT Strategy & Transformation Consultant'
# [DBG] domain: 'IT and Consulting'
# [DBG] category: 'IT Jobs'
# [DBG] desc_head: '[IT and Consulting] IT Strategy & Transformation Consultant'
# [DBG] tasks_head: '[IT and Consulting] Help organisations source and deliver infrastructure Support'
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl
# Allocated: 14.99052906036377 GB
# Reserved: 50.923828125 GB
# [END] 2026-02-05 13:12:23
# [RUNTIME] 2.30 minutes (138.3 seconds)
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:03,  1.22s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.30s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.42s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.06it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.09s/it]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:31<03:42, 31.74s/it]
# Batches:  25%|██▌       | 2/8 [00:45<02:08, 21.39s/it]
# Batches:  38%|███▊      | 3/8 [01:01<01:34, 18.85s/it]
# Batches:  50%|█████     | 4/8 [01:11<01:01, 15.28s/it]
# Batches:  62%|██████▎   | 5/8 [01:18<00:37, 12.36s/it]
# Batches:  75%|███████▌  | 6/8 [01:33<00:26, 13.25s/it]
# Batches:  88%|████████▊ | 7/8 [01:41<00:11, 11.55s/it]
# Batches: 100%|██████████| 8/8 [02:11<00:00, 17.26s/it]
# Batches: 100%|██████████| 8/8 [02:11<00:00, 16.40s/it]
# [W205 13:12:23.391535616 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 27
#      24 if not sq:
#      25     break
# ---> 27 time.sleep(5)
#
# KeyboardInterrupt:

# %%
import time, subprocess
from pathlib import Path
bge_jobid =2161867
e5_jobid =2161867
gte_jobid = 2161867
for jobid in [bge_jobid, e5_jobid, gte_jobid]:
    LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
    
    DONE_TAG = "DONE] wrote:"
    
    def sh(cmd: str) -> str:
        return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout
    
    def tail(path: Path, n: int = 80) -> str:
        return sh(f"tail -n {n} {path}")
    
    def latest_log(jobid: int, suffix: str) -> Path | None:
        logs = sorted(LOG_DIR.glob(f"*{jobid}*{suffix}"))
        return logs[-1] if logs else None
    
    seen = set()
    
    import time
    
    done_path = None
    
    while True:
        out_log = latest_log(jobid, ".out")
    
        if out_log and out_log.exists():
            chunk = tail(out_log, 120)
            for line in chunk.splitlines():
                if DONE_TAG in line:
                    done_path = line.split(DONE_TAG, 1)[1].strip()
                    print(f"[DONE] {done_path}")
                    break
    
            if done_path:
                break
    
        time.sleep(5)
    
    
    done_path
    print('**'*50)
# Out:
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl
# ****************************************************************************************************
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl
# ****************************************************************************************************
# [DONE] /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl
# ****************************************************************************************************

# %% [markdown]
# ## Results comparison

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn3
from pathlib import Path

# ---- CONFIG ----
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# 1. Define once (Update these only)
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161866_task0_20260205_131005.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl"
}

# 2. Run reports automatically for each
for model_name, file_path in PATHS.items():
    print(f"\n--- {model_name} ---")
    if file_path.exists():
        gen_report(str(file_path))
    else:
        print(f"Error: File for {model_name} not found at {file_path}")
def load_data(filepath):
    data = {}
    if not filepath.exists(): return data
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            data[obj['job_id']] = set(obj['final'])
    return data

# 1. Load and Intersect
results = {name: load_data(path) for name, path in PATHS.items()}
loaded = [n for n, d in results.items() if d]
common_ids = set.intersection(*[set(results[m].keys()) for m in loaded])

# 2. Extract Commonalities and Differences
report_data = []
for jid in common_ids:
    bge_set = results["BGE"].get(jid, set())
    e5_set = results["E5"].get(jid, set())
    gte_set = results["GTE"].get(jid, set())
    
    # Are they identical?
    all_agree = (bge_set == e5_set == gte_set)
    
    # Who is the outlier?
    outlier = "None"
    if bge_set == e5_set != gte_set: outlier = "GTE"
    elif bge_set == gte_set != e5_set: outlier = "E5"
    elif e5_set == gte_set != bge_set: outlier = "BGE"
    elif not all_agree: outlier = "All Diverged"

    report_data.append({
        "job_id": jid,
        "all_agree": all_agree,
        "outlier": outlier,
        "bge_count": len(bge_set),
        "e5_count": len(e5_set),
        "gte_count": len(gte_set),
        "consensus_count": len(bge_set & e5_set & gte_set)
    })

df = pd.DataFrame(report_data)

# 3. Print Statistical Summary
print("=== COMPREHENSIVE COMPARISON REPORT ===")
print(f"Total Common Jobs: {len(df)}")
print(f"Absolute Consensus: {df['all_agree'].sum()} ({df['all_agree'].mean():.1%})")
print("\n--- Outlier Frequency (Who disagrees with the majority?) ---")
print(df[df['outlier'] != "None"]['outlier'].value_counts())

# 4. Generate Visualizations
# Jaccard Heatmap
model_names = list(results.keys())
j_matrix = np.zeros((3, 3))
for i, m1 in enumerate(model_names):
    for j, m2 in enumerate(model_names):
        scores = [len(results[m1][jid] & results[m2][jid]) / len(results[m1][jid] | results[m2][jid]) 
                  for jid in common_ids]
        j_matrix[i, j] = np.mean(scores)

plt.figure(figsize=(8, 6))
sns.heatmap(j_matrix, annot=True, xticklabels=model_names, yticklabels=model_names, cmap="YlGnBu")
plt.title("Jaccard Similarity Matrix (Semantic Overlap)")
plt.savefig("semantic_overlap_heatmap.png")

# Venn Diagram
venn_sets = []
for name in model_names:
    s = set()
    for jid in common_ids:
        for occ in results[name][jid]:
            s.add(f"{jid}|{occ}")
    venn_sets.append(s)

plt.figure(figsize=(10, 8))
venn3(venn_sets, set_labels=model_names)
plt.title("Consensus Core vs. Model-Specific Hallucinations")
plt.savefig("assignment_venn.png")
# Out:
# --- BGE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649_report.txt
#
# --- E5 ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161866_task0_20260205_131005.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161866_task0_20260205_131005_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161866_task0_20260205_131005_report.txt
#
# --- GTE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005_report.txt
# === COMPREHENSIVE COMPARISON REPORT ===
# Total Common Jobs: 1000
# Absolute Consensus: 34 (3.4%)
#
# --- Outlier Frequency (Who disagrees with the majority?) ---
# outlier
# All Diverged    758
# BGE              74
# E5               72
# GTE              62
# Name: count, dtype: int64

# %%
from pathlib import Path

# 1. Define your specific report files once
REPORTS = {
    "BGE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649_report.txt",
    "E5_LARGE":  "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161866_task0_20260205_131005_report.txt",
    "GTE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005_report.txt"
}

# 2. Loop through and print with clear headers
for model_name, file_path in REPORTS.items():
    p = Path(file_path)
    
    # Visual Header for scannability
    print("\n" + "="*60)
    print(f"****** {model_name} ******")
    print("="*60)
    
    if p.exists():
        print(p.read_text())
    else:
        print(f"FILE NOT FOUND: {file_path}")
# Out:
# ============================================================
# ****** BGE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.221
# avg_candidates_after: 2.148
# drop_rate: 0.7387
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0703
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 42  Information Technology Project Managers
# 35  Personal Care Aides
# 31  Customer Service Representatives
# 31  Software Developers
# 28  Financial Managers
# 24  Mental Health and Substance Abuse Social Workers
# 24  Sales Managers
# 23  Social and Human Service Assistants
# 20  Marketing Managers
# 20  Healthcare Social Workers
# 19  Chefs and Head Cooks
# 19  Accountants and Auditors
# 19  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 19  First-Line Supervisors of Retail Sales Workers
# 19  Computer Systems Engineers/Architects
# 19  Teaching Assistants, Special Education
# 19  Nursing Assistants
# 18  Advertising and Promotions Managers
# 18  Laborers and Freight, Stock, and Material Movers, Hand
# 18  Food Service Managers
# 17  Acute Care Nurses
# 17  Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 16  Registered Nurses
# 15  Web Developers
# 15  Architectural and Engineering Managers
#
# === DOMAIN AVG KEPT ===
# Administration/Office Support: 3
# Administrative/Office: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Infrastructure: 3
# Construction and Property: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Digital/Technology: 3
# Domestic Services: 3
# Domestic help & Cleaning: 3
# Education and Training: 3
# Fashion: 3
# Food and Beverage: 3
# Government: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Social Work: 3
# IT and Consulting: 3
# IT/Software Development: 3
# Leisure: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Logistics and Transportation: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Marketing and Public Relations: 3
# Media: 3
# Military/Defence: 3
# Non-profit/Charity: 3
# Nuclear Engineering: 3
# Other/General Jobs: 3
# PR and Communications: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Publishing: 3
# Real Estate/Property Management: 3
# Remote Work/Online Opportunities: 3
# Renewable Energy/Electric Vehicle: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# Sales and Recruitment: 3
# Security and Law Enforcement: 3
# Telecommunications: 3
# Tourism/Hospitality: 3
# Transportation/Fleet Management: 3
# Transportation/Logistics: 3
# Utilities: 3
# Waste Management: 3
# Admin Jobs: 2.8
# Marketing/PR: 2.75
# Real Estate: 2.714
# IT Jobs: 2.667
# Social work: 2.567
# Logistics: 2.538
# Agriculture: 2.5
# Beauty and Cosmetics: 2.5
# Construction and Engineering: 2.5
# Construction and Maintenance: 2.5
# Consulting: 2.5
# Healthcare/Social Care: 2.5
# Logistics/Transportation: 2.5
# Media and Advertising: 2.5
# Non-Profit: 2.5
# Security: 2.5
# Retail: 2.472
# Sales and Marketing: 2.429
# Market Research: 2.4
# Digital Marketing: 2.333
# IT and Technology: 2.333
# Legal: 2.333
# Marketing: 2.333
# Public Administration: 2.333
# Scientific & QA: 2.333
# Automotive: 2.308
# Finance: 2.286
# Domestic help & Cleaning Jobs: 2.25
# Manufacturing: 2.237
# Hospitality & Catering: 2.214
# Logistics & Warehouse: 2.209
# Transportation: 2.2
# Administration: 2.167
# Customer Services: 2.167
# Recruitment: 2.167
# Construction: 2.156
# Healthcare: 2.143
# Engineering: 2.135
# Education: 2.132
# Human Resources: 2.125
# Trade & Construction: 2.125
# Accounting & Finance: 2.102
# Advertising and Marketing: 2
# Automotive Retail: 2
# Biotechnology: 2
# Construction/Engineering: 2
# Construction/Property Maintenance: 2
# Cybersecurity: 2
# Electronics Technology: 2
# Environmental Science: 2
# Estate Agency: 2
# Executive Search Firm: 2
# Fashion Retail: 2
# Financial Services: 2
# Food Service/Hospitality: 2
# Health and Fitness: 2
# Higher Education: 2
# Home Accessories Manufacturing: 2
# IT and Telecommunications: 2
# IT, Fintech, Blockchain, AI: 2
# Insurance: 2
# Manufacturing/Production: 2
# Media and Communications: 2
# Property: 2
# Recruitment Consultancy: 2
# Recruitment/Consultancy: 2
# Renewable Energy: 2
# Renewables: 2
# Research and Market Analysis: 2
# Sales Jobs: 2
# Sales and Business Development: 2
# Sales and Customer Service: 2
# Scientific & QA Jobs: 2
# Security and Customer Service: 2
# Security and Surveillance: 2
# Social Work: 2
# Software Development: 2
# Travel and Tourism: 2
# Utility: 2
# IT: 1.988
# Healthcare & Nursing: 1.976
# Sales: 1.857
# Consultancy: 1.8
# Creative & Design: 1.667
# Energy: 1.667
# Media and Entertainment: 1.667
# PR: 1.667
# Technology: 1.667
# Law: 1.6
# Digital Media: 1.5
# Fintech: 1.5
# Pharmaceutical: 1.5
# HR & Recruitment: 1.375
# Hospitality: 1.333
# Public Relations: 1.25
# Facilities Management: 1.2
# Aerospace: 1
# Aerospace & Manufacturing: 1
# Agriculture/Rural: 1
# Customer Service: 1
# Data and Intelligence consultancy: 1
# Domestic Help & Cleaning: 1
# Education Technology: 1
# Education/Training: 1
# Electrical Engineering: 1
# Energy Trading: 1
# Energy and Utilities: 1
# Engineering/Manufacturing: 1
# Farming/Agribusiness: 1
# Finance/Banking: 1
# Food Industry: 1
# Food Service: 1
# Health & Social Care: 1
# Healthcare/Hospitality: 1
# Healthcare/Pharmaceutical: 1
# Leisure and Fitness: 1
# Non-Profit/Charity: 1
# Non-Profit/NGO: 1
# Online Surveys/Admin Jobs: 1
# SaaS: 1
# Sales and Events: 1
# Social Housing: 1
# Social Services/Social Work: 1
# Software Engineering: 1
# Sports/Leisure: 1
# Technology & Engineering: 1
# Technology/Software: 1
# Trade and Construction: 1
# Translation and Interpreting: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Waiters and Waitresses', 'Food Service Managers']
# drop:   ['Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Chefs and Head Cooks', 'Bartenders']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Microsystems Engineers']
# drop:   ['Electronics Engineers, Except Computer', 'Electrical and Electronics Drafters', 'Electrical and Electronic Engineering Technologists and Technicians', 'Electrical and Electronics Repairers, Commercial and Industrial Equipment', 'Manufacturing Engineers', 'Nanosystems Engineers', 'Electrical Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Solar Photovoltaic Installers', 'Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment']
# drop:   ['Electrical Power-Line Installers and Repairers', 'Helpers--Electricians', 'Solar Sales Representatives and Assessors', 'Solar Energy Installation Managers', 'Solar Thermal Installers and Technicians', 'Electrical and Electronics Repairers, Powerhouse, Substation, and Relay']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Human Resources Assistants, Except Payroll and Timekeeping']
# drop:   ['Telephone Operators', 'Loan Interviewers and Clerks', 'Telemarketers', 'Receptionists and Information Clerks', 'New Accounts Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers', 'Personal Care Aides']
# drop:   ['Mental Health and Substance Abuse Social Workers', 'Child, Family, and School Social Workers', 'Childcare Workers', 'Social and Human Service Assistants', 'Occupational Therapists']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Biochemists and Biophysicists', 'Bioengineers and Biomedical Engineers', 'Natural Sciences Managers']
# drop:   ['Biological Technicians', 'Chemical Technicians', 'Biofuels/Biodiesel Technology and Product Development Managers', 'Bioinformatics Technicians', 'Bioinformatics Scientists', 'Agricultural Technicians']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Software Developers', 'Photonics Engineers', 'Human Factors Engineers and Ergonomists']
# drop:   ['Robotics Engineers', 'Automotive Engineers', 'Telecommunications Engineering Specialists', 'Wind Energy Engineers', 'Talent Directors', 'Media Programming Directors', 'Web Developers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['First-Line Supervisors of Material-Moving Machine and Vehicle Operators', 'Heavy and Tractor-Trailer Truck Drivers', 'Laborers and Freight, Stock, and Material Movers, Hand']
# drop:   ['Industrial Truck and Tractor Operators', 'Crane and Tower Operators', 'Driver/Sales Workers', 'Light Truck Drivers', 'Bus Drivers, Transit and Intercity', 'Cargo and Freight Agents']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers', 'Social and Community Service Managers', 'Healthcare Social Workers']
# drop:   ['Mental Health and Substance Abuse Social Workers', 'Recreation Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Rehabilitation Counselors', 'Compensation and Benefits Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mobile Heavy Equipment Mechanics, Except Engines', 'Mechanical Engineering Technologists and Technicians', 'Aircraft Mechanics and Service Technicians']
# drop:   ['Outdoor Power Equipment and Other Small Engine Mechanics', 'Bus and Truck Mechanics and Diesel Engine Specialists', 'Medical Equipment Repairers', 'Locomotive Engineers', 'Mechanical Engineers', 'Aerospace Engineers', 'Civil Engineers']
#
#
# ============================================================
# ****** E5_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.618
# avg_candidates_after: 2.119
# drop_rate: 0.7541
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0731
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 38  Software Developers
# 36  Customer Service Representatives
# 34  Sales Managers
# 31  Personal Care Aides
# 30  Financial Managers
# 27  Healthcare Social Workers
# 27  Information Technology Project Managers
# 27  Home Health Aides
# 25  Accountants and Auditors
# 24  Treasurers and Controllers
# 24  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 22  Heavy and Tractor-Trailer Truck Drivers
# 22  First-Line Supervisors of Retail Sales Workers
# 21  Nursing Assistants
# 19  Software Quality Assurance Analysts and Testers
# 19  Packers and Packagers, Hand
# 18  Computer Systems Engineers/Architects
# 17  Business Intelligence Analysts
# 17  Registered Nurses
# 17  Food Service Managers
# 16  Mental Health and Substance Abuse Social Workers
# 16  Cooks, Restaurant
# 16  Chefs and Head Cooks
# 16  Advertising and Promotions Managers
# 16  Marketing Managers
#
# === DOMAIN AVG KEPT ===
# Administrative/Office: 3
# Advertising and Marketing: 3
# Aerospace & Manufacturing: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction/Engineering: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Education Technology: 3
# Electronics Technology: 3
# Engineering/Manufacturing: 3
# Environmental Science: 3
# Finance/Banking: 3
# Food Industry: 3
# Health & Social Care: 3
# Health and Social Care: 3
# Healthcare Administration: 3
# Home Accessories Manufacturing: 3
# IT Jobs: 3
# IT and Consulting: 3
# Leisure: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Manufacturing/Production: 3
# Marketing/PR: 3
# Media: 3
# Non-Profit: 3
# Online Surveys/Admin Jobs: 3
# PR and Communications: 3
# Property: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Publishing: 3
# Recruitment Consultancy: 3
# Renewable Energy/Electric Vehicle: 3
# Retail/Food Industry: 3
# Sales and Business Development: 3
# Sales and Customer Service: 3
# Sales and Events: 3
# Sales and Recruitment: 3
# Sports/Leisure: 3
# Tourism/Hospitality: 3
# Transportation/Fleet Management: 3
# Transportation/Logistics: 3
# Utility: 3
# Waste Management: 3
# Consulting: 2.75
# Administration: 2.667
# Biotechnology: 2.667
# IT and Technology: 2.667
# Marketing: 2.667
# Logistics: 2.538
# Construction and Property: 2.5
# Customer Services: 2.5
# Digital Media: 2.5
# Healthcare/Social Care: 2.5
# Healthcare/Social Work: 2.5
# Non-Profit/Charity: 2.5
# Utilities: 2.5
# Construction: 2.469
# Legal: 2.444
# Social Work: 2.429
# Creative & Design: 2.333
# Health and Fitness: 2.333
# Public Administration: 2.333
# Engineering: 2.324
# Trade & Construction: 2.292
# Sales and Marketing: 2.286
# Human Resources: 2.25
# Retail: 2.25
# Automotive: 2.231
# Logistics & Warehouse: 2.186
# Healthcare & Nursing: 2.146
# Healthcare: 2.143
# Education: 2.132
# Hospitality & Catering: 2.119
# Manufacturing: 2.105
# IT: 2.036
# Social work: 2.033
# Beauty and Cosmetics: 2
# Construction and Maintenance: 2
# Construction/Property Maintenance: 2
# Data and Intelligence consultancy: 2
# Digital Marketing: 2
# Digital/Technology: 2
# Domestic Help & Cleaning: 2
# Domestic Services: 2
# Domestic help & Cleaning: 2
# Domestic help & Cleaning Jobs: 2
# Education and Training: 2
# Education/Training: 2
# Electrical Engineering: 2
# Energy and Utilities: 2
# Executive Search Firm: 2
# Food Service: 2
# Healthcare/Hospitality: 2
# Healthcare/Pharmaceutical: 2
# Higher Education: 2
# Hospitality: 2
# IT/Software Development: 2
# Insurance: 2
# Marketing and Public Relations: 2
# Media and Advertising: 2
# Non-Profit/NGO: 2
# Non-profit/Charity: 2
# Nuclear Engineering: 2
# Pharmaceutical: 2
# Real Estate: 2
# Remote Work/Online Opportunities: 2
# Renewable Energy: 2
# Renewables: 2
# Research and Market Analysis: 2
# Retail Marketing: 2
# Sales Jobs: 2
# Scientific & QA: 2
# Scientific & QA Jobs: 2
# Security: 2
# Security and Customer Service: 2
# Security and Law Enforcement: 2
# Social Services/Social Work: 2
# Software Development: 2
# Software Engineering: 2
# Travel and Tourism: 2
# Accounting & Finance: 1.983
# Financial Services: 1.875
# Sales: 1.821
# Consultancy: 1.8
# Facilities Management: 1.8
# Law: 1.8
# Transportation: 1.8
# HR & Recruitment: 1.75
# Media and Entertainment: 1.667
# PR: 1.667
# Fintech: 1.5
# Logistics/Transportation: 1.5
# Recruitment: 1.5
# Technology: 1.5
# Finance: 1.429
# Admin Jobs: 1.4
# Market Research: 1.4
# Energy: 1.333
# Public Relations: 1.25
# Administration/Office Support: 1
# Aerospace: 1
# Agriculture: 1
# Agriculture/Rural: 1
# Automotive Retail: 1
# Customer Service: 1
# Cybersecurity: 1
# Energy Trading: 1
# Estate Agency: 1
# Farming/Agribusiness: 1
# Fashion: 1
# Fashion Retail: 1
# Food Service/Hospitality: 1
# Food and Beverage: 1
# Government: 1
# Healthcare & Nursing Jobs: 1
# Healthcare Advertising: 1
# IT and Telecommunications: 1
# IT, Fintech, Blockchain, AI: 1
# Leisure and Fitness: 1
# Logistics and Transportation: 1
# Media and Communications: 1
# Military/Defence: 1
# Other/General Jobs: 1
# Real Estate/Property Management: 1
# Recruitment/Consultancy: 1
# SaaS: 1
# Security and Surveillance: 1
# Social Housing: 1
# Technology & Engineering: 1
# Technology/Software: 1
# Telecommunications: 1
# Trade and Construction: 1
# Translation and Interpreting: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Waiters and Waitresses']
# drop:   ['Bartenders', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Chefs and Head Cooks', 'Cooks, Private Household', 'Cooks, Restaurant']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Computer Hardware Engineers', 'Electrical and Electronic Engineering Technologists and Technicians']
# drop:   ['Electrical and Electronic Equipment Assemblers', 'Model Makers, Metal and Plastic', 'Robotics Engineers', 'Microsystems Engineers', 'Electrical Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians', 'Electric Motor, Power Tool, and Related Repairers', 'Electrical and Electronics Installers and Repairers, Transportation Equipment']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Recreational Vehicle Service Technicians', 'Solar Sales Representatives and Assessors', 'Solar Energy Installation Managers', 'Power Distributors and Dispatchers']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan']
# drop:   ['Telemarketers', 'Telephone Operators', 'Word Processors and Typists', 'Bookkeeping, Accounting, and Auditing Clerks', 'Data Entry Keyers', 'Loan Interviewers and Clerks', 'Receptionists and Information Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Mental Health and Substance Abuse Social Workers', 'Psychiatric Technicians']
# drop:   ['Healthcare Social Workers', 'Child, Family, and School Social Workers', 'Childcare Workers', 'Community Health Workers', 'Special Education Teachers, Preschool', 'Special Education Teachers, Middle School']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Medical Scientists, Except Epidemiologists', 'Bioengineers and Biomedical Engineers', 'Chemists']
# drop:   ['Biochemists and Biophysicists', 'Physicians, Pathologists', 'Biomass Plant Technicians', 'Molecular and Cellular Biologists', 'Robotics Engineers', 'Embalmers', 'Animal Scientists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Telecommunications Engineering Specialists', 'Robotics Engineers']
# drop:   ['Software Developers', 'Software Quality Assurance Analysts and Testers', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products', 'Natural Sciences Managers', 'Human Factors Engineers and Ergonomists', 'Media Programming Directors', 'Dancers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Heavy and Tractor-Trailer Truck Drivers', 'Industrial Truck and Tractor Operators', 'Power Distributors and Dispatchers']
# drop:   ['Cargo and Freight Agents', 'Crane and Tower Operators', 'Couriers and Messengers', 'Tire Repairers and Changers', 'Parts Salespersons', 'Bus Drivers, Transit and Intercity', 'Tax Preparers']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers', 'Social and Community Service Managers']
# drop:   ['Personal Care Aides', 'Mental Health and Substance Abuse Social Workers', 'Recreation Workers', 'Home Health Aides', 'Licensed Practical and Licensed Vocational Nurses', 'Registered Nurses', 'Medical and Health Services Managers', 'Administrative Services Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Aircraft Mechanics and Service Technicians', 'Maintenance Workers, Machinery', 'Mechanical Engineering Technologists and Technicians']
# drop:   ['Automotive Service Technicians and Mechanics', 'Maintenance and Repair Workers, General', 'Robotics Engineers', 'Bicycle Repairers']
#
#
# ============================================================
# ****** GTE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.229
# avg_candidates_after: 2.162
# drop_rate: 0.7373
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0846
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 35  Personal Care Aides
# 31  Information Technology Project Managers
# 30  Computer Systems Engineers/Architects
# 30  Software Developers
# 27  Financial Managers
# 26  Healthcare Social Workers
# 23  Nursing Assistants
# 21  Sales Managers
# 19  Cooks, Institution and Cafeteria
# 19  Chefs and Head Cooks
# 19  Treasurers and Controllers
# 18  Mental Health and Substance Abuse Social Workers
# 18  Secretaries and Administrative Assistants, Except Legal, Medical, and Executive
# 17  Accountants and Auditors
# 17  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 17  Advertising and Promotions Managers
# 17  Web Developers
# 17  Home Health Aides
# 16  Market Research Analysts and Marketing Specialists
# 16  Human Resources Specialists
# 16  Laborers and Freight, Stock, and Material Movers, Hand
# 16  Registered Nurses
# 15  Acute Care Nurses
# 15  Construction Managers
# 14  Medical and Health Services Managers
#
# === DOMAIN AVG KEPT ===
# Administration/Office Support: 3
# Advertising and Marketing: 3
# Agriculture: 3
# Agriculture/Rural: 3
# Automotive Retail: 3
# Construction and Maintenance: 3
# Construction/Property Maintenance: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Cybersecurity: 3
# Education and Training: 3
# Electronics Technology: 3
# Energy Trading: 3
# Executive Search Firm: 3
# Food Service: 3
# Health & Social Care: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Hospitality: 3
# Healthcare/Social Work: 3
# Higher Education: 3
# Home Accessories Manufacturing: 3
# IT Jobs: 3
# IT and Consulting: 3
# IT and Technology: 3
# IT, Fintech, Blockchain, AI: 3
# IT/Software Development: 3
# Leisure: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Manufacturing/Production: 3
# Marketing and Public Relations: 3
# Marketing/PR: 3
# Media and Advertising: 3
# Military/Defence: 3
# Non-Profit/NGO: 3
# Other/General Jobs: 3
# PR and Communications: 3
# Property: 3
# Public Health: 3
# Real Estate/Property Management: 3
# Recruitment Consultancy: 3
# Remote Work/Online Opportunities: 3
# Renewable Energy/Electric Vehicle: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# Sales and Business Development: 3
# Sales and Customer Service: 3
# Sales and Recruitment: 3
# Security and Customer Service: 3
# Security and Law Enforcement: 3
# Social Services/Social Work: 3
# Sports/Leisure: 3
# Trade and Construction: 3
# Transportation/Fleet Management: 3
# Utility: 3
# Waste Management: 3
# Administration: 2.833
# Legal: 2.778
# Creative & Design: 2.667
# Digital Marketing: 2.667
# Scientific & QA: 2.667
# Social Work: 2.571
# Administrative/Office: 2.5
# Beauty and Cosmetics: 2.5
# Construction and Engineering: 2.5
# Construction and Property: 2.5
# Fintech: 2.5
# Healthcare/Social Care: 2.5
# Logistics & Transportation: 2.5
# Logistics/Transportation: 2.5
# Non-Profit: 2.5
# Travel and Tourism: 2.5
# Hospitality & Catering: 2.429
# Transportation: 2.4
# Retail: 2.389
# Healthcare: 2.388
# Financial Services: 2.375
# Manufacturing: 2.368
# Biotechnology: 2.333
# Health and Fitness: 2.333
# Insurance: 2.333
# Logistics and Transportation: 2.333
# Public Administration: 2.333
# Trade & Construction: 2.333
# Healthcare & Nursing: 2.293
# Social work: 2.267
# Accounting & Finance: 2.254
# Human Resources: 2.25
# Automotive: 2.231
# Admin Jobs: 2.2
# Construction: 2.156
# Logistics & Warehouse: 2.093
# Education: 2.066
# Biotechnology/Pharmaceutical: 2
# Digital Media: 2
# Digital/Technology: 2
# Domestic Help & Cleaning: 2
# Domestic Services: 2
# Domestic help & Cleaning Jobs: 2
# Education/Training: 2
# Electrical Engineering: 2
# Environmental Science: 2
# Farming/Agribusiness: 2
# Fashion: 2
# Food Industry: 2
# Food Service/Hospitality: 2
# Government: 2
# Healthcare/Pharmaceutical: 2
# IT and Telecommunications: 2
# Logistics: 2
# Marketing: 2
# Media: 2
# Media and Communications: 2
# Nuclear Engineering: 2
# Pharmaceutical: 2
# Publishing: 2
# Recruitment/Consultancy: 2
# Renewable Energy: 2
# Renewables: 2
# Scientific & QA Jobs: 2
# Security and Surveillance: 2
# Social Housing: 2
# Software Engineering: 2
# Technology: 2
# Utilities: 2
# IT: 1.988
# Engineering: 1.946
# Sales: 1.929
# Customer Services: 1.917
# Finance: 1.857
# Real Estate: 1.857
# Software Development: 1.857
# Facilities Management: 1.8
# Consulting: 1.75
# Domestic help & Cleaning: 1.75
# Law: 1.7
# Hospitality: 1.667
# PR: 1.667
# Recruitment: 1.5
# Consultancy: 1.4
# Market Research: 1.4
# HR & Recruitment: 1.375
# Media and Entertainment: 1.333
# Sales and Marketing: 1.286
# Public Relations: 1.25
# Energy: 1.167
# Aerospace: 1
# Aerospace & Manufacturing: 1
# Construction and Infrastructure: 1
# Construction/Engineering: 1
# Consultancy Jobs: 1
# Customer Service: 1
# Data and Intelligence consultancy: 1
# Education Technology: 1
# Energy and Utilities: 1
# Engineering/Manufacturing: 1
# Estate Agency: 1
# Fashion Retail: 1
# Finance/Banking: 1
# Food and Beverage: 1
# Leisure and Fitness: 1
# Logistics and Supply Chain: 1
# Non-Profit/Charity: 1
# Non-profit/Charity: 1
# Online Surveys/Admin Jobs: 1
# Public Sector/ Law Enforcement: 1
# Research and Market Analysis: 1
# SaaS: 1
# Sales Jobs: 1
# Sales and Events: 1
# Security: 1
# Technology & Engineering: 1
# Technology/Software: 1
# Telecommunications: 1
# Tourism/Hospitality: 1
# Translation and Interpreting: 1
# Transportation/Logistics: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Food Service Managers', 'Bartenders']
# drop:   ['Waiters and Waitresses', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Chefs and Head Cooks', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Cooks, Private Household', 'Baristas']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Electrical Engineers', 'Solar Energy Systems Engineers', 'Electrical and Electronics Drafters', 'Manufacturing Engineers', 'Microsystems Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Solar Photovoltaic Installers', 'Electrical Power-Line Installers and Repairers', 'Electrical and Electronics Installers and Repairers, Transportation Equipment']
# drop:   ['Electrical Engineers', 'Electrical and Electronic Engineering Technologists and Technicians', 'Solar Energy Installation Managers', 'Power Distributors and Dispatchers', 'Fuel Cell Engineers']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan']
# drop:   ['Loan Interviewers and Clerks', 'Human Resources Assistants, Except Payroll and Timekeeping', 'Word Processors and Typists', 'Receptionists and Information Clerks', 'Human Resources Specialists', 'New Accounts Clerks', 'Archivists']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Mental Health and Substance Abuse Social Workers', 'Personal Care Aides', 'Community Health Workers']
# drop:   ['Healthcare Social Workers', 'Nannies', 'Social and Human Service Assistants', 'Child, Family, and School Social Workers', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Bioengineers and Biomedical Engineers', 'Molecular and Cellular Biologists']
# drop:   ['Medical and Clinical Laboratory Technologists', 'Chemical Technicians', 'Quality Control Analysts', 'Validation Engineers', 'Bioinformatics Scientists', 'Chemists', 'Medical Dosimetrists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Computer and Information Research Scientists', 'Microsystems Engineers']
# drop:   ['Software Developers', 'Computer Systems Engineers/Architects', 'Computer Network Architects', 'Radio Frequency Identification Device Specialists', 'Telecommunications Engineering Specialists', 'Software Quality Assurance Analysts and Testers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Industrial Truck and Tractor Operators', 'Heavy and Tractor-Trailer Truck Drivers', 'Laborers and Freight, Stock, and Material Movers, Hand']
# drop:   ['Crane and Tower Operators', 'Tank Car, Truck, and Ship Loaders', 'Transportation, Storage, and Distribution Managers', 'Logistics Analysts', 'Light Truck Drivers', 'Logistics Engineers', 'Locomotive Engineers']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers', 'Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers']
# drop:   ['Personal Care Aides', 'Community Health Workers', 'Regulatory Affairs Managers', 'Social and Community Service Managers', 'Food Service Managers', 'Human Resources Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mechanical Engineering Technologists and Technicians', 'Mechanical Engineers', 'Aircraft Mechanics and Service Technicians']
# drop:   ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Maintenance and Repair Workers, General', 'Mobile Heavy Equipment Mechanics, Except Engines', 'Bus and Truck Mechanics and Diesel Engine Specialists', 'Fuel Cell Engineers', 'Manufacturing Engineers']

# %%
import json

# Altere para qualquer um dos seus caminhos
path = "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649.jsonl"

with open(path, 'r') as f:
    line = f.readline()
    data = json.loads(line)
    print("KEYS ENCONTRADAS:", data.keys())
    print("\nEXEMPLO DE DADO:")
    print(json.dumps(data, indent=2))
# Out:
# KEYS ENCONTRADAS: dict_keys(['job_id', 'candidates', 'drop', 'final'])
#
# EXEMPLO DE DADO:
# {
#   "job_id": "2804978349",
#   "candidates": [
#     "Meter Readers, Utilities",
#     "Energy Auditors",
#     "Control and Valve Installers and Repairers, Except Mechanical Door",
#     "Home Appliance Repairers",
#     "Gas Compressor and Gas Pumping Station Operators",
#     "Electrical and Electronics Repairers, Powerhouse, Substation, and Relay",
#     "Power Distributors and Dispatchers",
#     "Bill and Account Collectors",
#     "Solar Sales Representatives and Assessors"
#   ],
#   "drop": [
#     "Energy Auditors",
#     "Control and Valve Installers and Repairers, Except Mechanical Door",
#     "Home Appliance Repairers",
#     "Gas Compressor and Gas Pumping Station Operators",
#     "Electrical and Electronics Repairers, Powerhouse, Substation, and Relay",
#     "Power Distributors and Dispatchers",
#     "Bill and Account Collectors",
#     "Solar Sales Representatives and Assessors"
#   ],
#   "final": [
#     "Meter Readers, Utilities"
#   ]
# }

# %%
import json
from pathlib import Path
import numpy as np
import pandas as pd

# 1. EXACT CONFIGURATION
PATHS = {
    "BGE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz",
    },
    "E5": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161866_task0_20260205_131005.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz",
    },
    "GTE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz",
    },
}

# 2. HELPER FUNCTIONS
def _to_str_array(x: np.ndarray) -> np.ndarray:
    if x.dtype == object:
        return np.array([v.decode("utf-8") if isinstance(v, (bytes, bytearray)) else str(v) for v in x])
    if np.issubdtype(x.dtype, np.bytes_):
        return np.array([v.decode("utf-8") for v in x])
    return x.astype(str)

def load_meta_from_npz(npz_path: str) -> pd.DataFrame:
    with np.load(npz_path, allow_pickle=True) as npz:
        job_id_key = "job_id" if "job_id" in npz.files else ("job_ids" if "job_ids" in npz.files else None)
        title_key = "job_ad_title" if "job_ad_title" in npz.files else ("title" if "title" in npz.files else None)
        domain_key = "domain" if "domain" in npz.files else None
        sector_key = "job_sector_category" if "job_sector_category" in npz.files else None

        meta = {
            "job_id": _to_str_array(npz[job_id_key]),
            "title": _to_str_array(npz[title_key]),
        }
        meta["domain"] = _to_str_array(npz[domain_key]) if domain_key else ""
        meta["sector"] = _to_str_array(npz[sector_key]) if sector_key else ""
    return pd.DataFrame(meta)

def load_results_from_jsonl(jsonl_path: str) -> pd.DataFrame:
    rows = []
    with open(jsonl_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            try: rows.append(json.loads(line))
            except: continue

    df = pd.DataFrame(rows)
    df["job_id"] = df["job_id"].astype(str)

    # Normalize fields (final -> kept | drop -> dropped)
    if "final" in df.columns: df = df.rename(columns={"final": "kept"})
    if "drop" in df.columns: df = df.rename(columns={"drop": "dropped"})
    
    if "kept" not in df.columns: df["kept"] = None
    if "dropped" not in df.columns: df["dropped"] = None

    def _list_to_csv(x):
        if isinstance(x, list): return ", ".join(map(str, x))
        return "" if x is None else str(x)

    df["kept"] = df["kept"].apply(_list_to_csv)
    df["dropped"] = df["dropped"].apply(_list_to_csv)
    return df[["job_id", "kept", "dropped"]]

# 3. CORE BUILDER
def build_audit_dataset(paths_by_model: dict, n_jobs_per_model: int = 100, seed: int = 42) -> pd.DataFrame:
    all_frames = []
    for model, p in paths_by_model.items():
        print(f"Lendo dados para {model}...")
        meta = load_meta_from_npz(p["npz"])
        res = load_results_from_jsonl(p["jsonl"])
        
        merged = res.merge(meta, on="job_id", how="inner")
        if merged.empty:
            print(f"!!! [AVISO] {model} resultou em merge vazio.")
            continue
            
        sample_size = min(n_jobs_per_model, len(merged))
        sampled = merged.sample(n=sample_size, random_state=seed).copy()
        sampled["model"] = model
        all_frames.append(sampled)

    out = pd.concat(all_frames, ignore_index=True)
    cols = ["job_id", "model", "title", "domain", "sector", "kept", "dropped"]
    for c in cols:
        if c not in out.columns: out[c] = ""
            
    return out[cols].sort_values(["model", "job_id"]).reset_index(drop=True)

# 4. EXECUTION
if __name__ == "__main__":
    # Fixed argument name to match the function definition
    audit_df = build_audit_dataset(PATHS, n_jobs_per_model=100, seed=42)
    
    out_path = Path("sanity_check_300_jobs_FINAL.csv")
    audit_df.to_csv(out_path, index=False)
    
    print("-" * 30)
    print(f"[SUCESSO] Arquivo escrito: {out_path}")
    print(f"Total de linhas: {len(audit_df)}")
    print(f"Distribuição por modelo:\n{audit_df['model'].value_counts()}")
    print("-" * 30)
# Out:
# Lendo dados para BGE...
# Lendo dados para E5...
# Lendo dados para GTE...
# ------------------------------
# [SUCESSO] Arquivo escrito: sanity_check_300_jobs_FINAL.csv
# Total de linhas: 300
# Distribuição por modelo:
# model
# BGE    100
# E5     100
# GTE    100
# Name: count, dtype: int64
# ------------------------------

# %%
import pandas as pd

df = pd.read_csv("sanity_check_300_jobs_FINAL.csv")

# 1. Criar contador de itens mantidos
df['n_kept'] = df['kept'].str.split(',').apply(lambda x: len(x) if isinstance(x, list) else 0)

# 2. Filtrar domínios Non-IT (ignorando IT e Software Development)
it_domains = ['IT', 'Software Development', 'IT Jobs', 'IT and Technology']
non_it_df = df[~df['domain'].isin(it_domains)].copy()

# 3. Calcular a média de candidatos mantidos por modelo
contamination_report = non_it_df.groupby('model')['n_kept'].mean().sort_values()

print("--- MÉDIA DE CANDIDATOS EM DOMÍNIOS NON-IT ---")
print("(Quanto menor, mais limpo é o índice)")
print(contamination_report)
print("-" * 45)

# 4. Verificar o "Custo da Ambiguidade" (Frequência de Kept > 1)
multi_match = non_it_df[non_it_df['n_kept'] > 1].groupby('model').size() / non_it_df.groupby('model').size()
print("\n--- TAXA DE MULTI-MATCH (HEDGING) ---")
print(multi_match.sort_values())
# Out:
# --- MÉDIA DE CANDIDATOS EM DOMÍNIOS NON-IT ---
# (Quanto menor, mais limpo é o índice)
# model
# BGE    3.044444
# GTE    3.155556
# E5     3.288889
# Name: n_kept, dtype: float64
# ---------------------------------------------
#
# --- TAXA DE MULTI-MATCH (HEDGING) ---
# model
# E5     0.777778
# GTE    0.800000
# BGE    0.822222
# dtype: float64

# %%
import json
import sys
from pathlib import Path
import numpy as np
import pandas as pd

# 1. EXACT CONFIGURATION
PATHS = {
    "BGE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161851_task0_20260205_130649.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz",
    },
    "E5": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161866_task0_20260205_131005.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz",
    },
    "GTE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2161867_task0_20260205_131005.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz",
    },
}

# 2. HELPER FUNCTIONS
def _to_str_array(x: np.ndarray) -> np.ndarray:
    if x.dtype == object:
        return np.array([v.decode("utf-8") if isinstance(v, (bytes, bytearray)) else str(v) for v in x])
    if np.issubdtype(x.dtype, np.bytes_):
        return np.array([v.decode("utf-8") for v in x])
    return x.astype(str)

def load_meta_from_npz(npz_path: str) -> pd.DataFrame:
    with np.load(npz_path, allow_pickle=True) as npz:
        job_id_key = "job_id" if "job_id" in npz.files else ("job_ids" if "job_ids" in npz.files else None)
        title_key = "job_ad_title" if "job_ad_title" in npz.files else ("title" if "title" in npz.files else None)
        domain_key = "domain" if "domain" in npz.files else None
        sector_key = "job_sector_category" if "job_sector_category" in npz.files else None

        meta = {
            "job_id": _to_str_array(npz[job_id_key]),
            "title": _to_str_array(npz[title_key]),
        }
        meta["domain"] = _to_str_array(npz[domain_key]) if domain_key else ""
        meta["sector"] = _to_str_array(npz[sector_key]) if sector_key else ""
    return pd.DataFrame(meta)

def load_results_from_jsonl(jsonl_path: str) -> pd.DataFrame:
    rows = []
    with open(jsonl_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            try: rows.append(json.loads(line))
            except: continue

    df = pd.DataFrame(rows)
    df["job_id"] = df["job_id"].astype(str)

    if "final" in df.columns: df = df.rename(columns={"final": "kept"})
    if "drop" in df.columns: df = df.rename(columns={"drop": "dropped"})
    
    if "kept" not in df.columns: df["kept"] = None
    if "dropped" not in df.columns: df["dropped"] = None

    def _list_to_csv(x):
        if isinstance(x, list): return ", ".join(map(str, x))
        return "" if x is None else str(x)

    df["kept"] = df["kept"].apply(_list_to_csv)
    df["dropped"] = df["dropped"].apply(_list_to_csv)
    return df[["job_id", "kept", "dropped"]]

# 3. CORE BUILDER
def build_audit_dataset(paths_by_model: dict, n_jobs_per_model: int = 100, seed: int = 42) -> pd.DataFrame:
    all_frames = []
    for model, p in paths_by_model.items():
        print(f"Lendo dados para {model}...")
        meta = load_meta_from_npz(p["npz"])
        res = load_results_from_jsonl(p["jsonl"])
        
        merged = res.merge(meta, on="job_id", how="inner")
        if merged.empty:
            print(f"!!! [AVISO] {model} resultou em merge vazio.")
            continue
            
        sample_size = min(n_jobs_per_model, len(merged))
        sampled = merged.sample(n=sample_size, random_state=seed).copy()
        sampled["model"] = model
        all_frames.append(sampled)

    out = pd.concat(all_frames, ignore_index=True)
    cols = ["job_id", "model", "title", "domain", "sector", "kept", "dropped"]
    for c in cols:
        if c not in out.columns: out[c] = ""
            
    return out[cols].sort_values(["model", "job_id"]).reset_index(drop=True)

# 4. EXECUTION
if __name__ == "__main__":
    # Dinamicamente tenta pegar o nome do arquivo/notebook
    try:
        # Se for um script .py
        prefix = Path(__file__).stem
    except NameError:
        # Fallback para Jupyter Notebook (ajuste manualmente se preferir)
        prefix = "aisi_audit" 

    # Gera o dataset
    audit_df = build_audit_dataset(PATHS, n_jobs_per_model=100, seed=42)
    
    # Define o nome do arquivo com o prefixo
    out_filename = f"{prefix}_sanity_check_300_jobs_FINAL.csv"
    out_path = Path(out_filename)
    
    # Salva o CSV
    audit_df.to_csv(out_path, index=False)
    
    print("-" * 30)
    print(f"[SUCESSO] Arquivo escrito: {out_path}")
    print(f"Total de linhas: {len(audit_df)}")
    print(f"Distribuição por modelo:\n{audit_df['model'].value_counts()}")
    print("-" * 30)
# Out:
# Lendo dados para BGE...
# Lendo dados para E5...
# Lendo dados para GTE...
# ------------------------------
# [SUCESSO] Arquivo escrito: aisi_audit_sanity_check_300_jobs_FINAL.csv
# Total de linhas: 300
# Distribuição por modelo:
# model
# BGE    100
# E5     100
# GTE    100
# Name: count, dtype: int64
# ------------------------------
