# %% [markdown]
# # prompt apos diversos testes do prompt 12 mais loose ainda que o 11

# %% [markdown]
# # Helpers

# %%
import json
import re
import random
import statistics
from pathlib import Path
from collections import Counter, defaultdict
from datetime import datetime

import numpy as np

# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------
_RUN_RE = re.compile(
    r"llama_drop_only_(?P<month>adzuna_month\d{2})_(?P<start>\d+)_(?P<stop>\d+)_job(?P<jobid>\d+)_task(?P<taskid>\d+)_\d{8}_\d{6}\.jsonl$"
)

IT_PATTERNS = [
    r"\bsoftware\b", r"\bdeveloper\b", r"\bengineer\b", r"\bdata\b", r"\bml\b", r"\bai\b",
    r"\bcloud\b", r"\bcyber\b", r"\bsecurity\b", r"\bnetwork\b", r"\bsystems?\b",
    r"\bdatabase\b", r"\bit\b", r"\bdevops\b"
]
_IT_RE = re.compile("|".join(IT_PATTERNS), flags=re.I)

def _is_it_role(title: str) -> bool:
    if not title:
        return False
    return bool(_IT_RE.search(title))


def _infer_npz_from_jsonl(jsonl_path: Path) -> Path:
    """
    NEW layout:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>/llama_drop_only_....jsonl
    NPZ sits at:
      .../llm_negative_selection/<EMBED>/<adzuna_monthXX>.npz
    """
    m = _RUN_RE.search(jsonl_path.name)
    if not m:
        raise ValueError(f"JSONL filename doesn't match expected pattern: {jsonl_path.name}")

    month = m.group("month")
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    return embed_root / f"{month}.npz"


def _get_job_ids(z) -> np.ndarray:
    """
    Supports both schemas:
      new: job_ids
      old: job_id
    Returns np.ndarray[str]
    """
    if "job_ids" in z.files:
        return z["job_ids"].astype(str)
    if "job_id" in z.files:
        return z["job_id"].astype(str)
    raise KeyError(f"NPZ missing job id key. Need job_ids or job_id. Have={sorted(z.files)}")


def _load_npz_lookup(npz_path: Path):
    """
    Expects stage3-prep NPZ keys (canonical):
      job_ids (or job_id), job_ad_title, job_desc, job_tasks, domain, job_sector_category, job_description
    """
    with np.load(npz_path, allow_pickle=True) as z:
        job_ids = _get_job_ids(z)

        # canonical (your stage3-prep)
        job_ad_title = z["job_ad_title"]
        job_desc = z["job_desc"]
        job_tasks = z["job_tasks"]

        domain = z["domain"] if "domain" in z.files else None
        job_sector_category = z["job_sector_category"] if "job_sector_category" in z.files else None
        job_description = z["job_description"] if "job_description" in z.files else None

    lookup = {}
    for i, jid in enumerate(job_ids):
        lookup[jid] = {
            "job_ad_title": None if job_ad_title[i] is None else str(job_ad_title[i]),
            "job_desc": None if job_desc[i] is None else str(job_desc[i]),
            "job_tasks": None if job_tasks[i] is None else str(job_tasks[i]),
            "job_description": None if job_description is None or job_description[i] is None else str(job_description[i]),
            "domain": None if domain is None or domain[i] is None else str(domain[i]),
            "job_sector_category": None if job_sector_category is None or job_sector_category[i] is None else str(job_sector_category[i]),
        }
    return lookup


# ---------------------------------------------------------------------
# Main: report generator
# ---------------------------------------------------------------------
def gen_report(jsonl_path: str, *, npz_path: str | None = None, sample_n: int = 30, seed: int = 0):
    """
    jsonl_path: path to llama_drop_only_*.jsonl
    npz_path  : optional explicit context NPZ. If None, inferred from jsonl name/dir.
    """
    random.seed(seed)

    jsonl_path = Path(jsonl_path)
    if not jsonl_path.exists():
        raise FileNotFoundError(f"Missing JSONL: {jsonl_path}")

    inferred_npz = _infer_npz_from_jsonl(jsonl_path)
    npz_path = Path(npz_path) if npz_path else inferred_npz
    if not npz_path.exists():
        raise FileNotFoundError(f"Missing NPZ: {npz_path}")

    # report folder: put it under .../llm_negative_selection/<EMBED>/evaluation_reports/
    embed_root = jsonl_path.parent.parent  # .../llm_negative_selection/<EMBED>
    report_dir = embed_root / "evaluation_reports"
    report_dir.mkdir(parents=True, exist_ok=True)

    print("JSONL:", jsonl_path)
    print("NPZ :", npz_path)
    print("OUT :", report_dir)

    lookup = _load_npz_lookup(npz_path)

    before_counts = []
    after_counts = []
    kept_titles = Counter()
    domain_kept = defaultdict(list)

    it_leak = 0
    total_kept = 0
    empty_outputs = 0

    samples = []
    seen_sample_ids = set()

    with jsonl_path.open("r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            try:
                r = json.loads(line)
            except Exception:
                continue

            jid = str(r.get("job_id", "")).strip()
            if not jid:
                continue

            ctx = lookup.get(jid, {})

            cand = r.get("candidates") or []
            final = r.get("final") or []

            before_counts.append(len(cand))
            after_counts.append(len(final))

            if len(final) == 0:
                empty_outputs += 1

            for t in final:
                kept_titles[t] += 1
                total_kept += 1
                if _is_it_role(t):
                    it_leak += 1

            dom = ctx.get("domain") or "UNKNOWN"
            domain_kept[dom].append(len(final))

            # sample gate
            if len(samples) < sample_n and jid not in seen_sample_ids and random.random() < 0.05:
                seen_sample_ids.add(jid)
                samples.append({
                    "job_id": jid,
                    "job_ad_title": ctx.get("job_ad_title"),
                    "domain": ctx.get("domain"),
                    "sector": ctx.get("job_sector_category"),
                    "job_desc": ctx.get("job_desc"),
                    "kept": final,
                    "dropped": r.get("drop") or [],
                })

    if not before_counts:
        raise RuntimeError("No valid rows parsed from JSONL.")

    before_avg = statistics.mean(before_counts)
    after_avg = statistics.mean(after_counts)
    drop_rate = 1.0 - (after_avg / before_avg if before_avg else 0.0)
    it_share = it_leak / max(total_kept, 1)

    metrics = {
        "jobs": len(before_counts),
        "avg_candidates_before": round(before_avg, 3),
        "avg_candidates_after": round(after_avg, 3),
        "drop_rate": round(drop_rate, 4),
        "empty_outputs_percent": round(100.0 * empty_outputs / len(before_counts), 3),
        "it_leakage_share": round(it_share, 4),
        "min_kept": int(min(after_counts)),
        "max_kept": int(max(after_counts)),
    }

    domain_summary = {d: round(statistics.mean(v), 3) for d, v in domain_kept.items()}

    report = {
        "run": {
            "jsonl": str(jsonl_path),
            "npz": str(npz_path),
            "generated_at": datetime.now().isoformat(timespec="seconds"),
        },
        "global_metrics": metrics,
        "top_kept_roles": kept_titles.most_common(25),
        "domain_summary_avg_kept": dict(sorted(domain_summary.items(), key=lambda x: (-x[1], x[0]))),
        "sample_cases": samples,
    }

    base = jsonl_path.stem
    report_json = report_dir / f"{base}_report.json"
    report_txt = report_dir / f"{base}_report.txt"

    with report_json.open("w", encoding="utf-8") as f:
        json.dump(report, f, indent=2, ensure_ascii=False)

    with report_txt.open("w", encoding="utf-8") as f:
        f.write("=== GLOBAL METRICS ===\n")
        for k, v in metrics.items():
            f.write(f"{k}: {v}\n")

        f.write("\n=== TOP KEPT OCCUPATIONS ===\n")
        for title, cnt in kept_titles.most_common(25):
            f.write(f"{cnt}  {title}\n")

        f.write("\n=== DOMAIN AVG KEPT ===\n")
        for d, v in sorted(domain_summary.items(), key=lambda x: (-x[1], x[0])):
            f.write(f"{d}: {v}\n")

        f.write("\n=== SAMPLE CASES (truncated) ===\n")
        for s in samples[:10]:
            f.write(f"\njob_id: {s['job_id']}\n")
            f.write(f"title:  {s.get('job_ad_title')}\n")
            f.write(f"domain: {s.get('domain')} | sector: {s.get('sector')}\n")
            f.write(f"kept:   {s.get('kept')}\n")
            f.write(f"drop:   {s.get('dropped')}\n")

    print("\nSaved:")
    print(" ", report_json)
    print(" ", report_txt)

    return report_json, report_txt

# %% [markdown]
# def build_prompt(
#     job_desc: str,
#     tasks_str: str,
#     clean_titles: list[str],
#     domain: str,
#     job_ad_title: str,
#     job_sector_category: str,
#     full_ad_text: str,
# ) -> str:
#     n_candidates = len(clean_titles)
#     numbered = "\n".join(f"{i+1}. {t}" for i, t in enumerate(clean_titles))
#
#     full_excerpt = full_ad_text.strip()[:700] if full_ad_text else ""
#     full_block = f"\nFULL AD EXCERPT (use for concrete tools/duties only):\n{full_excerpt}\n" if full_excerpt else ""
#
#     return f"""
# TASK
# You are a Senior Labor Market Economist auditing SOC matches. Evaluate candidates and DROP those that are NOT functional matches for the job.
#
# GOAL: THE 3 TARGET
# There are {n_candidates} candidates.
# - Your goal is to keep 2 to 4 candidates for every job.
# - Assume that at least 2 candidates should normally be KEPT.
# - Only keep 1 if you are really sure all others are CLEARLY wrong.
# - If more than 4 are valid, drop the most generic ones to fit the 4-candidate cap.
#
# DEFAULT BEHAVIOUR
# - When in doubt, KEEP rather than DROP, as long as the candidate is in the correct functional family.
# - Actively look for a SECOND and THIRD valid match before dropping.
#
# JOB CONTEXT (SOURCE OF TRUTH)
# Title: {job_ad_title}
# Sector/Domain: {job_sector_category} | {domain}
# Functional Tasks: {tasks_str}
# {full_block}
#
# CANDIDATES (1-based)
# {numbered}
#
# ANCHOR PROTECTION (FUNCTION FIRST)
# 1) The ANCHOR is the candidate whose FUNCTION best matches the title’s role type (not seniority, not niche specialism).
# 2) You MUST KEEP the ANCHOR unless CORE EVIDENCE explicitly contradicts it.
# 3) TITLE KEYWORD LOCK: If the job title contains a functional keyword (e.g. driver, nurse, electrician, developer, sommelier), and a candidate directly matching that function exists, you MUST keep it.
#
# KEEPING LOGIC (JOB MIX RECALL)
# After keeping the ANCHOR, you SHOULD normally keep 2–3 additional candidates.
#
# Keep an additional candidate if ANY apply:
# - Same functional family (e.g. sommelier <-> waiter; care worker <-> home health aide).
# - Same occupation at a different level (e.g. engineer <-> technologist/technician).
# - Tasks partially overlap or describe adjacent duties.
# - Do NOT keep roles that are purely generic or cross-sector (e.g. general managers, administrators, laborers) unless the tasks clearly align.
# - The role plausibly spans more than one SOC in real labour markets.
#
# HIERARCHY & IT GATES
# 1) MANAGER RULE
#    - If the title does NOT include Manager/Lead/Director, only keep a managerial candidate if tasks explicitly describe staff oversight, rotas, or budgeting.
#    - Do NOT keep managerial SOCs based on seniority alone.
#
# 2) IT DOMAIN LOCK
#    - If the title is explicitly IT, do NOT drop the IT anchor regardless of domain.
#    - For non-IT domains, keep tech roles if:
#      - tasks mention specific tools (Python, SQL, APIs, etc), OR
#      - the title strongly implies a digital/technical function (analyst, systems, platform, data).
#
#
# RE-ANCHOR (FINAL CHECK)
# Title: {job_ad_title}
# Count: {n_candidates} candidates.
# You should keep 2–4 candidates.
# Keeping only 1 should be rare and requires clear mismatch for all others.
#
# OUTPUT
# Return ONLY a valid JSON object with exactly one key: "drop".
# Schema:
# {{"drop":[...]}}
# """.strip()

# %% [markdown]
# ## bge

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_bge.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
bge_jobid = jobid
# Out:
# JOBID: 2188078

# %% [markdown]
# ## e5

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_e5.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
e5_jobid = jobid
# Out:
# JOBID: 2188079

# %% [markdown]
# ## gte

# %%
import subprocess, re
from pathlib import Path

SBATCH = Path("/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drop_gte.sbatch")
assert SBATCH.exists(), f"Missing sbatch file: {SBATCH}"

out = subprocess.check_output(["sbatch", str(SBATCH)], text=True)
jobid = re.search(r"(\d+)", out).group(1)
print("JOBID:", jobid)
gte_jobid = jobid
# Out:
# JOBID: 2188080

# %%
# monitoring

# %%
import time, subprocess
from pathlib import Path

LOG_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/logs")
def sh(cmd):
    return subprocess.run(cmd, shell=True, text=True, capture_output=True).stdout.strip()
while True:
    print("\n=== squeue ===")
    sq = sh(f"squeue -j {jobid}")
    print(sq if sq else "<finished>")

    out_logs = sorted(LOG_DIR.glob(f"*{jobid}*.out"))
    err_logs = sorted(LOG_DIR.glob(f"*{jobid}*.err"))

    if out_logs:
        print("\n--- STDOUT ---")
        print(sh(f"tail -n 20 {out_logs[-1]}"))

    if err_logs:
        print("\n--- STDERR ---")
        print(sh(f"tail -n 20 {err_logs[-1]}"))

    if not sq:
        break

    time.sleep(5)
# Out:
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt PD    6:00:00       0:00    6:00:00     1 (None)
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:04    5:59:56     1 nid010567
#
# --- STDOUT ---
# PROJECT=/projects/a5u/adu_dev/aisi-economy-index
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:09    5:59:51     1 nid010567
#
# --- STDOUT ---
# PROJECT=/projects/a5u/adu_dev/aisi-economy-index
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:15    5:59:45     1 nid010567
#
# --- STDOUT ---
# PROJECT=/projects/a5u/adu_dev/aisi-economy-index
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:20    5:59:40     1 nid010567
#
# --- STDOUT ---
# PROJECT=/projects/a5u/adu_dev/aisi-economy-index
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:25    5:59:35     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
#
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:30    5:59:30     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:35    5:59:25     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:40    5:59:20     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:45    5:59:15     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:50    5:59:10     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       0:55    5:59:05     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:00    5:59:00     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:05    5:58:55     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:10    5:58:50     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:15    5:58:45     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:20    5:58:40     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:25    5:58:35     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:30    5:58:30     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:35    5:58:25     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:40    5:58:20     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:45    5:58:15     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
# 2188080 autonomyluiz     workq z_llama_drop_new_test_gt  R    6:00:00       1:50    5:58:10     1 nid010567
#
# --- STDOUT ---
# BASE=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev
# SCRIPT=/projects/a5u/adu_dev/aisi-economy-index/nbs/AISI_demo/Stage_3_negative_selection/dev/sbatch/run_llama_drops_fix_test.py
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# ...
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:34<03:59, 34.22s/it]
# Batches:  25%|██▌       | 2/8 [00:49<02:17, 22.92s/it]
# Batches:  38%|███▊      | 3/8 [01:20<02:14, 26.85s/it]
# Batches:  50%|█████     | 4/8 [01:39<01:35, 23.78s/it]
# Batches:  62%|██████▎   | 5/8 [01:55<01:02, 20.80s/it]
# Batches:  75%|███████▌  | 6/8 [02:13<00:39, 19.93s/it]
# Batches:  88%|████████▊ | 7/8 [02:28<00:18, 18.31s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 20.79s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 21.83s/it]
# [W206 21:35:53.717840574 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.04 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:34<03:59, 34.22s/it]
# Batches:  25%|██▌       | 2/8 [00:49<02:17, 22.92s/it]
# Batches:  38%|███▊      | 3/8 [01:20<02:14, 26.85s/it]
# Batches:  50%|█████     | 4/8 [01:39<01:35, 23.78s/it]
# Batches:  62%|██████▎   | 5/8 [01:55<01:02, 20.80s/it]
# Batches:  75%|███████▌  | 6/8 [02:13<00:39, 19.93s/it]
# Batches:  88%|████████▊ | 7/8 [02:28<00:18, 18.31s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 20.79s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 21.83s/it]
# [W206 21:35:53.717840574 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.04 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:34<03:59, 34.22s/it]
# Batches:  25%|██▌       | 2/8 [00:49<02:17, 22.92s/it]
# Batches:  38%|███▊      | 3/8 [01:20<02:14, 26.85s/it]
# Batches:  50%|█████     | 4/8 [01:39<01:35, 23.78s/it]
# Batches:  62%|██████▎   | 5/8 [01:55<01:02, 20.80s/it]
# Batches:  75%|███████▌  | 6/8 [02:13<00:39, 19.93s/it]
# Batches:  88%|████████▊ | 7/8 [02:28<00:18, 18.31s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 20.79s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 21.83s/it]
# [W206 21:35:53.717840574 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.04 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:34<03:59, 34.22s/it]
# Batches:  25%|██▌       | 2/8 [00:49<02:17, 22.92s/it]
# Batches:  38%|███▊      | 3/8 [01:20<02:14, 26.85s/it]
# Batches:  50%|█████     | 4/8 [01:39<01:35, 23.78s/it]
# Batches:  62%|██████▎   | 5/8 [01:55<01:02, 20.80s/it]
# Batches:  75%|███████▌  | 6/8 [02:13<00:39, 19.93s/it]
# Batches:  88%|████████▊ | 7/8 [02:28<00:18, 18.31s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 20.79s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 21.83s/it]
# [W206 21:35:53.717840574 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.04 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:34<03:59, 34.22s/it]
# Batches:  25%|██▌       | 2/8 [00:49<02:17, 22.92s/it]
# Batches:  38%|███▊      | 3/8 [01:20<02:14, 26.85s/it]
# Batches:  50%|█████     | 4/8 [01:39<01:35, 23.78s/it]
# Batches:  62%|██████▎   | 5/8 [01:55<01:02, 20.80s/it]
# Batches:  75%|███████▌  | 6/8 [02:13<00:39, 19.93s/it]
# Batches:  88%|████████▊ | 7/8 [02:28<00:18, 18.31s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 20.79s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 21.83s/it]
# [W206 21:35:53.717840574 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# === squeue ===
# JOBID         USER PARTITION                     NAME ST TIME_LIMIT       TIME  TIME_LEFT NODES NODELIST(REASON)
#
# --- STDOUT ---
# NPZ_DIR=/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large
# total 7,0M
# drwxr-xr-x 2 autonomyluiz.a5u autonomyluiz.a5u 4,0K fev  6 21:01 adzuna_month01
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:02 adzuna_month01.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 570K fev  5 16:03 adzuna_month02.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:03 adzuna_month03.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:04 adzuna_month04.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 569K fev  5 16:04 adzuna_month05.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 571K fev  5 16:05 adzuna_month06.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 565K fev  5 16:05 adzuna_month07.npz
# -rw-r--r-- 1 autonomyluiz.a5u autonomyluiz.a5u 562K fev  5 16:05 adzuna_month08.npz
# EMBED=gte_large
# [TASK] 0 -> adzuna_month01
# [NPZ]  /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [START] 2026-02-06 21:32:50
# [LOAD] npz: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# [RANGE] 0:1000 -> 1000 jobs
# [MODEL] snapshot: /projects/a5u/adu_dev/aisi-economy-index/hf_cache/models--meta-llama--Meta-Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659
# [DONE] 3.04 minutes
# [DONE] wrote: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl
#
# --- STDERR ---
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:03<00:01,  1.08s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.43it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]
#
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:  12%|█▎        | 1/8 [00:34<03:59, 34.22s/it]
# Batches:  25%|██▌       | 2/8 [00:49<02:17, 22.92s/it]
# Batches:  38%|███▊      | 3/8 [01:20<02:14, 26.85s/it]
# Batches:  50%|█████     | 4/8 [01:39<01:35, 23.78s/it]
# Batches:  62%|██████▎   | 5/8 [01:55<01:02, 20.80s/it]
# Batches:  75%|███████▌  | 6/8 [02:13<00:39, 19.93s/it]
# Batches:  88%|████████▊ | 7/8 [02:28<00:18, 18.31s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 20.79s/it]
# Batches: 100%|██████████| 8/8 [02:54<00:00, 21.83s/it]
# [W206 21:35:53.717840574 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 26
#      23 if not sq:
#      24     break
# ---> 26 time.sleep(5)
#
# KeyboardInterrupt:

# %%
import os
import json
from pathlib import Path

# Base directory for your production runs
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# Models to check
MODELS = ["bge_large", "e5_large", "gte_large"]

def print_most_recent_outputs():
    print(f"{'MODEL':<10} | {'LATEST FILENAME'}")
    print("-" * 60)
    
    for model_dir_name in MODELS:
        # Construct path to the month folder
        target_path = BASE_DIR / model_dir_name / "adzuna_month01"
        
        if not target_path.exists():
            print(f"{model_dir_name:<10} | Path not found: {target_path}")
            continue
            
        # Get all jsonl files in the directory
        files = list(target_path.glob("*.jsonl"))
        
        if not files:
            print(f"{model_dir_name:<10} | No .jsonl files found.")
            continue
            
        # Find the most recent file based on modification time (mtime)
        latest_file = max(files, key=os.path.getmtime)
        
        print(f"{model_dir_name:<10} | {latest_file.name}")
        
        # Optional: Print the last 2 records from this specific latest file
        try:
            with open(latest_file, 'r', encoding='utf-8') as f:
                lines = f.readlines()
                if lines:
                    last_record = json.loads(lines[-1])
                    print(f"   -> Last Job ID: {last_record.get('job_id')}")
                    print(f"   -> Kept: {last_record.get('final')}")
        except Exception as e:
            print(f"   -> Error reading file: {e}")
        print("-" * 60)

if __name__ == "__main__":
    print_most_recent_outputs()
# Out:
# MODEL      | LATEST FILENAME
# ------------------------------------------------------------
# bge_large  | llama_drop_only_adzuna_month01_0_1000_job2188078_task0_20260206_213247.jsonl
#    -> Last Job ID: 2767917838
#    -> Kept: ['First-Line Supervisors of Retail Sales Workers', 'Logisticians', 'First-Line Supervisors of Non-Retail Sales Workers']
# ------------------------------------------------------------
# e5_large   | llama_drop_only_adzuna_month01_0_1000_job2188079_task0_20260206_213250.jsonl
#    -> Last Job ID: 2767917838
#    -> Kept: ['Sales Managers']
# ------------------------------------------------------------
# gte_large  | llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl
#    -> Last Job ID: 2767917838
#    -> Kept: ['Stockers and Order Fillers', 'First-Line Supervisors of Non-Retail Sales Workers', 'Transportation, Storage, and Distribution Managers']
# ------------------------------------------------------------

# %% [markdown]
# ## Results comparison

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn3
from pathlib import Path

# ---- CONFIG ----
BASE_DIR = Path("/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection")

# 1. Define once (Update these only)
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188078_task0_20260206_213247.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188079_task0_20260206_213250.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl"
}

# 2. Run reports automatically for each
for model_name, file_path in PATHS.items():
    print(f"\n--- {model_name} ---")
    if file_path.exists():
        gen_report(str(file_path))
    else:
        print(f"Error: File for {model_name} not found at {file_path}")
def load_data(filepath):
    data = {}
    if not filepath.exists(): return data
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            data[obj['job_id']] = set(obj['final'])
    return data

# 1. Load and Intersect
results = {name: load_data(path) for name, path in PATHS.items()}
loaded = [n for n, d in results.items() if d]
common_ids = set.intersection(*[set(results[m].keys()) for m in loaded])

# 2. Extract Commonalities and Differences
report_data = []
for jid in common_ids:
    bge_set = results["BGE"].get(jid, set())
    e5_set = results["E5"].get(jid, set())
    gte_set = results["GTE"].get(jid, set())
    
    # Are they identical?
    all_agree = (bge_set == e5_set == gte_set)
    
    # Who is the outlier?
    outlier = "None"
    if bge_set == e5_set != gte_set: outlier = "GTE"
    elif bge_set == gte_set != e5_set: outlier = "E5"
    elif e5_set == gte_set != bge_set: outlier = "BGE"
    elif not all_agree: outlier = "All Diverged"

    report_data.append({
        "job_id": jid,
        "all_agree": all_agree,
        "outlier": outlier,
        "bge_count": len(bge_set),
        "e5_count": len(e5_set),
        "gte_count": len(gte_set),
        "consensus_count": len(bge_set & e5_set & gte_set)
    })

df = pd.DataFrame(report_data)

# 3. Print Statistical Summary
print("=== COMPREHENSIVE COMPARISON REPORT ===")
print(f"Total Common Jobs: {len(df)}")
print(f"Absolute Consensus: {df['all_agree'].sum()} ({df['all_agree'].mean():.1%})")
print("\n--- Outlier Frequency (Who disagrees with the majority?) ---")
print(df[df['outlier'] != "None"]['outlier'].value_counts())

# 4. Generate Visualizations
# Jaccard Heatmap
model_names = list(results.keys())
j_matrix = np.zeros((3, 3))
for i, m1 in enumerate(model_names):
    for j, m2 in enumerate(model_names):
        scores = [len(results[m1][jid] & results[m2][jid]) / len(results[m1][jid] | results[m2][jid]) 
                  for jid in common_ids]
        j_matrix[i, j] = np.mean(scores)

plt.figure(figsize=(8, 6))
sns.heatmap(j_matrix, annot=True, xticklabels=model_names, yticklabels=model_names, cmap="YlGnBu")
plt.title("Jaccard Similarity Matrix (Semantic Overlap)")
plt.savefig("semantic_overlap_heatmap.png")

# Venn Diagram
venn_sets = []
for name in model_names:
    s = set()
    for jid in common_ids:
        for occ in results[name][jid]:
            s.add(f"{jid}|{occ}")
    venn_sets.append(s)

plt.figure(figsize=(10, 8))
venn3(venn_sets, set_labels=model_names)
plt.title("Consensus Core vs. Model-Specific Hallucinations")
plt.savefig("assignment_venn.png")
# Out:
# --- BGE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188078_task0_20260206_213247.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188078_task0_20260206_213247_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188078_task0_20260206_213247_report.txt
#
# --- E5 ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188079_task0_20260206_213250.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188079_task0_20260206_213250_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188079_task0_20260206_213250_report.txt
#
# --- GTE ---
# JSONL: /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250.jsonl
# NPZ : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz
# OUT : /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports
#
# Saved:
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250_report.json
#   /projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250_report.txt
# === COMPREHENSIVE COMPARISON REPORT ===
# Total Common Jobs: 1000
# Absolute Consensus: 22 (2.2%)
#
# --- Outlier Frequency (Who disagrees with the majority?) ---
# outlier
# All Diverged    800
# E5               65
# BGE              57
# GTE              56
# Name: count, dtype: int64

# %%
from pathlib import Path

# 1. Define your specific report files once
REPORTS = {
    "BGE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188078_task0_20260206_213247_report.txt",
    "E5_LARGE":  "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188079_task0_20260206_213250_report.txt",
    "GTE_LARGE": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/evaluation_reports/llama_drop_only_adzuna_month01_0_1000_job2188080_task0_20260206_213250_report.txt"
}
# 1. Define once (Update these only)


# 2. Loop through and print with clear headers
for model_name, file_path in REPORTS.items():
    p = Path(file_path)
    
    # Visual Header for scannability
    print("\n" + "="*60)
    print(f"****** {model_name} ******")
    print("="*60)
    
    if p.exists():
        print(p.read_text())
    else:
        print(f"FILE NOT FOUND: {file_path}")
# Out:
# ============================================================
# ****** BGE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.221
# avg_candidates_after: 2.752
# drop_rate: 0.6652
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0716
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 47  Information Technology Project Managers
# 43  Personal Care Aides
# 42  Sales Managers
# 38  Software Developers
# 37  Customer Service Representatives
# 37  Financial Managers
# 33  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 31  Marketing Managers
# 31  Computer Systems Engineers/Architects
# 29  Food Service Managers
# 29  Architectural and Engineering Managers
# 26  Market Research Analysts and Marketing Specialists
# 25  Mental Health and Substance Abuse Social Workers
# 25  Advertising and Promotions Managers
# 24  Healthcare Social Workers
# 24  Administrative Services Managers
# 24  Home Health Aides
# 22  Nursing Assistants
# 21  Acute Care Nurses
# 21  Business Intelligence Analysts
# 21  First-Line Supervisors of Retail Sales Workers
# 20  Chefs and Head Cooks
# 19  Human Resources Specialists
# 19  Accountants and Auditors
# 19  Financial Examiners
#
# === DOMAIN AVG KEPT ===
# Admin Jobs: 3
# Administration: 3
# Administration/Office Support: 3
# Administrative/Office: 3
# Advertising and Marketing: 3
# Aerospace & Manufacturing: 3
# Agriculture: 3
# Automotive Retail: 3
# Beauty and Cosmetics: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction and Maintenance: 3
# Construction and Property: 3
# Construction/Property Maintenance: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Consulting: 3
# Customer Service: 3
# Cybersecurity: 3
# Data and Intelligence consultancy: 3
# Digital Marketing: 3
# Digital/Technology: 3
# Domestic Services: 3
# Domestic help & Cleaning: 3
# Education and Training: 3
# Education/Training: 3
# Electronics Technology: 3
# Energy Trading: 3
# Energy and Utilities: 3
# Engineering/Manufacturing: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Farming/Agribusiness: 3
# Fashion: 3
# Fashion Retail: 3
# Fintech: 3
# Food Industry: 3
# Food Service: 3
# Food Service/Hospitality: 3
# Food and Beverage: 3
# Government: 3
# Health & Social Care: 3
# Health and Fitness: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Pharmaceutical: 3
# Healthcare/Social Work: 3
# IT Jobs: 3
# IT and Consulting: 3
# IT and Telecommunications: 3
# IT, Fintech, Blockchain, AI: 3
# IT/Software Development: 3
# Leisure: 3
# Leisure and Fitness: 3
# Logistics & Transportation: 3
# Logistics and Supply Chain: 3
# Logistics/Transportation: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Production: 3
# Market Research: 3
# Marketing: 3
# Marketing and Public Relations: 3
# Marketing/PR: 3
# Media: 3
# Media and Advertising: 3
# Media and Communications: 3
# Media and Entertainment: 3
# Military/Defence: 3
# Non-profit/Charity: 3
# Nuclear Engineering: 3
# Online Surveys/Admin Jobs: 3
# Other/General Jobs: 3
# PR: 3
# PR and Communications: 3
# Pharmaceutical: 3
# Property: 3
# Public Administration: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Publishing: 3
# Recruitment Consultancy: 3
# Recruitment/Consultancy: 3
# Remote Work/Online Opportunities: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Renewables: 3
# Research and Market Analysis: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# SaaS: 3
# Sales Jobs: 3
# Sales and Business Development: 3
# Sales and Customer Service: 3
# Sales and Events: 3
# Sales and Recruitment: 3
# Scientific & QA: 3
# Scientific & QA Jobs: 3
# Security: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Social Housing: 3
# Social Services/Social Work: 3
# Sports/Leisure: 3
# Technology: 3
# Technology & Engineering: 3
# Technology/Software: 3
# Telecommunications: 3
# Tourism/Hospitality: 3
# Transportation/Fleet Management: 3
# Transportation/Logistics: 3
# Utilities: 3
# Utility: 3
# Waste Management: 3
# Logistics: 2.923
# Healthcare & Nursing: 2.902
# Sales: 2.893
# HR & Recruitment: 2.875
# Human Resources: 2.875
# Social work: 2.867
# Retail: 2.861
# Finance: 2.857
# Real Estate: 2.857
# Sales and Marketing: 2.857
# Social Work: 2.857
# Software Development: 2.857
# Automotive: 2.846
# Recruitment: 2.833
# Healthcare: 2.816
# Legal: 2.778
# Domestic help & Cleaning Jobs: 2.75
# IT: 2.75
# Accounting & Finance: 2.746
# Hospitality & Catering: 2.714
# Education: 2.711
# Manufacturing: 2.684
# Engineering: 2.676
# Biotechnology: 2.667
# Creative & Design: 2.667
# IT and Technology: 2.667
# Financial Services: 2.625
# Consultancy: 2.6
# Transportation: 2.6
# Construction: 2.594
# Logistics & Warehouse: 2.581
# Customer Services: 2.5
# Digital Media: 2.5
# Non-Profit: 2.5
# Non-Profit/Charity: 2.5
# Software Engineering: 2.5
# Trade & Construction: 2.5
# Facilities Management: 2.4
# Law: 2.4
# Hospitality: 2.333
# Insurance: 2.333
# Logistics and Transportation: 2.333
# Public Relations: 2.25
# Agriculture/Rural: 2
# Construction/Engineering: 2
# Education Technology: 2
# Electrical Engineering: 2
# Healthcare/Hospitality: 2
# Healthcare/Social Care: 2
# Higher Education: 2
# Home Accessories Manufacturing: 2
# Manufacturing/Industrial: 2
# Real Estate/Property Management: 2
# Security and Customer Service: 2
# Trade and Construction: 2
# Translation and Interpreting: 2
# Travel and Tourism: 2
# Energy: 1.833
# Aerospace: 1
# Domestic Help & Cleaning: 1
# Environmental Science: 1
# Finance/Banking: 1
# Non-Profit/NGO: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Food Service Managers', 'Bartenders']
# drop:   ['Waiters and Waitresses', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Chefs and Head Cooks']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Microsystems Engineers', 'Electrical and Electronics Drafters', 'Electrical and Electronic Engineering Technologists and Technicians']
# drop:   ['Electronics Engineers, Except Computer', 'Electrical and Electronics Repairers, Commercial and Industrial Equipment', 'Manufacturing Engineers', 'Nanosystems Engineers', 'Electrical Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Power-Line Installers and Repairers']
# drop:   ['Solar Photovoltaic Installers', 'Helpers--Electricians', 'Solar Sales Representatives and Assessors', 'Solar Energy Installation Managers', 'Solar Thermal Installers and Technicians', 'Electrical and Electronics Repairers, Powerhouse, Substation, and Relay']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Human Resources Assistants, Except Payroll and Timekeeping']
# drop:   ['Telephone Operators', 'Loan Interviewers and Clerks', 'Telemarketers', 'Receptionists and Information Clerks', 'New Accounts Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Healthcare Social Workers', 'Child, Family, and School Social Workers', 'Personal Care Aides']
# drop:   ['Mental Health and Substance Abuse Social Workers', 'Childcare Workers', 'Social and Human Service Assistants', 'Occupational Therapists']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Biochemists and Biophysicists', 'Bioengineers and Biomedical Engineers', 'Natural Sciences Managers']
# drop:   ['Biological Technicians', 'Chemical Technicians', 'Biofuels/Biodiesel Technology and Product Development Managers', 'Bioinformatics Technicians', 'Bioinformatics Scientists', 'Agricultural Technicians']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Robotics Engineers', 'Software Developers', 'Telecommunications Engineering Specialists']
# drop:   ['Automotive Engineers', 'Photonics Engineers', 'Human Factors Engineers and Ergonomists', 'Wind Energy Engineers', 'Talent Directors', 'Media Programming Directors', 'Web Developers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['First-Line Supervisors of Material-Moving Machine and Vehicle Operators', 'Heavy and Tractor-Trailer Truck Drivers', 'Laborers and Freight, Stock, and Material Movers, Hand']
# drop:   ['Industrial Truck and Tractor Operators', 'Crane and Tower Operators', 'Driver/Sales Workers', 'Light Truck Drivers', 'Bus Drivers, Transit and Intercity', 'Cargo and Freight Agents']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers', 'Social and Community Service Managers', 'Healthcare Social Workers']
# drop:   ['Mental Health and Substance Abuse Social Workers', 'Recreation Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Rehabilitation Counselors', 'Compensation and Benefits Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mechanical Engineering Technologists and Technicians', 'Bus and Truck Mechanics and Diesel Engine Specialists', 'Aircraft Mechanics and Service Technicians']
# drop:   ['Mobile Heavy Equipment Mechanics, Except Engines', 'Outdoor Power Equipment and Other Small Engine Mechanics', 'Medical Equipment Repairers', 'Locomotive Engineers', 'Mechanical Engineers', 'Aerospace Engineers', 'Civil Engineers']
#
#
# ============================================================
# ****** E5_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.599
# avg_candidates_after: 2.72
# drop_rate: 0.6837
# empty_outputs_percent: 0.0
# it_leakage_share: 0.061
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 54  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 47  Customer Service Representatives
# 42  Personal Care Aides
# 41  Software Developers
# 37  Home Health Aides
# 37  Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products
# 36  Accountants and Auditors
# 34  First-Line Supervisors of Material-Moving Machine and Vehicle Operators
# 31  Treasurers and Controllers
# 30  Financial Managers
# 28  Sales Managers
# 24  Information Technology Project Managers
# 23  Healthcare Social Workers
# 22  Advertising and Promotions Managers
# 22  Clinical Nurse Specialists
# 22  Architectural and Engineering Managers
# 20  Secretaries and Administrative Assistants, Except Legal, Medical, and Executive
# 20  First-Line Supervisors of Retail Sales Workers
# 19  Robotics Engineers
# 19  Heavy and Tractor-Trailer Truck Drivers
# 19  Web Developers
# 18  Community Health Workers
# 17  Computer User Support Specialists
# 17  Sales Engineers
# 17  First-Line Supervisors of Personal Service Workers
#
# === DOMAIN AVG KEPT ===
# Admin Jobs: 3
# Administration: 3
# Advertising and Marketing: 3
# Agriculture: 3
# Agriculture/Rural: 3
# Automotive Retail: 3
# Biotechnology: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction and Maintenance: 3
# Construction and Property: 3
# Construction/Engineering: 3
# Construction/Property Maintenance: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Creative & Design: 3
# Cybersecurity: 3
# Digital/Technology: 3
# Domestic Help & Cleaning: 3
# Education Technology: 3
# Education and Training: 3
# Education/Training: 3
# Electronics Technology: 3
# Energy Trading: 3
# Engineering/Manufacturing: 3
# Environmental Science: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Farming/Agribusiness: 3
# Fashion Retail: 3
# Finance/Banking: 3
# Food Industry: 3
# Food Service: 3
# Food Service/Hospitality: 3
# Food and Beverage: 3
# Government: 3
# Health & Social Care: 3
# Health and Fitness: 3
# Health and Social Care: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Pharmaceutical: 3
# Higher Education: 3
# Home Accessories Manufacturing: 3
# Human Resources: 3
# IT and Consulting: 3
# IT, Fintech, Blockchain, AI: 3
# IT/Software Development: 3
# Leisure: 3
# Leisure and Fitness: 3
# Logistics and Supply Chain: 3
# Logistics/Transportation: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Market Research: 3
# Marketing: 3
# Marketing and Public Relations: 3
# Marketing/PR: 3
# Media: 3
# Media and Advertising: 3
# Media and Communications: 3
# Media and Entertainment: 3
# Military/Defence: 3
# Non-Profit: 3
# Non-Profit/NGO: 3
# Non-profit/Charity: 3
# Nuclear Engineering: 3
# Online Surveys/Admin Jobs: 3
# Other/General Jobs: 3
# PR and Communications: 3
# Property: 3
# Public Administration: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Publishing: 3
# Real Estate: 3
# Real Estate/Property Management: 3
# Recruitment: 3
# Recruitment Consultancy: 3
# Recruitment/Consultancy: 3
# Remote Work/Online Opportunities: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Renewables: 3
# Research and Market Analysis: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# SaaS: 3
# Sales Jobs: 3
# Sales and Customer Service: 3
# Sales and Events: 3
# Sales and Marketing: 3
# Sales and Recruitment: 3
# Scientific & QA Jobs: 3
# Security: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Social Housing: 3
# Social Services/Social Work: 3
# Social Work: 3
# Software Development: 3
# Software Engineering: 3
# Sports/Leisure: 3
# Technology & Engineering: 3
# Technology/Software: 3
# Telecommunications: 3
# Tourism/Hospitality: 3
# Trade and Construction: 3
# Translation and Interpreting: 3
# Transportation/Fleet Management: 3
# Transportation/Logistics: 3
# Waste Management: 3
# Social work: 2.933
# Accounting & Finance: 2.898
# Legal: 2.889
# Healthcare & Nursing: 2.878
# Financial Services: 2.875
# Healthcare: 2.857
# Technology: 2.833
# Facilities Management: 2.8
# Transportation: 2.8
# Engineering: 2.757
# HR & Recruitment: 2.75
# Trade & Construction: 2.75
# Hospitality & Catering: 2.738
# Manufacturing: 2.711
# Automotive: 2.692
# Customer Services: 2.667
# Hospitality: 2.667
# IT Jobs: 2.667
# IT and Technology: 2.667
# PR: 2.667
# Scientific & QA: 2.667
# Sales: 2.607
# Construction: 2.594
# Education: 2.592
# IT: 2.583
# Logistics & Warehouse: 2.581
# Retail: 2.528
# Administrative/Office: 2.5
# Beauty and Cosmetics: 2.5
# Customer Service: 2.5
# Domestic help & Cleaning: 2.5
# Domestic help & Cleaning Jobs: 2.5
# Energy: 2.5
# Healthcare/Social Care: 2.5
# Healthcare/Social Work: 2.5
# Logistics & Transportation: 2.5
# Pharmaceutical: 2.5
# Travel and Tourism: 2.5
# Utilities: 2.5
# Logistics: 2.462
# Finance: 2.429
# Digital Marketing: 2.333
# Insurance: 2.333
# Logistics and Transportation: 2.333
# Law: 2.3
# Consulting: 2.25
# Public Relations: 2.25
# Consultancy: 2.2
# Administration/Office Support: 2
# Aerospace: 2
# Aerospace & Manufacturing: 2
# Data and Intelligence consultancy: 2
# Digital Media: 2
# Domestic Services: 2
# Electrical Engineering: 2
# Energy and Utilities: 2
# Fintech: 2
# Manufacturing/Production: 2
# Sales and Business Development: 2
# Security and Customer Service: 2
# Utility: 2
# Non-Profit/Charity: 1.5
# Fashion: 1
# Healthcare & Nursing Jobs: 1
# Healthcare/Hospitality: 1
# IT and Telecommunications: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['First-Line Supervisors of Personal Service Workers']
# drop:   ['Waiters and Waitresses', 'Bartenders', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'First-Line Supervisors of Food Preparation and Serving Workers']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Microsystems Engineers', 'Computer Hardware Engineers']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Model Makers, Metal and Plastic', 'Electrical Engineers', 'Telecommunications Engineering Specialists']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electricians', 'Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical and Electronic Engineering Technologists and Technicians']
# drop:   ['Electrical Power-Line Installers and Repairers', 'Helpers--Installation, Maintenance, and Repair Workers', 'Solar Sales Representatives and Assessors', 'Shampooers', 'Solar Energy Installation Managers', 'Tire Repairers and Changers', 'Tire Builders']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Word Processors and Typists', 'Secretaries and Administrative Assistants, Except Legal, Medical, and Executive', 'Data Entry Keyers']
# drop:   ['Interviewers, Except Eligibility and Loan', 'Telephone Operators', 'Billing and Posting Clerks', 'Telemarketers', 'Procurement Clerks', 'Receptionists and Information Clerks']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Personal Care Aides', 'Locker Room, Coatroom, and Dressing Room Attendants', 'Home Health Aides']
# drop:   ['Maids and Housekeeping Cleaners', 'Community Health Workers', 'Psychiatrists', 'Healthcare Social Workers', 'Psychiatric Technicians', 'Social and Human Service Assistants', 'Mental Health and Substance Abuse Social Workers']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Bioengineers and Biomedical Engineers', 'Medical Scientists, Except Epidemiologists', 'Chemists']
# drop:   ['Natural Sciences Managers', 'Physicians, Pathologists', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products', 'Agricultural Technicians', 'Bioinformatics Scientists', 'Materials Scientists', 'Molecular and Cellular Biologists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Software Developers', 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products', 'Software Quality Assurance Analysts and Testers']
# drop:   ['Natural Sciences Managers', 'Grinding and Polishing Workers, Hand', 'Telecommunications Engineering Specialists', 'Dancers', 'Robotics Engineers', 'Tire Builders']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Heavy and Tractor-Trailer Truck Drivers', 'Industrial Truck and Tractor Operators', 'First-Line Supervisors of Material-Moving Machine and Vehicle Operators']
# drop:   ['Crane and Tower Operators', 'Laborers and Freight, Stock, and Material Movers, Hand', 'Loading and Moving Machine Operators, Underground Mining', 'Light Truck Drivers', 'Driver/Sales Workers', 'Pile Driver Operators']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Social and Community Service Managers', 'Registered Nurses']
# drop:   ['Personal Care Aides', 'Recreation Workers', 'Home Health Aides', 'Healthcare Social Workers', 'Licensed Practical and Licensed Vocational Nurses', 'Psychiatrists', 'Medical and Health Services Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Heating, Air Conditioning, and Refrigeration Mechanics and Installers', 'Aircraft Mechanics and Service Technicians', 'Maintenance Workers, Machinery']
# drop:   ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Maintenance and Repair Workers, General', 'Outdoor Power Equipment and Other Small Engine Mechanics', 'Electric Motor, Power Tool, and Related Repairers', 'Industrial Machinery Mechanics', 'Wind Energy Engineers', 'Mechanical Engineers']
#
#
# ============================================================
# ****** GTE_LARGE ******
# ============================================================
# === GLOBAL METRICS ===
# jobs: 1000
# avg_candidates_before: 8.229
# avg_candidates_after: 2.776
# drop_rate: 0.6627
# empty_outputs_percent: 0.0
# it_leakage_share: 0.0879
# min_kept: 1
# max_kept: 3
#
# === TOP KEPT OCCUPATIONS ===
# 40  Software Developers
# 39  Healthcare Social Workers
# 39  Information Technology Project Managers
# 38  Personal Care Aides
# 36  Computer Systems Engineers/Architects
# 36  Treasurers and Controllers
# 31  Sales Managers
# 30  Nursing Assistants
# 29  Advertising and Promotions Managers
# 29  Financial Managers
# 28  Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
# 25  Mental Health and Substance Abuse Social Workers
# 24  Human Resources Specialists
# 23  Accountants and Auditors
# 21  Cooks, Institution and Cafeteria
# 21  Computer Network Architects
# 20  Customer Service Representatives
# 20  Solar Sales Representatives and Assessors
# 20  Database Architects
# 20  Human Resources Managers
# 20  Acute Care Nurses
# 19  Financial Quantitative Analysts
# 19  Food Service Managers
# 19  Secretaries and Administrative Assistants, Except Legal, Medical, and Executive
# 19  Web Developers
#
# === DOMAIN AVG KEPT ===
# Admin Jobs: 3
# Administration: 3
# Administration/Office Support: 3
# Advertising and Marketing: 3
# Aerospace: 3
# Aerospace & Manufacturing: 3
# Agriculture: 3
# Agriculture/Rural: 3
# Automotive: 3
# Automotive Retail: 3
# Biotechnology/Pharmaceutical: 3
# Construction and Engineering: 3
# Construction and Infrastructure: 3
# Construction and Property: 3
# Construction/Rail: 3
# Construction/Real Estate: 3
# Consultancy Jobs: 3
# Consulting: 3
# Cybersecurity: 3
# Data and Intelligence consultancy: 3
# Digital/Technology: 3
# Domestic Services: 3
# Domestic help & Cleaning: 3
# Domestic help & Cleaning Jobs: 3
# Education and Training: 3
# Education/Training: 3
# Electrical Engineering: 3
# Electronics Technology: 3
# Energy Trading: 3
# Energy and Utilities: 3
# Estate Agency: 3
# Executive Search Firm: 3
# Facilities Management: 3
# Farming/Agribusiness: 3
# Fashion: 3
# Fashion Retail: 3
# Finance: 3
# Finance/Banking: 3
# Fintech: 3
# Food Industry: 3
# Food Service: 3
# Food and Beverage: 3
# Government: 3
# Health & Social Care: 3
# Health and Fitness: 3
# Health and Social Care: 3
# Healthcare & Nursing Jobs: 3
# Healthcare Administration: 3
# Healthcare Advertising: 3
# Healthcare/Pharmaceutical: 3
# Healthcare/Social Care: 3
# Healthcare/Social Work: 3
# Home Accessories Manufacturing: 3
# Hospitality: 3
# IT Jobs: 3
# IT and Consulting: 3
# IT and Technology: 3
# IT and Telecommunications: 3
# IT, Fintech, Blockchain, AI: 3
# IT/Software Development: 3
# Insurance: 3
# Leisure: 3
# Leisure and Fitness: 3
# Logistics and Supply Chain: 3
# Logistics and Transportation: 3
# Manufacturing and Engineering: 3
# Manufacturing/Engineering: 3
# Manufacturing/Industrial: 3
# Manufacturing/Production: 3
# Marketing: 3
# Marketing and Public Relations: 3
# Marketing/PR: 3
# Media: 3
# Media and Advertising: 3
# Media and Communications: 3
# Military/Defence: 3
# Non-Profit: 3
# Non-Profit/Charity: 3
# Non-Profit/NGO: 3
# Nuclear Engineering: 3
# Online Surveys/Admin Jobs: 3
# Other/General Jobs: 3
# PR and Communications: 3
# Property: 3
# Public Administration: 3
# Public Health: 3
# Public Sector/ Law Enforcement: 3
# Publishing: 3
# Real Estate/Property Management: 3
# Recruitment: 3
# Recruitment Consultancy: 3
# Recruitment/Consultancy: 3
# Remote Work/Online Opportunities: 3
# Renewable Energy: 3
# Renewable Energy/Electric Vehicle: 3
# Research and Market Analysis: 3
# Retail Marketing: 3
# Retail/Food Industry: 3
# SaaS: 3
# Sales Jobs: 3
# Sales and Business Development: 3
# Sales and Customer Service: 3
# Sales and Events: 3
# Sales and Recruitment: 3
# Scientific & QA: 3
# Scientific & QA Jobs: 3
# Security: 3
# Security and Customer Service: 3
# Security and Law Enforcement: 3
# Security and Surveillance: 3
# Social Housing: 3
# Social Work: 3
# Sports/Leisure: 3
# Technology & Engineering: 3
# Technology/Software: 3
# Telecommunications: 3
# Trade and Construction: 3
# Transportation/Fleet Management: 3
# Transportation/Logistics: 3
# Travel and Tourism: 3
# Utility: 3
# Waste Management: 3
# IT: 2.905
# HR & Recruitment: 2.875
# Human Resources: 2.875
# Accounting & Finance: 2.864
# Healthcare: 2.857
# Real Estate: 2.857
# Software Development: 2.857
# Manufacturing: 2.816
# Social work: 2.8
# Transportation: 2.8
# Trade & Construction: 2.792
# Legal: 2.778
# Healthcare & Nursing: 2.756
# Construction: 2.75
# Financial Services: 2.75
# Public Relations: 2.75
# Sales: 2.75
# Education: 2.737
# Engineering: 2.703
# Logistics: 2.692
# Biotechnology: 2.667
# Customer Services: 2.667
# Hospitality & Catering: 2.667
# PR: 2.667
# Retail: 2.667
# Technology: 2.667
# Consultancy: 2.6
# Market Research: 2.6
# Logistics & Warehouse: 2.512
# Beauty and Cosmetics: 2.5
# Construction and Maintenance: 2.5
# Digital Media: 2.5
# Logistics & Transportation: 2.5
# Pharmaceutical: 2.5
# Software Engineering: 2.5
# Utilities: 2.5
# Sales and Marketing: 2.429
# Digital Marketing: 2.333
# Media and Entertainment: 2.333
# Law: 2.3
# Administrative/Office: 2
# Construction/Engineering: 2
# Construction/Property Maintenance: 2
# Creative & Design: 2
# Domestic Help & Cleaning: 2
# Education Technology: 2
# Energy: 2
# Engineering/Manufacturing: 2
# Environmental Science: 2
# Food Service/Hospitality: 2
# Healthcare/Hospitality: 2
# Higher Education: 2
# Logistics/Transportation: 2
# Non-profit/Charity: 2
# Renewables: 2
# Social Services/Social Work: 2
# Tourism/Hospitality: 2
# Customer Service: 1.5
# Translation and Interpreting: 1
#
# === SAMPLE CASES (truncated) ===
#
# job_id: 2780653104
# title:  Sommelier-Restaurant Gordon Ramsay
# domain: Hospitality & Catering | sector: Hospitality & Catering Jobs
# kept:   ['Food Service Managers', 'Bartenders']
# drop:   ['Waiters and Waitresses', 'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop', 'Chefs and Head Cooks', 'Dining Room and Cafeteria Attendants and Bartender Helpers', 'Cooks, Private Household', 'Baristas']
#
# job_id: 2813395527
# title:  Senior Electronic Design Engineer
# domain: Engineering/Manufacturing | sector: Engineering Jobs
# kept:   ['Electronics Engineers, Except Computer', 'Electrical Engineers']
# drop:   ['Electrical and Electronic Engineering Technologists and Technicians', 'Solar Energy Systems Engineers', 'Electrical and Electronics Drafters', 'Manufacturing Engineers', 'Microsystems Engineers']
#
# job_id: 2828669962
# title:  Electric Vehicle Charge Point Installer
# domain: Renewable Energy/Electric Vehicle | sector: Engineering Jobs
# kept:   ['Electrical and Electronics Installers and Repairers, Transportation Equipment', 'Electrical Engineers', 'Electrical and Electronic Engineering Technologists and Technicians']
# drop:   ['Solar Photovoltaic Installers', 'Electrical Power-Line Installers and Repairers', 'Solar Energy Installation Managers', 'Power Distributors and Dispatchers', 'Fuel Cell Engineers']
#
# job_id: 2836679279
# title:  Telephone Interviewer
# domain: Recruitment | sector: Admin Jobs
# kept:   ['Interviewers, Except Eligibility and Loan', 'Human Resources Assistants, Except Payroll and Timekeeping', 'Word Processors and Typists']
# drop:   ['Loan Interviewers and Clerks', 'Receptionists and Information Clerks', 'Human Resources Specialists', 'New Accounts Clerks', 'Archivists']
#
# job_id: 2825288483
# title:  Female Support Worker - Bank Staff
# domain: Social Work | sector: Social work Jobs
# kept:   ['Mental Health and Substance Abuse Social Workers', 'Healthcare Social Workers', 'Personal Care Aides']
# drop:   ['Community Health Workers', 'Nannies', 'Social and Human Service Assistants', 'Child, Family, and School Social Workers', 'First-Line Supervisors of Farming, Fishing, and Forestry Workers']
#
# job_id: 2834732675
# title:  Senior Scientist - ATMP
# domain: Biotechnology/Pharmaceutical | sector: Scientific & QA Jobs
# kept:   ['Bioengineers and Biomedical Engineers', 'Molecular and Cellular Biologists', 'Quality Control Analysts']
# drop:   ['Medical and Clinical Laboratory Technologists', 'Chemical Technicians', 'Validation Engineers', 'Bioinformatics Scientists', 'Chemists', 'Medical Dosimetrists']
#
# job_id: 2822982103
# title:  Senior Android Developer
# domain: IT | sector: IT Jobs
# kept:   ['Software Developers', 'Computer and Information Research Scientists', 'Microsystems Engineers']
# drop:   ['Computer Systems Engineers/Architects', 'Computer Network Architects', 'Radio Frequency Identification Device Specialists', 'Telecommunications Engineering Specialists', 'Software Quality Assurance Analysts and Testers']
#
# job_id: 2821136828
# title:  HGV 1 Driver
# domain: Logistics | sector: Logistics & Warehouse Jobs
# kept:   ['Industrial Truck and Tractor Operators', 'Heavy and Tractor-Trailer Truck Drivers', 'Laborers and Freight, Stock, and Material Movers, Hand']
# drop:   ['Crane and Tower Operators', 'Tank Car, Truck, and Ship Loaders', 'Transportation, Storage, and Distribution Managers', 'Logistics Analysts', 'Light Truck Drivers', 'Logistics Engineers', 'Locomotive Engineers']
#
# job_id: 2824914939
# title:  Registered Manager Learning Disabilities
# domain: Healthcare/Social Work | sector: Social work Jobs
# kept:   ['Medical and Health Services Managers', 'Healthcare Social Workers', 'Mental Health and Substance Abuse Social Workers']
# drop:   ['Personal Care Aides', 'Community Health Workers', 'Regulatory Affairs Managers', 'Social and Community Service Managers', 'Food Service Managers', 'Human Resources Managers']
#
# job_id: 2831341197
# title:  Field Service Engineer Mechanical
# domain: Engineering | sector: Engineering Jobs
# kept:   ['Mechanical Engineering Technologists and Technicians', 'Mechanical Engineers', 'Aircraft Mechanics and Service Technicians']
# drop:   ['Control and Valve Installers and Repairers, Except Mechanical Door', 'Maintenance and Repair Workers, General', 'Mobile Heavy Equipment Mechanics, Except Engines', 'Bus and Truck Mechanics and Diesel Engine Specialists', 'Fuel Cell Engineers', 'Manufacturing Engineers']

# %%
# 1. Define once (Update these only)
PATHS = {
    "BGE": BASE_DIR / "bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187870_task0_20260206_210150.jsonl",
    "E5":  BASE_DIR / "e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187871_task0_20260206_210150.jsonl",
    "GTE": BASE_DIR / "gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187872_task0_20260206_210150.jsonl"
}
notebook_name ='11_prompt'

# %%
import json
import sys
from pathlib import Path
import numpy as np
import pandas as pd



# 1. EXACT CONFIGURATION
PATHS = {
    "BGE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187870_task0_20260206_210150.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/bge_large/adzuna_month01.npz",
    },
    "E5": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187871_task0_20260206_210150.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/e5_large/adzuna_month01.npz",
    },
    "GTE": {
        "jsonl": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01/llama_drop_only_adzuna_month01_0_1000_job2187872_task0_20260206_210150.jsonl",
        "npz": "/projects/a5u/adu_dev/aisi-economy-index/aisi_economy_index/store/AISI_demo/stage_3/dev/llm_negative_selection/gte_large/adzuna_month01.npz",
    },
}

# 2. HELPER FUNCTIONS
def _to_str_array(x: np.ndarray) -> np.ndarray:
    if x.dtype == object:
        return np.array([v.decode("utf-8") if isinstance(v, (bytes, bytearray)) else str(v) for v in x])
    if np.issubdtype(x.dtype, np.bytes_):
        return np.array([v.decode("utf-8") for v in x])
    return x.astype(str)

def load_meta_from_npz(npz_path: str) -> pd.DataFrame:
    with np.load(npz_path, allow_pickle=True) as npz:
        job_id_key = "job_id" if "job_id" in npz.files else ("job_ids" if "job_ids" in npz.files else None)
        title_key = "job_ad_title" if "job_ad_title" in npz.files else ("title" if "title" in npz.files else None)
        domain_key = "domain" if "domain" in npz.files else None
        sector_key = "job_sector_category" if "job_sector_category" in npz.files else None

        meta = {
            "job_id": _to_str_array(npz[job_id_key]),
            "title": _to_str_array(npz[title_key]),
        }
        meta["domain"] = _to_str_array(npz[domain_key]) if domain_key else ""
        meta["sector"] = _to_str_array(npz[sector_key]) if sector_key else ""
    return pd.DataFrame(meta)

def load_results_from_jsonl(jsonl_path: str) -> pd.DataFrame:
    rows = []
    with open(jsonl_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            try: rows.append(json.loads(line))
            except: continue

    df = pd.DataFrame(rows)
    df["job_id"] = df["job_id"].astype(str)

    if "final" in df.columns: df = df.rename(columns={"final": "kept"})
    if "drop" in df.columns: df = df.rename(columns={"drop": "dropped"})
    
    if "kept" not in df.columns: df["kept"] = None
    if "dropped" not in df.columns: df["dropped"] = None

    def _list_to_csv(x):
        if isinstance(x, list): return ", ".join(map(str, x))
        return "" if x is None else str(x)

    df["kept"] = df["kept"].apply(_list_to_csv)
    df["dropped"] = df["dropped"].apply(_list_to_csv)
    return df[["job_id", "kept", "dropped"]]

# 3. CORE BUILDER
def build_audit_dataset(paths_by_model: dict, n_jobs_per_model: int = 100, seed: int = 42) -> pd.DataFrame:
    all_frames = []
    for model, p in paths_by_model.items():
        print(f"Lendo dados para {model}...")
        meta = load_meta_from_npz(p["npz"])
        res = load_results_from_jsonl(p["jsonl"])
        
        merged = res.merge(meta, on="job_id", how="inner")
        if merged.empty:
            print(f"!!! [AVISO] {model} resultou em merge vazio.")
            continue
            
        sample_size = min(n_jobs_per_model, len(merged))
        sampled = merged.sample(n=sample_size, random_state=seed).copy()
        sampled["model"] = model
        all_frames.append(sampled)

    out = pd.concat(all_frames, ignore_index=True)
    cols = ["job_id", "model", "title", "domain", "sector", "kept", "dropped"]
    for c in cols:
        if c not in out.columns: out[c] = ""
            
    return out[cols].sort_values(["model", "job_id"]).reset_index(drop=True)

# 4. EXECUTION
if __name__ == "__main__":
    # Dinamicamente tenta pegar o nome do arquivo/notebook
    try:
        # Se for um script .py
        prefix = Path(__file__).stem
    except NameError:
        # Fallback para Jupyter Notebook (ajuste manualmente se preferir)
        prefix = notebook_name

    # Gera o dataset
    audit_df = build_audit_dataset(PATHS, n_jobs_per_model=100, seed=42)
    
    # Define o nome do arquivo com o prefixo
    out_filename = f"{prefix}_sanity_check_300_jobs_FINAL.csv"
    out_path = Path(out_filename)
    
    # Salva o CSV
    audit_df.to_csv(out_path, index=False)
    
    print("-" * 30)
    print(f"[SUCESSO] Arquivo escrito: {out_path}")
    print(f"Total de linhas: {len(audit_df)}")
    print(f"Distribuição por modelo:\n{audit_df['model'].value_counts()}")
    print("-" * 30)

# %%
import pandas as pd
import re
import ast

# =============================================================================
# Load
# =============================================================================
file_path = "11_prompt_sanity_check_300_jobs_FINAL.csv"
df = pd.read_csv(file_path)

# Normalise model names so pivot columns are predictable
df["model"] = df["model"].astype(str).str.strip().str.lower()

# =============================================================================
# Robust parser for `kept` (handles: "['a','b']" AND "a, b")
# =============================================================================
def parse_kept(x):
    if pd.isna(x):
        return []

    s = str(x).strip()

    # Case 1: Python list literal
    if s.startswith("[") and s.endswith("]"):
        try:
            out = ast.literal_eval(s)
            if isinstance(out, list):
                return [str(i).strip() for i in out if str(i).strip()]
        except Exception:
            pass

    # Case 2: plain comma-separated
    items = re.split(r",\s*(?=[A-Z0-9])", s)
    return [i.strip().strip("[]'\"") for i in items if i.strip()]

df["kept_list"] = df["kept"].apply(parse_kept)

# =============================================================================
# Pivot: one row per job, one column per model
# =============================================================================
pivot = df.pivot_table(
    index=["job_id", "title", "domain", "sector"],
    columns="model",
    values="kept_list",
    aggfunc="first"
).reset_index()

need_models = ['bge', 'e5', 'gte']
missing_cols = [c for c in need_models if c not in pivot.columns]
if missing_cols:
    raise ValueError(
        f"Missing model columns in pivot: {missing_cols}. "
        f"Available: {sorted([c for c in pivot.columns if c not in ['job_id','title','domain','sector']])}"
    )

pivot = pivot.dropna(subset=need_models)

# =============================================================================
# Helpers
# =============================================================================
def top1(lst):
    return lst[0] if isinstance(lst, list) and len(lst) else None

def jaccard(a, b):
    sa = set(a) if isinstance(a, list) else set()
    sb = set(b) if isinstance(b, list) else set()
    if not sa and not sb:
        return 1.0
    return len(sa & sb) / len(sa | sb)

# =============================================================================
# Divergence metrics
# =============================================================================
pivot["top1_bge"] = pivot["bge"].apply(top1)
pivot["top1_e5"]  = pivot["e5"].apply(top1)
pivot["top1_gte"] = pivot["gte"].apply(top1)

pivot["all_top1_same"] = (
    (pivot["top1_bge"] == pivot["top1_e5"]) &
    (pivot["top1_bge"] == pivot["top1_gte"])
)

pivot["jac_bge_e5"] = pivot.apply(lambda r: jaccard(r["bge"], r["e5"]), axis=1)
pivot["jac_bge_gte"] = pivot.apply(lambda r: jaccard(r["bge"], r["gte"]), axis=1)
pivot["jac_e5_gte"] = pivot.apply(lambda r: jaccard(r["e5"], r["gte"]), axis=1)

pivot["avg_jaccard"] = pivot[["jac_bge_e5", "jac_bge_gte", "jac_e5_gte"]].mean(axis=1)

# =============================================================================
# Most divergent jobs
# =============================================================================
divergent = pivot.sort_values(
    by=["avg_jaccard", "all_top1_same"],
    ascending=[True, True]
).head(20)

divergent[[
    "job_id",
    "title",
    "top1_bge",
    "top1_e5",
    "top1_gte",
    "avg_jaccard",
    "jac_bge_e5",
    "jac_bge_gte",
    "jac_e5_gte",
]]
